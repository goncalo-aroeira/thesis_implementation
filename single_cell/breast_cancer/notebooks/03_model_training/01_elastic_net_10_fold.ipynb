# %% [markdown]
# # Elastic Net Evaluation
#
# This notebook trains **ElasticNet regression models per drug** using gene expression features.
# ElasticNet combines L1 (Lasso) and L2 (Ridge) regularization. We use `ElasticNetCV` to tune hyperparameters using 5-fold cross-validation.
#
# Elastic Net combines both:
# - **L1 regularization** (Lasso) → promotes sparsity
# - **L2 regularization** (Ridge) → stabilizes coefficients
#
# This allows it to both regularize and select features, making it a simple but powerful linear model.
#
# We evaluate performance using:
# - **RMSE (Root Mean Squared Error)**
# - **R² (Coefficient of Determination)**
#
# and visualize their **distribution across all drugs**.

# %%
import os
import joblib
import numpy as np
import pandas as pd
from sklearn.linear_model import ElasticNetCV
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.metrics import r2_score, root_mean_squared_error
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy.stats import pearsonr, spearmanr

# %%
# Parameters
NUM_PCS = 30
DATA_PATH = "../../data/gdsc_bulk_embeddings_voom.parquet"
data = pd.read_parquet(DATA_PATH)
print("✅ Dataset loaded:", data.shape)

# Setup
os.makedirs("results/elastic_net", exist_ok=True)
non_features = ["SANGER_MODEL_ID", "DRUG_ID", "LN_IC50"]
gene_cols = [col for col in data.columns if col not in non_features]
kf = KFold(n_splits=10, shuffle=True, random_state=42)

results = []
# Out:
# ✅ Dataset loaded: (8238, 3075)

# %%
# Best-performing drug IDs you selected earlier
best_drugs = [1845, 2540, 2038, 2508, 1096, 1931, 2515, 1089, 427, 1526]

# Subset data to only these drugs
data = data[data["DRUG_ID"].isin(best_drugs)]
print("Subset shape:", data.shape)
print("Drugs present:", sorted(data["DRUG_ID"].unique()))
# Out:
# Subset shape: (8238, 3075)
# Drugs present: [427, 1089, 1096, 1526, 1845, 1931, 2038, 2508, 2515, 2540]

# %% [markdown]
# ## 1. Compute Metrics per Drug
#
# For each drug:
# - Select only rows where that drug was tested
# - Split the data into training and test sets
# - Fit an **Elastic Net** regressor on the PCA features
# - Evaluate on test set with **RMSE** and **R²**
#
# We only include drugs with **≥ 10 samples** to ensure meaningful evaluation.

# %%
# Main loop
for drug_id in sorted(data["DRUG_ID"].unique()):
    df = data[data["DRUG_ID"] == drug_id].dropna(subset=["LN_IC50"])
    if df.shape[0] < 100:
        continue

    X = df[gene_cols].values
    y = df["LN_IC50"].values

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    X_scaled = X_scaled.astype("float64")
    y = y.astype("float64")

    model = ElasticNetCV(
        alphas=[0.01, 0.1, 1.0, 10.0],
        l1_ratio=[0.1, 0.5, 0.9],
        cv=kf,
        max_iter=20000,
        random_state=42,
        n_jobs=-1
    )

    # Cross-validated predictions
    y_pred = cross_val_predict(model, X_scaled, y, cv=kf, n_jobs=-1)

    # Compute global metrics
    r2 = r2_score(y, y_pred)
    pearson_r, p_val = pearsonr(y, y_pred)
    rmse = root_mean_squared_error(y, y_pred)

    print(f"\n🧬 Drug {drug_id} | Samples: {len(df)}")
    print(f"  ➤ Global R²: {r2:.4f}")
    print(f"  ➤ Pearson r: {pearson_r:.4f} (p={p_val:.2e})")
    print(f"  ➤ RMSE: {rmse:.4f}")
    
    results.append({
        "DRUG_ID": drug_id,
        "n_samples": len(df),
        "r2_global": r2,
        "pearson_r": pearson_r,
        "pearson_pval": p_val,
        "rmse": rmse
    })
# Out:
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.043e+00, tolerance: 8.089e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.098e+00, tolerance: 6.877e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.189e+00, tolerance: 7.468e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.365e+00, tolerance: 7.587e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.494e+00, tolerance: 7.804e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.914e+00, tolerance: 7.895e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.766e+00, tolerance: 7.518e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.334e+00, tolerance: 8.500e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.500e+00, tolerance: 7.513e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.544e+00, tolerance: 7.082e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.176e+00, tolerance: 7.943e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.995e+00, tolerance: 7.686e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.950e+00, tolerance: 8.123e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.140e+00, tolerance: 7.272e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.846e+00, tolerance: 7.857e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.877e+00, tolerance: 7.742e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.843e+00, tolerance: 7.636e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.550e+00, tolerance: 8.203e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.488e+00, tolerance: 7.658e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.858e+00, tolerance: 6.894e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.468e+00, tolerance: 7.149e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.815e+00, tolerance: 7.507e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.327e+00, tolerance: 7.484e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.805e+00, tolerance: 7.514e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.416e+00, tolerance: 7.760e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.062e+00, tolerance: 7.656e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.885e+00, tolerance: 7.516e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.685e+00, tolerance: 7.627e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.658e+00, tolerance: 7.819e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.102e+00, tolerance: 7.640e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.365e+00, tolerance: 6.658e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.710e+00, tolerance: 8.375e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.212e+00, tolerance: 8.517e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.694e+00, tolerance: 7.528e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.517e+00, tolerance: 7.858e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.678e+00, tolerance: 7.756e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.345e+00, tolerance: 6.347e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.828e+00, tolerance: 7.398e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.396e+00, tolerance: 7.763e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.939e+00, tolerance: 7.982e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.758e+00, tolerance: 8.192e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.103e+00, tolerance: 8.041e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.731e+00, tolerance: 7.605e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.403e+00, tolerance: 7.846e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.863e+00, tolerance: 7.736e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.416e+00, tolerance: 8.024e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.824e+00, tolerance: 7.907e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.583e+00, tolerance: 7.376e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.092e+00, tolerance: 7.821e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.847e+00, tolerance: 7.812e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.047e+00, tolerance: 6.815e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.485e+00, tolerance: 8.103e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.720e+00, tolerance: 7.280e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.389e+00, tolerance: 8.111e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.258e+00, tolerance: 8.373e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.528e+00, tolerance: 7.457e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.096e+00, tolerance: 6.733e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.815e+00, tolerance: 7.949e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.179e+00, tolerance: 7.383e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.620e+00, tolerance: 7.939e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.099e+00, tolerance: 8.123e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.420e+00, tolerance: 7.715e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.381e+00, tolerance: 7.562e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.405e+00, tolerance: 7.753e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.612e+00, tolerance: 7.881e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.687e+00, tolerance: 7.515e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.778e+00, tolerance: 7.079e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.365e+00, tolerance: 6.979e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.367e+00, tolerance: 6.879e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.479e+00, tolerance: 6.811e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.524e+00, tolerance: 8.460e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.444e+00, tolerance: 8.334e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.245e+00, tolerance: 7.423e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.438e+00, tolerance: 7.151e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.629e+00, tolerance: 7.830e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.054e+00, tolerance: 7.939e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.184e+00, tolerance: 7.335e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.049e+00, tolerance: 7.977e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.552e+00, tolerance: 7.944e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.739e+00, tolerance: 7.439e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.322e+00, tolerance: 7.315e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.174e+00, tolerance: 7.916e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.248e+00, tolerance: 7.666e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.552e+00, tolerance: 8.420e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.141e+00, tolerance: 7.677e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.392e+00, tolerance: 6.952e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.437e+00, tolerance: 8.106e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.384e+00, tolerance: 7.987e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.896e+00, tolerance: 7.944e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.392e+00, tolerance: 8.391e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.179e+00, tolerance: 7.611e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.675e+00, tolerance: 8.276e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.879e+00, tolerance: 8.301e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.759e+00, tolerance: 6.833e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.216e+00, tolerance: 8.015e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.108e+00, tolerance: 6.937e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.327e+00, tolerance: 7.819e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.567e+00, tolerance: 8.214e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.569e+00, tolerance: 7.891e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/guests3/gba/.conda/envs/tese-env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.959e+00, tolerance: 7.746e-02
#   model = cd_fast.enet_coordinate_descent(
# 🧬 Drug 427 | Samples: 900
#   ➤ Global R²: 0.4136
#   ➤ Pearson r: 0.6447 (p=7.20e-107)
#   ➤ RMSE: 0.7860

# %%
# Results dataframe
results_df = pd.DataFrame(results)
results_df.to_csv(f"results/elastic_net/bulk_top400_genes.csv", index=False)
print("📁 Saved results to results/elastic_net/top400_genes.csv")
# Out:
# 📁 Saved results to results/elastic_net/top400_genes.csv

# %% [markdown]
# ## 2. RMSE Distribution
#
# We visualize the distribution of **RMSE** values across all drugs.
#
# This shows how much prediction error the Elastic Net model makes on average, and how much it varies between drugs.

# %%
# Visualization: RMSE
plt.figure(figsize=(8, 5))
sns.histplot(results_df["rmse"], kde=True, bins=30, color="darkorange")
plt.title(f"RMSE Distribution Across Drugs (ElasticNet, 10-fold CV, concatenated)")
plt.xlabel("RMSE")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# ## 3. R² Distribution
#
# This distribution shows how well Elastic Net explains the variance in IC50 values.
#
# - **R² > 0** means the model is better than the mean predictor
# - **R² = 1** would be a perfect model
# - Drugs with **R² close to or < 0** may not be predictable using current features

# %%
# Visualization: R²
plt.figure(figsize=(8, 5))
sns.histplot(results_df["r2_global"], kde=True, bins=30, color="teal")
plt.title(f"Global R² Distribution Across Drugs (ElasticNet, 10-fold CV, concatenated)")
plt.xlabel("Global R² Score")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# ## 4. Summary
#
# Elastic Net gives a more flexible alternative to linear regression models by combining L1 and L2 penalties.
#
# From the plots above, we can see:
# - The **average RMSE** and its spread across drugs
# - The **R² values**, showing how well the model captures IC50 variance
#
# This gives us a strong baseline for comparison with more complex models like XGBoost or neural networks.

# %%
# Visualization: R² vs. n_samples
plt.figure(figsize=(8, 6))
sns.scatterplot(x="n_samples", y="r2_global", data=results_df)
plt.title("Global R² vs. Sample Size per Drug (ElasticNet)")
plt.xlabel("Number of Samples")
plt.ylabel("Global R² Score")
plt.grid(True)
plt.show()
plt.close()

# %%
# Correlations with sample size
pearson_corr, pval_pearson = pearsonr(results_df["n_samples"], results_df["r2_global"])
print(f"📊 Pearson r (samples vs R²) = {pearson_corr:.3f} (p = {pval_pearson:.3g})")

spearman_corr, pval_spearman = spearmanr(results_df["n_samples"], results_df["r2_global"])
print(f"📊 Spearman ρ (samples vs R²) = {spearman_corr:.3f} (p = {pval_spearman:.3g})")
# Out:
# 📊 Pearson r (samples vs R²) = -0.064 (p = 0.861)
# 📊 Spearman ρ (samples vs R²) = -0.273 (p = 0.446)

# %%
# R² vs. IC50 Variance
variances = data.groupby("DRUG_ID")["LN_IC50"].var()
results_df = results_df.merge(variances.rename("ic50_variance"), on="DRUG_ID")

plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="ic50_variance", y="r2_global")
plt.title("Global R² vs. IC50 Variance (ElasticNet)")
plt.xlabel("IC50 Variance (LN_IC50)")
plt.ylabel("Global R² Score")
plt.grid(True)
plt.show()
plt.close()

# %%
# 📊 Pearson r Distribution Across Drugs
plt.figure(figsize=(8, 5))
sns.histplot(results_df["pearson_r"], kde=True, bins=30, color="mediumpurple")
plt.title(f"Pearson r Distribution Across Drugs (ElasticNet, 10-fold CV, concatenated)")
plt.xlabel("Pearson r")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %%
# 📊 Pearson r vs. Number of Samples per Drug
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="n_samples", y="pearson_r")
plt.title("Pearson r vs. Sample Size per Drug (ElasticNet)")
plt.xlabel("Number of Samples")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()
plt.close()

# %%
pearson_corr_r, pval_pearson_r = pearsonr(results_df["n_samples"], results_df["pearson_r"])
print(f"📊 Pearson r (samples vs Pearson r) = {pearson_corr_r:.3f} (p = {pval_pearson_r:.3g})")

spearman_corr_r, pval_spearman_r = spearmanr(results_df["n_samples"], results_df["pearson_r"])
print(f"📊 Spearman ρ (samples vs Pearson r) = {spearman_corr_r:.3f} (p = {pval_spearman_r:.3g})")
# Out:
# 📊 Pearson r (samples vs Pearson r) = -0.061 (p = 0.868)
# 📊 Spearman ρ (samples vs Pearson r) = -0.273 (p = 0.446)

# %%
# 📊 Pearson r vs. IC50 Variance
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="ic50_variance", y="pearson_r")
plt.title("Pearson r vs. IC50 Variance per Drug (ElasticNet)")
plt.xlabel("IC50 Variance (LN_IC50)")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()
plt.close()

# %%
# 📊 Compute correlations for interpretation
pearson_corr_var, pval_pearson_var = pearsonr(results_df["ic50_variance"], results_df["pearson_r"])
print(f"📊 Pearson r (IC50 variance vs Pearson r) = {pearson_corr_var:.3f} (p = {pval_pearson_var:.3g})")

spearman_corr_var, pval_spearman_var = spearmanr(results_df["ic50_variance"], results_df["pearson_r"])
print(f"📊 Spearman ρ (IC50 variance vs Pearson r) = {spearman_corr_var:.3f} (p = {pval_spearman_var:.3g})")
# Out:
# 📊 Pearson r (IC50 variance vs Pearson r) = 0.221 (p = 0.54)
# 📊 Spearman ρ (IC50 variance vs Pearson r) = 0.164 (p = 0.651)
