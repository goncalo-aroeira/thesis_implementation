# %% [markdown]
# # Elastic Net Evaluation
#
# This notebook trains **ElasticNet regression models per drug** using gene expression features.
# ElasticNet combines L1 (Lasso) and L2 (Ridge) regularization. We use `ElasticNetCV` to tune hyperparameters using 5-fold cross-validation.
#
# Elastic Net combines both:
# - **L1 regularization** (Lasso) → promotes sparsity
# - **L2 regularization** (Ridge) → stabilizes coefficients
#
# This allows it to both regularize and select features, making it a simple but powerful linear model.
#
# We evaluate performance using:
# - **RMSE (Root Mean Squared Error)**
# - **R² (Coefficient of Determination)**
#
# and visualize their **distribution across all drugs**.

# %%
import os
import joblib
import numpy as np
import pandas as pd
from sklearn.linear_model import ElasticNetCV
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.metrics import r2_score, root_mean_squared_error
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy.stats import pearsonr, spearmanr

# %%
# Parameters
NUM_PCS = 30
DATA_PATH = "../../../data/processed/gdsc_pancancer_pseudobulk_30_pcs_tissue_growth.parquet"
data = pd.read_parquet(DATA_PATH)
print("✅ Dataset loaded:", data.shape)

# Setup
os.makedirs("results/elastic_net", exist_ok=True)
non_features = ["SANGER_MODEL_ID", "DRUG_ID", "LN_IC50"]
gene_cols = [col for col in data.columns if col not in non_features]
kf = KFold(n_splits=10, shuffle=True, random_state=42)

results = []
# Out:
# ✅ Dataset loaded: (83624, 45)

# %% [markdown]
# ## 1. Compute Metrics per Drug
#
# For each drug:
# - Select only rows where that drug was tested
# - Split the data into training and test sets
# - Fit an **Elastic Net** regressor on the PCA features
# - Evaluate on test set with **RMSE** and **R²**
#
# We only include drugs with **≥ 10 samples** to ensure meaningful evaluation.

# %%
# Main loop
for drug_id in sorted(data["DRUG_ID"].unique()):
    df = data[data["DRUG_ID"] == drug_id].dropna(subset=["LN_IC50"])
    if df.shape[0] < 100:
        continue

    X = df[gene_cols].values
    y = df["LN_IC50"].values

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    X_scaled = X_scaled.astype("float64")
    y = y.astype("float64")

    model = ElasticNetCV(
        alphas=[0.01, 0.1, 1.0, 10.0],
        l1_ratio=[0.1, 0.5, 0.9],
        cv=kf,
        max_iter=5000,
        random_state=42,
        n_jobs=-1
    )

    # Cross-validated predictions
    y_pred = cross_val_predict(model, X_scaled, y, cv=kf, n_jobs=-1)

    # Compute global metrics
    r2 = r2_score(y, y_pred)
    pearson_r, p_val = pearsonr(y, y_pred)
    rmse = root_mean_squared_error(y, y_pred)

    print(f"\n🧬 Drug {drug_id} | Samples: {len(df)}")
    print(f"  ➤ Global R²: {r2:.4f}")
    print(f"  ➤ Pearson r: {pearson_r:.4f} (p={p_val:.2e})")
    print(f"  ➤ RMSE: {rmse:.4f}")
    
    results.append({
        "DRUG_ID": drug_id,
        "n_samples": len(df),
        "r2_global": r2,
        "pearson_r": pearson_r,
        "pearson_pval": p_val,
        "rmse": rmse
    })
# Out:
# 🧬 Drug 133 | Samples: 132
#   ➤ Global R²: 0.1006
#   ➤ Pearson r: 0.3340 (p=9.09e-05)
#   ➤ RMSE: 1.6069
#
# 🧬 Drug 134 | Samples: 132
#   ➤ Global R²: 0.0927
#   ➤ Pearson r: 0.3093 (p=3.08e-04)
#   ➤ RMSE: 1.8215
#
# 🧬 Drug 135 | Samples: 131
#   ➤ Global R²: 0.0394
#   ➤ Pearson r: 0.2037 (p=1.96e-02)
#   ➤ RMSE: 2.5582
#
# 🧬 Drug 136 | Samples: 133
#   ➤ Global R²: 0.0236
#   ➤ Pearson r: 0.1733 (p=4.60e-02)
#   ➤ RMSE: 1.4890
#
# 🧬 Drug 140 | Samples: 133
#   ➤ Global R²: 0.0695
#   ➤ Pearson r: 0.2696 (p=1.70e-03)
#   ➤ RMSE: 1.5804
#
# 🧬 Drug 147 | Samples: 132
#   ➤ Global R²: 0.0000
#   ➤ Pearson r: 0.1534 (p=7.90e-02)
#   ➤ RMSE: 0.7649
#
# 🧬 Drug 150 | Samples: 133
#   ➤ Global R²: 0.0120
#   ➤ Pearson r: 0.1274 (p=1.44e-01)
#   ➤ RMSE: 0.5431
#
# 🧬 Drug 151 | Samples: 133
#   ➤ Global R²: 0.0046
#   ➤ Pearson r: 0.1100 (p=2.07e-01)
#   ➤ RMSE: 1.4293
#
# 🧬 Drug 152 | Samples: 135
#   ➤ Global R²: -0.0477
#   ➤ Pearson r: -0.0884 (p=3.08e-01)
#   ➤ RMSE: 1.1744
#
# 🧬 Drug 153 | Samples: 133
#   ➤ Global R²: 0.0774
#   ➤ Pearson r: 0.2829 (p=9.67e-04)
#   ➤ RMSE: 1.2047
#
# 🧬 Drug 154 | Samples: 132
#   ➤ Global R²: -0.0352
#   ➤ Pearson r: 0.0178 (p=8.40e-01)
#   ➤ RMSE: 0.8843
#
# 🧬 Drug 155 | Samples: 133
#   ➤ Global R²: 0.1013
#   ➤ Pearson r: 0.3195 (p=1.78e-04)
#   ➤ RMSE: 1.1727
#
# 🧬 Drug 156 | Samples: 131
#   ➤ Global R²: -0.0202
#   ➤ Pearson r: 0.1097 (p=2.12e-01)
#   ➤ RMSE: 1.3277
#
# 🧬 Drug 157 | Samples: 133
#   ➤ Global R²: 0.0198
#   ➤ Pearson r: 0.1733 (p=4.61e-02)
#   ➤ RMSE: 1.0097
#
# 🧬 Drug 158 | Samples: 130
#   ➤ Global R²: 0.0115
#   ➤ Pearson r: 0.1367 (p=1.21e-01)
#   ➤ RMSE: 1.0159
#
# 🧬 Drug 159 | Samples: 133
#   ➤ Global R²: 0.0671
#   ➤ Pearson r: 0.2621 (p=2.31e-03)
#   ➤ RMSE: 1.4094
#
# 🧬 Drug 163 | Samples: 133
#   ➤ Global R²: -0.0133
#   ➤ Pearson r: 0.0006 (p=9.95e-01)
#   ➤ RMSE: 1.3580
#
# 🧬 Drug 164 | Samples: 133
#   ➤ Global R²: -0.0205
#   ➤ Pearson r: 0.0263 (p=7.64e-01)
#   ➤ RMSE: 1.4983
#
# 🧬 Drug 165 | Samples: 132
#   ➤ Global R²: 0.0527
#   ➤ Pearson r: 0.2301 (p=7.95e-03)
#   ➤ RMSE: 1.3655
#
# 🧬 Drug 166 | Samples: 133
#   ➤ Global R²: -0.0681
#   ➤ Pearson r: 0.1224 (p=1.60e-01)
#   ➤ RMSE: 0.8690
#
# 🧬 Drug 167 | Samples: 132
#   ➤ Global R²: 0.0253
#   ➤ Pearson r: 0.1592 (p=6.83e-02)
#   ➤ RMSE: 1.1076
#
# 🧬 Drug 170 | Samples: 132
#   ➤ Global R²: -0.0107
#   ➤ Pearson r: -0.2140 (p=1.37e-02)
#   ➤ RMSE: 1.2051
#
# 🧬 Drug 171 | Samples: 132
#   ➤ Global R²: 0.0068
#   ➤ Pearson r: 0.1508 (p=8.43e-02)
#   ➤ RMSE: 0.9429
#
# 🧬 Drug 172 | Samples: 133
#   ➤ Global R²: -0.0685
#   ➤ Pearson r: 0.0148 (p=8.66e-01)
#   ➤ RMSE: 0.9673
#
# 🧬 Drug 173 | Samples: 133
#   ➤ Global R²: 0.1142
#   ➤ Pearson r: 0.3436 (p=5.15e-05)
#   ➤ RMSE: 1.2039
#
# 🧬 Drug 175 | Samples: 132
#   ➤ Global R²: -0.0217
#   ➤ Pearson r: -0.0522 (p=5.53e-01)
#   ➤ RMSE: 1.2031
#
# 🧬 Drug 176 | Samples: 132
#   ➤ Global R²: -0.1032
#   ➤ Pearson r: -0.0954 (p=2.76e-01)
#   ➤ RMSE: 1.5350
#
# 🧬 Drug 177 | Samples: 131
#   ➤ Global R²: 0.0513
#   ➤ Pearson r: 0.2412 (p=5.51e-03)
#   ➤ RMSE: 1.5741
#
# 🧬 Drug 178 | Samples: 133
#   ➤ Global R²: 0.0106
#   ➤ Pearson r: 0.1230 (p=1.58e-01)
#   ➤ RMSE: 1.4326
#
# 🧬 Drug 179 | Samples: 135
#   ➤ Global R²: 0.0954
#   ➤ Pearson r: 0.3129 (p=2.20e-04)
#   ➤ RMSE: 1.4396
#
# 🧬 Drug 180 | Samples: 130
#   ➤ Global R²: -0.0560
#   ➤ Pearson r: -0.1353 (p=1.25e-01)
#   ➤ RMSE: 1.9361
#
# 🧬 Drug 182 | Samples: 133
#   ➤ Global R²: -0.0091
#   ➤ Pearson r: 0.1386 (p=1.12e-01)
#   ➤ RMSE: 1.5534
#
# 🧬 Drug 184 | Samples: 132
#   ➤ Global R²: -0.0121
#   ➤ Pearson r: 0.0586 (p=5.05e-01)
#   ➤ RMSE: 1.5870
#
# 🧬 Drug 185 | Samples: 132
#   ➤ Global R²: -0.0138
#   ➤ Pearson r: -0.1062 (p=2.26e-01)
#   ➤ RMSE: 1.3570
#
# 🧬 Drug 186 | Samples: 130
#   ➤ Global R²: -0.0080
#   ➤ Pearson r: -0.1841 (p=3.60e-02)
#   ➤ RMSE: 1.0267
#
# 🧬 Drug 190 | Samples: 130
#   ➤ Global R²: -0.0352
#   ➤ Pearson r: 0.0099 (p=9.11e-01)
#   ➤ RMSE: 2.1637
#
# 🧬 Drug 192 | Samples: 133
#   ➤ Global R²: -0.0197
#   ➤ Pearson r: 0.0677 (p=4.39e-01)
#   ➤ RMSE: 0.6649
#
# 🧬 Drug 193 | Samples: 135
#   ➤ Global R²: 0.0781
#   ➤ Pearson r: 0.2801 (p=1.00e-03)
#   ➤ RMSE: 0.5274
#
# 🧬 Drug 194 | Samples: 132
#   ➤ Global R²: -0.0018
#   ➤ Pearson r: 0.0813 (p=3.54e-01)
#   ➤ RMSE: 1.5947
#
# 🧬 Drug 196 | Samples: 132
#   ➤ Global R²: 0.0236
#   ➤ Pearson r: 0.1547 (p=7.66e-02)
#   ➤ RMSE: 1.4740
#
# 🧬 Drug 197 | Samples: 133
#   ➤ Global R²: -0.0184
#   ➤ Pearson r: -0.2265 (p=8.75e-03)
#   ➤ RMSE: 0.8552
#
# 🧬 Drug 199 | Samples: 132
#   ➤ Global R²: -0.0634
#   ➤ Pearson r: -0.0107 (p=9.03e-01)
#   ➤ RMSE: 1.3318
#
# 🧬 Drug 200 | Samples: 133
#   ➤ Global R²: -0.0109
#   ➤ Pearson r: 0.0235 (p=7.88e-01)
#   ➤ RMSE: 1.1226
#
# 🧬 Drug 201 | Samples: 132
#   ➤ Global R²: 0.0535
#   ➤ Pearson r: 0.2349 (p=6.71e-03)
#   ➤ RMSE: 1.7496
#
# 🧬 Drug 202 | Samples: 133
#   ➤ Global R²: -0.0156
#   ➤ Pearson r: 0.0666 (p=4.46e-01)
#   ➤ RMSE: 0.7355
#
# 🧬 Drug 203 | Samples: 136
#   ➤ Global R²: 0.0338
#   ➤ Pearson r: 0.1838 (p=3.22e-02)
#   ➤ RMSE: 1.0176
#
# 🧬 Drug 204 | Samples: 133
#   ➤ Global R²: -0.0371
#   ➤ Pearson r: -0.0399 (p=6.48e-01)
#   ➤ RMSE: 1.5843
#
# 🧬 Drug 205 | Samples: 135
#   ➤ Global R²: -0.0386
#   ➤ Pearson r: -0.1243 (p=1.51e-01)
#   ➤ RMSE: 0.5537
#
# 🧬 Drug 206 | Samples: 136
#   ➤ Global R²: 0.0382
#   ➤ Pearson r: 0.2055 (p=1.64e-02)
#   ➤ RMSE: 0.5966
#
# 🧬 Drug 207 | Samples: 132
#   ➤ Global R²: -0.0606
#   ➤ Pearson r: -0.1013 (p=2.48e-01)
#   ➤ RMSE: 1.1269
#
# 🧬 Drug 208 | Samples: 134
#   ➤ Global R²: 0.0406
#   ➤ Pearson r: 0.2016 (p=1.95e-02)
#   ➤ RMSE: 1.6113
#
# 🧬 Drug 211 | Samples: 134
#   ➤ Global R²: -0.0295
#   ➤ Pearson r: -0.0430 (p=6.22e-01)
#   ➤ RMSE: 1.0544
#
# 🧬 Drug 219 | Samples: 130
#   ➤ Global R²: -0.0137
#   ➤ Pearson r: -0.0342 (p=6.99e-01)
#   ➤ RMSE: 1.6435
#
# 🧬 Drug 221 | Samples: 136
#   ➤ Global R²: -0.0190
#   ➤ Pearson r: -0.0020 (p=9.82e-01)
#   ➤ RMSE: 1.0950
#
# 🧬 Drug 222 | Samples: 136
#   ➤ Global R²: 0.0553
#   ➤ Pearson r: 0.2371 (p=5.44e-03)
#   ➤ RMSE: 1.4104
#
# 🧬 Drug 223 | Samples: 135
#   ➤ Global R²: -0.1094
#   ➤ Pearson r: -0.1187 (p=1.70e-01)
#   ➤ RMSE: 1.5329
#
# 🧬 Drug 224 | Samples: 134
#   ➤ Global R²: -0.0441
#   ➤ Pearson r: -0.1225 (p=1.58e-01)
#   ➤ RMSE: 1.4762
#
# 🧬 Drug 225 | Samples: 135
#   ➤ Global R²: -0.0424
#   ➤ Pearson r: -0.3454 (p=4.07e-05)
#   ➤ RMSE: 1.5576
#
# 🧬 Drug 226 | Samples: 129
#   ➤ Global R²: 0.0077
#   ➤ Pearson r: 0.1243 (p=1.61e-01)
#   ➤ RMSE: 1.5650
#
# 🧬 Drug 228 | Samples: 135
#   ➤ Global R²: -0.0584
#   ➤ Pearson r: -0.0140 (p=8.72e-01)
#   ➤ RMSE: 1.3330
#
# 🧬 Drug 229 | Samples: 134
#   ➤ Global R²: -0.0215
#   ➤ Pearson r: -0.1908 (p=2.73e-02)
#   ➤ RMSE: 1.5665
#
# 🧬 Drug 230 | Samples: 136
#   ➤ Global R²: 0.1115
#   ➤ Pearson r: 0.3403 (p=5.05e-05)
#   ➤ RMSE: 0.9577
#
# 🧬 Drug 231 | Samples: 124
#   ➤ Global R²: -0.0913
#   ➤ Pearson r: -0.0992 (p=2.73e-01)
#   ➤ RMSE: 0.8347
#
# 🧬 Drug 235 | Samples: 133
#   ➤ Global R²: -0.0015
#   ➤ Pearson r: 0.0439 (p=6.16e-01)
#   ➤ RMSE: 1.6153
#
# 🧬 Drug 236 | Samples: 135
#   ➤ Global R²: -0.0305
#   ➤ Pearson r: 0.0446 (p=6.08e-01)
#   ➤ RMSE: 0.6848
#
# 🧬 Drug 238 | Samples: 136
#   ➤ Global R²: 0.0002
#   ➤ Pearson r: 0.1383 (p=1.08e-01)
#   ➤ RMSE: 1.0989
#
# 🧬 Drug 245 | Samples: 135
#   ➤ Global R²: -0.0496
#   ➤ Pearson r: -0.1915 (p=2.61e-02)
#   ➤ RMSE: 1.5317
#
# 🧬 Drug 249 | Samples: 134
#   ➤ Global R²: -0.0191
#   ➤ Pearson r: 0.0822 (p=3.45e-01)
#   ➤ RMSE: 1.2907
#
# 🧬 Drug 252 | Samples: 135
#   ➤ Global R²: -0.0564
#   ➤ Pearson r: -0.1684 (p=5.09e-02)
#   ➤ RMSE: 1.7935
#
# 🧬 Drug 253 | Samples: 135
#   ➤ Global R²: -0.0410
#   ➤ Pearson r: -0.3546 (p=2.44e-05)
#   ➤ RMSE: 0.7738
#
# 🧬 Drug 254 | Samples: 135
#   ➤ Global R²: 0.0366
#   ➤ Pearson r: 0.2201 (p=1.03e-02)
#   ➤ RMSE: 0.7635
#
# 🧬 Drug 255 | Samples: 135
#   ➤ Global R²: 0.0383
#   ➤ Pearson r: 0.2566 (p=2.66e-03)
#   ➤ RMSE: 0.9335
#
# 🧬 Drug 256 | Samples: 135
#   ➤ Global R²: -0.0533
#   ➤ Pearson r: -0.1669 (p=5.30e-02)
#   ➤ RMSE: 1.4067
#
# 🧬 Drug 257 | Samples: 134
#   ➤ Global R²: 0.0484
#   ➤ Pearson r: 0.2548 (p=2.96e-03)
#   ➤ RMSE: 1.3848
#
# 🧬 Drug 258 | Samples: 135
#   ➤ Global R²: -0.0301
#   ➤ Pearson r: -0.2606 (p=2.27e-03)
#   ➤ RMSE: 0.7087
#
# 🧬 Drug 260 | Samples: 135
#   ➤ Global R²: 0.0121
#   ➤ Pearson r: 0.1450 (p=9.35e-02)
#   ➤ RMSE: 1.3306
#
# 🧬 Drug 261 | Samples: 135
#   ➤ Global R²: 0.0121
#   ➤ Pearson r: 0.1934 (p=2.46e-02)
#   ➤ RMSE: 1.2276
#
# 🧬 Drug 262 | Samples: 135
#   ➤ Global R²: 0.0324
#   ➤ Pearson r: 0.2010 (p=1.94e-02)
#   ➤ RMSE: 1.4068
#
# 🧬 Drug 263 | Samples: 135
#   ➤ Global R²: -0.0910
#   ➤ Pearson r: -0.0383 (p=6.59e-01)
#   ➤ RMSE: 0.8059
#
# 🧬 Drug 264 | Samples: 134
#   ➤ Global R²: 0.0585
#   ➤ Pearson r: 0.2450 (p=4.33e-03)
#   ➤ RMSE: 1.1219
#
# 🧬 Drug 265 | Samples: 135
#   ➤ Global R²: -0.0415
#   ➤ Pearson r: -0.0908 (p=2.95e-01)
#   ➤ RMSE: 1.0464
#
# 🧬 Drug 266 | Samples: 135
#   ➤ Global R²: 0.0055
#   ➤ Pearson r: 0.1344 (p=1.20e-01)
#   ➤ RMSE: 0.4622
#
# 🧬 Drug 268 | Samples: 130
#   ➤ Global R²: 0.0135
#   ➤ Pearson r: 0.1476 (p=9.38e-02)
#   ➤ RMSE: 2.7709
#
# 🧬 Drug 269 | Samples: 135
#   ➤ Global R²: 0.0149
#   ➤ Pearson r: 0.1297 (p=1.34e-01)
#   ➤ RMSE: 1.3765
#
# 🧬 Drug 271 | Samples: 135
#   ➤ Global R²: -0.0215
#   ➤ Pearson r: 0.0804 (p=3.54e-01)
#   ➤ RMSE: 0.6343
#
# 🧬 Drug 272 | Samples: 133
#   ➤ Global R²: -0.0512
#   ➤ Pearson r: -0.0756 (p=3.87e-01)
#   ➤ RMSE: 1.6107
#
# 🧬 Drug 273 | Samples: 134
#   ➤ Global R²: -0.0121
#   ➤ Pearson r: -0.2233 (p=9.49e-03)
#   ➤ RMSE: 1.6290
#
# 🧬 Drug 274 | Samples: 131
#   ➤ Global R²: -0.0399
#   ➤ Pearson r: -0.1644 (p=6.06e-02)
#   ➤ RMSE: 1.9796
#
# 🧬 Drug 275 | Samples: 134
#   ➤ Global R²: -0.0463
#   ➤ Pearson r: -0.2773 (p=1.18e-03)
#   ➤ RMSE: 1.3197
#
# 🧬 Drug 276 | Samples: 133
#   ➤ Global R²: -0.0319
#   ➤ Pearson r: -0.0033 (p=9.70e-01)
#   ➤ RMSE: 1.6624
#
# 🧬 Drug 277 | Samples: 135
#   ➤ Global R²: -0.0171
#   ➤ Pearson r: -0.2703 (p=1.52e-03)
#   ➤ RMSE: 0.7091
#
# 🧬 Drug 279 | Samples: 135
#   ➤ Global R²: -0.0956
#   ➤ Pearson r: -0.0874 (p=3.13e-01)
#   ➤ RMSE: 1.0176
#
# 🧬 Drug 281 | Samples: 135
#   ➤ Global R²: -0.0543
#   ➤ Pearson r: -0.1339 (p=1.22e-01)
#   ➤ RMSE: 0.8172
#
# 🧬 Drug 282 | Samples: 135
#   ➤ Global R²: -0.0310
#   ➤ Pearson r: -0.0389 (p=6.54e-01)
#   ➤ RMSE: 1.7512
#
# 🧬 Drug 283 | Samples: 135
#   ➤ Global R²: -0.0288
#   ➤ Pearson r: -0.1363 (p=1.15e-01)
#   ➤ RMSE: 1.6823
#
# 🧬 Drug 284 | Samples: 135
#   ➤ Global R²: -0.0756
#   ➤ Pearson r: -0.0915 (p=2.91e-01)
#   ➤ RMSE: 1.1209
#
# 🧬 Drug 285 | Samples: 135
#   ➤ Global R²: 0.0130
#   ➤ Pearson r: 0.1739 (p=4.37e-02)
#   ➤ RMSE: 1.1617
#
# 🧬 Drug 286 | Samples: 135
#   ➤ Global R²: -0.0707
#   ➤ Pearson r: -0.0272 (p=7.54e-01)
#   ➤ RMSE: 0.7431
#
# 🧬 Drug 287 | Samples: 135
#   ➤ Global R²: -0.0370
#   ➤ Pearson r: 0.0592 (p=4.95e-01)
#   ➤ RMSE: 1.1030
#
# 🧬 Drug 288 | Samples: 135
#   ➤ Global R²: -0.0124
#   ➤ Pearson r: 0.1550 (p=7.26e-02)
#   ➤ RMSE: 1.0416
#
# 🧬 Drug 289 | Samples: 135
#   ➤ Global R²: -0.0217
#   ➤ Pearson r: -0.3125 (p=2.24e-04)
#   ➤ RMSE: 0.7102
#
# 🧬 Drug 290 | Samples: 135
#   ➤ Global R²: -0.0871
#   ➤ Pearson r: 0.0124 (p=8.87e-01)
#   ➤ RMSE: 0.8848
#
# 🧬 Drug 291 | Samples: 134
#   ➤ Global R²: -0.0984
#   ➤ Pearson r: -0.1725 (p=4.63e-02)
#   ➤ RMSE: 1.2184
#
# 🧬 Drug 292 | Samples: 135
#   ➤ Global R²: -0.0079
#   ➤ Pearson r: 0.0240 (p=7.82e-01)
#   ➤ RMSE: 1.1623
#
# 🧬 Drug 293 | Samples: 134
#   ➤ Global R²: -0.0817
#   ➤ Pearson r: -0.1493 (p=8.51e-02)
#   ➤ RMSE: 1.5977
#
# 🧬 Drug 294 | Samples: 135
#   ➤ Global R²: 0.0789
#   ➤ Pearson r: 0.2977 (p=4.54e-04)
#   ➤ RMSE: 1.1815
#
# 🧬 Drug 295 | Samples: 135
#   ➤ Global R²: -0.0243
#   ➤ Pearson r: 0.0229 (p=7.92e-01)
#   ➤ RMSE: 1.3907
#
# 🧬 Drug 298 | Samples: 135
#   ➤ Global R²: -0.0314
#   ➤ Pearson r: 0.0053 (p=9.51e-01)
#   ➤ RMSE: 0.8539
#
# 🧬 Drug 299 | Samples: 131
#   ➤ Global R²: -0.0527
#   ➤ Pearson r: -0.1102 (p=2.10e-01)
#   ➤ RMSE: 2.1395
#
# 🧬 Drug 300 | Samples: 135
#   ➤ Global R²: 0.0430
#   ➤ Pearson r: 0.2333 (p=6.48e-03)
#   ➤ RMSE: 1.6249
#
# 🧬 Drug 301 | Samples: 135
#   ➤ Global R²: -0.0387
#   ➤ Pearson r: -0.0136 (p=8.76e-01)
#   ➤ RMSE: 1.6126
#
# 🧬 Drug 302 | Samples: 133
#   ➤ Global R²: -0.0032
#   ➤ Pearson r: 0.1029 (p=2.38e-01)
#   ➤ RMSE: 2.0354
#
# 🧬 Drug 303 | Samples: 134
#   ➤ Global R²: -0.0087
#   ➤ Pearson r: 0.1205 (p=1.65e-01)
#   ➤ RMSE: 1.4667
#
# 🧬 Drug 304 | Samples: 134
#   ➤ Global R²: 0.1060
#   ➤ Pearson r: 0.3508 (p=3.24e-05)
#   ➤ RMSE: 1.3199
#
# 🧬 Drug 305 | Samples: 135
#   ➤ Global R²: 0.0511
#   ➤ Pearson r: 0.2652 (p=1.88e-03)
#   ➤ RMSE: 1.3279
#
# 🧬 Drug 306 | Samples: 135
#   ➤ Global R²: -0.0324
#   ➤ Pearson r: -0.2629 (p=2.06e-03)
#   ➤ RMSE: 1.3902
#
# 🧬 Drug 308 | Samples: 134
#   ➤ Global R²: 0.1081
#   ➤ Pearson r: 0.3289 (p=1.04e-04)
#   ➤ RMSE: 1.3552
#
# 🧬 Drug 309 | Samples: 135
#   ➤ Global R²: -0.0517
#   ➤ Pearson r: -0.1078 (p=2.13e-01)
#   ➤ RMSE: 1.0128
#
# 🧬 Drug 310 | Samples: 135
#   ➤ Global R²: 0.0751
#   ➤ Pearson r: 0.2809 (p=9.66e-04)
#   ➤ RMSE: 1.1383
#
# 🧬 Drug 312 | Samples: 135
#   ➤ Global R²: -0.0311
#   ➤ Pearson r: 0.0866 (p=3.18e-01)
#   ➤ RMSE: 0.6543
#
# 🧬 Drug 317 | Samples: 132
#   ➤ Global R²: 0.0790
#   ➤ Pearson r: 0.2876 (p=8.25e-04)
#   ➤ RMSE: 1.8605
#
# 🧬 Drug 326 | Samples: 135
#   ➤ Global R²: -0.0463
#   ➤ Pearson r: -0.0593 (p=4.94e-01)
#   ➤ RMSE: 1.5470
#
# 🧬 Drug 328 | Samples: 132
#   ➤ Global R²: 0.0395
#   ➤ Pearson r: 0.2231 (p=1.01e-02)
#   ➤ RMSE: 1.9172
#
# 🧬 Drug 329 | Samples: 135
#   ➤ Global R²: 0.0101
#   ➤ Pearson r: 0.1394 (p=1.07e-01)
#   ➤ RMSE: 0.9294
#
# 🧬 Drug 330 | Samples: 135
#   ➤ Global R²: 0.0183
#   ➤ Pearson r: 0.1358 (p=1.16e-01)
#   ➤ RMSE: 1.0829
#
# 🧬 Drug 331 | Samples: 134
#   ➤ Global R²: -0.0747
#   ➤ Pearson r: -0.2171 (p=1.17e-02)
#   ➤ RMSE: 1.6682
#
# 🧬 Drug 332 | Samples: 135
#   ➤ Global R²: -0.0664
#   ➤ Pearson r: -0.1194 (p=1.68e-01)
#   ➤ RMSE: 0.6870
#
# 🧬 Drug 333 | Samples: 133
#   ➤ Global R²: -0.0122
#   ➤ Pearson r: 0.0044 (p=9.60e-01)
#   ➤ RMSE: 0.8376
#
# 🧬 Drug 341 | Samples: 135
#   ➤ Global R²: 0.1520
#   ➤ Pearson r: 0.3914 (p=2.68e-06)
#   ➤ RMSE: 0.6058
#
# 🧬 Drug 342 | Samples: 135
#   ➤ Global R²: 0.0207
#   ➤ Pearson r: 0.1490 (p=8.45e-02)
#   ➤ RMSE: 1.0470
#
# 🧬 Drug 344 | Samples: 131
#   ➤ Global R²: 0.0587
#   ➤ Pearson r: 0.2592 (p=2.79e-03)
#   ➤ RMSE: 2.0840
#
# 🧬 Drug 345 | Samples: 135
#   ➤ Global R²: 0.1102
#   ➤ Pearson r: 0.3343 (p=7.41e-05)
#   ➤ RMSE: 0.6764
#
# 🧬 Drug 346 | Samples: 130
#   ➤ Global R²: 0.1047
#   ➤ Pearson r: 0.3328 (p=1.09e-04)
#   ➤ RMSE: 2.4226
#
# 🧬 Drug 356 | Samples: 135
#   ➤ Global R²: 0.1729
#   ➤ Pearson r: 0.4190 (p=4.24e-07)
#   ➤ RMSE: 1.2926
#
# 🧬 Drug 362 | Samples: 135
#   ➤ Global R²: -0.0173
#   ➤ Pearson r: 0.1032 (p=2.34e-01)
#   ➤ RMSE: 1.5183
#
# 🧬 Drug 363 | Samples: 135
#   ➤ Global R²: -0.0297
#   ➤ Pearson r: -0.0141 (p=8.71e-01)
#   ➤ RMSE: 1.3217
#
# 🧬 Drug 366 | Samples: 135
#   ➤ Global R²: -0.0278
#   ➤ Pearson r: 0.0349 (p=6.88e-01)
#   ➤ RMSE: 1.3445
#
# 🧬 Drug 371 | Samples: 130
#   ➤ Global R²: 0.0194
#   ➤ Pearson r: 0.1537 (p=8.08e-02)
#   ➤ RMSE: 1.9264
#
# 🧬 Drug 372 | Samples: 135
#   ➤ Global R²: 0.0551
#   ➤ Pearson r: 0.2405 (p=4.96e-03)
#   ➤ RMSE: 1.0737
#
# 🧬 Drug 374 | Samples: 133
#   ➤ Global R²: 0.1781
#   ➤ Pearson r: 0.4242 (p=3.61e-07)
#   ➤ RMSE: 1.4585
#
# 🧬 Drug 375 | Samples: 135
#   ➤ Global R²: -0.0059
#   ➤ Pearson r: 0.0708 (p=4.14e-01)
#   ➤ RMSE: 0.9406
#
# 🧬 Drug 376 | Samples: 135
#   ➤ Global R²: -0.0414
#   ➤ Pearson r: -0.0040 (p=9.63e-01)
#   ➤ RMSE: 1.0014
#
# 🧬 Drug 380 | Samples: 135
#   ➤ Global R²: -0.0025
#   ➤ Pearson r: 0.0647 (p=4.56e-01)
#   ➤ RMSE: 1.4781
#
# 🧬 Drug 381 | Samples: 133
#   ➤ Global R²: 0.0237
#   ➤ Pearson r: 0.1922 (p=2.67e-02)
#   ➤ RMSE: 1.2772
#
# 🧬 Drug 382 | Samples: 134
#   ➤ Global R²: 0.0490
#   ➤ Pearson r: 0.2290 (p=7.78e-03)
#   ➤ RMSE: 1.3569
#
# 🧬 Drug 406 | Samples: 135
#   ➤ Global R²: 0.0416
#   ➤ Pearson r: 0.2174 (p=1.13e-02)
#   ➤ RMSE: 0.9245
#
# 🧬 Drug 407 | Samples: 135
#   ➤ Global R²: 0.0090
#   ➤ Pearson r: 0.1604 (p=6.31e-02)
#   ➤ RMSE: 1.1266
#
# 🧬 Drug 408 | Samples: 135
#   ➤ Global R²: 0.0859
#   ➤ Pearson r: 0.2941 (p=5.36e-04)
#   ➤ RMSE: 0.4692
#
# 🧬 Drug 409 | Samples: 135
#   ➤ Global R²: 0.0215
#   ➤ Pearson r: 0.1640 (p=5.73e-02)
#   ➤ RMSE: 0.4879
#
# 🧬 Drug 410 | Samples: 132
#   ➤ Global R²: 0.0895
#   ➤ Pearson r: 0.3159 (p=2.24e-04)
#   ➤ RMSE: 0.7315
#
# 🧬 Drug 412 | Samples: 133
#   ➤ Global R²: -0.0741
#   ➤ Pearson r: -0.1063 (p=2.24e-01)
#   ➤ RMSE: 0.4803
#
# 🧬 Drug 415 | Samples: 132
#   ➤ Global R²: -0.0088
#   ➤ Pearson r: 0.0919 (p=2.95e-01)
#   ➤ RMSE: 0.8386
#
# 🧬 Drug 416 | Samples: 131
#   ➤ Global R²: -0.0540
#   ➤ Pearson r: -0.1763 (p=4.40e-02)
#   ➤ RMSE: 1.1530
#
# 🧬 Drug 427 | Samples: 131
#   ➤ Global R²: 0.0603
#   ➤ Pearson r: 0.2496 (p=4.03e-03)
#   ➤ RMSE: 0.5576
#
# 🧬 Drug 428 | Samples: 131
#   ➤ Global R²: 0.1345
#   ➤ Pearson r: 0.3732 (p=1.13e-05)
#   ➤ RMSE: 1.2720
#
# 🧬 Drug 431 | Samples: 132
#   ➤ Global R²: 0.0849
#   ➤ Pearson r: 0.3134 (p=2.53e-04)
#   ➤ RMSE: 1.2803
#
# 🧬 Drug 432 | Samples: 132
#   ➤ Global R²: -0.0378
#   ➤ Pearson r: -0.0791 (p=3.67e-01)
#   ➤ RMSE: 0.9239
#
# 🧬 Drug 435 | Samples: 132
#   ➤ Global R²: -0.0801
#   ➤ Pearson r: 0.0928 (p=2.90e-01)
#   ➤ RMSE: 1.1360
#
# 🧬 Drug 436 | Samples: 132
#   ➤ Global R²: 0.0544
#   ➤ Pearson r: 0.2358 (p=6.50e-03)
#   ➤ RMSE: 1.2225
#
# 🧬 Drug 437 | Samples: 132
#   ➤ Global R²: -0.1198
#   ➤ Pearson r: -0.0328 (p=7.09e-01)
#   ➤ RMSE: 1.1938
#
# 🧬 Drug 438 | Samples: 132
#   ➤ Global R²: -0.0805
#   ➤ Pearson r: -0.0386 (p=6.61e-01)
#   ➤ RMSE: 1.1380
#
# 🧬 Drug 439 | Samples: 133
#   ➤ Global R²: 0.0312
#   ➤ Pearson r: 0.1771 (p=4.14e-02)
#   ➤ RMSE: 0.9080
#
# 🧬 Drug 442 | Samples: 133
#   ➤ Global R²: 0.0831
#   ➤ Pearson r: 0.2885 (p=7.60e-04)
#   ➤ RMSE: 1.3819
#
# 🧬 Drug 446 | Samples: 133
#   ➤ Global R²: 0.1139
#   ➤ Pearson r: 0.3380 (p=6.91e-05)
#   ➤ RMSE: 0.9230
#
# 🧬 Drug 447 | Samples: 135
#   ➤ Global R²: 0.1067
#   ➤ Pearson r: 0.3284 (p=1.01e-04)
#   ➤ RMSE: 0.5682
#
# 🧬 Drug 449 | Samples: 133
#   ➤ Global R²: 0.2370
#   ➤ Pearson r: 0.5009 (p=8.26e-10)
#   ➤ RMSE: 0.8616
#
# 🧬 Drug 461 | Samples: 131
#   ➤ Global R²: -0.0200
#   ➤ Pearson r: -0.2911 (p=7.45e-04)
#   ➤ RMSE: 1.8142
#
# 🧬 Drug 474 | Samples: 132
#   ➤ Global R²: 0.1223
#   ➤ Pearson r: 0.3498 (p=3.93e-05)
#   ➤ RMSE: 1.7434
#
# 🧬 Drug 476 | Samples: 132
#   ➤ Global R²: -0.0111
#   ➤ Pearson r: 0.0564 (p=5.20e-01)
#   ➤ RMSE: 1.4740
#
# 🧬 Drug 477 | Samples: 133
#   ➤ Global R²: 0.0089
#   ➤ Pearson r: 0.1051 (p=2.28e-01)
#   ➤ RMSE: 0.8483
#
# 🧬 Drug 478 | Samples: 133
#   ➤ Global R²: -0.0316
#   ➤ Pearson r: 0.1081 (p=2.16e-01)
#   ➤ RMSE: 0.6769
#
# 🧬 Drug 546 | Samples: 132
#   ➤ Global R²: -0.0294
#   ➤ Pearson r: -0.0526 (p=5.49e-01)
#   ➤ RMSE: 0.5785
#
# 🧬 Drug 552 | Samples: 132
#   ➤ Global R²: -0.0300
#   ➤ Pearson r: 0.1942 (p=2.56e-02)
#   ➤ RMSE: 0.8623
#
# 🧬 Drug 562 | Samples: 132
#   ➤ Global R²: 0.0196
#   ➤ Pearson r: 0.2063 (p=1.76e-02)
#   ➤ RMSE: 0.5922
#
# 🧬 Drug 563 | Samples: 132
#   ➤ Global R²: -0.0273
#   ➤ Pearson r: 0.0569 (p=5.17e-01)
#   ➤ RMSE: 0.9082
#
# 🧬 Drug 573 | Samples: 132
#   ➤ Global R²: 0.0998
#   ➤ Pearson r: 0.3220 (p=1.67e-04)
#   ➤ RMSE: 0.7938
#
# 🧬 Drug 574 | Samples: 133
#   ➤ Global R²: 0.1435
#   ➤ Pearson r: 0.3799 (p=6.48e-06)
#   ➤ RMSE: 0.7124
#
# 🧬 Drug 576 | Samples: 132
#   ➤ Global R²: 0.0454
#   ➤ Pearson r: 0.2271 (p=8.82e-03)
#   ➤ RMSE: 1.0032
#
# 🧬 Drug 1001 | Samples: 134
#   ➤ Global R²: -0.1582
#   ➤ Pearson r: -0.0943 (p=2.78e-01)
#   ➤ RMSE: 1.2680
#
# 🧬 Drug 1003 | Samples: 138
#   ➤ Global R²: 0.1329
#   ➤ Pearson r: 0.3756 (p=5.65e-06)
#   ➤ RMSE: 1.6403
#
# 🧬 Drug 1004 | Samples: 134
#   ➤ Global R²: 0.1934
#   ➤ Pearson r: 0.4401 (p=1.04e-07)
#   ➤ RMSE: 1.2280
#
# 🧬 Drug 1005 | Samples: 134
#   ➤ Global R²: 0.0271
#   ➤ Pearson r: 0.2541 (p=3.05e-03)
#   ➤ RMSE: 1.1665
#
# 🧬 Drug 1006 | Samples: 132
#   ➤ Global R²: 0.1026
#   ➤ Pearson r: 0.3452 (p=5.04e-05)
#   ➤ RMSE: 1.3358
#
# 🧬 Drug 1007 | Samples: 134
#   ➤ Global R²: 0.1939
#   ➤ Pearson r: 0.4546 (p=3.44e-08)
#   ➤ RMSE: 1.2149
#
# 🧬 Drug 1008 | Samples: 134
#   ➤ Global R²: 0.0759
#   ➤ Pearson r: 0.2795 (p=1.07e-03)
#   ➤ RMSE: 1.2091
#
# 🧬 Drug 1009 | Samples: 134
#   ➤ Global R²: -0.0156
#   ➤ Pearson r: -0.1561 (p=7.16e-02)
#   ➤ RMSE: 1.0104
#
# 🧬 Drug 1010 | Samples: 133
#   ➤ Global R²: 0.0307
#   ➤ Pearson r: 0.2079 (p=1.63e-02)
#   ➤ RMSE: 0.9533
#
# 🧬 Drug 1011 | Samples: 135
#   ➤ Global R²: -0.0211
#   ➤ Pearson r: 0.0008 (p=9.92e-01)
#   ➤ RMSE: 1.2164
#
# 🧬 Drug 1012 | Samples: 134
#   ➤ Global R²: -0.0252
#   ➤ Pearson r: -0.0463 (p=5.95e-01)
#   ➤ RMSE: 1.0272
#
# 🧬 Drug 1013 | Samples: 134
#   ➤ Global R²: -0.0317
#   ➤ Pearson r: -0.0957 (p=2.71e-01)
#   ➤ RMSE: 0.8319
#
# 🧬 Drug 1014 | Samples: 130
#   ➤ Global R²: 0.2374
#   ➤ Pearson r: 0.4873 (p=4.10e-09)
#   ➤ RMSE: 1.4855
#
# 🧬 Drug 1015 | Samples: 129
#   ➤ Global R²: 0.1787
#   ➤ Pearson r: 0.4311 (p=3.39e-07)
#   ➤ RMSE: 1.2645
#
# 🧬 Drug 1016 | Samples: 130
#   ➤ Global R²: 0.0514
#   ➤ Pearson r: 0.2315 (p=8.04e-03)
#   ➤ RMSE: 1.5048
#
# 🧬 Drug 1017 | Samples: 134
#   ➤ Global R²: 0.1688
#   ➤ Pearson r: 0.4116 (p=7.79e-07)
#   ➤ RMSE: 0.7960
#
# 🧬 Drug 1018 | Samples: 133
#   ➤ Global R²: -0.0214
#   ➤ Pearson r: -0.1211 (p=1.65e-01)
#   ➤ RMSE: 0.7099
#
# 🧬 Drug 1019 | Samples: 134
#   ➤ Global R²: 0.0424
#   ➤ Pearson r: 0.2350 (p=6.27e-03)
#   ➤ RMSE: 1.2068
#
# 🧬 Drug 1020 | Samples: 133
#   ➤ Global R²: -0.0223
#   ➤ Pearson r: 0.0598 (p=4.94e-01)
#   ➤ RMSE: 0.6928
#
# 🧬 Drug 1021 | Samples: 131
#   ➤ Global R²: 0.0637
#   ➤ Pearson r: 0.2781 (p=1.30e-03)
#   ➤ RMSE: 1.0841
#
# 🧬 Drug 1022 | Samples: 134
#   ➤ Global R²: 0.0704
#   ➤ Pearson r: 0.2658 (p=1.91e-03)
#   ➤ RMSE: 1.2950
#
# 🧬 Drug 1023 | Samples: 134
#   ➤ Global R²: -0.0815
#   ➤ Pearson r: -0.0553 (p=5.26e-01)
#   ➤ RMSE: 0.9505
#
# 🧬 Drug 1024 | Samples: 134
#   ➤ Global R²: 0.1353
#   ➤ Pearson r: 0.3695 (p=1.11e-05)
#   ➤ RMSE: 1.3345
#
# 🧬 Drug 1025 | Samples: 114
#   ➤ Global R²: 0.0509
#   ➤ Pearson r: 0.2415 (p=9.64e-03)
#   ➤ RMSE: 0.7234
#
# 🧬 Drug 1026 | Samples: 134
#   ➤ Global R²: 0.0819
#   ➤ Pearson r: 0.3108 (p=2.57e-04)
#   ➤ RMSE: 1.6833
#
# 🧬 Drug 1028 | Samples: 134
#   ➤ Global R²: 0.1345
#   ➤ Pearson r: 0.3688 (p=1.16e-05)
#   ➤ RMSE: 0.5827
#
# 🧬 Drug 1029 | Samples: 134
#   ➤ Global R²: -0.0445
#   ➤ Pearson r: -0.0183 (p=8.34e-01)
#   ➤ RMSE: 0.8893
#
# 🧬 Drug 1030 | Samples: 134
#   ➤ Global R²: -0.0465
#   ➤ Pearson r: -0.1444 (p=9.59e-02)
#   ➤ RMSE: 0.8273
#
# 🧬 Drug 1031 | Samples: 134
#   ➤ Global R²: 0.0925
#   ➤ Pearson r: 0.3089 (p=2.82e-04)
#   ➤ RMSE: 1.6731
#
# 🧬 Drug 1032 | Samples: 134
#   ➤ Global R²: 0.1111
#   ➤ Pearson r: 0.3530 (p=2.87e-05)
#   ➤ RMSE: 1.3893
#
# 🧬 Drug 1033 | Samples: 134
#   ➤ Global R²: 0.0432
#   ➤ Pearson r: 0.2127 (p=1.36e-02)
#   ➤ RMSE: 0.7196
#
# 🧬 Drug 1034 | Samples: 138
#   ➤ Global R²: 0.1490
#   ➤ Pearson r: 0.3905 (p=2.19e-06)
#   ➤ RMSE: 1.2126
#
# 🧬 Drug 1036 | Samples: 135
#   ➤ Global R²: 0.3501
#   ➤ Pearson r: 0.5917 (p=4.14e-14)
#   ➤ RMSE: 1.1755
#
# 🧬 Drug 1037 | Samples: 135
#   ➤ Global R²: 0.2718
#   ➤ Pearson r: 0.5214 (p=8.91e-11)
#   ➤ RMSE: 0.9686
#
# 🧬 Drug 1038 | Samples: 133
#   ➤ Global R²: 0.0720
#   ➤ Pearson r: 0.2773 (p=1.23e-03)
#   ➤ RMSE: 0.8127
#
# 🧬 Drug 1039 | Samples: 131
#   ➤ Global R²: -0.0403
#   ➤ Pearson r: 0.1124 (p=2.01e-01)
#   ➤ RMSE: 0.7761
#
# 🧬 Drug 1042 | Samples: 134
#   ➤ Global R²: -0.0502
#   ➤ Pearson r: -0.1749 (p=4.33e-02)
#   ➤ RMSE: 0.7725
#
# 🧬 Drug 1043 | Samples: 134
#   ➤ Global R²: 0.0491
#   ➤ Pearson r: 0.2220 (p=9.93e-03)
#   ➤ RMSE: 0.8030
#
# 🧬 Drug 1046 | Samples: 120
#   ➤ Global R²: 0.0616
#   ➤ Pearson r: 0.2566 (p=4.66e-03)
#   ➤ RMSE: 0.9968
#
# 🧬 Drug 1047 | Samples: 135
#   ➤ Global R²: 0.1445
#   ➤ Pearson r: 0.4101 (p=7.85e-07)
#   ➤ RMSE: 1.1989
#
# 🧬 Drug 1048 | Samples: 125
#   ➤ Global R²: -0.0024
#   ➤ Pearson r: 0.1086 (p=2.28e-01)
#   ➤ RMSE: 1.2253
#
# 🧬 Drug 1049 | Samples: 135
#   ➤ Global R²: 0.0977
#   ➤ Pearson r: 0.3238 (p=1.28e-04)
#   ➤ RMSE: 0.9183
#
# 🧬 Drug 1050 | Samples: 135
#   ➤ Global R²: -0.0480
#   ➤ Pearson r: -0.0585 (p=5.01e-01)
#   ➤ RMSE: 1.1986
#
# 🧬 Drug 1051 | Samples: 137
#   ➤ Global R²: 0.3002
#   ➤ Pearson r: 0.5529 (p=2.47e-12)
#   ➤ RMSE: 1.4458
#
# 🧬 Drug 1052 | Samples: 135
#   ➤ Global R²: -0.0541
#   ➤ Pearson r: -0.0954 (p=2.71e-01)
#   ➤ RMSE: 0.9872
#
# 🧬 Drug 1053 | Samples: 126
#   ➤ Global R²: -0.0601
#   ➤ Pearson r: -0.0414 (p=6.45e-01)
#   ➤ RMSE: 1.4254
#
# 🧬 Drug 1054 | Samples: 126
#   ➤ Global R²: 0.0863
#   ➤ Pearson r: 0.3155 (p=3.20e-04)
#   ➤ RMSE: 1.4319
#
# 🧬 Drug 1057 | Samples: 132
#   ➤ Global R²: 0.1018
#   ➤ Pearson r: 0.3898 (p=3.83e-06)
#   ➤ RMSE: 1.1550
#
# 🧬 Drug 1058 | Samples: 132
#   ➤ Global R²: -0.0300
#   ➤ Pearson r: -0.0457 (p=6.03e-01)
#   ➤ RMSE: 1.3958
#
# 🧬 Drug 1059 | Samples: 132
#   ➤ Global R²: -0.0186
#   ➤ Pearson r: 0.1491 (p=8.79e-02)
#   ➤ RMSE: 1.0194
#
# 🧬 Drug 1060 | Samples: 132
#   ➤ Global R²: 0.1973
#   ➤ Pearson r: 0.4447 (p=9.23e-08)
#   ➤ RMSE: 1.6634
#
# 🧬 Drug 1061 | Samples: 128
#   ➤ Global R²: 0.3338
#   ➤ Pearson r: 0.5789 (p=8.23e-13)
#   ➤ RMSE: 1.1853
#
# 🧬 Drug 1062 | Samples: 124
#   ➤ Global R²: -0.0265
#   ➤ Pearson r: 0.0611 (p=5.00e-01)
#   ➤ RMSE: 1.6336
#
# 🧬 Drug 1066 | Samples: 131
#   ➤ Global R²: -0.0572
#   ➤ Pearson r: 0.0639 (p=4.68e-01)
#   ➤ RMSE: 1.2803
#
# 🧬 Drug 1067 | Samples: 135
#   ➤ Global R²: 0.0565
#   ➤ Pearson r: 0.2395 (p=5.15e-03)
#   ➤ RMSE: 0.7536
#
# 🧬 Drug 1068 | Samples: 121
#   ➤ Global R²: 0.2202
#   ➤ Pearson r: 0.4696 (p=5.51e-08)
#   ➤ RMSE: 0.8962
#
# 🧬 Drug 1069 | Samples: 135
#   ➤ Global R²: 0.0697
#   ➤ Pearson r: 0.2642 (p=1.96e-03)
#   ➤ RMSE: 0.8928
#
# 🧬 Drug 1070 | Samples: 134
#   ➤ Global R²: 0.1835
#   ➤ Pearson r: 0.4291 (p=2.31e-07)
#   ➤ RMSE: 0.9374
#
# 🧬 Drug 1071 | Samples: 134
#   ➤ Global R²: 0.0167
#   ➤ Pearson r: 0.1319 (p=1.29e-01)
#   ➤ RMSE: 0.9230
#
# 🧬 Drug 1072 | Samples: 135
#   ➤ Global R²: -0.0051
#   ➤ Pearson r: -0.0417 (p=6.31e-01)
#   ➤ RMSE: 0.8949
#
# 🧬 Drug 1073 | Samples: 138
#   ➤ Global R²: 0.3630
#   ➤ Pearson r: 0.6027 (p=5.26e-15)
#   ➤ RMSE: 1.3000
#
# 🧬 Drug 1079 | Samples: 138
#   ➤ Global R²: 0.3559
#   ➤ Pearson r: 0.5969 (p=1.10e-14)
#   ➤ RMSE: 1.6724
#
# 🧬 Drug 1080 | Samples: 138
#   ➤ Global R²: 0.2535
#   ➤ Pearson r: 0.5057 (p=2.50e-10)
#   ➤ RMSE: 1.5276
#
# 🧬 Drug 1083 | Samples: 138
#   ➤ Global R²: 0.2434
#   ➤ Pearson r: 0.4956 (p=6.38e-10)
#   ➤ RMSE: 1.3167
#
# 🧬 Drug 1084 | Samples: 137
#   ➤ Global R²: 0.2681
#   ➤ Pearson r: 0.5247 (p=4.64e-11)
#   ➤ RMSE: 1.2218
#
# 🧬 Drug 1085 | Samples: 138
#   ➤ Global R²: 0.0739
#   ➤ Pearson r: 0.2871 (p=6.40e-04)
#   ➤ RMSE: 0.9793
#
# 🧬 Drug 1086 | Samples: 138
#   ➤ Global R²: 0.3536
#   ➤ Pearson r: 0.5954 (p=1.34e-14)
#   ➤ RMSE: 1.8299
#
# 🧬 Drug 1088 | Samples: 138
#   ➤ Global R²: 0.1248
#   ➤ Pearson r: 0.3917 (p=2.03e-06)
#   ➤ RMSE: 1.6032
#
# 🧬 Drug 1089 | Samples: 138
#   ➤ Global R²: 0.3750
#   ➤ Pearson r: 0.6138 (p=1.20e-15)
#   ➤ RMSE: 1.2017
#
# 🧬 Drug 1091 | Samples: 134
#   ➤ Global R²: 0.0266
#   ➤ Pearson r: 0.1651 (p=5.65e-02)
#   ➤ RMSE: 1.1135
#
# 🧬 Drug 1093 | Samples: 138
#   ➤ Global R²: 0.0393
#   ➤ Pearson r: 0.2036 (p=1.66e-02)
#   ➤ RMSE: 0.9816
#
# 🧬 Drug 1114 | Samples: 121
#   ➤ Global R²: 0.0293
#   ➤ Pearson r: 0.2326 (p=1.03e-02)
#   ➤ RMSE: 1.1305
#
# 🧬 Drug 1128 | Samples: 135
#   ➤ Global R²: 0.0281
#   ➤ Pearson r: 0.1710 (p=4.73e-02)
#   ➤ RMSE: 1.2445
#
# 🧬 Drug 1129 | Samples: 134
#   ➤ Global R²: -0.0343
#   ➤ Pearson r: -0.0443 (p=6.11e-01)
#   ➤ RMSE: 0.8711
#
# 🧬 Drug 1131 | Samples: 133
#   ➤ Global R²: 0.0587
#   ➤ Pearson r: 0.2454 (p=4.41e-03)
#   ➤ RMSE: 1.5845
#
# 🧬 Drug 1133 | Samples: 135
#   ➤ Global R²: 0.0729
#   ➤ Pearson r: 0.2898 (p=6.50e-04)
#   ➤ RMSE: 0.9201
#
# 🧬 Drug 1135 | Samples: 133
#   ➤ Global R²: 0.1577
#   ➤ Pearson r: 0.4069 (p=1.17e-06)
#   ➤ RMSE: 1.1990
#
# 🧬 Drug 1136 | Samples: 134
#   ➤ Global R²: 0.1329
#   ➤ Pearson r: 0.3713 (p=1.00e-05)
#   ➤ RMSE: 1.6455
#
# 🧬 Drug 1149 | Samples: 135
#   ➤ Global R²: 0.0559
#   ➤ Pearson r: 0.3009 (p=3.92e-04)
#   ➤ RMSE: 1.1610
#
# 🧬 Drug 1168 | Samples: 138
#   ➤ Global R²: 0.0509
#   ➤ Pearson r: 0.2904 (p=5.50e-04)
#   ➤ RMSE: 1.3311
#
# 🧬 Drug 1170 | Samples: 135
#   ➤ Global R²: 0.1304
#   ➤ Pearson r: 0.3629 (p=1.52e-05)
#   ➤ RMSE: 0.9402
#
# 🧬 Drug 1175 | Samples: 135
#   ➤ Global R²: 0.0909
#   ➤ Pearson r: 0.3052 (p=3.18e-04)
#   ➤ RMSE: 0.9234
#
# 🧬 Drug 1177 | Samples: 133
#   ➤ Global R²: 0.2714
#   ➤ Pearson r: 0.5220 (p=1.17e-10)
#   ➤ RMSE: 1.0208
#
# 🧬 Drug 1179 | Samples: 138
#   ➤ Global R²: 0.2562
#   ➤ Pearson r: 0.5062 (p=2.39e-10)
#   ➤ RMSE: 1.1448
#
# 🧬 Drug 1180 | Samples: 132
#   ➤ Global R²: 0.2828
#   ➤ Pearson r: 0.5320 (p=5.23e-11)
#   ➤ RMSE: 1.2667
#
# 🧬 Drug 1183 | Samples: 135
#   ➤ Global R²: -0.0303
#   ➤ Pearson r: -0.1281 (p=1.39e-01)
#   ➤ RMSE: 1.2048
#
# 🧬 Drug 1184 | Samples: 135
#   ➤ Global R²: 0.1339
#   ➤ Pearson r: 0.3695 (p=1.03e-05)
#   ➤ RMSE: 0.9592
#
# 🧬 Drug 1185 | Samples: 134
#   ➤ Global R²: 0.0422
#   ➤ Pearson r: 0.2341 (p=6.47e-03)
#   ➤ RMSE: 0.9565
#
# 🧬 Drug 1186 | Samples: 135
#   ➤ Global R²: 0.2655
#   ➤ Pearson r: 0.5210 (p=9.30e-11)
#   ➤ RMSE: 1.2004
#
# 🧬 Drug 1187 | Samples: 135
#   ➤ Global R²: 0.1330
#   ➤ Pearson r: 0.3652 (p=1.33e-05)
#   ➤ RMSE: 1.0116
#
# 🧬 Drug 1188 | Samples: 135
#   ➤ Global R²: -0.0193
#   ➤ Pearson r: 0.0747 (p=3.89e-01)
#   ➤ RMSE: 1.0251
#
# 🧬 Drug 1190 | Samples: 138
#   ➤ Global R²: 0.1350
#   ➤ Pearson r: 0.3792 (p=4.50e-06)
#   ➤ RMSE: 2.7667
#
# 🧬 Drug 1191 | Samples: 138
#   ➤ Global R²: 0.1402
#   ➤ Pearson r: 0.3870 (p=2.74e-06)
#   ➤ RMSE: 1.1627
#
# 🧬 Drug 1192 | Samples: 134
#   ➤ Global R²: 0.0903
#   ➤ Pearson r: 0.3031 (p=3.71e-04)
#   ➤ RMSE: 1.2773
#
# 🧬 Drug 1194 | Samples: 134
#   ➤ Global R²: 0.0105
#   ➤ Pearson r: 0.1218 (p=1.61e-01)
#   ➤ RMSE: 0.8794
#
# 🧬 Drug 1195 | Samples: 134
#   ➤ Global R²: 0.0271
#   ➤ Pearson r: 0.1943 (p=2.44e-02)
#   ➤ RMSE: 0.9781
#
# 🧬 Drug 1196 | Samples: 133
#   ➤ Global R²: -0.0698
#   ➤ Pearson r: 0.1498 (p=8.52e-02)
#   ➤ RMSE: 1.1014
#
# 🧬 Drug 1197 | Samples: 133
#   ➤ Global R²: -0.0267
#   ➤ Pearson r: -0.0352 (p=6.87e-01)
#   ➤ RMSE: 1.0773
#
# 🧬 Drug 1198 | Samples: 134
#   ➤ Global R²: 0.0637
#   ➤ Pearson r: 0.2784 (p=1.13e-03)
#   ➤ RMSE: 0.8791
#
# 🧬 Drug 1199 | Samples: 134
#   ➤ Global R²: 0.0731
#   ➤ Pearson r: 0.2706 (p=1.56e-03)
#   ➤ RMSE: 0.8052
#
# 🧬 Drug 1200 | Samples: 138
#   ➤ Global R²: 0.1411
#   ➤ Pearson r: 0.3964 (p=1.49e-06)
#   ➤ RMSE: 0.7933
#
# 🧬 Drug 1218 | Samples: 130
#   ➤ Global R²: 0.0349
#   ➤ Pearson r: 0.2016 (p=2.14e-02)
#   ➤ RMSE: 0.6529
#
# 🧬 Drug 1219 | Samples: 134
#   ➤ Global R²: -0.0026
#   ➤ Pearson r: 0.0432 (p=6.21e-01)
#   ➤ RMSE: 0.9086
#
# 🧬 Drug 1230 | Samples: 134
#   ➤ Global R²: 0.0251
#   ➤ Pearson r: 0.1677 (p=5.27e-02)
#   ➤ RMSE: 0.8523
#
# 🧬 Drug 1232 | Samples: 130
#   ➤ Global R²: 0.0046
#   ➤ Pearson r: 0.0956 (p=2.79e-01)
#   ➤ RMSE: 1.0821
#
# 🧬 Drug 1236 | Samples: 134
#   ➤ Global R²: -0.0324
#   ➤ Pearson r: 0.0108 (p=9.01e-01)
#   ➤ RMSE: 1.4535
#
# 🧬 Drug 1237 | Samples: 138
#   ➤ Global R²: 0.1156
#   ➤ Pearson r: 0.3403 (p=4.44e-05)
#   ➤ RMSE: 0.7690
#
# 🧬 Drug 1239 | Samples: 115
#   ➤ Global R²: 0.1527
#   ➤ Pearson r: 0.3918 (p=1.49e-05)
#   ➤ RMSE: 1.0360
#
# 🧬 Drug 1241 | Samples: 130
#   ➤ Global R²: 0.0118
#   ➤ Pearson r: 0.1635 (p=6.31e-02)
#   ➤ RMSE: 1.0085
#
# 🧬 Drug 1242 | Samples: 130
#   ➤ Global R²: 0.2635
#   ➤ Pearson r: 0.5152 (p=3.56e-10)
#   ➤ RMSE: 1.2356
#
# 🧬 Drug 1243 | Samples: 134
#   ➤ Global R²: 0.0958
#   ➤ Pearson r: 0.3112 (p=2.52e-04)
#   ➤ RMSE: 0.9268
#
# 🧬 Drug 1248 | Samples: 127
#   ➤ Global R²: 0.1593
#   ➤ Pearson r: 0.4011 (p=2.96e-06)
#   ➤ RMSE: 2.3997
#
# 🧬 Drug 1249 | Samples: 133
#   ➤ Global R²: 0.2237
#   ➤ Pearson r: 0.4736 (p=8.51e-09)
#   ➤ RMSE: 1.0921
#
# 🧬 Drug 1250 | Samples: 133
#   ➤ Global R²: 0.1926
#   ➤ Pearson r: 0.4645 (p=1.78e-08)
#   ➤ RMSE: 1.3927
#
# 🧬 Drug 1251 | Samples: 134
#   ➤ Global R²: 0.0083
#   ➤ Pearson r: 0.1284 (p=1.39e-01)
#   ➤ RMSE: 0.9066
#
# 🧬 Drug 1252 | Samples: 133
#   ➤ Global R²: -0.0209
#   ➤ Pearson r: -0.0676 (p=4.40e-01)
#   ➤ RMSE: 0.7120
#
# 🧬 Drug 1253 | Samples: 130
#   ➤ Global R²: -0.0143
#   ➤ Pearson r: 0.0339 (p=7.02e-01)
#   ➤ RMSE: 0.6043
#
# 🧬 Drug 1254 | Samples: 130
#   ➤ Global R²: 0.0767
#   ➤ Pearson r: 0.2811 (p=1.20e-03)
#   ➤ RMSE: 1.3147
#
# 🧬 Drug 1259 | Samples: 130
#   ➤ Global R²: 0.2653
#   ➤ Pearson r: 0.5158 (p=3.39e-10)
#   ➤ RMSE: 1.5816
#
# 🧬 Drug 1261 | Samples: 130
#   ➤ Global R²: -0.0588
#   ➤ Pearson r: -0.0883 (p=3.18e-01)
#   ➤ RMSE: 1.3938
#
# 🧬 Drug 1262 | Samples: 126
#   ➤ Global R²: 0.1881
#   ➤ Pearson r: 0.4417 (p=2.24e-07)
#   ➤ RMSE: 0.4857
#
# 🧬 Drug 1263 | Samples: 125
#   ➤ Global R²: 0.0755
#   ➤ Pearson r: 0.2765 (p=1.80e-03)
#   ➤ RMSE: 0.5859
#
# 🧬 Drug 1264 | Samples: 126
#   ➤ Global R²: 0.0166
#   ➤ Pearson r: 0.1719 (p=5.43e-02)
#   ➤ RMSE: 0.5336
#
# 🧬 Drug 1266 | Samples: 129
#   ➤ Global R²: 0.1713
#   ➤ Pearson r: 0.4200 (p=7.23e-07)
#   ➤ RMSE: 1.4956
#
# 🧬 Drug 1268 | Samples: 130
#   ➤ Global R²: 0.0104
#   ➤ Pearson r: 0.1929 (p=2.79e-02)
#   ➤ RMSE: 0.9795
#
# 🧬 Drug 1359 | Samples: 122
#   ➤ Global R²: 0.0748
#   ➤ Pearson r: 0.2874 (p=1.33e-03)
#   ➤ RMSE: 0.9434
#
# 🧬 Drug 1360 | Samples: 122
#   ➤ Global R²: 0.0179
#   ➤ Pearson r: 0.2624 (p=3.50e-03)
#   ➤ RMSE: 0.7862
#
# 🧬 Drug 1362 | Samples: 122
#   ➤ Global R²: 0.1428
#   ➤ Pearson r: 0.3787 (p=1.70e-05)
#   ➤ RMSE: 0.6505
#
# 🧬 Drug 1363 | Samples: 122
#   ➤ Global R²: 0.0159
#   ➤ Pearson r: 0.1393 (p=1.26e-01)
#   ➤ RMSE: 1.3393
#
# 🧬 Drug 1364 | Samples: 122
#   ➤ Global R²: 0.1970
#   ➤ Pearson r: 0.4439 (p=3.04e-07)
#   ➤ RMSE: 1.0448
#
# 🧬 Drug 1365 | Samples: 122
#   ➤ Global R²: -0.1186
#   ➤ Pearson r: -0.0699 (p=4.44e-01)
#   ➤ RMSE: 1.1034
#
# 🧬 Drug 1367 | Samples: 122
#   ➤ Global R²: -0.0226
#   ➤ Pearson r: 0.1240 (p=1.74e-01)
#   ➤ RMSE: 1.0118
#
# 🧬 Drug 1368 | Samples: 122
#   ➤ Global R²: 0.1953
#   ➤ Pearson r: 0.4533 (p=1.58e-07)
#   ➤ RMSE: 1.3500
#
# 🧬 Drug 1369 | Samples: 106
#   ➤ Global R²: 0.2113
#   ➤ Pearson r: 0.4636 (p=5.60e-07)
#   ➤ RMSE: 1.2186
#
# 🧬 Drug 1370 | Samples: 107
#   ➤ Global R²: 0.1989
#   ➤ Pearson r: 0.4501 (p=1.15e-06)
#   ➤ RMSE: 1.2056
#
# 🧬 Drug 1371 | Samples: 133
#   ➤ Global R²: 0.2942
#   ➤ Pearson r: 0.5426 (p=1.51e-11)
#   ➤ RMSE: 1.1540
#
# 🧬 Drug 1372 | Samples: 125
#   ➤ Global R²: 0.2608
#   ➤ Pearson r: 0.5133 (p=9.34e-10)
#   ➤ RMSE: 2.1360
#
# 🧬 Drug 1373 | Samples: 119
#   ➤ Global R²: 0.2996
#   ➤ Pearson r: 0.5487 (p=1.04e-10)
#   ➤ RMSE: 1.7502
#
# 🧬 Drug 1375 | Samples: 126
#   ➤ Global R²: 0.0956
#   ➤ Pearson r: 0.3215 (p=2.41e-04)
#   ➤ RMSE: 0.5840
#
# 🧬 Drug 1377 | Samples: 129
#   ➤ Global R²: 0.1319
#   ➤ Pearson r: 0.3784 (p=9.78e-06)
#   ➤ RMSE: 1.4597
#
# 🧬 Drug 1378 | Samples: 135
#   ➤ Global R²: 0.3378
#   ➤ Pearson r: 0.5842 (p=1.03e-13)
#   ➤ RMSE: 1.6110
#
# 🧬 Drug 1379 | Samples: 134
#   ➤ Global R²: 0.2691
#   ➤ Pearson r: 0.5189 (p=1.34e-10)
#   ➤ RMSE: 0.7557
#
# 🧬 Drug 1382 | Samples: 135
#   ➤ Global R²: 0.0163
#   ➤ Pearson r: 0.1391 (p=1.08e-01)
#   ➤ RMSE: 0.8697
#
# 🧬 Drug 1386 | Samples: 135
#   ➤ Global R²: 0.2699
#   ➤ Pearson r: 0.5197 (p=1.05e-10)
#   ➤ RMSE: 1.1223
#
# 🧬 Drug 1392 | Samples: 134
#   ➤ Global R²: 0.3309
#   ➤ Pearson r: 0.5753 (p=3.59e-13)
#   ➤ RMSE: 1.4524
#
# 🧬 Drug 1393 | Samples: 135
#   ➤ Global R²: 0.1306
#   ➤ Pearson r: 0.3730 (p=8.40e-06)
#   ➤ RMSE: 1.3681
#
# 🧬 Drug 1394 | Samples: 135
#   ➤ Global R²: 0.1012
#   ➤ Pearson r: 0.3355 (p=6.95e-05)
#   ➤ RMSE: 1.1420
#
# 🧬 Drug 1401 | Samples: 132
#   ➤ Global R²: 0.2247
#   ➤ Pearson r: 0.4810 (p=5.29e-09)
#   ➤ RMSE: 0.7558
#
# 🧬 Drug 1402 | Samples: 133
#   ➤ Global R²: 0.1449
#   ➤ Pearson r: 0.3811 (p=6.03e-06)
#   ➤ RMSE: 1.2047
#
# 🧬 Drug 1403 | Samples: 135
#   ➤ Global R²: -0.0207
#   ➤ Pearson r: -0.0360 (p=6.78e-01)
#   ➤ RMSE: 1.2990
#
# 🧬 Drug 1407 | Samples: 133
#   ➤ Global R²: 0.0316
#   ➤ Pearson r: 0.1785 (p=3.98e-02)
#   ➤ RMSE: 0.8905
#
# 🧬 Drug 1409 | Samples: 133
#   ➤ Global R²: 0.0718
#   ➤ Pearson r: 0.2746 (p=1.38e-03)
#   ➤ RMSE: 1.5087
#
# 🧬 Drug 1413 | Samples: 133
#   ➤ Global R²: 0.1596
#   ➤ Pearson r: 0.4029 (p=1.52e-06)
#   ➤ RMSE: 1.1123
#
# 🧬 Drug 1414 | Samples: 132
#   ➤ Global R²: -0.0003
#   ➤ Pearson r: 0.1770 (p=4.23e-02)
#   ➤ RMSE: 0.8735
#
# 🧬 Drug 1416 | Samples: 132
#   ➤ Global R²: 0.0945
#   ➤ Pearson r: 0.3226 (p=1.62e-04)
#   ➤ RMSE: 1.2416
#
# 🧬 Drug 1419 | Samples: 132
#   ➤ Global R²: 0.1986
#   ➤ Pearson r: 0.4461 (p=8.30e-08)
#   ➤ RMSE: 0.9654
#
# 🧬 Drug 1421 | Samples: 133
#   ➤ Global R²: 0.0597
#   ➤ Pearson r: 0.2642 (p=2.12e-03)
#   ➤ RMSE: 0.9292
#
# 🧬 Drug 1422 | Samples: 132
#   ➤ Global R²: 0.0530
#   ➤ Pearson r: 0.2795 (p=1.17e-03)
#   ➤ RMSE: 1.2632
#
# 🧬 Drug 1425 | Samples: 132
#   ➤ Global R²: 0.0464
#   ➤ Pearson r: 0.2180 (p=1.20e-02)
#   ➤ RMSE: 1.2251
#
# 🧬 Drug 1426 | Samples: 132
#   ➤ Global R²: 0.2545
#   ➤ Pearson r: 0.5098 (p=4.29e-10)
#   ➤ RMSE: 1.0308
#
# 🧬 Drug 1427 | Samples: 134
#   ➤ Global R²: -0.0338
#   ➤ Pearson r: 0.0009 (p=9.92e-01)
#   ➤ RMSE: 2.2448
#
# 🧬 Drug 1428 | Samples: 135
#   ➤ Global R²: -0.0154
#   ➤ Pearson r: 0.0529 (p=5.42e-01)
#   ➤ RMSE: 1.9306
#
# 🧬 Drug 1429 | Samples: 133
#   ➤ Global R²: -0.0356
#   ➤ Pearson r: 0.0243 (p=7.81e-01)
#   ➤ RMSE: 1.6570
#
# 🧬 Drug 1430 | Samples: 133
#   ➤ Global R²: 0.2639
#   ➤ Pearson r: 0.5141 (p=2.47e-10)
#   ➤ RMSE: 1.2656
#
# 🧬 Drug 1432 | Samples: 135
#   ➤ Global R²: 0.0454
#   ➤ Pearson r: 0.2454 (p=4.11e-03)
#   ➤ RMSE: 1.1141
#
# 🧬 Drug 1433 | Samples: 135
#   ➤ Global R²: -0.0011
#   ➤ Pearson r: 0.1864 (p=3.04e-02)
#   ➤ RMSE: 0.8036
#
# 🧬 Drug 1434 | Samples: 133
#   ➤ Global R²: -0.0333
#   ➤ Pearson r: -0.0498 (p=5.69e-01)
#   ➤ RMSE: 1.1181
#
# 🧬 Drug 1436 | Samples: 131
#   ➤ Global R²: -0.0154
#   ➤ Pearson r: -0.0157 (p=8.59e-01)
#   ➤ RMSE: 0.9726
#
# 🧬 Drug 1437 | Samples: 133
#   ➤ Global R²: -0.0330
#   ➤ Pearson r: -0.0053 (p=9.52e-01)
#   ➤ RMSE: 0.8763
#
# 🧬 Drug 1441 | Samples: 133
#   ➤ Global R²: 0.1030
#   ➤ Pearson r: 0.3219 (p=1.58e-04)
#   ➤ RMSE: 1.1020
#
# 🧬 Drug 1444 | Samples: 132
#   ➤ Global R²: -0.0122
#   ➤ Pearson r: 0.0921 (p=2.94e-01)
#   ➤ RMSE: 1.2861
#
# 🧬 Drug 1445 | Samples: 131
#   ➤ Global R²: 0.0186
#   ➤ Pearson r: 0.1476 (p=9.26e-02)
#   ➤ RMSE: 1.0782
#
# 🧬 Drug 1446 | Samples: 130
#   ➤ Global R²: -0.0402
#   ➤ Pearson r: -0.0481 (p=5.87e-01)
#   ➤ RMSE: 1.1816
#
# 🧬 Drug 1449 | Samples: 135
#   ➤ Global R²: 0.0501
#   ➤ Pearson r: 0.2253 (p=8.61e-03)
#   ➤ RMSE: 0.8177
#
# 🧬 Drug 1451 | Samples: 130
#   ➤ Global R²: 0.1084
#   ➤ Pearson r: 0.3540 (p=3.60e-05)
#   ➤ RMSE: 1.6797
#
# 🧬 Drug 1453 | Samples: 133
#   ➤ Global R²: 0.3176
#   ➤ Pearson r: 0.5637 (p=1.61e-12)
#   ➤ RMSE: 1.0284
#
# 🧬 Drug 1458 | Samples: 134
#   ➤ Global R²: 0.2397
#   ➤ Pearson r: 0.4954 (p=1.16e-09)
#   ➤ RMSE: 1.1254
#
# 🧬 Drug 1459 | Samples: 135
#   ➤ Global R²: 0.2678
#   ➤ Pearson r: 0.5276 (p=4.88e-11)
#   ➤ RMSE: 1.6310
#
# 🧬 Drug 1460 | Samples: 134
#   ➤ Global R²: 0.3128
#   ➤ Pearson r: 0.5628 (p=1.47e-12)
#   ➤ RMSE: 1.7617
#
# 🧬 Drug 1461 | Samples: 133
#   ➤ Global R²: 0.0402
#   ➤ Pearson r: 0.2474 (p=4.10e-03)
#   ➤ RMSE: 1.1376
#
# 🧬 Drug 1463 | Samples: 133
#   ➤ Global R²: 0.0204
#   ➤ Pearson r: 0.1741 (p=4.51e-02)
#   ➤ RMSE: 0.9813
#
# 🧬 Drug 1464 | Samples: 133
#   ➤ Global R²: 0.1207
#   ➤ Pearson r: 0.3479 (p=4.06e-05)
#   ➤ RMSE: 0.7974
#
# 🧬 Drug 1490 | Samples: 132
#   ➤ Global R²: 0.0695
#   ➤ Pearson r: 0.2655 (p=2.09e-03)
#   ➤ RMSE: 1.7241
#
# 🧬 Drug 1494 | Samples: 135
#   ➤ Global R²: 0.1001
#   ➤ Pearson r: 0.3226 (p=1.36e-04)
#   ➤ RMSE: 1.4807
#
# 🧬 Drug 1495 | Samples: 126
#   ➤ Global R²: 0.1365
#   ➤ Pearson r: 0.3733 (p=1.67e-05)
#   ➤ RMSE: 0.9557
#
# 🧬 Drug 1496 | Samples: 134
#   ➤ Global R²: 0.1679
#   ➤ Pearson r: 0.4099 (p=8.73e-07)
#   ➤ RMSE: 1.1386
#
# 🧬 Drug 1497 | Samples: 128
#   ➤ Global R²: -0.0268
#   ➤ Pearson r: 0.1159 (p=1.93e-01)
#   ➤ RMSE: 1.1470
#
# 🧬 Drug 1498 | Samples: 131
#   ➤ Global R²: 0.2900
#   ➤ Pearson r: 0.5390 (p=3.12e-11)
#   ➤ RMSE: 1.4415
#
# 🧬 Drug 1502 | Samples: 122
#   ➤ Global R²: -0.0271
#   ➤ Pearson r: 0.0771 (p=3.99e-01)
#   ➤ RMSE: 0.6438
#
# 🧬 Drug 1507 | Samples: 134
#   ➤ Global R²: 0.0247
#   ➤ Pearson r: 0.3390 (p=6.16e-05)
#   ➤ RMSE: 0.8895
#
# 🧬 Drug 1510 | Samples: 138
#   ➤ Global R²: 0.1546
#   ➤ Pearson r: 0.3935 (p=1.80e-06)
#   ➤ RMSE: 1.0520
#
# 🧬 Drug 1511 | Samples: 138
#   ➤ Global R²: 0.3064
#   ➤ Pearson r: 0.5633 (p=6.35e-13)
#   ➤ RMSE: 1.2184
#
# 🧬 Drug 1512 | Samples: 138
#   ➤ Global R²: 0.0565
#   ➤ Pearson r: 0.2500 (p=3.11e-03)
#   ➤ RMSE: 0.7776
#
# 🧬 Drug 1526 | Samples: 126
#   ➤ Global R²: 0.3469
#   ➤ Pearson r: 0.5925 (p=2.71e-13)
#   ➤ RMSE: 1.3382
#
# 🧬 Drug 1527 | Samples: 126
#   ➤ Global R²: -0.0143
#   ➤ Pearson r: -0.2475 (p=5.20e-03)
#   ➤ RMSE: 1.1719
#
# 🧬 Drug 1529 | Samples: 100
#   ➤ Global R²: 0.0330
#   ➤ Pearson r: 0.1886 (p=6.02e-02)
#   ➤ RMSE: 1.4298
#
# 🧬 Drug 1530 | Samples: 126
#   ➤ Global R²: 0.0416
#   ➤ Pearson r: 0.2076 (p=1.97e-02)
#   ➤ RMSE: 0.5539
#
# 🧬 Drug 1531 | Samples: 125
#   ➤ Global R²: 0.0035
#   ➤ Pearson r: 0.0786 (p=3.83e-01)
#   ➤ RMSE: 0.5859
#
# 🧬 Drug 1549 | Samples: 138
#   ➤ Global R²: 0.2496
#   ➤ Pearson r: 0.5079 (p=2.04e-10)
#   ➤ RMSE: 1.5338
#
# 🧬 Drug 1553 | Samples: 133
#   ➤ Global R²: 0.0399
#   ➤ Pearson r: 0.2150 (p=1.29e-02)
#   ➤ RMSE: 1.5998
#
# 🧬 Drug 1557 | Samples: 133
#   ➤ Global R²: 0.0271
#   ➤ Pearson r: 0.1664 (p=5.55e-02)
#   ➤ RMSE: 1.2766
#
# 🧬 Drug 1558 | Samples: 138
#   ➤ Global R²: 0.0136
#   ➤ Pearson r: 0.2526 (p=2.80e-03)
#   ➤ RMSE: 1.6003
#
# 🧬 Drug 1559 | Samples: 138
#   ➤ Global R²: 0.2181
#   ➤ Pearson r: 0.4670 (p=7.75e-09)
#   ➤ RMSE: 1.6577
#
# 🧬 Drug 1560 | Samples: 138
#   ➤ Global R²: 0.0863
#   ➤ Pearson r: 0.3035 (p=2.96e-04)
#   ➤ RMSE: 1.2944
#
# 🧬 Drug 1561 | Samples: 138
#   ➤ Global R²: 0.1604
#   ➤ Pearson r: 0.4102 (p=5.85e-07)
#   ➤ RMSE: 1.4546
#
# 🧬 Drug 1563 | Samples: 137
#   ➤ Global R²: 0.1998
#   ➤ Pearson r: 0.4475 (p=4.19e-08)
#   ➤ RMSE: 0.7337
#
# 🧬 Drug 1564 | Samples: 138
#   ➤ Global R²: 0.3199
#   ➤ Pearson r: 0.5689 (p=3.36e-13)
#   ➤ RMSE: 1.4504
#
# 🧬 Drug 1576 | Samples: 133
#   ➤ Global R²: -0.0240
#   ➤ Pearson r: 0.1186 (p=1.74e-01)
#   ➤ RMSE: 0.7406
#
# 🧬 Drug 1578 | Samples: 133
#   ➤ Global R²: 0.0173
#   ➤ Pearson r: 0.1640 (p=5.93e-02)
#   ➤ RMSE: 0.8108
#
# 🧬 Drug 1580 | Samples: 115
#   ➤ Global R²: -0.0310
#   ➤ Pearson r: 0.0637 (p=4.99e-01)
#   ➤ RMSE: 0.7660
#
# 🧬 Drug 1581 | Samples: 115
#   ➤ Global R²: -0.0109
#   ➤ Pearson r: 0.0727 (p=4.40e-01)
#   ➤ RMSE: 1.0366
#
# 🧬 Drug 1582 | Samples: 115
#   ➤ Global R²: -0.0864
#   ➤ Pearson r: -0.0806 (p=3.92e-01)
#   ➤ RMSE: 0.7886
#
# 🧬 Drug 1583 | Samples: 115
#   ➤ Global R²: 0.0068
#   ➤ Pearson r: 0.1455 (p=1.21e-01)
#   ➤ RMSE: 0.7108
#
# 🧬 Drug 1584 | Samples: 115
#   ➤ Global R²: 0.1358
#   ➤ Pearson r: 0.3729 (p=4.05e-05)
#   ➤ RMSE: 0.8313
#
# 🧬 Drug 1585 | Samples: 115
#   ➤ Global R²: -0.0091
#   ➤ Pearson r: 0.0426 (p=6.51e-01)
#   ➤ RMSE: 0.7184
#
# 🧬 Drug 1586 | Samples: 115
#   ➤ Global R²: 0.0023
#   ➤ Pearson r: 0.1035 (p=2.71e-01)
#   ➤ RMSE: 0.7626
#
# 🧬 Drug 1593 | Samples: 132
#   ➤ Global R²: 0.0640
#   ➤ Pearson r: 0.2579 (p=2.83e-03)
#   ➤ RMSE: 1.3727
#
# 🧬 Drug 1594 | Samples: 137
#   ➤ Global R²: -0.0093
#   ➤ Pearson r: 0.0743 (p=3.88e-01)
#   ➤ RMSE: 1.3477
#
# 🧬 Drug 1598 | Samples: 138
#   ➤ Global R²: 0.1062
#   ➤ Pearson r: 0.3302 (p=7.64e-05)
#   ➤ RMSE: 1.0015
#
# 🧬 Drug 1613 | Samples: 132
#   ➤ Global R²: 0.1158
#   ➤ Pearson r: 0.3428 (p=5.73e-05)
#   ➤ RMSE: 1.4249
#
# 🧬 Drug 1614 | Samples: 132
#   ➤ Global R²: 0.0209
#   ➤ Pearson r: 0.1497 (p=8.66e-02)
#   ➤ RMSE: 1.2172
#
# 🧬 Drug 1615 | Samples: 132
#   ➤ Global R²: 0.0084
#   ➤ Pearson r: 0.1232 (p=1.59e-01)
#   ➤ RMSE: 0.7789
#
# 🧬 Drug 1617 | Samples: 131
#   ➤ Global R²: 0.0234
#   ➤ Pearson r: 0.2001 (p=2.19e-02)
#   ➤ RMSE: 2.3717
#
# 🧬 Drug 1618 | Samples: 132
#   ➤ Global R²: 0.0320
#   ➤ Pearson r: 0.2068 (p=1.73e-02)
#   ➤ RMSE: 1.1028
#
# 🧬 Drug 1620 | Samples: 132
#   ➤ Global R²: 0.0220
#   ➤ Pearson r: 0.1888 (p=3.01e-02)
#   ➤ RMSE: 0.6813
#
# 🧬 Drug 1621 | Samples: 132
#   ➤ Global R²: 0.2063
#   ➤ Pearson r: 0.4569 (p=3.65e-08)
#   ➤ RMSE: 0.9070
#
# 🧬 Drug 1622 | Samples: 132
#   ➤ Global R²: 0.0366
#   ➤ Pearson r: 0.2763 (p=1.34e-03)
#   ➤ RMSE: 0.9282
#
# 🧬 Drug 1624 | Samples: 132
#   ➤ Global R²: 0.0149
#   ➤ Pearson r: 0.1781 (p=4.11e-02)
#   ➤ RMSE: 1.3413
#
# 🧬 Drug 1625 | Samples: 132
#   ➤ Global R²: -0.0048
#   ➤ Pearson r: 0.0647 (p=4.61e-01)
#   ➤ RMSE: 0.8947
#
# 🧬 Drug 1626 | Samples: 132
#   ➤ Global R²: 0.1081
#   ➤ Pearson r: 0.3342 (p=9.01e-05)
#   ➤ RMSE: 1.5375
#
# 🧬 Drug 1627 | Samples: 132
#   ➤ Global R²: 0.0864
#   ➤ Pearson r: 0.2976 (p=5.29e-04)
#   ➤ RMSE: 0.7191
#
# 🧬 Drug 1629 | Samples: 132
#   ➤ Global R²: 0.2296
#   ➤ Pearson r: 0.4813 (p=5.16e-09)
#   ➤ RMSE: 0.8370
#
# 🧬 Drug 1630 | Samples: 132
#   ➤ Global R²: 0.0563
#   ➤ Pearson r: 0.2377 (p=6.07e-03)
#   ➤ RMSE: 1.0335
#
# 🧬 Drug 1631 | Samples: 132
#   ➤ Global R²: 0.1575
#   ➤ Pearson r: 0.3977 (p=2.34e-06)
#   ➤ RMSE: 1.1725
#
# 🧬 Drug 1632 | Samples: 137
#   ➤ Global R²: 0.2491
#   ➤ Pearson r: 0.5046 (p=3.24e-10)
#   ➤ RMSE: 0.8184
#
# 🧬 Drug 1634 | Samples: 132
#   ➤ Global R²: 0.0581
#   ➤ Pearson r: 0.2772 (p=1.29e-03)
#   ➤ RMSE: 0.8962
#
# 🧬 Drug 1635 | Samples: 132
#   ➤ Global R²: 0.1259
#   ➤ Pearson r: 0.3554 (p=2.90e-05)
#   ➤ RMSE: 0.5998
#
# 🧬 Drug 1706 | Samples: 116
#   ➤ Global R²: 0.1432
#   ➤ Pearson r: 0.3785 (p=2.80e-05)
#   ➤ RMSE: 1.3802
#
# 🧬 Drug 1708 | Samples: 116
#   ➤ Global R²: 0.3323
#   ➤ Pearson r: 0.5891 (p=3.52e-12)
#   ➤ RMSE: 1.1110
#
# 🧬 Drug 1709 | Samples: 116
#   ➤ Global R²: 0.3031
#   ➤ Pearson r: 0.5540 (p=1.11e-10)
#   ➤ RMSE: 1.3917
#
# 🧬 Drug 1712 | Samples: 115
#   ➤ Global R²: 0.2269
#   ➤ Pearson r: 0.4818 (p=4.99e-08)
#   ➤ RMSE: 1.5731
#
# 🧬 Drug 1713 | Samples: 116
#   ➤ Global R²: 0.1031
#   ➤ Pearson r: 0.3405 (p=1.84e-04)
#   ➤ RMSE: 1.4957
#
# 🧬 Drug 1714 | Samples: 116
#   ➤ Global R²: 0.1637
#   ➤ Pearson r: 0.4100 (p=4.87e-06)
#   ➤ RMSE: 1.4623
#
# 🧬 Drug 1716 | Samples: 116
#   ➤ Global R²: 0.0050
#   ➤ Pearson r: 0.0760 (p=4.18e-01)
#   ➤ RMSE: 0.8486
#
# 🧬 Drug 1718 | Samples: 116
#   ➤ Global R²: 0.1879
#   ➤ Pearson r: 0.4414 (p=7.06e-07)
#   ➤ RMSE: 0.8891
#
# 🧬 Drug 1720 | Samples: 115
#   ➤ Global R²: 0.1948
#   ➤ Pearson r: 0.4440 (p=6.69e-07)
#   ➤ RMSE: 1.7597
#
# 🧬 Drug 1730 | Samples: 115
#   ➤ Global R²: 0.0495
#   ➤ Pearson r: 0.2603 (p=4.96e-03)
#   ➤ RMSE: 0.7231
#
# 🧬 Drug 1732 | Samples: 116
#   ➤ Global R²: 0.0482
#   ➤ Pearson r: 0.2199 (p=1.77e-02)
#   ➤ RMSE: 1.5511
#
# 🧬 Drug 1733 | Samples: 116
#   ➤ Global R²: 0.0838
#   ➤ Pearson r: 0.2900 (p=1.59e-03)
#   ➤ RMSE: 1.5547
#
# 🧬 Drug 1734 | Samples: 116
#   ➤ Global R²: -0.0396
#   ➤ Pearson r: 0.1226 (p=1.90e-01)
#   ➤ RMSE: 0.9354
#
# 🧬 Drug 1736 | Samples: 116
#   ➤ Global R²: 0.2395
#   ➤ Pearson r: 0.4895 (p=2.46e-08)
#   ➤ RMSE: 1.6764
#
# 🧬 Drug 1738 | Samples: 116
#   ➤ Global R²: 0.2722
#   ➤ Pearson r: 0.5257 (p=1.37e-09)
#   ➤ RMSE: 1.3982
#
# 🧬 Drug 1739 | Samples: 116
#   ➤ Global R²: 0.2192
#   ➤ Pearson r: 0.4757 (p=6.81e-08)
#   ➤ RMSE: 1.3864
#
# 🧬 Drug 1776 | Samples: 115
#   ➤ Global R²: 0.0670
#   ➤ Pearson r: 0.2692 (p=3.63e-03)
#   ➤ RMSE: 0.7492
#
# 🧬 Drug 1777 | Samples: 115
#   ➤ Global R²: -0.0331
#   ➤ Pearson r: 0.0447 (p=6.35e-01)
#   ➤ RMSE: 1.0397
#
# 🧬 Drug 1778 | Samples: 115
#   ➤ Global R²: 0.0169
#   ➤ Pearson r: 0.1499 (p=1.10e-01)
#   ➤ RMSE: 1.5095
#
# 🧬 Drug 1779 | Samples: 115
#   ➤ Global R²: 0.1859
#   ➤ Pearson r: 0.4333 (p=1.32e-06)
#   ➤ RMSE: 0.5973
#
# 🧬 Drug 1780 | Samples: 115
#   ➤ Global R²: 0.0402
#   ➤ Pearson r: 0.2007 (p=3.15e-02)
#   ➤ RMSE: 0.8539
#
# 🧬 Drug 1782 | Samples: 115
#   ➤ Global R²: 0.0719
#   ➤ Pearson r: 0.2696 (p=3.57e-03)
#   ➤ RMSE: 0.7884
#
# 🧬 Drug 1783 | Samples: 115
#   ➤ Global R²: 0.1848
#   ➤ Pearson r: 0.4301 (p=1.61e-06)
#   ➤ RMSE: 0.6768
#
# 🧬 Drug 1784 | Samples: 115
#   ➤ Global R²: 0.0942
#   ➤ Pearson r: 0.3073 (p=8.35e-04)
#   ➤ RMSE: 0.6768
#
# 🧬 Drug 1785 | Samples: 115
#   ➤ Global R²: 0.0478
#   ➤ Pearson r: 0.2197 (p=1.83e-02)
#   ➤ RMSE: 0.8204
#
# 🧬 Drug 1786 | Samples: 138
#   ➤ Global R²: 0.1304
#   ➤ Pearson r: 0.3847 (p=3.19e-06)
#   ➤ RMSE: 1.3884
#
# 🧬 Drug 1799 | Samples: 130
#   ➤ Global R²: 0.1326
#   ➤ Pearson r: 0.3881 (p=5.04e-06)
#   ➤ RMSE: 1.5669
#
# 🧬 Drug 1802 | Samples: 115
#   ➤ Global R²: 0.1662
#   ➤ Pearson r: 0.4106 (p=5.16e-06)
#   ➤ RMSE: 0.7470
#
# 🧬 Drug 1803 | Samples: 115
#   ➤ Global R²: 0.2288
#   ➤ Pearson r: 0.5129 (p=4.63e-09)
#   ➤ RMSE: 1.8121
#
# 🧬 Drug 1804 | Samples: 115
#   ➤ Global R²: 0.2299
#   ➤ Pearson r: 0.5045 (p=8.96e-09)
#   ➤ RMSE: 2.2016
#
# 🧬 Drug 1806 | Samples: 115
#   ➤ Global R²: 0.3142
#   ➤ Pearson r: 0.5617 (p=6.54e-11)
#   ➤ RMSE: 1.1286
#
# 🧬 Drug 1808 | Samples: 115
#   ➤ Global R²: 0.1088
#   ➤ Pearson r: 0.3336 (p=2.69e-04)
#   ➤ RMSE: 1.6572
#
# 🧬 Drug 1809 | Samples: 115
#   ➤ Global R²: 0.1394
#   ➤ Pearson r: 0.3794 (p=2.90e-05)
#   ➤ RMSE: 1.6956
#
# 🧬 Drug 1810 | Samples: 115
#   ➤ Global R²: 0.2263
#   ➤ Pearson r: 0.4799 (p=5.75e-08)
#   ➤ RMSE: 1.6942
#
# 🧬 Drug 1811 | Samples: 115
#   ➤ Global R²: 0.1783
#   ➤ Pearson r: 0.4276 (p=1.87e-06)
#   ➤ RMSE: 1.0284
#
# 🧬 Drug 1812 | Samples: 115
#   ➤ Global R²: 0.0569
#   ➤ Pearson r: 0.2553 (p=5.90e-03)
#   ➤ RMSE: 1.2715
#
# 🧬 Drug 1813 | Samples: 115
#   ➤ Global R²: 0.0040
#   ➤ Pearson r: 0.1142 (p=2.24e-01)
#   ➤ RMSE: 1.6311
#
# 🧬 Drug 1814 | Samples: 115
#   ➤ Global R²: 0.1738
#   ➤ Pearson r: 0.4179 (p=3.37e-06)
#   ➤ RMSE: 0.6307
#
# 🧬 Drug 1815 | Samples: 115
#   ➤ Global R²: 0.1170
#   ➤ Pearson r: 0.3591 (p=8.10e-05)
#   ➤ RMSE: 0.8741
#
# 🧬 Drug 1816 | Samples: 115
#   ➤ Global R²: 0.2617
#   ➤ Pearson r: 0.5120 (p=4.97e-09)
#   ➤ RMSE: 0.9199
#
# 🧬 Drug 1817 | Samples: 115
#   ➤ Global R²: -0.0292
#   ➤ Pearson r: 0.0370 (p=6.95e-01)
#   ➤ RMSE: 1.0986
#
# 🧬 Drug 1819 | Samples: 109
#   ➤ Global R²: 0.1604
#   ➤ Pearson r: 0.4303 (p=3.01e-06)
#   ➤ RMSE: 2.6236
#
# 🧬 Drug 1820 | Samples: 115
#   ➤ Global R²: 0.0526
#   ➤ Pearson r: 0.2525 (p=6.48e-03)
#   ➤ RMSE: 1.5345
#
# 🧬 Drug 1821 | Samples: 115
#   ➤ Global R²: -0.0058
#   ➤ Pearson r: 0.0448 (p=6.35e-01)
#   ➤ RMSE: 0.9592
#
# 🧬 Drug 1824 | Samples: 115
#   ➤ Global R²: 0.0152
#   ➤ Pearson r: 0.1565 (p=9.50e-02)
#   ➤ RMSE: 0.7834
#
# 🧬 Drug 1825 | Samples: 115
#   ➤ Global R²: 0.2220
#   ➤ Pearson r: 0.4767 (p=7.20e-08)
#   ➤ RMSE: 1.3462
#
# 🧬 Drug 1826 | Samples: 115
#   ➤ Global R²: 0.1787
#   ➤ Pearson r: 0.4307 (p=1.55e-06)
#   ➤ RMSE: 1.1182
#
# 🧬 Drug 1827 | Samples: 115
#   ➤ Global R²: 0.0964
#   ➤ Pearson r: 0.3134 (p=6.48e-04)
#   ➤ RMSE: 1.6168
#
# 🧬 Drug 1828 | Samples: 115
#   ➤ Global R²: 0.1081
#   ➤ Pearson r: 0.3327 (p=2.80e-04)
#   ➤ RMSE: 0.8170
#
# 🧬 Drug 1829 | Samples: 115
#   ➤ Global R²: 0.1189
#   ➤ Pearson r: 0.3464 (p=1.49e-04)
#   ➤ RMSE: 1.3306
#
# 🧬 Drug 1830 | Samples: 115
#   ➤ Global R²: 0.1847
#   ➤ Pearson r: 0.4312 (p=1.51e-06)
#   ➤ RMSE: 0.7564
#
# 🧬 Drug 1831 | Samples: 115
#   ➤ Global R²: 0.1562
#   ➤ Pearson r: 0.3973 (p=1.10e-05)
#   ➤ RMSE: 0.6811
#
# 🧬 Drug 1832 | Samples: 115
#   ➤ Global R²: -0.0166
#   ➤ Pearson r: -0.0494 (p=6.00e-01)
#   ➤ RMSE: 0.8403
#
# 🧬 Drug 1833 | Samples: 115
#   ➤ Global R²: -0.0428
#   ➤ Pearson r: -0.0178 (p=8.50e-01)
#   ➤ RMSE: 1.4095
#
# 🧬 Drug 1834 | Samples: 115
#   ➤ Global R²: -0.0222
#   ➤ Pearson r: 0.0331 (p=7.25e-01)
#   ➤ RMSE: 1.4399
#
# 🧬 Drug 1835 | Samples: 115
#   ➤ Global R²: 0.0237
#   ➤ Pearson r: 0.2140 (p=2.16e-02)
#   ➤ RMSE: 1.3265
#
# 🧬 Drug 1836 | Samples: 115
#   ➤ Global R²: 0.1005
#   ➤ Pearson r: 0.3409 (p=1.93e-04)
#   ➤ RMSE: 1.0918
#
# 🧬 Drug 1838 | Samples: 115
#   ➤ Global R²: -0.0444
#   ➤ Pearson r: -0.0244 (p=7.96e-01)
#   ➤ RMSE: 0.8962
#
# 🧬 Drug 1839 | Samples: 115
#   ➤ Global R²: 0.0715
#   ➤ Pearson r: 0.2678 (p=3.81e-03)
#   ➤ RMSE: 0.7254
#
# 🧬 Drug 1840 | Samples: 115
#   ➤ Global R²: 0.2334
#   ➤ Pearson r: 0.4851 (p=3.92e-08)
#   ➤ RMSE: 1.1963
#
# 🧬 Drug 1843 | Samples: 115
#   ➤ Global R²: 0.1165
#   ➤ Pearson r: 0.3423 (p=1.81e-04)
#   ➤ RMSE: 2.0839
#
# 🧬 Drug 1844 | Samples: 115
#   ➤ Global R²: 0.0499
#   ➤ Pearson r: 0.2242 (p=1.60e-02)
#   ➤ RMSE: 1.4800
#
# 🧬 Drug 1845 | Samples: 115
#   ➤ Global R²: 0.1891
#   ➤ Pearson r: 0.4430 (p=7.13e-07)
#   ➤ RMSE: 1.6842
#
# 🧬 Drug 1847 | Samples: 115
#   ➤ Global R²: 0.0970
#   ➤ Pearson r: 0.3180 (p=5.34e-04)
#   ➤ RMSE: 1.9596
#
# 🧬 Drug 1849 | Samples: 132
#   ➤ Global R²: 0.1826
#   ➤ Pearson r: 0.4360 (p=1.73e-07)
#   ➤ RMSE: 1.0282
#
# 🧬 Drug 1852 | Samples: 132
#   ➤ Global R²: 0.0299
#   ➤ Pearson r: 0.1742 (p=4.57e-02)
#   ➤ RMSE: 0.9244
#
# 🧬 Drug 1853 | Samples: 132
#   ➤ Global R²: -0.0492
#   ➤ Pearson r: 0.0185 (p=8.33e-01)
#   ➤ RMSE: 1.2313
#
# 🧬 Drug 1854 | Samples: 132
#   ➤ Global R²: 0.1499
#   ➤ Pearson r: 0.3886 (p=4.12e-06)
#   ➤ RMSE: 0.8900
#
# 🧬 Drug 1855 | Samples: 132
#   ➤ Global R²: 0.1007
#   ➤ Pearson r: 0.3193 (p=1.90e-04)
#   ➤ RMSE: 1.3714
#
# 🧬 Drug 1862 | Samples: 138
#   ➤ Global R²: 0.1053
#   ➤ Pearson r: 0.3311 (p=7.30e-05)
#   ➤ RMSE: 0.7169
#
# 🧬 Drug 1866 | Samples: 114
#   ➤ Global R²: -0.0805
#   ➤ Pearson r: 0.0240 (p=8.00e-01)
#   ➤ RMSE: 1.2141
#
# 🧬 Drug 1873 | Samples: 138
#   ➤ Global R²: 0.1463
#   ➤ Pearson r: 0.3861 (p=2.91e-06)
#   ➤ RMSE: 0.9556
#
# 🧬 Drug 1908 | Samples: 138
#   ➤ Global R²: 0.2782
#   ➤ Pearson r: 0.5284 (p=2.73e-11)
#   ➤ RMSE: 1.1664
#
# 🧬 Drug 1909 | Samples: 138
#   ➤ Global R²: 0.0761
#   ➤ Pearson r: 0.3045 (p=2.82e-04)
#   ➤ RMSE: 1.1361
#
# 🧬 Drug 1910 | Samples: 138
#   ➤ Global R²: -0.0569
#   ➤ Pearson r: -0.2180 (p=1.02e-02)
#   ➤ RMSE: 1.4882
#
# 🧬 Drug 1911 | Samples: 138
#   ➤ Global R²: 0.2375
#   ➤ Pearson r: 0.4898 (p=1.08e-09)
#   ➤ RMSE: 1.5368
#
# 🧬 Drug 1912 | Samples: 138
#   ➤ Global R²: 0.0598
#   ➤ Pearson r: 0.2764 (p=1.03e-03)
#   ➤ RMSE: 1.4837
#
# 🧬 Drug 1913 | Samples: 138
#   ➤ Global R²: -0.0223
#   ➤ Pearson r: 0.0344 (p=6.89e-01)
#   ➤ RMSE: 0.9422
#
# 🧬 Drug 1915 | Samples: 138
#   ➤ Global R²: 0.1421
#   ➤ Pearson r: 0.4268 (p=1.79e-07)
#   ➤ RMSE: 1.0628
#
# 🧬 Drug 1916 | Samples: 138
#   ➤ Global R²: 0.0910
#   ➤ Pearson r: 0.3022 (p=3.15e-04)
#   ➤ RMSE: 1.4217
#
# 🧬 Drug 1917 | Samples: 138
#   ➤ Global R²: 0.2283
#   ➤ Pearson r: 0.4819 (p=2.17e-09)
#   ➤ RMSE: 1.2954
#
# 🧬 Drug 1918 | Samples: 138
#   ➤ Global R²: -0.0963
#   ➤ Pearson r: -0.0442 (p=6.07e-01)
#   ➤ RMSE: 1.4955
#
# 🧬 Drug 1919 | Samples: 138
#   ➤ Global R²: -0.0682
#   ➤ Pearson r: 0.1115 (p=1.93e-01)
#   ➤ RMSE: 1.2832
#
# 🧬 Drug 1922 | Samples: 138
#   ➤ Global R²: -0.0395
#   ➤ Pearson r: -0.0677 (p=4.30e-01)
#   ➤ RMSE: 1.1476
#
# 🧬 Drug 1924 | Samples: 138
#   ➤ Global R²: -0.0248
#   ➤ Pearson r: 0.0937 (p=2.74e-01)
#   ➤ RMSE: 1.5267
#
# 🧬 Drug 1925 | Samples: 138
#   ➤ Global R²: 0.1455
#   ➤ Pearson r: 0.3829 (p=3.57e-06)
#   ➤ RMSE: 0.9011
#
# 🧬 Drug 1926 | Samples: 136
#   ➤ Global R²: 0.0509
#   ➤ Pearson r: 0.2269 (p=7.90e-03)
#   ➤ RMSE: 1.2956
#
# 🧬 Drug 1927 | Samples: 138
#   ➤ Global R²: -0.0558
#   ➤ Pearson r: 0.1036 (p=2.26e-01)
#   ➤ RMSE: 0.8997
#
# 🧬 Drug 1928 | Samples: 138
#   ➤ Global R²: 0.0141
#   ➤ Pearson r: 0.1468 (p=8.58e-02)
#   ➤ RMSE: 0.9216
#
# 🧬 Drug 1930 | Samples: 138
#   ➤ Global R²: 0.2454
#   ➤ Pearson r: 0.4960 (p=6.17e-10)
#   ➤ RMSE: 1.0967
#
# 🧬 Drug 1931 | Samples: 138
#   ➤ Global R²: 0.1206
#   ➤ Pearson r: 0.3486 (p=2.80e-05)
#   ➤ RMSE: 0.8452
#
# 🧬 Drug 1932 | Samples: 138
#   ➤ Global R²: 0.0759
#   ➤ Pearson r: 0.2765 (p=1.03e-03)
#   ➤ RMSE: 1.3390
#
# 🧬 Drug 1933 | Samples: 138
#   ➤ Global R²: 0.0775
#   ➤ Pearson r: 0.2801 (p=8.77e-04)
#   ➤ RMSE: 1.4162
#
# 🧬 Drug 1936 | Samples: 138
#   ➤ Global R²: 0.0096
#   ➤ Pearson r: 0.1167 (p=1.73e-01)
#   ➤ RMSE: 1.4155
#
# 🧬 Drug 1939 | Samples: 114
#   ➤ Global R²: -0.0529
#   ➤ Pearson r: -0.0191 (p=8.40e-01)
#   ➤ RMSE: 1.4610
#
# 🧬 Drug 1940 | Samples: 138
#   ➤ Global R²: -0.0767
#   ➤ Pearson r: -0.0939 (p=2.73e-01)
#   ➤ RMSE: 1.0895
#
# 🧬 Drug 1941 | Samples: 138
#   ➤ Global R²: -0.0229
#   ➤ Pearson r: 0.0979 (p=2.54e-01)
#   ➤ RMSE: 1.8071
#
# 🧬 Drug 1996 | Samples: 114
#   ➤ Global R²: -0.0276
#   ➤ Pearson r: -0.1028 (p=2.76e-01)
#   ➤ RMSE: 1.0283
#
# 🧬 Drug 1997 | Samples: 138
#   ➤ Global R²: -0.0201
#   ➤ Pearson r: -0.2928 (p=4.92e-04)
#   ➤ RMSE: 1.4216
#
# 🧬 Drug 1998 | Samples: 114
#   ➤ Global R²: -0.0052
#   ➤ Pearson r: 0.1252 (p=1.84e-01)
#   ➤ RMSE: 0.8807
#
# 🧬 Drug 1999 | Samples: 114
#   ➤ Global R²: -0.0269
#   ➤ Pearson r: -0.0276 (p=7.71e-01)
#   ➤ RMSE: 1.1416
#
# 🧬 Drug 2000 | Samples: 114
#   ➤ Global R²: -0.0543
#   ➤ Pearson r: 0.0539 (p=5.69e-01)
#   ➤ RMSE: 0.7870
#
# 🧬 Drug 2002 | Samples: 114
#   ➤ Global R²: -0.0442
#   ➤ Pearson r: 0.0859 (p=3.64e-01)
#   ➤ RMSE: 0.8528
#
# 🧬 Drug 2003 | Samples: 114
#   ➤ Global R²: -0.0114
#   ➤ Pearson r: 0.1630 (p=8.31e-02)
#   ➤ RMSE: 0.8364
#
# 🧬 Drug 2010 | Samples: 113
#   ➤ Global R²: 0.0928
#   ➤ Pearson r: 0.3102 (p=8.26e-04)
#   ➤ RMSE: 1.3505
#
# 🧬 Drug 2011 | Samples: 113
#   ➤ Global R²: 0.2760
#   ➤ Pearson r: 0.5258 (p=2.23e-09)
#   ➤ RMSE: 0.9830
#
# 🧬 Drug 2037 | Samples: 113
#   ➤ Global R²: 0.1022
#   ➤ Pearson r: 0.3260 (p=4.25e-04)
#   ➤ RMSE: 1.0942
#
# 🧬 Drug 2038 | Samples: 111
#   ➤ Global R²: -0.0094
#   ➤ Pearson r: 0.1423 (p=1.36e-01)
#   ➤ RMSE: 1.1259
#
# 🧬 Drug 2039 | Samples: 134
#   ➤ Global R²: -0.0027
#   ➤ Pearson r: 0.0626 (p=4.72e-01)
#   ➤ RMSE: 0.9397
#
# 🧬 Drug 2040 | Samples: 138
#   ➤ Global R²: 0.0284
#   ➤ Pearson r: 0.2192 (p=9.79e-03)
#   ➤ RMSE: 1.3342
#
# 🧬 Drug 2043 | Samples: 138
#   ➤ Global R²: 0.0090
#   ➤ Pearson r: 0.1697 (p=4.66e-02)
#   ➤ RMSE: 0.8981
#
# 🧬 Drug 2044 | Samples: 137
#   ➤ Global R²: 0.2260
#   ➤ Pearson r: 0.4762 (p=4.08e-09)
#   ➤ RMSE: 0.9815
#
# 🧬 Drug 2045 | Samples: 138
#   ➤ Global R²: -0.0668
#   ➤ Pearson r: -0.0752 (p=3.81e-01)
#   ➤ RMSE: 0.9552
#
# 🧬 Drug 2046 | Samples: 138
#   ➤ Global R²: -0.0382
#   ➤ Pearson r: 0.0401 (p=6.40e-01)
#   ➤ RMSE: 1.3887
#
# 🧬 Drug 2047 | Samples: 113
#   ➤ Global R²: 0.2235
#   ➤ Pearson r: 0.4738 (p=1.15e-07)
#   ➤ RMSE: 1.2388
#
# 🧬 Drug 2048 | Samples: 136
#   ➤ Global R²: 0.1429
#   ➤ Pearson r: 0.4058 (p=9.52e-07)
#   ➤ RMSE: 1.9384
#
# 🧬 Drug 2055 | Samples: 112
#   ➤ Global R²: 0.1922
#   ➤ Pearson r: 0.4446 (p=9.05e-07)
#   ➤ RMSE: 1.3695
#
# 🧬 Drug 2096 | Samples: 137
#   ➤ Global R²: 0.3057
#   ➤ Pearson r: 0.5530 (p=2.43e-12)
#   ➤ RMSE: 1.1901
#
# 🧬 Drug 2106 | Samples: 112
#   ➤ Global R²: 0.0933
#   ➤ Pearson r: 0.3074 (p=9.78e-04)
#   ➤ RMSE: 1.8512
#
# 🧬 Drug 2107 | Samples: 137
#   ➤ Global R²: 0.2894
#   ➤ Pearson r: 0.5383 (p=1.17e-11)
#   ➤ RMSE: 0.8696
#
# 🧬 Drug 2109 | Samples: 137
#   ➤ Global R²: 0.1910
#   ➤ Pearson r: 0.4373 (p=9.14e-08)
#   ➤ RMSE: 1.1113
#
# 🧬 Drug 2110 | Samples: 137
#   ➤ Global R²: 0.2531
#   ➤ Pearson r: 0.5031 (p=3.70e-10)
#   ➤ RMSE: 0.9353
#
# 🧬 Drug 2111 | Samples: 136
#   ➤ Global R²: 0.2466
#   ➤ Pearson r: 0.5078 (p=2.80e-10)
#   ➤ RMSE: 1.1108
#
# 🧬 Drug 2112 | Samples: 112
#   ➤ Global R²: -0.0256
#   ➤ Pearson r: -0.0894 (p=3.49e-01)
#   ➤ RMSE: 0.7408
#
# 🧬 Drug 2113 | Samples: 112
#   ➤ Global R²: -0.0155
#   ➤ Pearson r: 0.0324 (p=7.34e-01)
#   ➤ RMSE: 0.7187
#
# 🧬 Drug 2145 | Samples: 112
#   ➤ Global R²: 0.2307
#   ➤ Pearson r: 0.4864 (p=5.39e-08)
#   ➤ RMSE: 1.3930
#
# 🧬 Drug 2148 | Samples: 112
#   ➤ Global R²: 0.1330
#   ➤ Pearson r: 0.3773 (p=4.11e-05)
#   ➤ RMSE: 1.1775
#
# 🧬 Drug 2149 | Samples: 112
#   ➤ Global R²: 0.2655
#   ➤ Pearson r: 0.5159 (p=5.85e-09)
#   ➤ RMSE: 1.0002
#
# 🧬 Drug 2154 | Samples: 112
#   ➤ Global R²: 0.1191
#   ➤ Pearson r: 0.3464 (p=1.83e-04)
#   ➤ RMSE: 0.8383
#
# 🧬 Drug 2156 | Samples: 112
#   ➤ Global R²: 0.3495
#   ➤ Pearson r: 0.5968 (p=3.80e-12)
#   ➤ RMSE: 1.1397
#
# 🧬 Drug 2157 | Samples: 112
#   ➤ Global R²: 0.1838
#   ➤ Pearson r: 0.4316 (p=2.02e-06)
#   ➤ RMSE: 0.8306
#
# 🧬 Drug 2158 | Samples: 112
#   ➤ Global R²: 0.0792
#   ➤ Pearson r: 0.2816 (p=2.63e-03)
#   ➤ RMSE: 1.1097
#
# 🧬 Drug 2159 | Samples: 112
#   ➤ Global R²: 0.1734
#   ➤ Pearson r: 0.4198 (p=4.08e-06)
#   ➤ RMSE: 1.0787
#
# 🧬 Drug 2170 | Samples: 137
#   ➤ Global R²: 0.2608
#   ➤ Pearson r: 0.5118 (p=1.64e-10)
#   ➤ RMSE: 1.3948
#
# 🧬 Drug 2171 | Samples: 138
#   ➤ Global R²: 0.1352
#   ➤ Pearson r: 0.3784 (p=4.75e-06)
#   ➤ RMSE: 1.8215
#
# 🧬 Drug 2172 | Samples: 138
#   ➤ Global R²: 0.0141
#   ➤ Pearson r: 0.1300 (p=1.29e-01)
#   ➤ RMSE: 1.7072
#
# 🧬 Drug 2173 | Samples: 136
#   ➤ Global R²: 0.0607
#   ➤ Pearson r: 0.2485 (p=3.53e-03)
#   ➤ RMSE: 0.9197
#
# 🧬 Drug 2177 | Samples: 136
#   ➤ Global R²: -0.0296
#   ➤ Pearson r: -0.1723 (p=4.49e-02)
#   ➤ RMSE: 0.7388
#
# 🧬 Drug 2359 | Samples: 113
#   ➤ Global R²: 0.0826
#   ➤ Pearson r: 0.3203 (p=5.43e-04)
#   ➤ RMSE: 0.7579
#
# 🧬 Drug 2360 | Samples: 113
#   ➤ Global R²: 0.0505
#   ➤ Pearson r: 0.2381 (p=1.11e-02)
#   ➤ RMSE: 0.7691
#
# 🧬 Drug 2361 | Samples: 113
#   ➤ Global R²: 0.0080
#   ➤ Pearson r: 0.1360 (p=1.51e-01)
#   ➤ RMSE: 0.8476
#
# 🧬 Drug 2362 | Samples: 113
#   ➤ Global R²: 0.1154
#   ➤ Pearson r: 0.3403 (p=2.26e-04)
#   ➤ RMSE: 0.9658
#
# 🧬 Drug 2438 | Samples: 116
#   ➤ Global R²: -0.0062
#   ➤ Pearson r: 0.0545 (p=5.61e-01)
#   ➤ RMSE: 1.2184
#
# 🧬 Drug 2439 | Samples: 116
#   ➤ Global R²: -0.0959
#   ➤ Pearson r: -0.1271 (p=1.74e-01)
#   ➤ RMSE: 0.7999
#
# 🧬 Drug 2498 | Samples: 116
#   ➤ Global R²: 0.0579
#   ➤ Pearson r: 0.2461 (p=7.75e-03)
#   ➤ RMSE: 0.8484
#
# 🧬 Drug 2499 | Samples: 116
#   ➤ Global R²: -0.0183
#   ➤ Pearson r: 0.0386 (p=6.81e-01)
#   ➤ RMSE: 0.8602
#
# 🧬 Drug 2500 | Samples: 114
#   ➤ Global R²: 0.2780
#   ➤ Pearson r: 0.5325 (p=1.08e-09)
#   ➤ RMSE: 1.7338
#
# 🧬 Drug 2501 | Samples: 114
#   ➤ Global R²: 0.0924
#   ➤ Pearson r: 0.3062 (p=9.23e-04)
#   ➤ RMSE: 1.6023
#
# 🧬 Drug 2502 | Samples: 114
#   ➤ Global R²: 0.2106
#   ➤ Pearson r: 0.4598 (p=2.65e-07)
#   ➤ RMSE: 1.5739
#
# 🧬 Drug 2503 | Samples: 138
#   ➤ Global R²: 0.2955
#   ➤ Pearson r: 0.5443 (p=5.17e-12)
#   ➤ RMSE: 1.3544
#
# 🧬 Drug 2504 | Samples: 132
#   ➤ Global R²: -0.0694
#   ➤ Pearson r: -0.0767 (p=3.82e-01)
#   ➤ RMSE: 2.2023
#
# 🧬 Drug 2506 | Samples: 138
#   ➤ Global R²: 0.0726
#   ➤ Pearson r: 0.3302 (p=7.66e-05)
#   ➤ RMSE: 1.1086
#
# 🧬 Drug 2507 | Samples: 137
#   ➤ Global R²: -0.0145
#   ➤ Pearson r: 0.0653 (p=4.48e-01)
#   ➤ RMSE: 1.5949
#
# 🧬 Drug 2508 | Samples: 138
#   ➤ Global R²: 0.1732
#   ➤ Pearson r: 0.4165 (p=3.76e-07)
#   ➤ RMSE: 0.9001
#
# 🧬 Drug 2509 | Samples: 138
#   ➤ Global R²: 0.1950
#   ➤ Pearson r: 0.4418 (p=5.83e-08)
#   ➤ RMSE: 1.0153
#
# 🧬 Drug 2510 | Samples: 138
#   ➤ Global R²: 0.2352
#   ➤ Pearson r: 0.4870 (p=1.38e-09)
#   ➤ RMSE: 1.5786
#
# 🧬 Drug 2511 | Samples: 134
#   ➤ Global R²: 0.1560
#   ➤ Pearson r: 0.4019 (p=1.49e-06)
#   ➤ RMSE: 1.4677
#
# 🧬 Drug 2512 | Samples: 138
#   ➤ Global R²: 0.2179
#   ➤ Pearson r: 0.4736 (p=4.44e-09)
#   ➤ RMSE: 0.9566
#
# 🧬 Drug 2513 | Samples: 138
#   ➤ Global R²: 0.0541
#   ➤ Pearson r: 0.2904 (p=5.51e-04)
#   ➤ RMSE: 0.7159
#
# 🧬 Drug 2514 | Samples: 138
#   ➤ Global R²: 0.0041
#   ➤ Pearson r: 0.1763 (p=3.85e-02)
#   ➤ RMSE: 1.1391
#
# 🧬 Drug 2515 | Samples: 138
#   ➤ Global R²: 0.1515
#   ➤ Pearson r: 0.3914 (p=2.06e-06)
#   ➤ RMSE: 0.6877
#
# 🧬 Drug 2516 | Samples: 137
#   ➤ Global R²: 0.1746
#   ➤ Pearson r: 0.4226 (p=2.69e-07)
#   ➤ RMSE: 1.2019
#
# 🧬 Drug 2517 | Samples: 138
#   ➤ Global R²: 0.1805
#   ➤ Pearson r: 0.4293 (p=1.49e-07)
#   ➤ RMSE: 1.2254
#
# 🧬 Drug 2518 | Samples: 136
#   ➤ Global R²: -0.0239
#   ➤ Pearson r: 0.0848 (p=3.26e-01)
#   ➤ RMSE: 0.8316
#
# 🧬 Drug 2519 | Samples: 138
#   ➤ Global R²: 0.1446
#   ➤ Pearson r: 0.3827 (p=3.62e-06)
#   ➤ RMSE: 1.2607
#
# 🧬 Drug 2520 | Samples: 137
#   ➤ Global R²: 0.0014
#   ➤ Pearson r: 0.0716 (p=4.05e-01)
#   ➤ RMSE: 0.9646
#
# 🧬 Drug 2521 | Samples: 138
#   ➤ Global R²: 0.0535
#   ➤ Pearson r: 0.2393 (p=4.70e-03)
#   ➤ RMSE: 1.6105
#
# 🧬 Drug 2522 | Samples: 138
#   ➤ Global R²: 0.0469
#   ➤ Pearson r: 0.2211 (p=9.17e-03)
#   ➤ RMSE: 0.8879
#
# 🧬 Drug 2523 | Samples: 137
#   ➤ Global R²: -0.0282
#   ➤ Pearson r: -0.1815 (p=3.38e-02)
#   ➤ RMSE: 0.9332
#
# 🧬 Drug 2525 | Samples: 137
#   ➤ Global R²: 0.0647
#   ➤ Pearson r: 0.2553 (p=2.60e-03)
#   ➤ RMSE: 1.4290
#
# 🧬 Drug 2526 | Samples: 138
#   ➤ Global R²: 0.0353
#   ➤ Pearson r: 0.2490 (p=3.23e-03)
#   ➤ RMSE: 0.8355
#
# 🧬 Drug 2527 | Samples: 138
#   ➤ Global R²: 0.1904
#   ➤ Pearson r: 0.4436 (p=5.07e-08)
#   ➤ RMSE: 1.3290
#
# 🧬 Drug 2529 | Samples: 137
#   ➤ Global R²: -0.0191
#   ➤ Pearson r: 0.1472 (p=8.60e-02)
#   ➤ RMSE: 1.2826
#
# 🧬 Drug 2531 | Samples: 137
#   ➤ Global R²: 0.0411
#   ➤ Pearson r: 0.2319 (p=6.39e-03)
#   ➤ RMSE: 1.1151
#
# 🧬 Drug 2532 | Samples: 136
#   ➤ Global R²: 0.1212
#   ➤ Pearson r: 0.3488 (p=3.16e-05)
#   ➤ RMSE: 0.8466
#
# 🧬 Drug 2533 | Samples: 138
#   ➤ Global R²: 0.1814
#   ➤ Pearson r: 0.4456 (p=4.33e-08)
#   ➤ RMSE: 1.3388
#
# 🧬 Drug 2534 | Samples: 138
#   ➤ Global R²: 0.2908
#   ➤ Pearson r: 0.5420 (p=6.66e-12)
#   ➤ RMSE: 1.2823
#
# 🧬 Drug 2535 | Samples: 133
#   ➤ Global R²: 0.2019
#   ➤ Pearson r: 0.4514 (p=4.95e-08)
#   ➤ RMSE: 1.0242
#
# 🧬 Drug 2536 | Samples: 138
#   ➤ Global R²: 0.0147
#   ➤ Pearson r: 0.1461 (p=8.74e-02)
#   ➤ RMSE: 1.1686
#
# 🧬 Drug 2537 | Samples: 137
#   ➤ Global R²: 0.0749
#   ➤ Pearson r: 0.2895 (p=6.00e-04)
#   ➤ RMSE: 1.3975
#
# 🧬 Drug 2538 | Samples: 137
#   ➤ Global R²: 0.3000
#   ➤ Pearson r: 0.5478 (p=4.29e-12)
#   ➤ RMSE: 1.2131
#
# 🧬 Drug 2539 | Samples: 138
#   ➤ Global R²: 0.0626
#   ➤ Pearson r: 0.2750 (p=1.10e-03)
#   ➤ RMSE: 1.3316
#
# 🧬 Drug 2540 | Samples: 138
#   ➤ Global R²: 0.2963
#   ➤ Pearson r: 0.5516 (p=2.36e-12)
#   ➤ RMSE: 1.0366
#
# 🧬 Drug 2541 | Samples: 138
#   ➤ Global R²: 0.1948
#   ➤ Pearson r: 0.4472 (p=3.83e-08)
#   ➤ RMSE: 1.3203
#
# 🧬 Drug 2542 | Samples: 138
#   ➤ Global R²: 0.0216
#   ➤ Pearson r: 0.2224 (p=8.74e-03)
#   ➤ RMSE: 1.2657
#
# 🧬 Drug 2543 | Samples: 112
#   ➤ Global R²: 0.2488
#   ➤ Pearson r: 0.5058 (p=1.28e-08)
#   ➤ RMSE: 1.2451
#
# 🧬 Drug 2544 | Samples: 138
#   ➤ Global R²: 0.3775
#   ➤ Pearson r: 0.6153 (p=9.76e-16)
#   ➤ RMSE: 1.6998
#
# 🧬 Drug 2545 | Samples: 137
#   ➤ Global R²: 0.3477
#   ➤ Pearson r: 0.5898 (p=3.35e-14)
#   ➤ RMSE: 1.1069
#
# 🧬 Drug 2546 | Samples: 138
#   ➤ Global R²: 0.3036
#   ➤ Pearson r: 0.5511 (p=2.48e-12)
#   ➤ RMSE: 1.4275
#
# 🧬 Drug 2547 | Samples: 137
#   ➤ Global R²: -0.1114
#   ➤ Pearson r: -0.0406 (p=6.38e-01)
#   ➤ RMSE: 0.8282
#
# 🧬 Drug 2548 | Samples: 137
#   ➤ Global R²: 0.2713
#   ➤ Pearson r: 0.5260 (p=4.10e-11)
#   ➤ RMSE: 0.8389
#
# 🧬 Drug 2549 | Samples: 138
#   ➤ Global R²: -0.0626
#   ➤ Pearson r: 0.2009 (p=1.81e-02)
#   ➤ RMSE: 0.9918
#
# 🧬 Drug 2550 | Samples: 138
#   ➤ Global R²: 0.0851
#   ➤ Pearson r: 0.3035 (p=2.97e-04)
#   ➤ RMSE: 1.1972
#
# 🧬 Drug 2552 | Samples: 138
#   ➤ Global R²: 0.2185
#   ➤ Pearson r: 0.4679 (p=7.20e-09)
#   ➤ RMSE: 1.0458
#
# 🧬 Drug 2555 | Samples: 137
#   ➤ Global R²: 0.0201
#   ➤ Pearson r: 0.2571 (p=2.42e-03)
#   ➤ RMSE: 0.9447
#
# 🧬 Drug 2558 | Samples: 138
#   ➤ Global R²: 0.0677
#   ➤ Pearson r: 0.2640 (p=1.75e-03)
#   ➤ RMSE: 1.0839
#
# 🧬 Drug 2559 | Samples: 138
#   ➤ Global R²: 0.1962
#   ➤ Pearson r: 0.4461 (p=4.16e-08)
#   ➤ RMSE: 1.4689
#
# 🧬 Drug 2562 | Samples: 138
#   ➤ Global R²: 0.3327
#   ➤ Pearson r: 0.5771 (p=1.28e-13)
#   ➤ RMSE: 1.5752
#
# 🧬 Drug 2563 | Samples: 133
#   ➤ Global R²: -0.1269
#   ➤ Pearson r: -0.0074 (p=9.32e-01)
#   ➤ RMSE: 1.0551
#
# 🧬 Drug 2564 | Samples: 138
#   ➤ Global R²: 0.3822
#   ➤ Pearson r: 0.6188 (p=6.04e-16)
#   ➤ RMSE: 1.7750
#
# 🧬 Drug 2565 | Samples: 137
#   ➤ Global R²: 0.2209
#   ➤ Pearson r: 0.4714 (p=6.11e-09)
#   ➤ RMSE: 1.6775
#
# 🧬 Drug 2566 | Samples: 138
#   ➤ Global R²: 0.0907
#   ➤ Pearson r: 0.3115 (p=2.00e-04)
#   ➤ RMSE: 0.9126
#
# 🧬 Drug 2567 | Samples: 113
#   ➤ Global R²: 0.0676
#   ➤ Pearson r: 0.2717 (p=3.61e-03)
#   ➤ RMSE: 2.0566
#
# 🧬 Drug 2568 | Samples: 116
#   ➤ Global R²: 0.1826
#   ➤ Pearson r: 0.4468 (p=4.98e-07)
#   ➤ RMSE: 1.2014
#
# 🧬 Drug 2569 | Samples: 115
#   ➤ Global R²: 0.0458
#   ➤ Pearson r: 0.2141 (p=2.16e-02)
#   ➤ RMSE: 1.6268
#
# 🧬 Drug 2570 | Samples: 116
#   ➤ Global R²: 0.0823
#   ➤ Pearson r: 0.2912 (p=1.52e-03)
#   ➤ RMSE: 1.4161
#
# 🧬 Drug 2571 | Samples: 116
#   ➤ Global R²: 0.0776
#   ➤ Pearson r: 0.2887 (p=1.67e-03)
#   ➤ RMSE: 0.8146
#
# 🧬 Drug 2572 | Samples: 116
#   ➤ Global R²: 0.0234
#   ➤ Pearson r: 0.1973 (p=3.38e-02)
#   ➤ RMSE: 1.3291
#
# 🧬 Drug 2573 | Samples: 137
#   ➤ Global R²: 0.0528
#   ➤ Pearson r: 0.2341 (p=5.90e-03)
#   ➤ RMSE: 1.8406
#
# 🧬 Drug 2575 | Samples: 138
#   ➤ Global R²: 0.1266
#   ➤ Pearson r: 0.3644 (p=1.11e-05)
#   ➤ RMSE: 2.0178

# %%
# Results dataframe
results_df = pd.DataFrame(results)
#results_df.to_csv(f"results/elastic_net/scfoundation_10_fold_embeddings_30_pcs_tissue_growth.csv", index=False)
print("📁 Saved results to results/elastic_net/elastic_net_cv_concatenated_metrics.csv")
# Out:
# 📁 Saved results to results/elastic_net/elastic_net_cv_concatenated_metrics.csv

# %% [markdown]
# ## 2. RMSE Distribution
#
# We visualize the distribution of **RMSE** values across all drugs.
#
# This shows how much prediction error the Elastic Net model makes on average, and how much it varies between drugs.

# %%
# Visualization: RMSE
plt.figure(figsize=(8, 5))
sns.histplot(results_df["rmse"], kde=True, bins=30, color="darkorange")
plt.title(f"RMSE Distribution Across Drugs (ElasticNet, 10-fold CV, concatenated)")
plt.xlabel("RMSE")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# ## 3. R² Distribution
#
# This distribution shows how well Elastic Net explains the variance in IC50 values.
#
# - **R² > 0** means the model is better than the mean predictor
# - **R² = 1** would be a perfect model
# - Drugs with **R² close to or < 0** may not be predictable using current features

# %%
# Visualization: R²
plt.figure(figsize=(8, 5))
sns.histplot(results_df["r2_global"], kde=True, bins=30, color="teal")
plt.title(f"Global R² Distribution Across Drugs (ElasticNet, 10-fold CV, concatenated)")
plt.xlabel("Global R² Score")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# ## 4. Summary
#
# Elastic Net gives a more flexible alternative to linear regression models by combining L1 and L2 penalties.
#
# From the plots above, we can see:
# - The **average RMSE** and its spread across drugs
# - The **R² values**, showing how well the model captures IC50 variance
#
# This gives us a strong baseline for comparison with more complex models like XGBoost or neural networks.

# %%
# Visualization: R² vs. n_samples
plt.figure(figsize=(8, 6))
sns.scatterplot(x="n_samples", y="r2_global", data=results_df)
plt.title("Global R² vs. Sample Size per Drug (ElasticNet)")
plt.xlabel("Number of Samples")
plt.ylabel("Global R² Score")
plt.grid(True)
plt.show()
plt.close()

# %%
# Correlations with sample size
pearson_corr, pval_pearson = pearsonr(results_df["n_samples"], results_df["r2_global"])
print(f"📊 Pearson r (samples vs R²) = {pearson_corr:.3f} (p = {pval_pearson:.3g})")

spearman_corr, pval_spearman = spearmanr(results_df["n_samples"], results_df["r2_global"])
print(f"📊 Spearman ρ (samples vs R²) = {spearman_corr:.3f} (p = {pval_spearman:.3g})")
# Out:
# 📊 Pearson r (samples vs R²) = -0.065 (p = 0.102)
# 📊 Spearman ρ (samples vs R²) = 0.017 (p = 0.665)

# %%
# R² vs. IC50 Variance
variances = data.groupby("DRUG_ID")["LN_IC50"].var()
results_df = results_df.merge(variances.rename("ic50_variance"), on="DRUG_ID")

plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="ic50_variance", y="r2_global")
plt.title("Global R² vs. IC50 Variance (ElasticNet)")
plt.xlabel("IC50 Variance (LN_IC50)")
plt.ylabel("Global R² Score")
plt.grid(True)
plt.show()
plt.close()

# %%
# 📊 Pearson r Distribution Across Drugs
plt.figure(figsize=(8, 5))
sns.histplot(results_df["pearson_r"], kde=True, bins=30, color="mediumpurple")
plt.title(f"Pearson r Distribution Across Drugs (ElasticNet, 10-fold CV, concatenated)")
plt.xlabel("Pearson r")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %%
# 📊 Pearson r vs. Number of Samples per Drug
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="n_samples", y="pearson_r")
plt.title("Pearson r vs. Sample Size per Drug (ElasticNet)")
plt.xlabel("Number of Samples")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()
plt.close()

# %%
pearson_corr_r, pval_pearson_r = pearsonr(results_df["n_samples"], results_df["pearson_r"])
print(f"📊 Pearson r (samples vs Pearson r) = {pearson_corr_r:.3f} (p = {pval_pearson_r:.3g})")

spearman_corr_r, pval_spearman_r = spearmanr(results_df["n_samples"], results_df["pearson_r"])
print(f"📊 Spearman ρ (samples vs Pearson r) = {spearman_corr_r:.3f} (p = {pval_spearman_r:.3g})")
# Out:
# 📊 Pearson r (samples vs Pearson r) = -0.093 (p = 0.0202)
# 📊 Spearman ρ (samples vs Pearson r) = 0.022 (p = 0.588)

# %%
# 📊 Pearson r vs. IC50 Variance
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="ic50_variance", y="pearson_r")
plt.title("Pearson r vs. IC50 Variance per Drug (ElasticNet)")
plt.xlabel("IC50 Variance (LN_IC50)")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()
plt.close()

# %%
# 📊 Compute correlations for interpretation
pearson_corr_var, pval_pearson_var = pearsonr(results_df["ic50_variance"], results_df["pearson_r"])
print(f"📊 Pearson r (IC50 variance vs Pearson r) = {pearson_corr_var:.3f} (p = {pval_pearson_var:.3g})")

spearman_corr_var, pval_spearman_var = spearmanr(results_df["ic50_variance"], results_df["pearson_r"])
print(f"📊 Spearman ρ (IC50 variance vs Pearson r) = {spearman_corr_var:.3f} (p = {pval_spearman_var:.3g})")
# Out:
# 📊 Pearson r (IC50 variance vs Pearson r) = 0.255 (p = 1.05e-10)
# 📊 Spearman ρ (IC50 variance vs Pearson r) = 0.286 (p = 3.22e-13)

# %%
# 📊 Global R² vs. Pearson r consistency plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="r2_global", y="pearson_r")
plt.title("Global R² vs. Pearson r per Drug (XGBoost)")
plt.xlabel("Global R² Score")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()

# %%
# Correlations
from scipy.stats import spearmanr

pearson_corr_r2, pval_pearson_r2 = pearsonr(results_df["n_samples"], results_df["r2_global"])
spearman_corr_r2, pval_spearman_r2 = spearmanr(results_df["n_samples"], results_df["r2_global"])
print(f"\n📊 Pearson r (samples vs R²) = {pearson_corr_r2:.3f} (p = {pval_pearson_r2:.3g})")
print(f"📊 Spearman ρ (samples vs R²) = {spearman_corr_r2:.3f} (p = {pval_spearman_r2:.3g})")

pearson_corr_r, pval_pearson_r = pearsonr(results_df["n_samples"], results_df["pearson_r"])
spearman_corr_r, pval_spearman_r = spearmanr(results_df["n_samples"], results_df["pearson_r"])
print(f"📊 Pearson r (samples vs Pearson r) = {pearson_corr_r:.3f} (p = {pval_pearson_r:.3g})")
print(f"📊 Spearman ρ (samples vs Pearson r) = {spearman_corr_r:.3f} (p = {pval_spearman_r:.3g})")
# Out:
# 📊 Pearson r (samples vs R²) = -0.065 (p = 0.102)
# 📊 Spearman ρ (samples vs R²) = 0.017 (p = 0.665)
# 📊 Pearson r (samples vs Pearson r) = -0.093 (p = 0.0202)
# 📊 Spearman ρ (samples vs Pearson r) = 0.022 (p = 0.588)

# %%
from scipy.stats import pearsonr, spearmanr

# Assuming `results_df` contains columns: "ic50_variance" and "r2_global"

# 📊 Correlation between IC50 variance and R²
pearson_corr_r2, pval_pearson_r2 = pearsonr(results_df["ic50_variance"], results_df["r2_global"])
print(f"📊 Pearson r (IC50 variance vs R²) = {pearson_corr_r2:.3f} (p = {pval_pearson_r2:.3g})")

spearman_corr_r2, pval_spearman_r2 = spearmanr(results_df["ic50_variance"], results_df["r2_global"])
print(f"📊 Spearman ρ (IC50 variance vs R²) = {spearman_corr_r2:.3f} (p = {pval_spearman_r2:.3g})")
# Out:
# 📊 Pearson r (IC50 variance vs R²) = 0.305 (p = 6.21e-15)
# 📊 Spearman ρ (IC50 variance vs R²) = 0.298 (p = 2.55e-14)
