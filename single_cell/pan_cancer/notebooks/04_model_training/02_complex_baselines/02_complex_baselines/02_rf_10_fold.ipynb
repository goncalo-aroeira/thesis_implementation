# %% [markdown]
# # 🌲 Random Forest Models for Drug Sensitivity Prediction
#
# This notebook trains a **Random Forest (RF)** regression model per drug using gene expression features (PCA or HVGs). RFs are robust, handle nonlinearities, and offer good interpretability with minimal hyperparameter tuning. We use **5-fold cross-validation** to evaluate each model’s performance with RMSE and R² metrics.

# %%
import os
import joblib
import numpy as np
import pandas as pd
from pathlib import Path

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.metrics import r2_score, root_mean_squared_error

from scipy.stats import pearsonr, spearmanr, ttest_rel, binomtest

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.dpi"] = 120
plt.rcParams["savefig.bbox"] = "tight"

# %%
NUM_PCS = 20

# Choose your dataset (PCA or HVG)
DATA_PATH = "../../../data/processed/gdsc_pancancer_scran_norm_top4000_30_pcs_tissue_growth.parquet"
data = pd.read_parquet(DATA_PATH)

print("✅ Dataset loaded:", data.shape)
# Out:
# ✅ Dataset loaded: (83624, 45)

# %% [markdown]
# ### 🔁 Train One Random Forest Per Drug
#
# For each drug, we train a separate RF model using its associated (cell line, IC50, features) data. We use train-test split and evaluate with RMSE and R².

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error
from scipy.stats import pearsonr, spearmanr

# Create result folders
os.makedirs("rf/models", exist_ok=True)
os.makedirs("rf/results", exist_ok=True)

non_features = ["SANGER_MODEL_ID", "DRUG_ID", "LN_IC50"]
gene_cols = [col for col in data.columns if col not in non_features]

kf = KFold(n_splits=10, shuffle=True, random_state=42)

results = []

for drug_id in sorted(data["DRUG_ID"].unique()):
    df = data[data["DRUG_ID"] == drug_id].dropna(subset=["LN_IC50"])
    if df.shape[0] < 100:
        print(f"⚠️ Skipped drug {drug_id} (samples: {df.shape[0]})")
        continue

    X = df[gene_cols].values.astype("float64")
    y = df["LN_IC50"].values.astype("float64")

    model = RandomForestRegressor(
        n_estimators=100,
        max_depth=None,
        n_jobs=-1,
        random_state=42
    )

    # Perform CV with prediction concatenation
    y_pred = cross_val_predict(model, X, y, cv=kf, n_jobs=-1)

    # Compute metrics
    r2 = r2_score(y, y_pred)
    pearson_r, p_val = pearsonr(y, y_pred)
    spearman_r, spearman_p = spearmanr(y, y_pred)  # Spearman rank correlation + p-value
    rmse = root_mean_squared_error(y, y_pred)

    print(f"\n🌲 Drug {drug_id} | Samples: {len(df)}")
    print(f"  ➤ Global R²: {r2:.4f}")
    print(f"  ➤ Pearson r: {pearson_r:.4f} (p={p_val:.2e})")
    print(f"  ➤ Spearman ρ: {spearman_r:.4f} (p={spearman_p:.2e})")
    print(f"  ➤ RMSE: {rmse:.4f}")

    results.append({
        "DRUG_ID": drug_id,
        "n_samples": len(df),
        "r2_global": r2,
        "pearson_r": pearson_r,
        "pearson_pval": p_val,
        "spearman_r": spearman_r,
        "spearman_pval": spearman_p,
        "rmse": rmse
    })

    # Optionally save the last fitted model for this drug on all data
    model.fit(X, y)
    # joblib.dump(model, f"rf/models/rf_drug_{drug_id}.pkl")
# Out:
# ⚠️ Skipped drug 1 (samples: 24)
# ⚠️ Skipped drug 3 (samples: 23)
# ⚠️ Skipped drug 5 (samples: 26)
# ⚠️ Skipped drug 6 (samples: 27)
# ⚠️ Skipped drug 9 (samples: 26)
# ⚠️ Skipped drug 11 (samples: 26)
# ⚠️ Skipped drug 17 (samples: 25)
# ⚠️ Skipped drug 29 (samples: 26)
# ⚠️ Skipped drug 30 (samples: 26)
# ⚠️ Skipped drug 32 (samples: 26)
# ⚠️ Skipped drug 34 (samples: 27)
# ⚠️ Skipped drug 35 (samples: 27)
# ⚠️ Skipped drug 37 (samples: 27)
# ⚠️ Skipped drug 38 (samples: 27)
# ⚠️ Skipped drug 41 (samples: 26)
# ⚠️ Skipped drug 45 (samples: 26)
# ⚠️ Skipped drug 51 (samples: 26)
# ⚠️ Skipped drug 52 (samples: 26)
# ⚠️ Skipped drug 53 (samples: 26)
# ⚠️ Skipped drug 54 (samples: 26)
# ⚠️ Skipped drug 55 (samples: 26)
# ⚠️ Skipped drug 56 (samples: 26)
# ⚠️ Skipped drug 59 (samples: 26)
# ⚠️ Skipped drug 60 (samples: 25)
# ⚠️ Skipped drug 62 (samples: 26)
# ⚠️ Skipped drug 63 (samples: 26)
# ⚠️ Skipped drug 64 (samples: 26)
# ⚠️ Skipped drug 71 (samples: 26)
# ⚠️ Skipped drug 83 (samples: 26)
# ⚠️ Skipped drug 86 (samples: 26)
# ⚠️ Skipped drug 87 (samples: 26)
# ⚠️ Skipped drug 88 (samples: 26)
# ⚠️ Skipped drug 89 (samples: 26)
# ⚠️ Skipped drug 91 (samples: 26)
# ⚠️ Skipped drug 94 (samples: 26)
# ⚠️ Skipped drug 104 (samples: 26)
# ⚠️ Skipped drug 106 (samples: 25)
# ⚠️ Skipped drug 110 (samples: 25)
# ⚠️ Skipped drug 111 (samples: 25)
# ⚠️ Skipped drug 119 (samples: 25)
# ⚠️ Skipped drug 127 (samples: 26)
#
# 🌲 Drug 133 | Samples: 132
#   ➤ Global R²: 0.0487
#   ➤ Pearson r: 0.2408 (p=5.42e-03)
#   ➤ Spearman ρ: 0.2705 (p=1.71e-03)
#   ➤ RMSE: 1.6526
#
# 🌲 Drug 134 | Samples: 132
#   ➤ Global R²: 0.1027
#   ➤ Pearson r: 0.3245 (p=1.47e-04)
#   ➤ Spearman ρ: 0.3106 (p=2.90e-04)
#   ➤ RMSE: 1.8115
#
# 🌲 Drug 135 | Samples: 131
#   ➤ Global R²: 0.0123
#   ➤ Pearson r: 0.1875 (p=3.20e-02)
#   ➤ Spearman ρ: 0.1749 (p=4.57e-02)
#   ➤ RMSE: 2.5941
#
# 🌲 Drug 136 | Samples: 133
#   ➤ Global R²: -0.0164
#   ➤ Pearson r: 0.1253 (p=1.51e-01)
#   ➤ Spearman ρ: 0.0956 (p=2.74e-01)
#   ➤ RMSE: 1.5192
#
# 🌲 Drug 140 | Samples: 133
#   ➤ Global R²: 0.0006
#   ➤ Pearson r: 0.1761 (p=4.26e-02)
#   ➤ Spearman ρ: 0.1784 (p=3.99e-02)
#   ➤ RMSE: 1.6378
#
# 🌲 Drug 147 | Samples: 132
#   ➤ Global R²: 0.0546
#   ➤ Pearson r: 0.2624 (p=2.37e-03)
#   ➤ Spearman ρ: 0.2572 (p=2.91e-03)
#   ➤ RMSE: 0.7437
#
# 🌲 Drug 150 | Samples: 133
#   ➤ Global R²: -0.0393
#   ➤ Pearson r: 0.1443 (p=9.75e-02)
#   ➤ Spearman ρ: 0.2077 (p=1.64e-02)
#   ➤ RMSE: 0.5570
#
# 🌲 Drug 151 | Samples: 133
#   ➤ Global R²: 0.1080
#   ➤ Pearson r: 0.3287 (p=1.12e-04)
#   ➤ Spearman ρ: 0.3247 (p=1.37e-04)
#   ➤ RMSE: 1.3531
#
# 🌲 Drug 152 | Samples: 135
#   ➤ Global R²: -0.0783
#   ➤ Pearson r: 0.0499 (p=5.66e-01)
#   ➤ Spearman ρ: 0.0691 (p=4.26e-01)
#   ➤ RMSE: 1.1914
#
# 🌲 Drug 153 | Samples: 133
#   ➤ Global R²: 0.0586
#   ➤ Pearson r: 0.2551 (p=3.04e-03)
#   ➤ Spearman ρ: 0.2400 (p=5.39e-03)
#   ➤ RMSE: 1.2170
#
# 🌲 Drug 154 | Samples: 132
#   ➤ Global R²: -0.1461
#   ➤ Pearson r: -0.0547 (p=5.34e-01)
#   ➤ Spearman ρ: 0.0230 (p=7.93e-01)
#   ➤ RMSE: 0.9305
#
# 🌲 Drug 155 | Samples: 133
#   ➤ Global R²: -0.0251
#   ➤ Pearson r: 0.1130 (p=1.95e-01)
#   ➤ Spearman ρ: 0.1161 (p=1.83e-01)
#   ➤ RMSE: 1.2525
#
# 🌲 Drug 156 | Samples: 131
#   ➤ Global R²: -0.0210
#   ➤ Pearson r: 0.1231 (p=1.61e-01)
#   ➤ Spearman ρ: 0.0685 (p=4.37e-01)
#   ➤ RMSE: 1.3282
#
# 🌲 Drug 157 | Samples: 133
#   ➤ Global R²: 0.0308
#   ➤ Pearson r: 0.2297 (p=7.82e-03)
#   ➤ Spearman ρ: 0.2994 (p=4.64e-04)
#   ➤ RMSE: 1.0041
#
# 🌲 Drug 158 | Samples: 130
#   ➤ Global R²: 0.0214
#   ➤ Pearson r: 0.1924 (p=2.83e-02)
#   ➤ Spearman ρ: 0.2686 (p=2.00e-03)
#   ➤ RMSE: 1.0108
#
# 🌲 Drug 159 | Samples: 133
#   ➤ Global R²: -0.0028
#   ➤ Pearson r: 0.1450 (p=9.58e-02)
#   ➤ Spearman ρ: 0.1979 (p=2.24e-02)
#   ➤ RMSE: 1.4613
#
# 🌲 Drug 163 | Samples: 133
#   ➤ Global R²: -0.0028
#   ➤ Pearson r: 0.1484 (p=8.82e-02)
#   ➤ Spearman ρ: 0.1532 (p=7.83e-02)
#   ➤ RMSE: 1.3509
#
# 🌲 Drug 164 | Samples: 133
#   ➤ Global R²: -0.0693
#   ➤ Pearson r: 0.0582 (p=5.06e-01)
#   ➤ Spearman ρ: 0.0738 (p=3.98e-01)
#   ➤ RMSE: 1.5338
#
# 🌲 Drug 165 | Samples: 132
#   ➤ Global R²: 0.1064
#   ➤ Pearson r: 0.3282 (p=1.22e-04)
#   ➤ Spearman ρ: 0.2773 (p=1.29e-03)
#   ➤ RMSE: 1.3262
#
# 🌲 Drug 166 | Samples: 133
#   ➤ Global R²: 0.0230
#   ➤ Pearson r: 0.1903 (p=2.82e-02)
#   ➤ Spearman ρ: 0.2286 (p=8.14e-03)
#   ➤ RMSE: 0.8312
#
# 🌲 Drug 167 | Samples: 132
#   ➤ Global R²: 0.0319
#   ➤ Pearson r: 0.2299 (p=8.01e-03)
#   ➤ Spearman ρ: 0.2624 (p=2.37e-03)
#   ➤ RMSE: 1.1038
#
# 🌲 Drug 170 | Samples: 132
#   ➤ Global R²: -0.0889
#   ➤ Pearson r: -0.0082 (p=9.26e-01)
#   ➤ Spearman ρ: 0.0127 (p=8.85e-01)
#   ➤ RMSE: 1.2509
#
# 🌲 Drug 171 | Samples: 132
#   ➤ Global R²: 0.0873
#   ➤ Pearson r: 0.3005 (p=4.64e-04)
#   ➤ Spearman ρ: 0.2699 (p=1.75e-03)
#   ➤ RMSE: 0.9039
#
# 🌲 Drug 172 | Samples: 133
#   ➤ Global R²: 0.0633
#   ➤ Pearson r: 0.2588 (p=2.63e-03)
#   ➤ Spearman ρ: 0.2637 (p=2.16e-03)
#   ➤ RMSE: 0.9057
#
# 🌲 Drug 173 | Samples: 133
#   ➤ Global R²: 0.1081
#   ➤ Pearson r: 0.3315 (p=9.72e-05)
#   ➤ Spearman ρ: 0.3509 (p=3.47e-05)
#   ➤ RMSE: 1.2081
#
# 🌲 Drug 175 | Samples: 132
#   ➤ Global R²: -0.0862
#   ➤ Pearson r: -0.0139 (p=8.74e-01)
#   ➤ Spearman ρ: -0.0011 (p=9.90e-01)
#   ➤ RMSE: 1.2405
#
# 🌲 Drug 176 | Samples: 132
#   ➤ Global R²: -0.1106
#   ➤ Pearson r: -0.0935 (p=2.86e-01)
#   ➤ Spearman ρ: -0.0610 (p=4.87e-01)
#   ➤ RMSE: 1.5401
#
# 🌲 Drug 177 | Samples: 131
#   ➤ Global R²: 0.1017
#   ➤ Pearson r: 0.3198 (p=1.97e-04)
#   ➤ Spearman ρ: 0.3213 (p=1.82e-04)
#   ➤ RMSE: 1.5318
#
# 🌲 Drug 178 | Samples: 133
#   ➤ Global R²: -0.0378
#   ➤ Pearson r: 0.0918 (p=2.93e-01)
#   ➤ Spearman ρ: 0.0866 (p=3.22e-01)
#   ➤ RMSE: 1.4672
#
# 🌲 Drug 179 | Samples: 135
#   ➤ Global R²: 0.0827
#   ➤ Pearson r: 0.2905 (p=6.30e-04)
#   ➤ Spearman ρ: 0.2579 (p=2.53e-03)
#   ➤ RMSE: 1.4496
#
# 🌲 Drug 180 | Samples: 130
#   ➤ Global R²: -0.0507
#   ➤ Pearson r: 0.1123 (p=2.03e-01)
#   ➤ Spearman ρ: 0.1199 (p=1.74e-01)
#   ➤ RMSE: 1.9313
#
# 🌲 Drug 182 | Samples: 133
#   ➤ Global R²: 0.0055
#   ➤ Pearson r: 0.1947 (p=2.47e-02)
#   ➤ Spearman ρ: 0.2062 (p=1.73e-02)
#   ➤ RMSE: 1.5421
#
# 🌲 Drug 184 | Samples: 132
#   ➤ Global R²: 0.0429
#   ➤ Pearson r: 0.2229 (p=1.02e-02)
#   ➤ Spearman ρ: 0.2025 (p=1.99e-02)
#   ➤ RMSE: 1.5433
#
# 🌲 Drug 185 | Samples: 132
#   ➤ Global R²: -0.0658
#   ➤ Pearson r: -0.0010 (p=9.91e-01)
#   ➤ Spearman ρ: -0.0278 (p=7.52e-01)
#   ➤ RMSE: 1.3913
#
# 🌲 Drug 186 | Samples: 130
#   ➤ Global R²: -0.2071
#   ➤ Pearson r: -0.1943 (p=2.68e-02)
#   ➤ Spearman ρ: -0.2086 (p=1.72e-02)
#   ➤ RMSE: 1.1236
#
# 🌲 Drug 190 | Samples: 130
#   ➤ Global R²: 0.0583
#   ➤ Pearson r: 0.2519 (p=3.84e-03)
#   ➤ Spearman ρ: 0.2728 (p=1.69e-03)
#   ➤ RMSE: 2.0637
#
# 🌲 Drug 192 | Samples: 133
#   ➤ Global R²: -0.0422
#   ➤ Pearson r: 0.0976 (p=2.64e-01)
#   ➤ Spearman ρ: 0.0897 (p=3.04e-01)
#   ➤ RMSE: 0.6722
#
# 🌲 Drug 193 | Samples: 135
#   ➤ Global R²: 0.0294
#   ➤ Pearson r: 0.2122 (p=1.35e-02)
#   ➤ Spearman ρ: 0.2039 (p=1.77e-02)
#   ➤ RMSE: 0.5411
#
# 🌲 Drug 194 | Samples: 132
#   ➤ Global R²: -0.1075
#   ➤ Pearson r: 0.0133 (p=8.79e-01)
#   ➤ Spearman ρ: 0.0877 (p=3.18e-01)
#   ➤ RMSE: 1.6767
#
# 🌲 Drug 196 | Samples: 132
#   ➤ Global R²: -0.1200
#   ➤ Pearson r: -0.0385 (p=6.61e-01)
#   ➤ Spearman ρ: -0.0568 (p=5.18e-01)
#   ➤ RMSE: 1.5786
#
# 🌲 Drug 197 | Samples: 133
#   ➤ Global R²: -0.0858
#   ➤ Pearson r: -0.0010 (p=9.91e-01)
#   ➤ Spearman ρ: 0.0400 (p=6.47e-01)
#   ➤ RMSE: 0.8830
#
# 🌲 Drug 199 | Samples: 132
#   ➤ Global R²: 0.0019
#   ➤ Pearson r: 0.1471 (p=9.24e-02)
#   ➤ Spearman ρ: 0.1104 (p=2.08e-01)
#   ➤ RMSE: 1.2903
#
# 🌲 Drug 200 | Samples: 133
#   ➤ Global R²: -0.0323
#   ➤ Pearson r: 0.1103 (p=2.06e-01)
#   ➤ Spearman ρ: 0.0606 (p=4.88e-01)
#   ➤ RMSE: 1.1344
#
# 🌲 Drug 201 | Samples: 132
#   ➤ Global R²: 0.0222
#   ➤ Pearson r: 0.2108 (p=1.53e-02)
#   ➤ Spearman ρ: 0.2039 (p=1.91e-02)
#   ➤ RMSE: 1.7782
#
# 🌲 Drug 202 | Samples: 133
#   ➤ Global R²: 0.0610
#   ➤ Pearson r: 0.2576 (p=2.76e-03)
#   ➤ Spearman ρ: 0.2748 (p=1.37e-03)
#   ➤ RMSE: 0.7072
#
# 🌲 Drug 203 | Samples: 136
#   ➤ Global R²: 0.0345
#   ➤ Pearson r: 0.2307 (p=6.88e-03)
#   ➤ Spearman ρ: 0.2414 (p=4.64e-03)
#   ➤ RMSE: 1.0172
#
# 🌲 Drug 204 | Samples: 133
#   ➤ Global R²: -0.0349
#   ➤ Pearson r: 0.0881 (p=3.13e-01)
#   ➤ Spearman ρ: 0.0760 (p=3.85e-01)
#   ➤ RMSE: 1.5826
#
# 🌲 Drug 205 | Samples: 135
#   ➤ Global R²: -0.0922
#   ➤ Pearson r: 0.0576 (p=5.07e-01)
#   ➤ Spearman ρ: 0.0835 (p=3.36e-01)
#   ➤ RMSE: 0.5678
#
# 🌲 Drug 206 | Samples: 136
#   ➤ Global R²: 0.0766
#   ➤ Pearson r: 0.2806 (p=9.38e-04)
#   ➤ Spearman ρ: 0.2892 (p=6.37e-04)
#   ➤ RMSE: 0.5845
#
# 🌲 Drug 207 | Samples: 132
#   ➤ Global R²: -0.0135
#   ➤ Pearson r: 0.1217 (p=1.65e-01)
#   ➤ Spearman ρ: 0.1450 (p=9.72e-02)
#   ➤ RMSE: 1.1015
#
# 🌲 Drug 208 | Samples: 134
#   ➤ Global R²: 0.0147
#   ➤ Pearson r: 0.1792 (p=3.83e-02)
#   ➤ Spearman ρ: 0.1759 (p=4.20e-02)
#   ➤ RMSE: 1.6329
#
# 🌲 Drug 211 | Samples: 134
#   ➤ Global R²: -0.0966
#   ➤ Pearson r: 0.0019 (p=9.83e-01)
#   ➤ Spearman ρ: -0.0446 (p=6.09e-01)
#   ➤ RMSE: 1.0882
#
# 🌲 Drug 219 | Samples: 130
#   ➤ Global R²: -0.0115
#   ➤ Pearson r: 0.1299 (p=1.41e-01)
#   ➤ Spearman ρ: 0.0515 (p=5.60e-01)
#   ➤ RMSE: 1.6417
#
# 🌲 Drug 221 | Samples: 136
#   ➤ Global R²: 0.0211
#   ➤ Pearson r: 0.1916 (p=2.55e-02)
#   ➤ Spearman ρ: 0.1582 (p=6.59e-02)
#   ➤ RMSE: 1.0732
#
# 🌲 Drug 222 | Samples: 136
#   ➤ Global R²: 0.0283
#   ➤ Pearson r: 0.2114 (p=1.35e-02)
#   ➤ Spearman ρ: 0.2043 (p=1.70e-02)
#   ➤ RMSE: 1.4304
#
# 🌲 Drug 223 | Samples: 135
#   ➤ Global R²: -0.0985
#   ➤ Pearson r: -0.0341 (p=6.94e-01)
#   ➤ Spearman ρ: -0.0230 (p=7.91e-01)
#   ➤ RMSE: 1.5254
#
# 🌲 Drug 224 | Samples: 134
#   ➤ Global R²: -0.1222
#   ➤ Pearson r: -0.0170 (p=8.46e-01)
#   ➤ Spearman ρ: 0.0416 (p=6.33e-01)
#   ➤ RMSE: 1.5304
#
# 🌲 Drug 225 | Samples: 135
#   ➤ Global R²: -0.1085
#   ➤ Pearson r: -0.0505 (p=5.60e-01)
#   ➤ Spearman ρ: -0.0195 (p=8.22e-01)
#   ➤ RMSE: 1.6062
#
# 🌲 Drug 226 | Samples: 129
#   ➤ Global R²: -0.0380
#   ➤ Pearson r: 0.1047 (p=2.38e-01)
#   ➤ Spearman ρ: 0.0767 (p=3.87e-01)
#   ➤ RMSE: 1.6006
#
# 🌲 Drug 228 | Samples: 135
#   ➤ Global R²: -0.0498
#   ➤ Pearson r: 0.1060 (p=2.21e-01)
#   ➤ Spearman ρ: 0.1137 (p=1.89e-01)
#   ➤ RMSE: 1.3276
#
# 🌲 Drug 229 | Samples: 134
#   ➤ Global R²: -0.1426
#   ➤ Pearson r: -0.1160 (p=1.82e-01)
#   ➤ Spearman ρ: -0.1749 (p=4.32e-02)
#   ➤ RMSE: 1.6567
#
# 🌲 Drug 230 | Samples: 136
#   ➤ Global R²: -0.0429
#   ➤ Pearson r: 0.1914 (p=2.56e-02)
#   ➤ Spearman ρ: 0.2778 (p=1.06e-03)
#   ➤ RMSE: 1.0376
#
# 🌲 Drug 231 | Samples: 124
#   ➤ Global R²: -0.0715
#   ➤ Pearson r: 0.0393 (p=6.65e-01)
#   ➤ Spearman ρ: 0.0605 (p=5.04e-01)
#   ➤ RMSE: 0.8271
#
# 🌲 Drug 235 | Samples: 133
#   ➤ Global R²: -0.0440
#   ➤ Pearson r: 0.0954 (p=2.75e-01)
#   ➤ Spearman ρ: 0.1172 (p=1.79e-01)
#   ➤ RMSE: 1.6492
#
# 🌲 Drug 236 | Samples: 135
#   ➤ Global R²: 0.0928
#   ➤ Pearson r: 0.3103 (p=2.50e-04)
#   ➤ Spearman ρ: 0.2482 (p=3.70e-03)
#   ➤ RMSE: 0.6425
#
# 🌲 Drug 238 | Samples: 136
#   ➤ Global R²: -0.0653
#   ➤ Pearson r: 0.0662 (p=4.44e-01)
#   ➤ Spearman ρ: 0.0560 (p=5.18e-01)
#   ➤ RMSE: 1.1343
#
# 🌲 Drug 245 | Samples: 135
#   ➤ Global R²: -0.2063
#   ➤ Pearson r: -0.1701 (p=4.86e-02)
#   ➤ Spearman ρ: -0.1840 (p=3.27e-02)
#   ➤ RMSE: 1.6421
#
# 🌲 Drug 249 | Samples: 134
#   ➤ Global R²: 0.0083
#   ➤ Pearson r: 0.1499 (p=8.38e-02)
#   ➤ Spearman ρ: 0.1510 (p=8.15e-02)
#   ➤ RMSE: 1.2733
#
# 🌲 Drug 252 | Samples: 135
#   ➤ Global R²: -0.0752
#   ➤ Pearson r: -0.0207 (p=8.12e-01)
#   ➤ Spearman ρ: 0.0007 (p=9.93e-01)
#   ➤ RMSE: 1.8094
#
# 🌲 Drug 253 | Samples: 135
#   ➤ Global R²: 0.0738
#   ➤ Pearson r: 0.2858 (p=7.78e-04)
#   ➤ Spearman ρ: 0.2307 (p=7.11e-03)
#   ➤ RMSE: 0.7299
#
# 🌲 Drug 254 | Samples: 135
#   ➤ Global R²: 0.0701
#   ➤ Pearson r: 0.2791 (p=1.05e-03)
#   ➤ Spearman ρ: 0.3495 (p=3.25e-05)
#   ➤ RMSE: 0.7501
#
# 🌲 Drug 255 | Samples: 135
#   ➤ Global R²: -0.0073
#   ➤ Pearson r: 0.1507 (p=8.11e-02)
#   ➤ Spearman ρ: 0.1544 (p=7.38e-02)
#   ➤ RMSE: 0.9554
#
# 🌲 Drug 256 | Samples: 135
#   ➤ Global R²: -0.0655
#   ➤ Pearson r: 0.0889 (p=3.05e-01)
#   ➤ Spearman ρ: 0.0976 (p=2.60e-01)
#   ➤ RMSE: 1.4149
#
# 🌲 Drug 257 | Samples: 134
#   ➤ Global R²: -0.0531
#   ➤ Pearson r: 0.1028 (p=2.37e-01)
#   ➤ Spearman ρ: 0.0685 (p=4.32e-01)
#   ➤ RMSE: 1.4568
#
# 🌲 Drug 258 | Samples: 135
#   ➤ Global R²: -0.1274
#   ➤ Pearson r: -0.0252 (p=7.71e-01)
#   ➤ Spearman ρ: -0.0103 (p=9.06e-01)
#   ➤ RMSE: 0.7414
#
# 🌲 Drug 260 | Samples: 135
#   ➤ Global R²: -0.0803
#   ➤ Pearson r: 0.0323 (p=7.10e-01)
#   ➤ Spearman ρ: 0.0756 (p=3.84e-01)
#   ➤ RMSE: 1.3914
#
# 🌲 Drug 261 | Samples: 135
#   ➤ Global R²: 0.0438
#   ➤ Pearson r: 0.2305 (p=7.15e-03)
#   ➤ Spearman ρ: 0.2249 (p=8.73e-03)
#   ➤ RMSE: 1.2078
#
# 🌲 Drug 262 | Samples: 135
#   ➤ Global R²: -0.0265
#   ➤ Pearson r: 0.1596 (p=6.44e-02)
#   ➤ Spearman ρ: 0.1926 (p=2.52e-02)
#   ➤ RMSE: 1.4490
#
# 🌲 Drug 263 | Samples: 135
#   ➤ Global R²: -0.0085
#   ➤ Pearson r: 0.1477 (p=8.73e-02)
#   ➤ Spearman ρ: 0.1471 (p=8.87e-02)
#   ➤ RMSE: 0.7749
#
# 🌲 Drug 264 | Samples: 134
#   ➤ Global R²: 0.0824
#   ➤ Pearson r: 0.2969 (p=4.94e-04)
#   ➤ Spearman ρ: 0.3405 (p=5.68e-05)
#   ➤ RMSE: 1.1076
#
# 🌲 Drug 265 | Samples: 135
#   ➤ Global R²: -0.1139
#   ➤ Pearson r: -0.0576 (p=5.07e-01)
#   ➤ Spearman ρ: -0.0517 (p=5.52e-01)
#   ➤ RMSE: 1.0821
#
# 🌲 Drug 266 | Samples: 135
#   ➤ Global R²: -0.0207
#   ➤ Pearson r: 0.1612 (p=6.18e-02)
#   ➤ Spearman ρ: 0.2079 (p=1.55e-02)
#   ➤ RMSE: 0.4683
#
# 🌲 Drug 268 | Samples: 130
#   ➤ Global R²: -0.0444
#   ➤ Pearson r: 0.1534 (p=8.14e-02)
#   ➤ Spearman ρ: 0.0522 (p=5.55e-01)
#   ➤ RMSE: 2.8511
#
# 🌲 Drug 269 | Samples: 135
#   ➤ Global R²: 0.0422
#   ➤ Pearson r: 0.2451 (p=4.17e-03)
#   ➤ Spearman ρ: 0.2286 (p=7.66e-03)
#   ➤ RMSE: 1.3573
#
# 🌲 Drug 271 | Samples: 135
#   ➤ Global R²: 0.0179
#   ➤ Pearson r: 0.2034 (p=1.80e-02)
#   ➤ Spearman ρ: 0.2377 (p=5.50e-03)
#   ➤ RMSE: 0.6220
#
# 🌲 Drug 272 | Samples: 133
#   ➤ Global R²: -0.1179
#   ➤ Pearson r: 0.0137 (p=8.76e-01)
#   ➤ Spearman ρ: -0.0474 (p=5.88e-01)
#   ➤ RMSE: 1.6610
#
# 🌲 Drug 273 | Samples: 134
#   ➤ Global R²: -0.1306
#   ➤ Pearson r: -0.0539 (p=5.36e-01)
#   ➤ Spearman ρ: -0.0141 (p=8.71e-01)
#   ➤ RMSE: 1.7218
#
# 🌲 Drug 274 | Samples: 131
#   ➤ Global R²: -0.1247
#   ➤ Pearson r: 0.0127 (p=8.86e-01)
#   ➤ Spearman ρ: -0.0430 (p=6.26e-01)
#   ➤ RMSE: 2.0588
#
# 🌲 Drug 275 | Samples: 134
#   ➤ Global R²: -0.0244
#   ➤ Pearson r: 0.1126 (p=1.95e-01)
#   ➤ Spearman ρ: 0.1493 (p=8.51e-02)
#   ➤ RMSE: 1.3059
#
# 🌲 Drug 276 | Samples: 133
#   ➤ Global R²: -0.1089
#   ➤ Pearson r: 0.0546 (p=5.32e-01)
#   ➤ Spearman ρ: -0.0466 (p=5.94e-01)
#   ➤ RMSE: 1.7233
#
# 🌲 Drug 277 | Samples: 135
#   ➤ Global R²: -0.2634
#   ➤ Pearson r: -0.0226 (p=7.95e-01)
#   ➤ Spearman ρ: 0.0283 (p=7.44e-01)
#   ➤ RMSE: 0.7903
#
# 🌲 Drug 279 | Samples: 135
#   ➤ Global R²: -0.0583
#   ➤ Pearson r: 0.0408 (p=6.39e-01)
#   ➤ Spearman ρ: 0.0223 (p=7.97e-01)
#   ➤ RMSE: 1.0002
#
# 🌲 Drug 281 | Samples: 135
#   ➤ Global R²: -0.1891
#   ➤ Pearson r: -0.0264 (p=7.61e-01)
#   ➤ Spearman ρ: -0.0061 (p=9.44e-01)
#   ➤ RMSE: 0.8679
#
# 🌲 Drug 282 | Samples: 135
#   ➤ Global R²: -0.0845
#   ➤ Pearson r: 0.0069 (p=9.37e-01)
#   ➤ Spearman ρ: -0.0330 (p=7.04e-01)
#   ➤ RMSE: 1.7962
#
# 🌲 Drug 283 | Samples: 135
#   ➤ Global R²: -0.0738
#   ➤ Pearson r: 0.0130 (p=8.81e-01)
#   ➤ Spearman ρ: 0.0455 (p=6.00e-01)
#   ➤ RMSE: 1.7187
#
# 🌲 Drug 284 | Samples: 135
#   ➤ Global R²: 0.0261
#   ➤ Pearson r: 0.2090 (p=1.50e-02)
#   ➤ Spearman ρ: 0.2351 (p=6.05e-03)
#   ➤ RMSE: 1.0666
#
# 🌲 Drug 285 | Samples: 135
#   ➤ Global R²: 0.0338
#   ➤ Pearson r: 0.2056 (p=1.68e-02)
#   ➤ Spearman ρ: 0.2232 (p=9.26e-03)
#   ➤ RMSE: 1.1495
#
# 🌲 Drug 286 | Samples: 135
#   ➤ Global R²: 0.0555
#   ➤ Pearson r: 0.2566 (p=2.67e-03)
#   ➤ Spearman ρ: 0.2922 (p=5.85e-04)
#   ➤ RMSE: 0.6980
#
# 🌲 Drug 287 | Samples: 135
#   ➤ Global R²: -0.0877
#   ➤ Pearson r: 0.0954 (p=2.71e-01)
#   ➤ Spearman ρ: 0.1954 (p=2.31e-02)
#   ➤ RMSE: 1.1297
#
# 🌲 Drug 288 | Samples: 135
#   ➤ Global R²: -0.0277
#   ➤ Pearson r: 0.1144 (p=1.86e-01)
#   ➤ Spearman ρ: 0.1825 (p=3.41e-02)
#   ➤ RMSE: 1.0494
#
# 🌲 Drug 289 | Samples: 135
#   ➤ Global R²: -0.0076
#   ➤ Pearson r: 0.1309 (p=1.30e-01)
#   ➤ Spearman ρ: 0.0603 (p=4.87e-01)
#   ➤ RMSE: 0.7053
#
# 🌲 Drug 290 | Samples: 135
#   ➤ Global R²: -0.0049
#   ➤ Pearson r: 0.1498 (p=8.30e-02)
#   ➤ Spearman ρ: 0.1593 (p=6.50e-02)
#   ➤ RMSE: 0.8507
#
# 🌲 Drug 291 | Samples: 134
#   ➤ Global R²: -0.1155
#   ➤ Pearson r: -0.0187 (p=8.30e-01)
#   ➤ Spearman ρ: 0.0201 (p=8.17e-01)
#   ➤ RMSE: 1.2278
#
# 🌲 Drug 292 | Samples: 135
#   ➤ Global R²: -0.0732
#   ➤ Pearson r: 0.0328 (p=7.06e-01)
#   ➤ Spearman ρ: 0.0923 (p=2.87e-01)
#   ➤ RMSE: 1.1994
#
# 🌲 Drug 293 | Samples: 134
#   ➤ Global R²: -0.1091
#   ➤ Pearson r: -0.0149 (p=8.65e-01)
#   ➤ Spearman ρ: 0.0195 (p=8.23e-01)
#   ➤ RMSE: 1.6178
#
# 🌲 Drug 294 | Samples: 135
#   ➤ Global R²: 0.0860
#   ➤ Pearson r: 0.2972 (p=4.65e-04)
#   ➤ Spearman ρ: 0.3407 (p=5.27e-05)
#   ➤ RMSE: 1.1769
#
# 🌲 Drug 295 | Samples: 135
#   ➤ Global R²: -0.0250
#   ➤ Pearson r: 0.1089 (p=2.08e-01)
#   ➤ Spearman ρ: 0.1132 (p=1.91e-01)
#   ➤ RMSE: 1.3912
#
# 🌲 Drug 298 | Samples: 135
#   ➤ Global R²: -0.0372
#   ➤ Pearson r: 0.0986 (p=2.55e-01)
#   ➤ Spearman ρ: 0.0910 (p=2.94e-01)
#   ➤ RMSE: 0.8563
#
# 🌲 Drug 299 | Samples: 131
#   ➤ Global R²: -0.0127
#   ➤ Pearson r: 0.1082 (p=2.19e-01)
#   ➤ Spearman ρ: 0.1020 (p=2.47e-01)
#   ➤ RMSE: 2.0984
#
# 🌲 Drug 300 | Samples: 135
#   ➤ Global R²: 0.0205
#   ➤ Pearson r: 0.2236 (p=9.15e-03)
#   ➤ Spearman ρ: 0.2349 (p=6.10e-03)
#   ➤ RMSE: 1.6438
#
# 🌲 Drug 301 | Samples: 135
#   ➤ Global R²: -0.0951
#   ➤ Pearson r: -0.0385 (p=6.58e-01)
#   ➤ Spearman ρ: -0.0823 (p=3.43e-01)
#   ➤ RMSE: 1.6558
#
# 🌲 Drug 302 | Samples: 133
#   ➤ Global R²: -0.0085
#   ➤ Pearson r: 0.1323 (p=1.29e-01)
#   ➤ Spearman ρ: 0.1301 (p=1.35e-01)
#   ➤ RMSE: 2.0407
#
# 🌲 Drug 303 | Samples: 134
#   ➤ Global R²: -0.0920
#   ➤ Pearson r: -0.0040 (p=9.64e-01)
#   ➤ Spearman ρ: 0.0529 (p=5.43e-01)
#   ➤ RMSE: 1.5261
#
# 🌲 Drug 304 | Samples: 134
#   ➤ Global R²: 0.1475
#   ➤ Pearson r: 0.3844 (p=4.53e-06)
#   ➤ Spearman ρ: 0.2709 (p=1.55e-03)
#   ➤ RMSE: 1.2889
#
# 🌲 Drug 305 | Samples: 135
#   ➤ Global R²: -0.0218
#   ➤ Pearson r: 0.1100 (p=2.04e-01)
#   ➤ Spearman ρ: 0.1281 (p=1.39e-01)
#   ➤ RMSE: 1.3779
#
# 🌲 Drug 306 | Samples: 135
#   ➤ Global R²: 0.0144
#   ➤ Pearson r: 0.1684 (p=5.09e-02)
#   ➤ Spearman ρ: 0.1804 (p=3.63e-02)
#   ➤ RMSE: 1.3583
#
# 🌲 Drug 308 | Samples: 134
#   ➤ Global R²: 0.1436
#   ➤ Pearson r: 0.3825 (p=5.08e-06)
#   ➤ Spearman ρ: 0.3696 (p=1.11e-05)
#   ➤ RMSE: 1.3279
#
# 🌲 Drug 309 | Samples: 135
#   ➤ Global R²: 0.0344
#   ➤ Pearson r: 0.2123 (p=1.34e-02)
#   ➤ Spearman ρ: 0.2162 (p=1.18e-02)
#   ➤ RMSE: 0.9705
#
# 🌲 Drug 310 | Samples: 135
#   ➤ Global R²: -0.0740
#   ➤ Pearson r: 0.0566 (p=5.14e-01)
#   ➤ Spearman ρ: 0.0643 (p=4.59e-01)
#   ➤ RMSE: 1.2266
#
# 🌲 Drug 312 | Samples: 135
#   ➤ Global R²: 0.0857
#   ➤ Pearson r: 0.3025 (p=3.62e-04)
#   ➤ Spearman ρ: 0.2886 (p=6.86e-04)
#   ➤ RMSE: 0.6161
#
# 🌲 Drug 317 | Samples: 132
#   ➤ Global R²: 0.0911
#   ➤ Pearson r: 0.3033 (p=4.08e-04)
#   ➤ Spearman ρ: 0.2696 (p=1.77e-03)
#   ➤ RMSE: 1.8482
#
# 🌲 Drug 326 | Samples: 135
#   ➤ Global R²: -0.0380
#   ➤ Pearson r: 0.1043 (p=2.28e-01)
#   ➤ Spearman ρ: 0.1048 (p=2.27e-01)
#   ➤ RMSE: 1.5408
#
# 🌲 Drug 328 | Samples: 132
#   ➤ Global R²: 0.0298
#   ➤ Pearson r: 0.2189 (p=1.17e-02)
#   ➤ Spearman ρ: 0.2337 (p=6.99e-03)
#   ➤ RMSE: 1.9268
#
# 🌲 Drug 329 | Samples: 135
#   ➤ Global R²: -0.0415
#   ➤ Pearson r: 0.0957 (p=2.70e-01)
#   ➤ Spearman ρ: 0.0841 (p=3.32e-01)
#   ➤ RMSE: 0.9533
#
# 🌲 Drug 330 | Samples: 135
#   ➤ Global R²: 0.0431
#   ➤ Pearson r: 0.2177 (p=1.12e-02)
#   ➤ Spearman ρ: 0.2045 (p=1.73e-02)
#   ➤ RMSE: 1.0692
#
# 🌲 Drug 331 | Samples: 134
#   ➤ Global R²: -0.0498
#   ➤ Pearson r: 0.0463 (p=5.95e-01)
#   ➤ Spearman ρ: 0.0601 (p=4.90e-01)
#   ➤ RMSE: 1.6487
#
# 🌲 Drug 332 | Samples: 135
#   ➤ Global R²: -0.0090
#   ➤ Pearson r: 0.1620 (p=6.04e-02)
#   ➤ Spearman ρ: 0.2289 (p=7.58e-03)
#   ➤ RMSE: 0.6682
#
# 🌲 Drug 333 | Samples: 133
#   ➤ Global R²: -0.0395
#   ➤ Pearson r: 0.1545 (p=7.58e-02)
#   ➤ Spearman ρ: 0.2077 (p=1.64e-02)
#   ➤ RMSE: 0.8488
#
# 🌲 Drug 341 | Samples: 135
#   ➤ Global R²: 0.0236
#   ➤ Pearson r: 0.2823 (p=9.08e-04)
#   ➤ Spearman ρ: 0.2014 (p=1.91e-02)
#   ➤ RMSE: 0.6501
#
# 🌲 Drug 342 | Samples: 135
#   ➤ Global R²: 0.1100
#   ➤ Pearson r: 0.3378 (p=6.17e-05)
#   ➤ Spearman ρ: 0.3153 (p=1.95e-04)
#   ➤ RMSE: 0.9981
#
# 🌲 Drug 344 | Samples: 131
#   ➤ Global R²: -0.0601
#   ➤ Pearson r: 0.0198 (p=8.22e-01)
#   ➤ Spearman ρ: -0.0144 (p=8.70e-01)
#   ➤ RMSE: 2.2117
#
# 🌲 Drug 345 | Samples: 135
#   ➤ Global R²: 0.0910
#   ➤ Pearson r: 0.3106 (p=2.46e-04)
#   ➤ Spearman ρ: 0.3537 (p=2.58e-05)
#   ➤ RMSE: 0.6836
#
# 🌲 Drug 346 | Samples: 130
#   ➤ Global R²: -0.0256
#   ➤ Pearson r: 0.1021 (p=2.48e-01)
#   ➤ Spearman ρ: 0.1215 (p=1.69e-01)
#   ➤ RMSE: 2.5929
#
# 🌲 Drug 356 | Samples: 135
#   ➤ Global R²: 0.1703
#   ➤ Pearson r: 0.4135 (p=6.19e-07)
#   ➤ Spearman ρ: 0.3905 (p=2.83e-06)
#   ➤ RMSE: 1.2946
#
# 🌲 Drug 362 | Samples: 135
#   ➤ Global R²: 0.0116
#   ➤ Pearson r: 0.1803 (p=3.64e-02)
#   ➤ Spearman ρ: 0.2438 (p=4.37e-03)
#   ➤ RMSE: 1.4965
#
# 🌲 Drug 363 | Samples: 135
#   ➤ Global R²: -0.0618
#   ➤ Pearson r: 0.1101 (p=2.04e-01)
#   ➤ Spearman ρ: 0.1766 (p=4.04e-02)
#   ➤ RMSE: 1.3421
#
# 🌲 Drug 366 | Samples: 135
#   ➤ Global R²: -0.0269
#   ➤ Pearson r: 0.1277 (p=1.40e-01)
#   ➤ Spearman ρ: 0.0942 (p=2.77e-01)
#   ➤ RMSE: 1.3439
#
# 🌲 Drug 371 | Samples: 130
#   ➤ Global R²: 0.0590
#   ➤ Pearson r: 0.2532 (p=3.66e-03)
#   ➤ Spearman ρ: 0.2913 (p=7.71e-04)
#   ➤ RMSE: 1.8871
#
# 🌲 Drug 372 | Samples: 135
#   ➤ Global R²: 0.0356
#   ➤ Pearson r: 0.2164 (p=1.17e-02)
#   ➤ Spearman ρ: 0.2294 (p=7.43e-03)
#   ➤ RMSE: 1.0848
#
# 🌲 Drug 374 | Samples: 133
#   ➤ Global R²: 0.0879
#   ➤ Pearson r: 0.2973 (p=5.10e-04)
#   ➤ Spearman ρ: 0.2995 (p=4.62e-04)
#   ➤ RMSE: 1.5365
#
# 🌲 Drug 375 | Samples: 135
#   ➤ Global R²: -0.0732
#   ➤ Pearson r: 0.0719 (p=4.08e-01)
#   ➤ Spearman ρ: 0.1104 (p=2.02e-01)
#   ➤ RMSE: 0.9716
#
# 🌲 Drug 376 | Samples: 135
#   ➤ Global R²: 0.1262
#   ➤ Pearson r: 0.3555 (p=2.32e-05)
#   ➤ Spearman ρ: 0.3382 (p=6.04e-05)
#   ➤ RMSE: 0.9172
#
# 🌲 Drug 380 | Samples: 135
#   ➤ Global R²: 0.1030
#   ➤ Pearson r: 0.3209 (p=1.48e-04)
#   ➤ Spearman ρ: 0.3340 (p=7.51e-05)
#   ➤ RMSE: 1.3982
#
# 🌲 Drug 381 | Samples: 133
#   ➤ Global R²: -0.0132
#   ➤ Pearson r: 0.1344 (p=1.23e-01)
#   ➤ Spearman ρ: 0.1935 (p=2.56e-02)
#   ➤ RMSE: 1.3011
#
# 🌲 Drug 382 | Samples: 134
#   ➤ Global R²: 0.0240
#   ➤ Pearson r: 0.1844 (p=3.29e-02)
#   ➤ Spearman ρ: 0.1991 (p=2.11e-02)
#   ➤ RMSE: 1.3746
#
# 🌲 Drug 406 | Samples: 135
#   ➤ Global R²: 0.0176
#   ➤ Pearson r: 0.1931 (p=2.49e-02)
#   ➤ Spearman ρ: 0.1906 (p=2.68e-02)
#   ➤ RMSE: 0.9360
#
# 🌲 Drug 407 | Samples: 135
#   ➤ Global R²: 0.1747
#   ➤ Pearson r: 0.4207 (p=3.75e-07)
#   ➤ Spearman ρ: 0.4288 (p=2.12e-07)
#   ➤ RMSE: 1.0282
#
# 🌲 Drug 408 | Samples: 135
#   ➤ Global R²: 0.1116
#   ➤ Pearson r: 0.3490 (p=3.34e-05)
#   ➤ Spearman ρ: 0.3564 (p=2.21e-05)
#   ➤ RMSE: 0.4626
#
# 🌲 Drug 409 | Samples: 135
#   ➤ Global R²: -0.0121
#   ➤ Pearson r: 0.2196 (p=1.05e-02)
#   ➤ Spearman ρ: 0.2146 (p=1.24e-02)
#   ➤ RMSE: 0.4962
#
# 🌲 Drug 410 | Samples: 132
#   ➤ Global R²: 0.0500
#   ➤ Pearson r: 0.2414 (p=5.30e-03)
#   ➤ Spearman ρ: 0.2490 (p=3.98e-03)
#   ➤ RMSE: 0.7472
#
# 🌲 Drug 412 | Samples: 133
#   ➤ Global R²: -0.0470
#   ➤ Pearson r: 0.0919 (p=2.93e-01)
#   ➤ Spearman ρ: 0.0835 (p=3.39e-01)
#   ➤ RMSE: 0.4742
#
# 🌲 Drug 415 | Samples: 132
#   ➤ Global R²: -0.0656
#   ➤ Pearson r: 0.0543 (p=5.36e-01)
#   ➤ Spearman ρ: 0.1207 (p=1.68e-01)
#   ➤ RMSE: 0.8618
#
# 🌲 Drug 416 | Samples: 131
#   ➤ Global R²: 0.0120
#   ➤ Pearson r: 0.2383 (p=6.13e-03)
#   ➤ Spearman ρ: 0.2422 (p=5.32e-03)
#   ➤ RMSE: 1.1163
#
# 🌲 Drug 427 | Samples: 131
#   ➤ Global R²: 0.1213
#   ➤ Pearson r: 0.3493 (p=4.32e-05)
#   ➤ Spearman ρ: 0.3719 (p=1.22e-05)
#   ➤ RMSE: 0.5392
#
# 🌲 Drug 428 | Samples: 131
#   ➤ Global R²: 0.0256
#   ➤ Pearson r: 0.2090 (p=1.66e-02)
#   ➤ Spearman ρ: 0.1825 (p=3.69e-02)
#   ➤ RMSE: 1.3496
#
# 🌲 Drug 431 | Samples: 132
#   ➤ Global R²: 0.1172
#   ➤ Pearson r: 0.3467 (p=4.64e-05)
#   ➤ Spearman ρ: 0.2964 (p=5.58e-04)
#   ➤ RMSE: 1.2575
#
# 🌲 Drug 432 | Samples: 132
#   ➤ Global R²: -0.0895
#   ➤ Pearson r: -0.0211 (p=8.11e-01)
#   ➤ Spearman ρ: -0.0159 (p=8.57e-01)
#   ➤ RMSE: 0.9466
#
# 🌲 Drug 435 | Samples: 132
#   ➤ Global R²: 0.0548
#   ➤ Pearson r: 0.2371 (p=6.19e-03)
#   ➤ Spearman ρ: 0.2363 (p=6.37e-03)
#   ➤ RMSE: 1.0626
#
# 🌲 Drug 436 | Samples: 132
#   ➤ Global R²: 0.0335
#   ➤ Pearson r: 0.2128 (p=1.43e-02)
#   ➤ Spearman ρ: 0.1896 (p=2.95e-02)
#   ➤ RMSE: 1.2360
#
# 🌲 Drug 437 | Samples: 132
#   ➤ Global R²: 0.0293
#   ➤ Pearson r: 0.2117 (p=1.48e-02)
#   ➤ Spearman ρ: 0.1771 (p=4.22e-02)
#   ➤ RMSE: 1.1115
#
# 🌲 Drug 438 | Samples: 132
#   ➤ Global R²: -0.0551
#   ➤ Pearson r: 0.0871 (p=3.20e-01)
#   ➤ Spearman ρ: 0.0452 (p=6.07e-01)
#   ➤ RMSE: 1.1246
#
# 🌲 Drug 439 | Samples: 133
#   ➤ Global R²: -0.0006
#   ➤ Pearson r: 0.1787 (p=3.96e-02)
#   ➤ Spearman ρ: 0.1377 (p=1.14e-01)
#   ➤ RMSE: 0.9228
#
# 🌲 Drug 442 | Samples: 133
#   ➤ Global R²: -0.0278
#   ➤ Pearson r: 0.1315 (p=1.31e-01)
#   ➤ Spearman ρ: 0.1750 (p=4.40e-02)
#   ➤ RMSE: 1.4631
#
# 🌲 Drug 446 | Samples: 133
#   ➤ Global R²: 0.1598
#   ➤ Pearson r: 0.4002 (p=1.82e-06)
#   ➤ Spearman ρ: 0.3454 (p=4.65e-05)
#   ➤ RMSE: 0.8988
#
# 🌲 Drug 447 | Samples: 135
#   ➤ Global R²: 0.1032
#   ➤ Pearson r: 0.3340 (p=7.52e-05)
#   ➤ Spearman ρ: 0.3489 (p=3.37e-05)
#   ➤ RMSE: 0.5693
#
# 🌲 Drug 449 | Samples: 133
#   ➤ Global R²: 0.3122
#   ➤ Pearson r: 0.6050 (p=1.24e-14)
#   ➤ Spearman ρ: 0.6055 (p=1.16e-14)
#   ➤ RMSE: 0.8180
#
# 🌲 Drug 461 | Samples: 131
#   ➤ Global R²: -0.1051
#   ➤ Pearson r: -0.0450 (p=6.10e-01)
#   ➤ Spearman ρ: -0.0667 (p=4.49e-01)
#   ➤ RMSE: 1.8884
#
# 🌲 Drug 474 | Samples: 132
#   ➤ Global R²: 0.1579
#   ➤ Pearson r: 0.3990 (p=2.15e-06)
#   ➤ Spearman ρ: 0.3784 (p=7.67e-06)
#   ➤ RMSE: 1.7076
#
# 🌲 Drug 476 | Samples: 132
#   ➤ Global R²: 0.0291
#   ➤ Pearson r: 0.2056 (p=1.80e-02)
#   ➤ Spearman ρ: 0.2236 (p=9.95e-03)
#   ➤ RMSE: 1.4443
#
# 🌲 Drug 477 | Samples: 133
#   ➤ Global R²: -0.0317
#   ➤ Pearson r: 0.0916 (p=2.94e-01)
#   ➤ Spearman ρ: 0.0284 (p=7.45e-01)
#   ➤ RMSE: 0.8655
#
# 🌲 Drug 478 | Samples: 133
#   ➤ Global R²: 0.1168
#   ➤ Pearson r: 0.3492 (p=3.81e-05)
#   ➤ Spearman ρ: 0.3750 (p=8.71e-06)
#   ➤ RMSE: 0.6263
#
# 🌲 Drug 546 | Samples: 132
#   ➤ Global R²: -0.0943
#   ➤ Pearson r: -0.0190 (p=8.29e-01)
#   ➤ Spearman ρ: 0.0080 (p=9.27e-01)
#   ➤ RMSE: 0.5965
#
# 🌲 Drug 552 | Samples: 132
#   ➤ Global R²: 0.0829
#   ➤ Pearson r: 0.2909 (p=7.15e-04)
#   ➤ Spearman ρ: 0.2390 (p=5.78e-03)
#   ➤ RMSE: 0.8137
#
# 🌲 Drug 562 | Samples: 132
#   ➤ Global R²: 0.0622
#   ➤ Pearson r: 0.2641 (p=2.22e-03)
#   ➤ Spearman ρ: 0.2768 (p=1.31e-03)
#   ➤ RMSE: 0.5792
#
# 🌲 Drug 563 | Samples: 132
#   ➤ Global R²: 0.0159
#   ➤ Pearson r: 0.1780 (p=4.12e-02)
#   ➤ Spearman ρ: 0.1852 (p=3.35e-02)
#   ➤ RMSE: 0.8889
#
# 🌲 Drug 573 | Samples: 132
#   ➤ Global R²: 0.0178
#   ➤ Pearson r: 0.2011 (p=2.08e-02)
#   ➤ Spearman ρ: 0.2361 (p=6.42e-03)
#   ➤ RMSE: 0.8291
#
# 🌲 Drug 574 | Samples: 133
#   ➤ Global R²: -0.0221
#   ➤ Pearson r: 0.1289 (p=1.39e-01)
#   ➤ Spearman ρ: 0.1486 (p=8.78e-02)
#   ➤ RMSE: 0.7782
#
# 🌲 Drug 576 | Samples: 132
#   ➤ Global R²: -0.0203
#   ➤ Pearson r: 0.1231 (p=1.60e-01)
#   ➤ Spearman ρ: 0.1239 (p=1.57e-01)
#   ➤ RMSE: 1.0371
#
# 🌲 Drug 1001 | Samples: 134
#   ➤ Global R²: -0.0045
#   ➤ Pearson r: 0.1646 (p=5.74e-02)
#   ➤ Spearman ρ: 0.1726 (p=4.62e-02)
#   ➤ RMSE: 1.1809
#
# 🌲 Drug 1003 | Samples: 138
#   ➤ Global R²: 0.1835
#   ➤ Pearson r: 0.4290 (p=1.52e-07)
#   ➤ Spearman ρ: 0.4316 (p=1.25e-07)
#   ➤ RMSE: 1.5917
#
# 🌲 Drug 1004 | Samples: 134
#   ➤ Global R²: 0.2175
#   ➤ Pearson r: 0.4674 (p=1.24e-08)
#   ➤ Spearman ρ: 0.3965 (p=2.11e-06)
#   ➤ RMSE: 1.2095
#
# 🌲 Drug 1005 | Samples: 134
#   ➤ Global R²: 0.0609
#   ➤ Pearson r: 0.2754 (p=1.28e-03)
#   ➤ Spearman ρ: 0.2847 (p=8.57e-04)
#   ➤ RMSE: 1.1461
#
# 🌲 Drug 1006 | Samples: 132
#   ➤ Global R²: -0.0089
#   ➤ Pearson r: 0.1309 (p=1.35e-01)
#   ➤ Spearman ρ: 0.1470 (p=9.26e-02)
#   ➤ RMSE: 1.4164
#
# 🌲 Drug 1007 | Samples: 134
#   ➤ Global R²: 0.1056
#   ➤ Pearson r: 0.3267 (p=1.17e-04)
#   ➤ Spearman ρ: 0.3186 (p=1.75e-04)
#   ➤ RMSE: 1.2797
#
# 🌲 Drug 1008 | Samples: 134
#   ➤ Global R²: 0.0893
#   ➤ Pearson r: 0.3033 (p=3.68e-04)
#   ➤ Spearman ρ: 0.3164 (p=1.96e-04)
#   ➤ RMSE: 1.2003
#
# 🌲 Drug 1009 | Samples: 134
#   ➤ Global R²: -0.0192
#   ➤ Pearson r: 0.1385 (p=1.11e-01)
#   ➤ Spearman ρ: 0.1825 (p=3.48e-02)
#   ➤ RMSE: 1.0121
#
# 🌲 Drug 1010 | Samples: 133
#   ➤ Global R²: -0.0223
#   ➤ Pearson r: 0.1021 (p=2.42e-01)
#   ➤ Spearman ρ: 0.0852 (p=3.30e-01)
#   ➤ RMSE: 0.9790
#
# 🌲 Drug 1011 | Samples: 135
#   ➤ Global R²: -0.0191
#   ➤ Pearson r: 0.1226 (p=1.57e-01)
#   ➤ Spearman ρ: 0.0576 (p=5.07e-01)
#   ➤ RMSE: 1.2151
#
# 🌲 Drug 1012 | Samples: 134
#   ➤ Global R²: -0.0187
#   ➤ Pearson r: 0.1340 (p=1.23e-01)
#   ➤ Spearman ρ: 0.1066 (p=2.20e-01)
#   ➤ RMSE: 1.0239
#
# 🌲 Drug 1013 | Samples: 134
#   ➤ Global R²: 0.0479
#   ➤ Pearson r: 0.2365 (p=5.94e-03)
#   ➤ Spearman ρ: 0.2902 (p=6.70e-04)
#   ➤ RMSE: 0.7992
#
# 🌲 Drug 1014 | Samples: 130
#   ➤ Global R²: 0.2392
#   ➤ Pearson r: 0.4903 (p=3.20e-09)
#   ➤ Spearman ρ: 0.4236 (p=5.13e-07)
#   ➤ RMSE: 1.4837
#
# 🌲 Drug 1015 | Samples: 129
#   ➤ Global R²: 0.1906
#   ➤ Pearson r: 0.4433 (p=1.43e-07)
#   ➤ Spearman ρ: 0.4560 (p=5.62e-08)
#   ➤ RMSE: 1.2553
#
# 🌲 Drug 1016 | Samples: 130
#   ➤ Global R²: 0.1454
#   ➤ Pearson r: 0.3835 (p=6.68e-06)
#   ➤ Spearman ρ: 0.3655 (p=1.90e-05)
#   ➤ RMSE: 1.4283
#
# 🌲 Drug 1017 | Samples: 134
#   ➤ Global R²: 0.1555
#   ➤ Pearson r: 0.4012 (p=1.55e-06)
#   ➤ Spearman ρ: 0.3078 (p=2.98e-04)
#   ➤ RMSE: 0.8023
#
# 🌲 Drug 1018 | Samples: 133
#   ➤ Global R²: -0.1483
#   ➤ Pearson r: 0.0337 (p=7.00e-01)
#   ➤ Spearman ρ: 0.1571 (p=7.10e-02)
#   ➤ RMSE: 0.7527
#
# 🌲 Drug 1019 | Samples: 134
#   ➤ Global R²: 0.0420
#   ➤ Pearson r: 0.2262 (p=8.59e-03)
#   ➤ Spearman ρ: 0.1617 (p=6.20e-02)
#   ➤ RMSE: 1.2070
#
# 🌲 Drug 1020 | Samples: 133
#   ➤ Global R²: -0.0852
#   ➤ Pearson r: 0.0210 (p=8.11e-01)
#   ➤ Spearman ρ: 0.0299 (p=7.33e-01)
#   ➤ RMSE: 0.7138
#
# 🌲 Drug 1021 | Samples: 131
#   ➤ Global R²: -0.0237
#   ➤ Pearson r: 0.1463 (p=9.55e-02)
#   ➤ Spearman ρ: 0.1960 (p=2.48e-02)
#   ➤ RMSE: 1.1336
#
# 🌲 Drug 1022 | Samples: 134
#   ➤ Global R²: 0.0314
#   ➤ Pearson r: 0.2201 (p=1.06e-02)
#   ➤ Spearman ρ: 0.1781 (p=3.95e-02)
#   ➤ RMSE: 1.3219
#
# 🌲 Drug 1023 | Samples: 134
#   ➤ Global R²: -0.0796
#   ➤ Pearson r: 0.0252 (p=7.73e-01)
#   ➤ Spearman ρ: 0.0070 (p=9.36e-01)
#   ➤ RMSE: 0.9496
#
# 🌲 Drug 1024 | Samples: 134
#   ➤ Global R²: 0.1098
#   ➤ Pearson r: 0.3440 (p=4.70e-05)
#   ➤ Spearman ρ: 0.3731 (p=8.98e-06)
#   ➤ RMSE: 1.3541
#
# 🌲 Drug 1025 | Samples: 114
#   ➤ Global R²: 0.0316
#   ➤ Pearson r: 0.2208 (p=1.83e-02)
#   ➤ Spearman ρ: 0.1959 (p=3.67e-02)
#   ➤ RMSE: 0.7307
#
# 🌲 Drug 1026 | Samples: 134
#   ➤ Global R²: 0.1077
#   ➤ Pearson r: 0.3367 (p=6.97e-05)
#   ➤ Spearman ρ: 0.3220 (p=1.48e-04)
#   ➤ RMSE: 1.6595
#
# 🌲 Drug 1028 | Samples: 134
#   ➤ Global R²: 0.0689
#   ➤ Pearson r: 0.3241 (p=1.33e-04)
#   ➤ Spearman ρ: 0.3261 (p=1.20e-04)
#   ➤ RMSE: 0.6044
#
# 🌲 Drug 1029 | Samples: 134
#   ➤ Global R²: -0.1428
#   ➤ Pearson r: -0.0650 (p=4.55e-01)
#   ➤ Spearman ρ: 0.0151 (p=8.63e-01)
#   ➤ RMSE: 0.9302
#
# 🌲 Drug 1030 | Samples: 134
#   ➤ Global R²: -0.0254
#   ➤ Pearson r: 0.1283 (p=1.39e-01)
#   ➤ Spearman ρ: 0.1121 (p=1.97e-01)
#   ➤ RMSE: 0.8189
#
# 🌲 Drug 1031 | Samples: 134
#   ➤ Global R²: 0.0829
#   ➤ Pearson r: 0.3253 (p=1.26e-04)
#   ➤ Spearman ρ: 0.2161 (p=1.22e-02)
#   ➤ RMSE: 1.6819
#
# 🌲 Drug 1032 | Samples: 134
#   ➤ Global R²: 0.1380
#   ➤ Pearson r: 0.3775 (p=6.92e-06)
#   ➤ Spearman ρ: 0.3621 (p=1.72e-05)
#   ➤ RMSE: 1.3682
#
# 🌲 Drug 1033 | Samples: 134
#   ➤ Global R²: 0.0407
#   ➤ Pearson r: 0.2542 (p=3.03e-03)
#   ➤ Spearman ρ: 0.2310 (p=7.25e-03)
#   ➤ RMSE: 0.7205
#
# 🌲 Drug 1034 | Samples: 138
#   ➤ Global R²: 0.1239
#   ➤ Pearson r: 0.3524 (p=2.25e-05)
#   ➤ Spearman ρ: 0.2809 (p=8.45e-04)
#   ➤ RMSE: 1.2304
#
# 🌲 Drug 1036 | Samples: 135
#   ➤ Global R²: 0.2590
#   ➤ Pearson r: 0.5195 (p=1.07e-10)
#   ➤ Spearman ρ: 0.4113 (p=7.19e-07)
#   ➤ RMSE: 1.2552
#
# 🌲 Drug 1037 | Samples: 135
#   ➤ Global R²: 0.2603
#   ➤ Pearson r: 0.5103 (p=2.56e-10)
#   ➤ Spearman ρ: 0.5168 (p=1.39e-10)
#   ➤ RMSE: 0.9761
#
# 🌲 Drug 1038 | Samples: 133
#   ➤ Global R²: 0.1106
#   ➤ Pearson r: 0.3374 (p=7.13e-05)
#   ➤ Spearman ρ: 0.3069 (p=3.27e-04)
#   ➤ RMSE: 0.7957
#
# 🌲 Drug 1039 | Samples: 131
#   ➤ Global R²: -0.0082
#   ➤ Pearson r: 0.1772 (p=4.29e-02)
#   ➤ Spearman ρ: 0.1328 (p=1.31e-01)
#   ➤ RMSE: 0.7640
#
# 🌲 Drug 1042 | Samples: 134
#   ➤ Global R²: -0.1659
#   ➤ Pearson r: -0.0783 (p=3.68e-01)
#   ➤ Spearman ρ: -0.0794 (p=3.62e-01)
#   ➤ RMSE: 0.8140
#
# 🌲 Drug 1043 | Samples: 134
#   ➤ Global R²: 0.0344
#   ➤ Pearson r: 0.2015 (p=1.95e-02)
#   ➤ Spearman ρ: 0.1895 (p=2.83e-02)
#   ➤ RMSE: 0.8091
#
# 🌲 Drug 1046 | Samples: 120
#   ➤ Global R²: 0.0455
#   ➤ Pearson r: 0.2324 (p=1.06e-02)
#   ➤ Spearman ρ: 0.2070 (p=2.33e-02)
#   ➤ RMSE: 1.0054
#
# 🌲 Drug 1047 | Samples: 135
#   ➤ Global R²: 0.1235
#   ➤ Pearson r: 0.3543 (p=2.49e-05)
#   ➤ Spearman ρ: 0.3158 (p=1.90e-04)
#   ➤ RMSE: 1.2135
#
# 🌲 Drug 1048 | Samples: 125
#   ➤ Global R²: 0.0033
#   ➤ Pearson r: 0.1512 (p=9.24e-02)
#   ➤ Spearman ρ: 0.1245 (p=1.66e-01)
#   ➤ RMSE: 1.2218
#
# 🌲 Drug 1049 | Samples: 135
#   ➤ Global R²: 0.1097
#   ➤ Pearson r: 0.3363 (p=6.68e-05)
#   ➤ Spearman ρ: 0.3712 (p=9.30e-06)
#   ➤ RMSE: 0.9122
#
# 🌲 Drug 1050 | Samples: 135
#   ➤ Global R²: 0.0243
#   ➤ Pearson r: 0.2133 (p=1.30e-02)
#   ➤ Spearman ρ: 0.2158 (p=1.19e-02)
#   ➤ RMSE: 1.1566
#
# 🌲 Drug 1051 | Samples: 137
#   ➤ Global R²: 0.2946
#   ➤ Pearson r: 0.5468 (p=4.78e-12)
#   ➤ Spearman ρ: 0.4905 (p=1.17e-09)
#   ➤ RMSE: 1.4515
#
# 🌲 Drug 1052 | Samples: 135
#   ➤ Global R²: -0.0174
#   ➤ Pearson r: 0.1359 (p=1.16e-01)
#   ➤ Spearman ρ: 0.1031 (p=2.34e-01)
#   ➤ RMSE: 0.9698
#
# 🌲 Drug 1053 | Samples: 126
#   ➤ Global R²: -0.0634
#   ➤ Pearson r: 0.0642 (p=4.75e-01)
#   ➤ Spearman ρ: 0.0765 (p=3.95e-01)
#   ➤ RMSE: 1.4276
#
# 🌲 Drug 1054 | Samples: 126
#   ➤ Global R²: 0.0481
#   ➤ Pearson r: 0.2559 (p=3.82e-03)
#   ➤ Spearman ρ: 0.2387 (p=7.11e-03)
#   ➤ RMSE: 1.4615
#
# 🌲 Drug 1057 | Samples: 132
#   ➤ Global R²: 0.2135
#   ➤ Pearson r: 0.4658 (p=1.82e-08)
#   ➤ Spearman ρ: 0.4418 (p=1.14e-07)
#   ➤ RMSE: 1.0808
#
# 🌲 Drug 1058 | Samples: 132
#   ➤ Global R²: -0.0420
#   ➤ Pearson r: 0.0690 (p=4.32e-01)
#   ➤ Spearman ρ: 0.0622 (p=4.79e-01)
#   ➤ RMSE: 1.4039
#
# 🌲 Drug 1059 | Samples: 132
#   ➤ Global R²: 0.0407
#   ➤ Pearson r: 0.2311 (p=7.68e-03)
#   ➤ Spearman ρ: 0.2664 (p=2.02e-03)
#   ➤ RMSE: 0.9893
#
# 🌲 Drug 1060 | Samples: 132
#   ➤ Global R²: 0.1292
#   ➤ Pearson r: 0.3727 (p=1.08e-05)
#   ➤ Spearman ρ: 0.3121 (p=2.70e-04)
#   ➤ RMSE: 1.7325
#
# 🌲 Drug 1061 | Samples: 128
#   ➤ Global R²: 0.3553
#   ➤ Pearson r: 0.6017 (p=5.87e-14)
#   ➤ Spearman ρ: 0.5319 (p=1.04e-10)
#   ➤ RMSE: 1.1660
#
# 🌲 Drug 1062 | Samples: 124
#   ➤ Global R²: -0.0316
#   ➤ Pearson r: 0.1542 (p=8.73e-02)
#   ➤ Spearman ρ: 0.2132 (p=1.75e-02)
#   ➤ RMSE: 1.6376
#
# 🌲 Drug 1066 | Samples: 131
#   ➤ Global R²: 0.0301
#   ➤ Pearson r: 0.2070 (p=1.77e-02)
#   ➤ Spearman ρ: 0.1804 (p=3.93e-02)
#   ➤ RMSE: 1.2263
#
# 🌲 Drug 1067 | Samples: 135
#   ➤ Global R²: -0.0030
#   ➤ Pearson r: 0.1659 (p=5.44e-02)
#   ➤ Spearman ρ: 0.1768 (p=4.02e-02)
#   ➤ RMSE: 0.7770
#
# 🌲 Drug 1068 | Samples: 121
#   ➤ Global R²: 0.1582
#   ➤ Pearson r: 0.4073 (p=3.55e-06)
#   ➤ Spearman ρ: 0.3958 (p=6.99e-06)
#   ➤ RMSE: 0.9312
#
# 🌲 Drug 1069 | Samples: 135
#   ➤ Global R²: 0.0459
#   ➤ Pearson r: 0.2211 (p=9.97e-03)
#   ➤ Spearman ρ: 0.1938 (p=2.43e-02)
#   ➤ RMSE: 0.9042
#
# 🌲 Drug 1070 | Samples: 134
#   ➤ Global R²: 0.0923
#   ➤ Pearson r: 0.3094 (p=2.75e-04)
#   ➤ Spearman ρ: 0.3523 (p=2.98e-05)
#   ➤ RMSE: 0.9884
#
# 🌲 Drug 1071 | Samples: 134
#   ➤ Global R²: 0.0474
#   ➤ Pearson r: 0.2335 (p=6.62e-03)
#   ➤ Spearman ρ: 0.2411 (p=5.02e-03)
#   ➤ RMSE: 0.9084
#
# 🌲 Drug 1072 | Samples: 135
#   ➤ Global R²: -0.0638
#   ➤ Pearson r: 0.0052 (p=9.52e-01)
#   ➤ Spearman ρ: -0.0560 (p=5.19e-01)
#   ➤ RMSE: 0.9206
#
# 🌲 Drug 1073 | Samples: 138
#   ➤ Global R²: 0.3422
#   ➤ Pearson r: 0.5892 (p=2.92e-14)
#   ➤ Spearman ρ: 0.5957 (p=1.28e-14)
#   ➤ RMSE: 1.3211
#
# 🌲 Drug 1079 | Samples: 138
#   ➤ Global R²: 0.1964
#   ➤ Pearson r: 0.4454 (p=4.40e-08)
#   ➤ Spearman ρ: 0.4696 (p=6.23e-09)
#   ➤ RMSE: 1.8680
#
# 🌲 Drug 1080 | Samples: 138
#   ➤ Global R²: 0.2400
#   ➤ Pearson r: 0.4902 (p=1.04e-09)
#   ➤ Spearman ρ: 0.4824 (p=2.08e-09)
#   ➤ RMSE: 1.5413
#
# 🌲 Drug 1083 | Samples: 138
#   ➤ Global R²: 0.1142
#   ➤ Pearson r: 0.3749 (p=5.90e-06)
#   ➤ Spearman ρ: 0.4528 (p=2.45e-08)
#   ➤ RMSE: 1.4247
#
# 🌲 Drug 1084 | Samples: 137
#   ➤ Global R²: 0.1680
#   ➤ Pearson r: 0.4134 (p=5.15e-07)
#   ➤ Spearman ρ: 0.4296 (p=1.61e-07)
#   ➤ RMSE: 1.3027
#
# 🌲 Drug 1085 | Samples: 138
#   ➤ Global R²: 0.1033
#   ➤ Pearson r: 0.3353 (p=5.80e-05)
#   ➤ Spearman ρ: 0.4151 (p=4.13e-07)
#   ➤ RMSE: 0.9636
#
# 🌲 Drug 1086 | Samples: 138
#   ➤ Global R²: 0.3498
#   ➤ Pearson r: 0.5968 (p=1.12e-14)
#   ➤ Spearman ρ: 0.5970 (p=1.10e-14)
#   ➤ RMSE: 1.8351
#
# 🌲 Drug 1088 | Samples: 138
#   ➤ Global R²: 0.1760
#   ➤ Pearson r: 0.4199 (p=2.94e-07)
#   ➤ Spearman ρ: 0.4224 (p=2.45e-07)
#   ➤ RMSE: 1.5556
#
# 🌲 Drug 1089 | Samples: 138
#   ➤ Global R²: 0.2963
#   ➤ Pearson r: 0.5455 (p=4.58e-12)
#   ➤ Spearman ρ: 0.5217 (p=5.32e-11)
#   ➤ RMSE: 1.2751
#
# 🌲 Drug 1091 | Samples: 134
#   ➤ Global R²: -0.0061
#   ➤ Pearson r: 0.1624 (p=6.09e-02)
#   ➤ Spearman ρ: 0.1361 (p=1.17e-01)
#   ➤ RMSE: 1.1320
#
# 🌲 Drug 1093 | Samples: 138
#   ➤ Global R²: 0.0225
#   ➤ Pearson r: 0.2162 (p=1.09e-02)
#   ➤ Spearman ρ: 0.2207 (p=9.28e-03)
#   ➤ RMSE: 0.9902
# ⚠️ Skipped drug 1096 (samples: 39)
#
# 🌲 Drug 1114 | Samples: 121
#   ➤ Global R²: -0.0327
#   ➤ Pearson r: 0.1326 (p=1.47e-01)
#   ➤ Spearman ρ: 0.1223 (p=1.81e-01)
#   ➤ RMSE: 1.1661
#
# 🌲 Drug 1128 | Samples: 135
#   ➤ Global R²: -0.0196
#   ➤ Pearson r: 0.1619 (p=6.07e-02)
#   ➤ Spearman ρ: 0.2565 (p=2.67e-03)
#   ➤ RMSE: 1.2746
#
# 🌲 Drug 1129 | Samples: 134
#   ➤ Global R²: -0.1322
#   ➤ Pearson r: -0.1042 (p=2.31e-01)
#   ➤ Spearman ρ: -0.0008 (p=9.93e-01)
#   ➤ RMSE: 0.9113
#
# 🌲 Drug 1131 | Samples: 133
#   ➤ Global R²: 0.0211
#   ➤ Pearson r: 0.1877 (p=3.05e-02)
#   ➤ Spearman ρ: 0.1959 (p=2.39e-02)
#   ➤ RMSE: 1.6159
#
# 🌲 Drug 1133 | Samples: 135
#   ➤ Global R²: 0.1098
#   ➤ Pearson r: 0.3364 (p=6.61e-05)
#   ➤ Spearman ρ: 0.3433 (p=4.59e-05)
#   ➤ RMSE: 0.9016
#
# 🌲 Drug 1135 | Samples: 133
#   ➤ Global R²: 0.1405
#   ➤ Pearson r: 0.3756 (p=8.37e-06)
#   ➤ Spearman ρ: 0.3698 (p=1.19e-05)
#   ➤ RMSE: 1.2112
#
# 🌲 Drug 1136 | Samples: 134
#   ➤ Global R²: 0.1757
#   ➤ Pearson r: 0.4316 (p=1.93e-07)
#   ➤ Spearman ρ: 0.4756 (p=6.35e-09)
#   ➤ RMSE: 1.6044
# ⚠️ Skipped drug 1142 (samples: 74)
# ⚠️ Skipped drug 1143 (samples: 74)
# ⚠️ Skipped drug 1145 (samples: 13)
#
# 🌲 Drug 1149 | Samples: 135
#   ➤ Global R²: 0.0105
#   ➤ Pearson r: 0.2080 (p=1.55e-02)
#   ➤ Spearman ρ: 0.2320 (p=6.78e-03)
#   ➤ RMSE: 1.1886
# ⚠️ Skipped drug 1155 (samples: 13)
# ⚠️ Skipped drug 1157 (samples: 13)
# ⚠️ Skipped drug 1158 (samples: 74)
# ⚠️ Skipped drug 1161 (samples: 74)
# ⚠️ Skipped drug 1164 (samples: 74)
# ⚠️ Skipped drug 1165 (samples: 13)
# ⚠️ Skipped drug 1166 (samples: 74)
# ⚠️ Skipped drug 1167 (samples: 12)
#
# 🌲 Drug 1168 | Samples: 138
#   ➤ Global R²: 0.0555
#   ➤ Pearson r: 0.2429 (p=4.09e-03)
#   ➤ Spearman ρ: 0.2302 (p=6.60e-03)
#   ➤ RMSE: 1.3278
#
# 🌲 Drug 1170 | Samples: 135
#   ➤ Global R²: 0.0776
#   ➤ Pearson r: 0.2923 (p=5.81e-04)
#   ➤ Spearman ρ: 0.3039 (p=3.40e-04)
#   ➤ RMSE: 0.9683
#
# 🌲 Drug 1175 | Samples: 135
#   ➤ Global R²: 0.0742
#   ➤ Pearson r: 0.2840 (p=8.43e-04)
#   ➤ Spearman ρ: 0.2942 (p=5.32e-04)
#   ➤ RMSE: 0.9318
#
# 🌲 Drug 1177 | Samples: 133
#   ➤ Global R²: 0.0800
#   ➤ Pearson r: 0.3179 (p=1.92e-04)
#   ➤ Spearman ρ: 0.2618 (p=2.34e-03)
#   ➤ RMSE: 1.1471
#
# 🌲 Drug 1179 | Samples: 138
#   ➤ Global R²: 0.2544
#   ➤ Pearson r: 0.5045 (p=2.81e-10)
#   ➤ Spearman ρ: 0.4933 (p=7.89e-10)
#   ➤ RMSE: 1.1462
#
# 🌲 Drug 1180 | Samples: 132
#   ➤ Global R²: 0.1980
#   ➤ Pearson r: 0.4483 (p=7.04e-08)
#   ➤ Spearman ρ: 0.4432 (p=1.03e-07)
#   ➤ RMSE: 1.3395
#
# 🌲 Drug 1183 | Samples: 135
#   ➤ Global R²: -0.1001
#   ➤ Pearson r: -0.0482 (p=5.79e-01)
#   ➤ Spearman ρ: -0.0511 (p=5.56e-01)
#   ➤ RMSE: 1.2450
#
# 🌲 Drug 1184 | Samples: 135
#   ➤ Global R²: 0.2129
#   ➤ Pearson r: 0.4618 (p=1.73e-08)
#   ➤ Spearman ρ: 0.4917 (p=1.40e-09)
#   ➤ RMSE: 0.9144
#
# 🌲 Drug 1185 | Samples: 134
#   ➤ Global R²: -0.0392
#   ➤ Pearson r: 0.1508 (p=8.20e-02)
#   ➤ Spearman ρ: 0.2138 (p=1.31e-02)
#   ➤ RMSE: 0.9963
#
# 🌲 Drug 1186 | Samples: 135
#   ➤ Global R²: 0.2383
#   ➤ Pearson r: 0.4898 (p=1.65e-09)
#   ➤ Spearman ρ: 0.4868 (p=2.14e-09)
#   ➤ RMSE: 1.2224
#
# 🌲 Drug 1187 | Samples: 135
#   ➤ Global R²: 0.0931
#   ➤ Pearson r: 0.3105 (p=2.47e-04)
#   ➤ Spearman ρ: 0.3321 (p=8.31e-05)
#   ➤ RMSE: 1.0346
#
# 🌲 Drug 1188 | Samples: 135
#   ➤ Global R²: 0.1002
#   ➤ Pearson r: 0.3175 (p=1.76e-04)
#   ➤ Spearman ρ: 0.3025 (p=3.63e-04)
#   ➤ RMSE: 0.9632
#
# 🌲 Drug 1190 | Samples: 138
#   ➤ Global R²: 0.2990
#   ➤ Pearson r: 0.5478 (p=3.56e-12)
#   ➤ Spearman ρ: 0.5367 (p=1.16e-11)
#   ➤ RMSE: 2.4907
#
# 🌲 Drug 1191 | Samples: 138
#   ➤ Global R²: 0.0785
#   ➤ Pearson r: 0.2970 (p=4.04e-04)
#   ➤ Spearman ρ: 0.3070 (p=2.50e-04)
#   ➤ RMSE: 1.2036
#
# 🌲 Drug 1192 | Samples: 134
#   ➤ Global R²: 0.1215
#   ➤ Pearson r: 0.3508 (p=3.25e-05)
#   ➤ Spearman ρ: 0.3292 (p=1.03e-04)
#   ➤ RMSE: 1.2552
#
# 🌲 Drug 1194 | Samples: 134
#   ➤ Global R²: -0.0253
#   ➤ Pearson r: 0.1403 (p=1.06e-01)
#   ➤ Spearman ρ: 0.0916 (p=2.93e-01)
#   ➤ RMSE: 0.8952
#
# 🌲 Drug 1195 | Samples: 134
#   ➤ Global R²: 0.0312
#   ➤ Pearson r: 0.2252 (p=8.88e-03)
#   ➤ Spearman ρ: 0.2054 (p=1.73e-02)
#   ➤ RMSE: 0.9760
#
# 🌲 Drug 1196 | Samples: 133
#   ➤ Global R²: 0.0261
#   ➤ Pearson r: 0.2132 (p=1.37e-02)
#   ➤ Spearman ρ: 0.1616 (p=6.32e-02)
#   ➤ RMSE: 1.0509
#
# 🌲 Drug 1197 | Samples: 133
#   ➤ Global R²: 0.1276
#   ➤ Pearson r: 0.3575 (p=2.40e-05)
#   ➤ Spearman ρ: 0.3234 (p=1.46e-04)
#   ➤ RMSE: 0.9930
#
# 🌲 Drug 1198 | Samples: 134
#   ➤ Global R²: 0.1135
#   ➤ Pearson r: 0.3400 (p=5.85e-05)
#   ➤ Spearman ρ: 0.3272 (p=1.14e-04)
#   ➤ RMSE: 0.8554
#
# 🌲 Drug 1199 | Samples: 134
#   ➤ Global R²: -0.0553
#   ➤ Pearson r: 0.0756 (p=3.85e-01)
#   ➤ Spearman ρ: 0.0765 (p=3.80e-01)
#   ➤ RMSE: 0.8591
#
# 🌲 Drug 1200 | Samples: 138
#   ➤ Global R²: 0.1087
#   ➤ Pearson r: 0.3451 (p=3.39e-05)
#   ➤ Spearman ρ: 0.4044 (p=8.71e-07)
#   ➤ RMSE: 0.8082
# ⚠️ Skipped drug 1202 (samples: 20)
# ⚠️ Skipped drug 1203 (samples: 70)
# ⚠️ Skipped drug 1204 (samples: 20)
#
# 🌲 Drug 1218 | Samples: 130
#   ➤ Global R²: -0.0794
#   ➤ Pearson r: 0.1220 (p=1.67e-01)
#   ➤ Spearman ρ: 0.1004 (p=2.56e-01)
#   ➤ RMSE: 0.6905
#
# 🌲 Drug 1219 | Samples: 134
#   ➤ Global R²: -0.0561
#   ➤ Pearson r: 0.0667 (p=4.44e-01)
#   ➤ Spearman ρ: 0.0863 (p=3.21e-01)
#   ➤ RMSE: 0.9326
#
# 🌲 Drug 1230 | Samples: 134
#   ➤ Global R²: -0.0149
#   ➤ Pearson r: 0.1500 (p=8.37e-02)
#   ➤ Spearman ρ: 0.1795 (p=3.79e-02)
#   ➤ RMSE: 0.8696
#
# 🌲 Drug 1232 | Samples: 130
#   ➤ Global R²: -0.0876
#   ➤ Pearson r: -0.0012 (p=9.89e-01)
#   ➤ Spearman ρ: 0.0227 (p=7.97e-01)
#   ➤ RMSE: 1.1311
#
# 🌲 Drug 1236 | Samples: 134
#   ➤ Global R²: -0.0280
#   ➤ Pearson r: 0.1524 (p=7.87e-02)
#   ➤ Spearman ρ: 0.1546 (p=7.44e-02)
#   ➤ RMSE: 1.4504
#
# 🌲 Drug 1237 | Samples: 138
#   ➤ Global R²: 0.1487
#   ➤ Pearson r: 0.3902 (p=2.23e-06)
#   ➤ Spearman ρ: 0.3467 (p=3.11e-05)
#   ➤ RMSE: 0.7545
#
# 🌲 Drug 1239 | Samples: 115
#   ➤ Global R²: 0.0987
#   ➤ Pearson r: 0.3219 (p=4.51e-04)
#   ➤ Spearman ρ: 0.3701 (p=4.68e-05)
#   ➤ RMSE: 1.0686
#
# 🌲 Drug 1241 | Samples: 130
#   ➤ Global R²: 0.0496
#   ➤ Pearson r: 0.2464 (p=4.72e-03)
#   ➤ Spearman ρ: 0.2104 (p=1.63e-02)
#   ➤ RMSE: 0.9891
#
# 🌲 Drug 1242 | Samples: 130
#   ➤ Global R²: 0.2394
#   ➤ Pearson r: 0.4907 (p=3.08e-09)
#   ➤ Spearman ρ: 0.3486 (p=4.83e-05)
#   ➤ RMSE: 1.2557
#
# 🌲 Drug 1243 | Samples: 134
#   ➤ Global R²: 0.0856
#   ➤ Pearson r: 0.3041 (p=3.54e-04)
#   ➤ Spearman ρ: 0.3691 (p=1.14e-05)
#   ➤ RMSE: 0.9320
#
# 🌲 Drug 1248 | Samples: 127
#   ➤ Global R²: 0.2284
#   ➤ Pearson r: 0.4846 (p=7.76e-09)
#   ➤ Spearman ρ: 0.4655 (p=3.49e-08)
#   ➤ RMSE: 2.2990
#
# 🌲 Drug 1249 | Samples: 133
#   ➤ Global R²: 0.1634
#   ➤ Pearson r: 0.4166 (p=6.13e-07)
#   ➤ Spearman ρ: 0.4202 (p=4.78e-07)
#   ➤ RMSE: 1.1338
#
# 🌲 Drug 1250 | Samples: 133
#   ➤ Global R²: 0.1531
#   ➤ Pearson r: 0.3913 (p=3.21e-06)
#   ➤ Spearman ρ: 0.3785 (p=7.06e-06)
#   ➤ RMSE: 1.4264
#
# 🌲 Drug 1251 | Samples: 134
#   ➤ Global R²: 0.0180
#   ➤ Pearson r: 0.1843 (p=3.31e-02)
#   ➤ Spearman ρ: 0.1358 (p=1.18e-01)
#   ➤ RMSE: 0.9022
#
# 🌲 Drug 1252 | Samples: 133
#   ➤ Global R²: -0.0603
#   ➤ Pearson r: 0.0806 (p=3.56e-01)
#   ➤ Spearman ρ: 0.0578 (p=5.09e-01)
#   ➤ RMSE: 0.7256
#
# 🌲 Drug 1253 | Samples: 130
#   ➤ Global R²: -0.0108
#   ➤ Pearson r: 0.1765 (p=4.46e-02)
#   ➤ Spearman ρ: 0.2292 (p=8.72e-03)
#   ➤ RMSE: 0.6033
#
# 🌲 Drug 1254 | Samples: 130
#   ➤ Global R²: 0.0621
#   ➤ Pearson r: 0.2698 (p=1.91e-03)
#   ➤ Spearman ρ: 0.3157 (p=2.54e-04)
#   ➤ RMSE: 1.3250
#
# 🌲 Drug 1259 | Samples: 130
#   ➤ Global R²: 0.2497
#   ➤ Pearson r: 0.5025 (p=1.11e-09)
#   ➤ Spearman ρ: 0.4655 (p=2.40e-08)
#   ➤ RMSE: 1.5983
#
# 🌲 Drug 1261 | Samples: 130
#   ➤ Global R²: -0.0703
#   ➤ Pearson r: 0.0560 (p=5.27e-01)
#   ➤ Spearman ρ: 0.0922 (p=2.97e-01)
#   ➤ RMSE: 1.4013
#
# 🌲 Drug 1262 | Samples: 126
#   ➤ Global R²: 0.1276
#   ➤ Pearson r: 0.3582 (p=3.82e-05)
#   ➤ Spearman ρ: 0.3892 (p=6.65e-06)
#   ➤ RMSE: 0.5035
#
# 🌲 Drug 1263 | Samples: 125
#   ➤ Global R²: -0.0149
#   ➤ Pearson r: 0.2021 (p=2.38e-02)
#   ➤ Spearman ρ: 0.2315 (p=9.39e-03)
#   ➤ RMSE: 0.6139
#
# 🌲 Drug 1264 | Samples: 126
#   ➤ Global R²: 0.1055
#   ➤ Pearson r: 0.3386 (p=1.05e-04)
#   ➤ Spearman ρ: 0.2982 (p=6.94e-04)
#   ➤ RMSE: 0.5090
#
# 🌲 Drug 1266 | Samples: 129
#   ➤ Global R²: 0.0803
#   ➤ Pearson r: 0.3033 (p=4.75e-04)
#   ➤ Spearman ρ: 0.2929 (p=7.57e-04)
#   ➤ RMSE: 1.5755
#
# 🌲 Drug 1268 | Samples: 130
#   ➤ Global R²: -0.0430
#   ➤ Pearson r: 0.1371 (p=1.20e-01)
#   ➤ Spearman ρ: 0.1507 (p=8.70e-02)
#   ➤ RMSE: 1.0056
#
# 🌲 Drug 1359 | Samples: 122
#   ➤ Global R²: 0.1002
#   ➤ Pearson r: 0.3217 (p=3.02e-04)
#   ➤ Spearman ρ: 0.3037 (p=6.73e-04)
#   ➤ RMSE: 0.9304
#
# 🌲 Drug 1360 | Samples: 122
#   ➤ Global R²: 0.0162
#   ➤ Pearson r: 0.2145 (p=1.77e-02)
#   ➤ Spearman ρ: 0.2008 (p=2.66e-02)
#   ➤ RMSE: 0.7869
#
# 🌲 Drug 1362 | Samples: 122
#   ➤ Global R²: 0.0092
#   ➤ Pearson r: 0.1671 (p=6.58e-02)
#   ➤ Spearman ρ: 0.2150 (p=1.74e-02)
#   ➤ RMSE: 0.6994
#
# 🌲 Drug 1363 | Samples: 122
#   ➤ Global R²: 0.0760
#   ➤ Pearson r: 0.2798 (p=1.80e-03)
#   ➤ Spearman ρ: 0.3247 (p=2.64e-04)
#   ➤ RMSE: 1.2977
#
# 🌲 Drug 1364 | Samples: 122
#   ➤ Global R²: 0.1087
#   ➤ Pearson r: 0.3402 (p=1.26e-04)
#   ➤ Spearman ρ: 0.3368 (p=1.49e-04)
#   ➤ RMSE: 1.1008
#
# 🌲 Drug 1365 | Samples: 122
#   ➤ Global R²: 0.0421
#   ➤ Pearson r: 0.2379 (p=8.34e-03)
#   ➤ Spearman ρ: 0.2933 (p=1.04e-03)
#   ➤ RMSE: 1.0211
#
# 🌲 Drug 1367 | Samples: 122
#   ➤ Global R²: 0.0936
#   ➤ Pearson r: 0.3065 (p=5.96e-04)
#   ➤ Spearman ρ: 0.3130 (p=4.48e-04)
#   ➤ RMSE: 0.9525
#
# 🌲 Drug 1368 | Samples: 122
#   ➤ Global R²: 0.2601
#   ➤ Pearson r: 0.5112 (p=1.79e-09)
#   ➤ Spearman ρ: 0.4855 (p=1.45e-08)
#   ➤ RMSE: 1.2945
#
# 🌲 Drug 1369 | Samples: 106
#   ➤ Global R²: 0.2102
#   ➤ Pearson r: 0.4627 (p=5.92e-07)
#   ➤ Spearman ρ: 0.4039 (p=1.76e-05)
#   ➤ RMSE: 1.2195
#
# 🌲 Drug 1370 | Samples: 107
#   ➤ Global R²: 0.1861
#   ➤ Pearson r: 0.4360 (p=2.67e-06)
#   ➤ Spearman ρ: 0.4148 (p=8.93e-06)
#   ➤ RMSE: 1.2152
#
# 🌲 Drug 1371 | Samples: 133
#   ➤ Global R²: 0.1225
#   ➤ Pearson r: 0.3912 (p=3.22e-06)
#   ➤ Spearman ρ: 0.3048 (p=3.61e-04)
#   ➤ RMSE: 1.2868
#
# 🌲 Drug 1372 | Samples: 125
#   ➤ Global R²: 0.2585
#   ➤ Pearson r: 0.5111 (p=1.13e-09)
#   ➤ Spearman ρ: 0.4480 (p=1.61e-07)
#   ➤ RMSE: 2.1394
#
# 🌲 Drug 1373 | Samples: 119
#   ➤ Global R²: 0.2921
#   ➤ Pearson r: 0.5414 (p=2.05e-10)
#   ➤ Spearman ρ: 0.2572 (p=4.75e-03)
#   ➤ RMSE: 1.7596
#
# 🌲 Drug 1375 | Samples: 126
#   ➤ Global R²: 0.0508
#   ➤ Pearson r: 0.2420 (p=6.33e-03)
#   ➤ Spearman ρ: 0.2002 (p=2.46e-02)
#   ➤ RMSE: 0.5983
#
# 🌲 Drug 1377 | Samples: 129
#   ➤ Global R²: 0.0020
#   ➤ Pearson r: 0.1927 (p=2.87e-02)
#   ➤ Spearman ρ: 0.0666 (p=4.53e-01)
#   ➤ RMSE: 1.5651
#
# 🌲 Drug 1378 | Samples: 135
#   ➤ Global R²: 0.1685
#   ➤ Pearson r: 0.4143 (p=5.88e-07)
#   ➤ Spearman ρ: 0.3512 (p=2.96e-05)
#   ➤ RMSE: 1.8051
#
# 🌲 Drug 1379 | Samples: 134
#   ➤ Global R²: 0.1921
#   ➤ Pearson r: 0.4430 (p=8.33e-08)
#   ➤ Spearman ρ: 0.3784 (p=6.54e-06)
#   ➤ RMSE: 0.7945
#
# 🌲 Drug 1382 | Samples: 135
#   ➤ Global R²: -0.0086
#   ➤ Pearson r: 0.1283 (p=1.38e-01)
#   ➤ Spearman ρ: 0.1449 (p=9.35e-02)
#   ➤ RMSE: 0.8806
#
# 🌲 Drug 1386 | Samples: 135
#   ➤ Global R²: 0.2314
#   ➤ Pearson r: 0.4815 (p=3.37e-09)
#   ➤ Spearman ρ: 0.4699 (p=8.91e-09)
#   ➤ RMSE: 1.1515
#
# 🌲 Drug 1392 | Samples: 134
#   ➤ Global R²: 0.1967
#   ➤ Pearson r: 0.4454 (p=6.96e-08)
#   ➤ Spearman ρ: 0.3794 (p=6.17e-06)
#   ➤ RMSE: 1.5915
#
# 🌲 Drug 1393 | Samples: 135
#   ➤ Global R²: 0.1656
#   ➤ Pearson r: 0.4074 (p=9.36e-07)
#   ➤ Spearman ρ: 0.3950 (p=2.13e-06)
#   ➤ RMSE: 1.3403
#
# 🌲 Drug 1394 | Samples: 135
#   ➤ Global R²: 0.1777
#   ➤ Pearson r: 0.4224 (p=3.34e-07)
#   ➤ Spearman ρ: 0.4931 (p=1.23e-09)
#   ➤ RMSE: 1.0923
#
# 🌲 Drug 1401 | Samples: 132
#   ➤ Global R²: 0.2051
#   ➤ Pearson r: 0.4556 (p=4.05e-08)
#   ➤ Spearman ρ: 0.4255 (p=3.65e-07)
#   ➤ RMSE: 0.7653
#
# 🌲 Drug 1402 | Samples: 133
#   ➤ Global R²: 0.1602
#   ➤ Pearson r: 0.4004 (p=1.79e-06)
#   ➤ Spearman ρ: 0.3060 (p=3.41e-04)
#   ➤ RMSE: 1.1938
#
# 🌲 Drug 1403 | Samples: 135
#   ➤ Global R²: -0.1518
#   ➤ Pearson r: -0.0430 (p=6.20e-01)
#   ➤ Spearman ρ: 0.0510 (p=5.57e-01)
#   ➤ RMSE: 1.3799
#
# 🌲 Drug 1407 | Samples: 133
#   ➤ Global R²: -0.1216
#   ➤ Pearson r: 0.0096 (p=9.13e-01)
#   ➤ Spearman ρ: 0.1299 (p=1.36e-01)
#   ➤ RMSE: 0.9583
#
# 🌲 Drug 1409 | Samples: 133
#   ➤ Global R²: 0.0797
#   ➤ Pearson r: 0.2954 (p=5.57e-04)
#   ➤ Spearman ρ: 0.2946 (p=5.78e-04)
#   ➤ RMSE: 1.5023
#
# 🌲 Drug 1413 | Samples: 133
#   ➤ Global R²: 0.0694
#   ➤ Pearson r: 0.2704 (p=1.65e-03)
#   ➤ Spearman ρ: 0.2704 (p=1.65e-03)
#   ➤ RMSE: 1.1704
#
# 🌲 Drug 1414 | Samples: 132
#   ➤ Global R²: -0.0050
#   ➤ Pearson r: 0.1847 (p=3.40e-02)
#   ➤ Spearman ρ: 0.1753 (p=4.44e-02)
#   ➤ RMSE: 0.8756
#
# 🌲 Drug 1416 | Samples: 132
#   ➤ Global R²: -0.0706
#   ➤ Pearson r: 0.0929 (p=2.89e-01)
#   ➤ Spearman ρ: 0.1145 (p=1.91e-01)
#   ➤ RMSE: 1.3500
#
# 🌲 Drug 1419 | Samples: 132
#   ➤ Global R²: 0.1798
#   ➤ Pearson r: 0.4365 (p=1.68e-07)
#   ➤ Spearman ρ: 0.3855 (p=4.99e-06)
#   ➤ RMSE: 0.9767
#
# ...
#   ➤ Pearson r: 0.0644 (p=4.53e-01)
#   ➤ Spearman ρ: 0.0729 (p=3.96e-01)
#   ➤ RMSE: 1.4359
#
# 🌲 Drug 1998 | Samples: 114
#   ➤ Global R²: 0.0113
#   ➤ Pearson r: 0.2035 (p=2.99e-02)
#   ➤ Spearman ρ: 0.1522 (p=1.06e-01)
#   ➤ RMSE: 0.8734
#
# 🌲 Drug 1999 | Samples: 114
#   ➤ Global R²: -0.0476
#   ➤ Pearson r: 0.0678 (p=4.74e-01)
#   ➤ Spearman ρ: 0.0457 (p=6.29e-01)
#   ➤ RMSE: 1.1530
#
# 🌲 Drug 2000 | Samples: 114
#   ➤ Global R²: 0.0088
#   ➤ Pearson r: 0.1979 (p=3.48e-02)
#   ➤ Spearman ρ: 0.1823 (p=5.23e-02)
#   ➤ RMSE: 0.7631
#
# 🌲 Drug 2002 | Samples: 114
#   ➤ Global R²: 0.0003
#   ➤ Pearson r: 0.1753 (p=6.21e-02)
#   ➤ Spearman ρ: 0.1436 (p=1.27e-01)
#   ➤ RMSE: 0.8344
#
# 🌲 Drug 2003 | Samples: 114
#   ➤ Global R²: 0.1325
#   ➤ Pearson r: 0.3640 (p=6.85e-05)
#   ➤ Spearman ρ: 0.3584 (p=9.04e-05)
#   ➤ RMSE: 0.7746
#
# 🌲 Drug 2010 | Samples: 113
#   ➤ Global R²: 0.0838
#   ➤ Pearson r: 0.3077 (p=9.14e-04)
#   ➤ Spearman ρ: 0.3039 (p=1.07e-03)
#   ➤ RMSE: 1.3572
#
# 🌲 Drug 2011 | Samples: 113
#   ➤ Global R²: 0.3272
#   ➤ Pearson r: 0.5765 (p=2.36e-11)
#   ➤ Spearman ρ: 0.4876 (p=4.32e-08)
#   ➤ RMSE: 0.9475
#
# 🌲 Drug 2037 | Samples: 113
#   ➤ Global R²: 0.1935
#   ➤ Pearson r: 0.4400 (p=1.08e-06)
#   ➤ Spearman ρ: 0.4355 (p=1.43e-06)
#   ➤ RMSE: 1.0370
#
# 🌲 Drug 2038 | Samples: 111
#   ➤ Global R²: 0.0278
#   ➤ Pearson r: 0.2093 (p=2.75e-02)
#   ➤ Spearman ρ: 0.1741 (p=6.77e-02)
#   ➤ RMSE: 1.1049
#
# 🌲 Drug 2039 | Samples: 134
#   ➤ Global R²: -0.1002
#   ➤ Pearson r: 0.0298 (p=7.33e-01)
#   ➤ Spearman ρ: 0.0746 (p=3.92e-01)
#   ➤ RMSE: 0.9843
#
# 🌲 Drug 2040 | Samples: 138
#   ➤ Global R²: 0.0614
#   ➤ Pearson r: 0.2857 (p=6.83e-04)
#   ➤ Spearman ρ: 0.3729 (p=6.66e-06)
#   ➤ RMSE: 1.3113
#
# 🌲 Drug 2043 | Samples: 138
#   ➤ Global R²: -0.0056
#   ➤ Pearson r: 0.1571 (p=6.58e-02)
#   ➤ Spearman ρ: 0.1722 (p=4.34e-02)
#   ➤ RMSE: 0.9047
#
# 🌲 Drug 2044 | Samples: 137
#   ➤ Global R²: 0.1400
#   ➤ Pearson r: 0.3762 (p=5.88e-06)
#   ➤ Spearman ρ: 0.3538 (p=2.23e-05)
#   ➤ RMSE: 1.0345
#
# 🌲 Drug 2045 | Samples: 138
#   ➤ Global R²: -0.0721
#   ➤ Pearson r: 0.0267 (p=7.56e-01)
#   ➤ Spearman ρ: 0.0717 (p=4.03e-01)
#   ➤ RMSE: 0.9576
#
# 🌲 Drug 2046 | Samples: 138
#   ➤ Global R²: -0.0606
#   ➤ Pearson r: 0.0216 (p=8.02e-01)
#   ➤ Spearman ρ: 0.0694 (p=4.19e-01)
#   ➤ RMSE: 1.4036
#
# 🌲 Drug 2047 | Samples: 113
#   ➤ Global R²: 0.1665
#   ➤ Pearson r: 0.4085 (p=7.07e-06)
#   ➤ Spearman ρ: 0.3996 (p=1.16e-05)
#   ➤ RMSE: 1.2834
#
# 🌲 Drug 2048 | Samples: 136
#   ➤ Global R²: 0.2184
#   ➤ Pearson r: 0.4681 (p=9.10e-09)
#   ➤ Spearman ρ: 0.4482 (p=4.47e-08)
#   ➤ RMSE: 1.8509
#
# 🌲 Drug 2055 | Samples: 112
#   ➤ Global R²: 0.1451
#   ➤ Pearson r: 0.4003 (p=1.22e-05)
#   ➤ Spearman ρ: 0.4208 (p=3.84e-06)
#   ➤ RMSE: 1.4089
# ⚠️ Skipped drug 2057 (samples: 68)
#
# 🌲 Drug 2096 | Samples: 137
#   ➤ Global R²: 0.2637
#   ➤ Pearson r: 0.5139 (p=1.34e-10)
#   ➤ Spearman ρ: 0.5310 (p=2.47e-11)
#   ➤ RMSE: 1.2255
#
# 🌲 Drug 2106 | Samples: 112
#   ➤ Global R²: 0.0197
#   ➤ Pearson r: 0.1940 (p=4.04e-02)
#   ➤ Spearman ρ: 0.1904 (p=4.44e-02)
#   ➤ RMSE: 1.9248
#
# 🌲 Drug 2107 | Samples: 137
#   ➤ Global R²: 0.1228
#   ➤ Pearson r: 0.3597 (p=1.58e-05)
#   ➤ Spearman ρ: 0.3541 (p=2.18e-05)
#   ➤ RMSE: 0.9661
#
# 🌲 Drug 2109 | Samples: 137
#   ➤ Global R²: 0.1314
#   ➤ Pearson r: 0.3711 (p=8.02e-06)
#   ➤ Spearman ρ: 0.4258 (p=2.13e-07)
#   ➤ RMSE: 1.1515
#
# 🌲 Drug 2110 | Samples: 137
#   ➤ Global R²: 0.1496
#   ➤ Pearson r: 0.3885 (p=2.72e-06)
#   ➤ Spearman ρ: 0.3030 (p=3.19e-04)
#   ➤ RMSE: 0.9980
#
# 🌲 Drug 2111 | Samples: 136
#   ➤ Global R²: 0.2338
#   ➤ Pearson r: 0.4838 (p=2.43e-09)
#   ➤ Spearman ρ: 0.5138 (p=1.58e-10)
#   ➤ RMSE: 1.1201
#
# 🌲 Drug 2112 | Samples: 112
#   ➤ Global R²: -0.1636
#   ➤ Pearson r: -0.1628 (p=8.64e-02)
#   ➤ Spearman ρ: -0.1843 (p=5.18e-02)
#   ➤ RMSE: 0.7891
#
# 🌲 Drug 2113 | Samples: 112
#   ➤ Global R²: -0.0472
#   ➤ Pearson r: 0.0940 (p=3.24e-01)
#   ➤ Spearman ρ: 0.0918 (p=3.36e-01)
#   ➤ RMSE: 0.7298
#
# 🌲 Drug 2145 | Samples: 112
#   ➤ Global R²: 0.2464
#   ➤ Pearson r: 0.4987 (p=2.19e-08)
#   ➤ Spearman ρ: 0.5285 (p=2.11e-09)
#   ➤ RMSE: 1.3788
#
# 🌲 Drug 2148 | Samples: 112
#   ➤ Global R²: 0.1340
#   ➤ Pearson r: 0.3722 (p=5.33e-05)
#   ➤ Spearman ρ: 0.3615 (p=8.98e-05)
#   ➤ RMSE: 1.1769
#
# 🌲 Drug 2149 | Samples: 112
#   ➤ Global R²: 0.1308
#   ➤ Pearson r: 0.3942 (p=1.70e-05)
#   ➤ Spearman ρ: 0.4692 (p=1.81e-07)
#   ➤ RMSE: 1.0880
#
# 🌲 Drug 2154 | Samples: 112
#   ➤ Global R²: 0.0678
#   ➤ Pearson r: 0.2828 (p=2.52e-03)
#   ➤ Spearman ρ: 0.2733 (p=3.55e-03)
#   ➤ RMSE: 0.8623
#
# 🌲 Drug 2156 | Samples: 112
#   ➤ Global R²: 0.3165
#   ➤ Pearson r: 0.5714 (p=4.74e-11)
#   ➤ Spearman ρ: 0.5416 (p=7.01e-10)
#   ➤ RMSE: 1.1682
#
# 🌲 Drug 2157 | Samples: 112
#   ➤ Global R²: 0.1475
#   ➤ Pearson r: 0.3843 (p=2.88e-05)
#   ➤ Spearman ρ: 0.4139 (p=5.73e-06)
#   ➤ RMSE: 0.8489
#
# 🌲 Drug 2158 | Samples: 112
#   ➤ Global R²: -0.0631
#   ➤ Pearson r: 0.0829 (p=3.85e-01)
#   ➤ Spearman ρ: 0.0723 (p=4.49e-01)
#   ➤ RMSE: 1.1923
#
# 🌲 Drug 2159 | Samples: 112
#   ➤ Global R²: 0.1375
#   ➤ Pearson r: 0.3907 (p=2.06e-05)
#   ➤ Spearman ρ: 0.4036 (p=1.02e-05)
#   ➤ RMSE: 1.1019
# ⚠️ Skipped drug 2169 (samples: 39)
#
# 🌲 Drug 2170 | Samples: 137
#   ➤ Global R²: 0.1111
#   ➤ Pearson r: 0.3336 (p=6.79e-05)
#   ➤ Spearman ρ: 0.3073 (p=2.60e-04)
#   ➤ RMSE: 1.5295
#
# 🌲 Drug 2171 | Samples: 138
#   ➤ Global R²: 0.0906
#   ➤ Pearson r: 0.3289 (p=8.21e-05)
#   ➤ Spearman ρ: 0.3177 (p=1.47e-04)
#   ➤ RMSE: 1.8677
#
# 🌲 Drug 2172 | Samples: 138
#   ➤ Global R²: 0.0308
#   ➤ Pearson r: 0.2424 (p=4.18e-03)
#   ➤ Spearman ρ: 0.2888 (p=5.92e-04)
#   ➤ RMSE: 1.6927
#
# 🌲 Drug 2173 | Samples: 136
#   ➤ Global R²: 0.0304
#   ➤ Pearson r: 0.2645 (p=1.86e-03)
#   ➤ Spearman ρ: 0.2564 (p=2.59e-03)
#   ➤ RMSE: 0.9344
# ⚠️ Skipped drug 2174 (samples: 27)
# ⚠️ Skipped drug 2175 (samples: 27)
#
# 🌲 Drug 2177 | Samples: 136
#   ➤ Global R²: -0.1225
#   ➤ Pearson r: -0.0874 (p=3.12e-01)
#   ➤ Spearman ρ: -0.0954 (p=2.69e-01)
#   ➤ RMSE: 0.7715
#
# 🌲 Drug 2359 | Samples: 113
#   ➤ Global R²: 0.1744
#   ➤ Pearson r: 0.4199 (p=3.66e-06)
#   ➤ Spearman ρ: 0.4183 (p=4.01e-06)
#   ➤ RMSE: 0.7190
#
# 🌲 Drug 2360 | Samples: 113
#   ➤ Global R²: -0.0376
#   ➤ Pearson r: 0.1041 (p=2.73e-01)
#   ➤ Spearman ρ: 0.0185 (p=8.46e-01)
#   ➤ RMSE: 0.8040
#
# 🌲 Drug 2361 | Samples: 113
#   ➤ Global R²: 0.0319
#   ➤ Pearson r: 0.2058 (p=2.88e-02)
#   ➤ Spearman ρ: 0.2411 (p=1.01e-02)
#   ➤ RMSE: 0.8373
#
# 🌲 Drug 2362 | Samples: 113
#   ➤ Global R²: 0.1462
#   ➤ Pearson r: 0.3846 (p=2.60e-05)
#   ➤ Spearman ρ: 0.3183 (p=5.91e-04)
#   ➤ RMSE: 0.9489
#
# 🌲 Drug 2438 | Samples: 116
#   ➤ Global R²: 0.0480
#   ➤ Pearson r: 0.2352 (p=1.10e-02)
#   ➤ Spearman ρ: 0.1141 (p=2.23e-01)
#   ➤ RMSE: 1.1851
#
# 🌲 Drug 2439 | Samples: 116
#   ➤ Global R²: -0.0385
#   ➤ Pearson r: 0.1116 (p=2.33e-01)
#   ➤ Spearman ρ: 0.1132 (p=2.26e-01)
#   ➤ RMSE: 0.7786
#
# 🌲 Drug 2498 | Samples: 116
#   ➤ Global R²: -0.0483
#   ➤ Pearson r: 0.1044 (p=2.65e-01)
#   ➤ Spearman ρ: 0.0754 (p=4.21e-01)
#   ➤ RMSE: 0.8950
#
# 🌲 Drug 2499 | Samples: 116
#   ➤ Global R²: -0.0251
#   ➤ Pearson r: 0.1049 (p=2.62e-01)
#   ➤ Spearman ρ: 0.0622 (p=5.07e-01)
#   ➤ RMSE: 0.8630
#
# 🌲 Drug 2500 | Samples: 114
#   ➤ Global R²: 0.2633
#   ➤ Pearson r: 0.5144 (p=4.80e-09)
#   ➤ Spearman ρ: 0.5150 (p=4.57e-09)
#   ➤ RMSE: 1.7514
#
# 🌲 Drug 2501 | Samples: 114
#   ➤ Global R²: 0.1389
#   ➤ Pearson r: 0.3751 (p=3.92e-05)
#   ➤ Spearman ρ: 0.3481 (p=1.47e-04)
#   ➤ RMSE: 1.5607
#
# 🌲 Drug 2502 | Samples: 114
#   ➤ Global R²: 0.1847
#   ➤ Pearson r: 0.4298 (p=1.82e-06)
#   ➤ Spearman ρ: 0.4250 (p=2.44e-06)
#   ➤ RMSE: 1.5995
#
# 🌲 Drug 2503 | Samples: 138
#   ➤ Global R²: 0.2447
#   ➤ Pearson r: 0.4960 (p=6.15e-10)
#   ➤ Spearman ρ: 0.4693 (p=6.40e-09)
#   ➤ RMSE: 1.4024
#
# 🌲 Drug 2504 | Samples: 132
#   ➤ Global R²: 0.0215
#   ➤ Pearson r: 0.2270 (p=8.85e-03)
#   ➤ Spearman ρ: 0.2125 (p=1.44e-02)
#   ➤ RMSE: 2.1067
# ⚠️ Skipped drug 2505 (samples: 27)
#
# 🌲 Drug 2506 | Samples: 138
#   ➤ Global R²: 0.0721
#   ➤ Pearson r: 0.2752 (p=1.09e-03)
#   ➤ Spearman ρ: 0.2396 (p=4.65e-03)
#   ➤ RMSE: 1.1089
#
# 🌲 Drug 2507 | Samples: 137
#   ➤ Global R²: 0.0748
#   ➤ Pearson r: 0.2950 (p=4.66e-04)
#   ➤ Spearman ρ: 0.2908 (p=5.67e-04)
#   ➤ RMSE: 1.5231
#
# 🌲 Drug 2508 | Samples: 138
#   ➤ Global R²: 0.1835
#   ➤ Pearson r: 0.4298 (p=1.44e-07)
#   ➤ Spearman ρ: 0.4485 (p=3.44e-08)
#   ➤ RMSE: 0.8945
#
# 🌲 Drug 2509 | Samples: 138
#   ➤ Global R²: 0.1770
#   ➤ Pearson r: 0.4269 (p=1.78e-07)
#   ➤ Spearman ρ: 0.4126 (p=4.95e-07)
#   ➤ RMSE: 1.0266
#
# 🌲 Drug 2510 | Samples: 138
#   ➤ Global R²: 0.2137
#   ➤ Pearson r: 0.4679 (p=7.20e-09)
#   ➤ Spearman ρ: 0.4816 (p=2.24e-09)
#   ➤ RMSE: 1.6006
#
# 🌲 Drug 2511 | Samples: 134
#   ➤ Global R²: 0.1005
#   ➤ Pearson r: 0.3198 (p=1.65e-04)
#   ➤ Spearman ρ: 0.3452 (p=4.41e-05)
#   ➤ RMSE: 1.5152
#
# 🌲 Drug 2512 | Samples: 138
#   ➤ Global R²: 0.1275
#   ➤ Pearson r: 0.3620 (p=1.29e-05)
#   ➤ Spearman ρ: 0.3277 (p=8.71e-05)
#   ➤ RMSE: 1.0103
#
# 🌲 Drug 2513 | Samples: 138
#   ➤ Global R²: 0.1145
#   ➤ Pearson r: 0.3511 (p=2.42e-05)
#   ➤ Spearman ρ: 0.3787 (p=4.65e-06)
#   ➤ RMSE: 0.6927
#
# 🌲 Drug 2514 | Samples: 138
#   ➤ Global R²: -0.0078
#   ➤ Pearson r: 0.1519 (p=7.53e-02)
#   ➤ Spearman ρ: 0.1381 (p=1.06e-01)
#   ➤ RMSE: 1.1459
#
# 🌲 Drug 2515 | Samples: 138
#   ➤ Global R²: 0.1485
#   ➤ Pearson r: 0.3871 (p=2.73e-06)
#   ➤ Spearman ρ: 0.3896 (p=2.32e-06)
#   ➤ RMSE: 0.6889
#
# 🌲 Drug 2516 | Samples: 137
#   ➤ Global R²: 0.1541
#   ➤ Pearson r: 0.3956 (p=1.71e-06)
#   ➤ Spearman ρ: 0.3869 (p=3.02e-06)
#   ➤ RMSE: 1.2168
#
# 🌲 Drug 2517 | Samples: 138
#   ➤ Global R²: 0.1279
#   ➤ Pearson r: 0.3598 (p=1.46e-05)
#   ➤ Spearman ρ: 0.3596 (p=1.48e-05)
#   ➤ RMSE: 1.2642
#
# 🌲 Drug 2518 | Samples: 136
#   ➤ Global R²: -0.0478
#   ➤ Pearson r: 0.0864 (p=3.17e-01)
#   ➤ Spearman ρ: 0.0495 (p=5.67e-01)
#   ➤ RMSE: 0.8413
#
# 🌲 Drug 2519 | Samples: 138
#   ➤ Global R²: 0.0616
#   ➤ Pearson r: 0.2670 (p=1.55e-03)
#   ➤ Spearman ρ: 0.2668 (p=1.56e-03)
#   ➤ RMSE: 1.3204
#
# 🌲 Drug 2520 | Samples: 137
#   ➤ Global R²: 0.0053
#   ➤ Pearson r: 0.1850 (p=3.05e-02)
#   ➤ Spearman ρ: 0.2261 (p=7.88e-03)
#   ➤ RMSE: 0.9627
#
# 🌲 Drug 2521 | Samples: 138
#   ➤ Global R²: 0.1453
#   ➤ Pearson r: 0.3828 (p=3.58e-06)
#   ➤ Spearman ρ: 0.3637 (p=1.16e-05)
#   ➤ RMSE: 1.5305
#
# 🌲 Drug 2522 | Samples: 138
#   ➤ Global R²: 0.0782
#   ➤ Pearson r: 0.2845 (p=7.21e-04)
#   ➤ Spearman ρ: 0.3733 (p=6.48e-06)
#   ➤ RMSE: 0.8732
#
# 🌲 Drug 2523 | Samples: 137
#   ➤ Global R²: 0.0124
#   ➤ Pearson r: 0.1721 (p=4.43e-02)
#   ➤ Spearman ρ: 0.1767 (p=3.89e-02)
#   ➤ RMSE: 0.9145
# ⚠️ Skipped drug 2524 (samples: 27)
#
# 🌲 Drug 2525 | Samples: 137
#   ➤ Global R²: 0.0753
#   ➤ Pearson r: 0.2779 (p=1.01e-03)
#   ➤ Spearman ρ: 0.2814 (p=8.65e-04)
#   ➤ RMSE: 1.4209
#
# 🌲 Drug 2526 | Samples: 138
#   ➤ Global R²: 0.0867
#   ➤ Pearson r: 0.3048 (p=2.79e-04)
#   ➤ Spearman ρ: 0.3112 (p=2.03e-04)
#   ➤ RMSE: 0.8129
#
# 🌲 Drug 2527 | Samples: 138
#   ➤ Global R²: 0.1251
#   ➤ Pearson r: 0.3824 (p=3.69e-06)
#   ➤ Spearman ρ: 0.2685 (p=1.45e-03)
#   ➤ RMSE: 1.3815
# ⚠️ Skipped drug 2528 (samples: 27)
#
# 🌲 Drug 2529 | Samples: 137
#   ➤ Global R²: -0.0019
#   ➤ Pearson r: 0.1566 (p=6.76e-02)
#   ➤ Spearman ρ: 0.1639 (p=5.56e-02)
#   ➤ RMSE: 1.2717
# ⚠️ Skipped drug 2530 (samples: 27)
#
# 🌲 Drug 2531 | Samples: 137
#   ➤ Global R²: -0.0145
#   ➤ Pearson r: 0.1541 (p=7.21e-02)
#   ➤ Spearman ρ: 0.1728 (p=4.34e-02)
#   ➤ RMSE: 1.1470
#
# 🌲 Drug 2532 | Samples: 136
#   ➤ Global R²: 0.0194
#   ➤ Pearson r: 0.2113 (p=1.35e-02)
#   ➤ Spearman ρ: 0.2313 (p=6.75e-03)
#   ➤ RMSE: 0.8943
#
# 🌲 Drug 2533 | Samples: 138
#   ➤ Global R²: 0.2150
#   ➤ Pearson r: 0.4676 (p=7.37e-09)
#   ➤ Spearman ρ: 0.5015 (p=3.72e-10)
#   ➤ RMSE: 1.3111
#
# 🌲 Drug 2534 | Samples: 138
#   ➤ Global R²: 0.2001
#   ➤ Pearson r: 0.4482 (p=3.54e-08)
#   ➤ Spearman ρ: 0.4444 (p=4.77e-08)
#   ➤ RMSE: 1.3618
#
# 🌲 Drug 2535 | Samples: 133
#   ➤ Global R²: 0.2797
#   ➤ Pearson r: 0.5294 (p=5.69e-11)
#   ➤ Spearman ρ: 0.5450 (p=1.19e-11)
#   ➤ RMSE: 0.9730
#
# 🌲 Drug 2536 | Samples: 138
#   ➤ Global R²: 0.0494
#   ➤ Pearson r: 0.2608 (p=2.01e-03)
#   ➤ Spearman ρ: 0.2906 (p=5.45e-04)
#   ➤ RMSE: 1.1478
#
# 🌲 Drug 2537 | Samples: 137
#   ➤ Global R²: 0.1400
#   ➤ Pearson r: 0.3744 (p=6.57e-06)
#   ➤ Spearman ρ: 0.3689 (p=9.18e-06)
#   ➤ RMSE: 1.3475
#
# 🌲 Drug 2538 | Samples: 137
#   ➤ Global R²: 0.3045
#   ➤ Pearson r: 0.5552 (p=1.91e-12)
#   ➤ Spearman ρ: 0.5644 (p=6.87e-13)
#   ➤ RMSE: 1.2092
#
# 🌲 Drug 2539 | Samples: 138
#   ➤ Global R²: 0.0389
#   ➤ Pearson r: 0.2402 (p=4.54e-03)
#   ➤ Spearman ρ: 0.2503 (p=3.06e-03)
#   ➤ RMSE: 1.3483
#
# 🌲 Drug 2540 | Samples: 138
#   ➤ Global R²: 0.3530
#   ➤ Pearson r: 0.5947 (p=1.46e-14)
#   ➤ Spearman ρ: 0.5777 (p=1.18e-13)
#   ➤ RMSE: 0.9939
#
# 🌲 Drug 2541 | Samples: 138
#   ➤ Global R²: 0.2529
#   ➤ Pearson r: 0.5050 (p=2.67e-10)
#   ➤ Spearman ρ: 0.5050 (p=2.67e-10)
#   ➤ RMSE: 1.2718
#
# 🌲 Drug 2542 | Samples: 138
#   ➤ Global R²: 0.1248
#   ➤ Pearson r: 0.3681 (p=8.94e-06)
#   ➤ Spearman ρ: 0.2617 (p=1.93e-03)
#   ➤ RMSE: 1.1970
#
# 🌲 Drug 2543 | Samples: 112
#   ➤ Global R²: 0.2960
#   ➤ Pearson r: 0.5444 (p=5.49e-10)
#   ➤ Spearman ρ: 0.5133 (p=7.17e-09)
#   ➤ RMSE: 1.2053
#
# 🌲 Drug 2544 | Samples: 138
#   ➤ Global R²: 0.3205
#   ➤ Pearson r: 0.5664 (p=4.45e-13)
#   ➤ Spearman ρ: 0.5519 (p=2.28e-12)
#   ➤ RMSE: 1.7759
#
# 🌲 Drug 2545 | Samples: 137
#   ➤ Global R²: 0.2310
#   ➤ Pearson r: 0.4904 (p=1.18e-09)
#   ➤ Spearman ρ: 0.4448 (p=5.17e-08)
#   ➤ RMSE: 1.2019
#
# 🌲 Drug 2546 | Samples: 138
#   ➤ Global R²: 0.3002
#   ➤ Pearson r: 0.5483 (p=3.39e-12)
#   ➤ Spearman ρ: 0.5103 (p=1.62e-10)
#   ➤ RMSE: 1.4309
#
# 🌲 Drug 2547 | Samples: 137
#   ➤ Global R²: -0.0277
#   ➤ Pearson r: 0.1194 (p=1.65e-01)
#   ➤ Spearman ρ: 0.1417 (p=9.85e-02)
#   ➤ RMSE: 0.7964
#
# 🌲 Drug 2548 | Samples: 137
#   ➤ Global R²: 0.1189
#   ➤ Pearson r: 0.3455 (p=3.54e-05)
#   ➤ Spearman ρ: 0.3420 (p=4.31e-05)
#   ➤ RMSE: 0.9224
#
# 🌲 Drug 2549 | Samples: 138
#   ➤ Global R²: 0.1236
#   ➤ Pearson r: 0.3566 (p=1.76e-05)
#   ➤ Spearman ρ: 0.2489 (p=3.24e-03)
#   ➤ RMSE: 0.9007
#
# 🌲 Drug 2550 | Samples: 138
#   ➤ Global R²: 0.0961
#   ➤ Pearson r: 0.3173 (p=1.50e-04)
#   ➤ Spearman ρ: 0.2125 (p=1.24e-02)
#   ➤ RMSE: 1.1900
# ⚠️ Skipped drug 2551 (samples: 39)
#
# 🌲 Drug 2552 | Samples: 138
#   ➤ Global R²: 0.1548
#   ➤ Pearson r: 0.4046 (p=8.55e-07)
#   ➤ Spearman ρ: 0.3322 (p=6.86e-05)
#   ➤ RMSE: 1.0876
# ⚠️ Skipped drug 2553 (samples: 46)
# ⚠️ Skipped drug 2554 (samples: 27)
#
# 🌲 Drug 2555 | Samples: 137
#   ➤ Global R²: 0.1180
#   ➤ Pearson r: 0.3463 (p=3.40e-05)
#   ➤ Spearman ρ: 0.3428 (p=4.13e-05)
#   ➤ RMSE: 0.8963
# ⚠️ Skipped drug 2556 (samples: 39)
# ⚠️ Skipped drug 2557 (samples: 35)
#
# 🌲 Drug 2558 | Samples: 138
#   ➤ Global R²: -0.0271
#   ➤ Pearson r: 0.1131 (p=1.86e-01)
#   ➤ Spearman ρ: 0.1231 (p=1.50e-01)
#   ➤ RMSE: 1.1377
#
# 🌲 Drug 2559 | Samples: 138
#   ➤ Global R²: 0.1122
#   ➤ Pearson r: 0.3436 (p=3.69e-05)
#   ➤ Spearman ρ: 0.3408 (p=4.31e-05)
#   ➤ RMSE: 1.5438
# ⚠️ Skipped drug 2560 (samples: 27)
# ⚠️ Skipped drug 2561 (samples: 70)
#
# 🌲 Drug 2562 | Samples: 138
#   ➤ Global R²: 0.1506
#   ➤ Pearson r: 0.3885 (p=2.49e-06)
#   ➤ Spearman ρ: 0.4153 (p=4.10e-07)
#   ➤ RMSE: 1.7771
#
# 🌲 Drug 2563 | Samples: 133
#   ➤ Global R²: -0.0703
#   ➤ Pearson r: 0.0390 (p=6.56e-01)
#   ➤ Spearman ρ: 0.0380 (p=6.64e-01)
#   ➤ RMSE: 1.0283
#
# 🌲 Drug 2564 | Samples: 138
#   ➤ Global R²: 0.2967
#   ➤ Pearson r: 0.5466 (p=4.08e-12)
#   ➤ Spearman ρ: 0.5348 (p=1.41e-11)
#   ➤ RMSE: 1.8938
#
# 🌲 Drug 2565 | Samples: 137
#   ➤ Global R²: 0.1456
#   ➤ Pearson r: 0.4129 (p=5.34e-07)
#   ➤ Spearman ρ: 0.3434 (p=3.98e-05)
#   ➤ RMSE: 1.7567
#
# 🌲 Drug 2566 | Samples: 138
#   ➤ Global R²: 0.0754
#   ➤ Pearson r: 0.2864 (p=6.62e-04)
#   ➤ Spearman ρ: 0.2703 (p=1.35e-03)
#   ➤ RMSE: 0.9202
#
# 🌲 Drug 2567 | Samples: 113
#   ➤ Global R²: 0.1302
#   ➤ Pearson r: 0.3612 (p=8.48e-05)
#   ➤ Spearman ρ: 0.3601 (p=8.94e-05)
#   ➤ RMSE: 1.9864
#
# 🌲 Drug 2568 | Samples: 116
#   ➤ Global R²: 0.2543
#   ➤ Pearson r: 0.5071 (p=6.29e-09)
#   ➤ Spearman ρ: 0.5324 (p=7.69e-10)
#   ➤ RMSE: 1.1476
#
# 🌲 Drug 2569 | Samples: 115
#   ➤ Global R²: 0.0591
#   ➤ Pearson r: 0.2742 (p=3.02e-03)
#   ➤ Spearman ρ: 0.1924 (p=3.94e-02)
#   ➤ RMSE: 1.6154
#
# 🌲 Drug 2570 | Samples: 116
#   ➤ Global R²: 0.0995
#   ➤ Pearson r: 0.3271 (p=3.38e-04)
#   ➤ Spearman ρ: 0.3737 (p=3.60e-05)
#   ➤ RMSE: 1.4028
#
# 🌲 Drug 2571 | Samples: 116
#   ➤ Global R²: 0.0523
#   ➤ Pearson r: 0.2439 (p=8.33e-03)
#   ➤ Spearman ρ: 0.2716 (p=3.18e-03)
#   ➤ RMSE: 0.8258
#
# 🌲 Drug 2572 | Samples: 116
#   ➤ Global R²: -0.0220
#   ➤ Pearson r: 0.1238 (p=1.85e-01)
#   ➤ Spearman ρ: 0.1919 (p=3.91e-02)
#   ➤ RMSE: 1.3596
#
# 🌲 Drug 2573 | Samples: 137
#   ➤ Global R²: 0.0393
#   ➤ Pearson r: 0.2226 (p=8.94e-03)
#   ➤ Spearman ρ: 0.2324 (p=6.27e-03)
#   ➤ RMSE: 1.8537
# ⚠️ Skipped drug 2574 (samples: 27)
#
# 🌲 Drug 2575 | Samples: 138
#   ➤ Global R²: 0.1713
#   ➤ Pearson r: 0.4152 (p=4.12e-07)
#   ➤ Spearman ρ: 0.4402 (p=6.56e-08)
#   ➤ RMSE: 1.9655

# %%
results_df = pd.DataFrame(results)
results_df.to_csv(f"results/rf/10_fold_pseudobulk_scran_norm_top4000_30_pcs_tissue_growth.csv", index=False)

print("📁 Saved to rf/results/model_performance_summary.csv")
results_df.head()
# Out:
# 📁 Saved to rf/results/model_performance_summary.csv
#    DRUG_ID  n_samples  r2_global  pearson_r  pearson_pval  spearman_r  \
# 0      133        132   0.048712   0.240764      0.005421    0.270484
# 1      134        132   0.102730   0.324531      0.000147    0.310551
# 2      135        131   0.012254   0.187512      0.031980    0.174932
# 3      136        133  -0.016396   0.125283      0.150756    0.095587
# 4      140        133   0.000634   0.176087      0.042618    0.178385
#
#    spearman_pval      rmse
# 0       0.001708  1.652570
# 1       0.000290  1.811496
# 2       0.045669  2.594143
# 3       0.273753  1.519176
# 4       0.039944  1.637827

# %% [markdown]
# ### 📊 Distribution of RF Model Performance
# We now visualize the RMSE and R² scores to analyze how well the RF models performed across all drugs.

# %%
plt.figure(figsize=(8, 5))
sns.histplot(results_df["rmse"], kde=True, bins=30, color="darkorange")
plt.title(f"RMSE Distribution Across Drugs for {NUM_PCS} pcs (Random Forest, CV)")
plt.xlabel("RMSE")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(results_df["r2_global"], kde=True, bins=30, color="teal")
plt.title(f"R² Distribution Across Drugs for {NUM_PCS} pcs (Random Forest, CV)")
plt.xlabel("R² Score")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x="n_samples", y="r2_global", data=results_df)
plt.title("R² vs. Sample Size per Drug")
plt.xlabel("Number of Samples")
plt.ylabel("R² Score (CV mean)")
plt.grid(True)
plt.show()

# %%
from scipy.stats import pearsonr, spearmanr

# Pearson (linear)
pearson_corr, pval_pearson = pearsonr(results_df["n_samples"], results_df["r2_global"])
print(f"📊 Pearson r = {pearson_corr:.3f} (p = {pval_pearson:.3g})")

# Spearman (rank-based, robust to non-linearities)
spearman_corr, pval_spearman = spearmanr(results_df["n_samples"], results_df["r2_global"])
print(f"📊 Spearman ρ = {spearman_corr:.3f} (p = {pval_spearman:.3g})")
# Out:
# 📊 Pearson r = -0.076 (p = 0.057)
# 📊 Spearman ρ = 0.043 (p = 0.28)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(results_df["pearson_r"], kde=True, bins=30, color="mediumpurple")
plt.title("Distribution of Pearson r Across Drugs (Random Forest, 10-fold CV)")
plt.xlabel("Pearson r")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(results_df["spearman_r"], kde=True, bins=30, color="teal")
plt.title("Distribution of Spearman ρ Across Drugs (Random Forest, 10-fold CV)")
plt.xlabel("Spearman ρ")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="n_samples", y="pearson_r")
plt.title("Pearson r vs. Sample Size per Drug")
plt.xlabel("Number of Samples")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()
plt.close()

# %%
pearson_corr_r, pval_pearson_r = pearsonr(results_df["n_samples"], results_df["pearson_r"])
spearman_corr_r, pval_spearman_r = spearmanr(results_df["n_samples"], results_df["pearson_r"])

print(f"📊 Pearson r (sample size vs Pearson r) = {pearson_corr_r:.3f} (p = {pval_pearson_r:.3g})")
print(f"📊 Spearman ρ (sample size vs Pearson r) = {spearman_corr_r:.3f} (p = {pval_spearman_r:.3g})")
# Out:
# 📊 Pearson r (sample size vs Pearson r) = -0.073 (p = 0.0688)
# 📊 Spearman ρ (sample size vs Pearson r) = 0.044 (p = 0.276)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr, spearmanr

# ✅ 1) Pearson r vs. IC50 variance
# Already merged? If not, do:
variances = data.groupby("DRUG_ID")["LN_IC50"].var()
results_df = results_df.merge(variances.rename("ic50_variance"), on="DRUG_ID")

plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="ic50_variance", y="pearson_r")
plt.title("Pearson r vs. IC50 Variance per Drug")
plt.xlabel("IC50 Variance (LN_IC50)")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()

# Compute correlations
pearson_corr_var, pval_pearson_var = pearsonr(results_df["ic50_variance"], results_df["pearson_r"])
spearman_corr_var, pval_spearman_var = spearmanr(results_df["ic50_variance"], results_df["pearson_r"])
print(f"Pearson r (IC50 variance vs Pearson r) = {pearson_corr_var:.3f} (p = {pval_pearson_var:.3g})")
print(f"Spearman ρ (IC50 variance vs Pearson r) = {spearman_corr_var:.3f} (p = {pval_spearman_var:.3g})")

# ✅ 2) R² vs. Pearson r consistency plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="r2_global", y="pearson_r")
plt.title("Global R² vs. Pearson r per Drug")
plt.xlabel("Global R²")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()

# ✅ 3) Identify top & bottom 5 drugs by Pearson r
top5 = results_df.nlargest(5, "pearson_r")
bottom5 = results_df.nsmallest(5, "pearson_r")
print("\nTop 5 drugs by Pearson r:\n", top5[["DRUG_ID", "pearson_r", "r2_global", "rmse"]])
print("\nBottom 5 drugs by Pearson r:\n", bottom5[["DRUG_ID", "pearson_r", "r2_global", "rmse"]])

# ✅ 4) Optional: Save top/bottom drugs table
top_bottom = pd.concat([top5.assign(rank="top5"), bottom5.assign(rank="bottom5")])
top_bottom.to_csv("rf/results/top_bottom_pearson_r.csv", index=False)
print("\nSaved top/bottom drugs summary to rf/results/top_bottom_pearson_r.csv")

# ✅ 5) Optional: Feature importances for best vs. worst
# Refit models for top & bottom example drugs if needed:
# Example for top drug:
best_drug_id = top5.iloc[0]["DRUG_ID"]
df_best = data[data["DRUG_ID"] == best_drug_id].dropna(subset=["LN_IC50"])
X_best = df_best[gene_cols].values
y_best = df_best["LN_IC50"].values

model_best = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
model_best.fit(X_best, y_best)

importances = pd.Series(model_best.feature_importances_, index=gene_cols)
top_genes = importances.sort_values(ascending=False).head(20)
print(f"\nTop 20 features for best drug ({best_drug_id}):\n", top_genes)
top_genes.to_csv(f"rf/results/top_features_drug_{best_drug_id}.csv")
# Out:
# Pearson r (IC50 variance vs Pearson r) = 0.284 (p = 4.34e-13)
# Spearman ρ (IC50 variance vs Pearson r) = 0.278 (p = 1.52e-12)
# Top 5 drugs by Pearson r:
#       DRUG_ID  pearson_r  r2_global      rmse
# 341     1430   0.611087   0.335761  1.202217
# 165      449   0.604957   0.312221  0.818033
# 229     1061   0.601684   0.355303  1.166015
# 371     1526   0.598820   0.357046  1.327807
# 244     1086   0.596826   0.349845  1.835140
#
# Bottom 5 drugs by Pearson r:
#       DRUG_ID  pearson_r  r2_global      rmse
# 34       186  -0.194262  -0.207091  1.123568
# 66       245  -0.170072  -0.206323  1.642089
# 538     2112  -0.162775  -0.163614  0.789101
# 60       229  -0.115995  -0.142619  1.656717
# 251     1129  -0.104246  -0.132175  0.911324
#
# Saved top/bottom drugs summary to rf/results/top_bottom_pearson_r.csv
#
# Top 20 features for best drug (1430.0):
#  day4_day1_ratio    0.124043
# PC3                0.101610
# PC7                0.076738
# PC6                0.076428
# PC5                0.076413
# PC17               0.050137
# PC4                0.045084
# Tissue_Breast      0.040531
# PC12               0.030122
# PC18               0.029570
# PC24               0.026888
# PC15               0.026772
# PC21               0.024094
# PC10               0.022625
# PC19               0.017520
# PC22               0.016541
# PC14               0.016534
# PC1                0.016167
# PC20               0.015854
# PC13               0.014956
# dtype: float64
