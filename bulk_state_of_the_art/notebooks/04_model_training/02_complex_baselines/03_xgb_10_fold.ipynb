# %% [markdown]
# # ⚡ XGBoost Models for Drug Sensitivity Prediction
#
# This notebook trains an **XGBoost regression model per drug** using gene expression features. XGBoost is widely used for structured data due to its speed, regularization, and strong predictive performance. We use **5-fold cross-validation** to evaluate model generalization with both RMSE and R² scores.

# %%
import os
import numpy as np
import pandas as pd
from xgboost import XGBRegressor
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.metrics import r2_score, root_mean_squared_error
from scipy.stats import pearsonr
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Parameters
NUM_PCS = 30
DATA_PATH = "../../../data/processed/bulk_with_pca_tissue_growth.parquet"
data = pd.read_parquet(DATA_PATH)
print("✅ Dataset loaded:", data.shape)

# Setup
os.makedirs("results/xgboost", exist_ok=True)
non_features = ["SANGER_MODEL_ID", "DRUG_ID", "LN_IC50"]
gene_cols = [col for col in data.columns if col not in non_features]
kf = KFold(n_splits=10, shuffle=True, random_state=42)

results = []
# Out:
# ✅ Dataset loaded: (566992, 49)

# %% [markdown]
# ### 🔁 Train One XGBoost Model Per Drug
#
# For each drug, we train a separate XGBoost regressor using its associated (cell line, IC50, features) data. Performance is evaluated using RMSE and R².

# %%
# Main loop with clean progress prints
for idx, drug_id in enumerate(sorted(data["DRUG_ID"].unique()), 1):
    df = data[data["DRUG_ID"] == drug_id].dropna(subset=["LN_IC50"])
    if df.shape[0] < 100:
        print(f"⚠️ Skipped drug {drug_id} (samples: {df.shape[0]})")
        continue

    X = df[gene_cols].values
    y = df["LN_IC50"].values

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X).astype("float64")
    y = y.astype("float64")

    model = XGBRegressor(
        n_estimators=100,
        max_depth=5,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        n_jobs=-1
    )

    # Cross-validated concatenated predictions
    y_pred = cross_val_predict(model, X_scaled, y, cv=kf, n_jobs=-1, method='predict')

    # Fit on all data for potential downstream feature importance extraction
    model.fit(X_scaled, y)

    # Compute metrics
    r2 = r2_score(y, y_pred)
    pearson_r, p_val = pearsonr(y, y_pred)
    rmse = root_mean_squared_error(y, y_pred)

    # Clean progress print
    print(f"\n🌿 Drug {drug_id} | Samples: {len(df)}")
    print(f"  ➤ Global R²: {r2:.4f}")
    print(f"  ➤ Pearson r: {pearson_r:.4f} (p={p_val:.2e})")
    print(f"  ➤ RMSE: {rmse:.4f}")

    results.append({
        "DRUG_ID": drug_id,
        "n_samples": len(df),
        "r2_global": r2,
        "pearson_r": pearson_r,
        "pearson_pval": p_val,
        "rmse": rmse
    })
# Out:
# 🌿 Drug 1 | Samples: 384
#   ➤ Global R²: 0.1312
#   ➤ Pearson r: 0.3786 (p=1.57e-14)
#   ➤ RMSE: 1.0367
#
# 🌿 Drug 3 | Samples: 350
#   ➤ Global R²: -0.0036
#   ➤ Pearson r: 0.2188 (p=3.64e-05)
#   ➤ RMSE: 2.0139
#
# 🌿 Drug 5 | Samples: 387
#   ➤ Global R²: 0.1843
#   ➤ Pearson r: 0.4426 (p=5.43e-20)
#   ➤ RMSE: 1.4935
#
# 🌿 Drug 6 | Samples: 396
#   ➤ Global R²: -0.0648
#   ➤ Pearson r: 0.1291 (p=1.01e-02)
#   ➤ RMSE: 0.9235
#
# 🌿 Drug 9 | Samples: 390
#   ➤ Global R²: 0.0143
#   ➤ Pearson r: 0.2437 (p=1.11e-06)
#   ➤ RMSE: 1.4453
#
# 🌿 Drug 11 | Samples: 386
#   ➤ Global R²: 0.0067
#   ➤ Pearson r: 0.2217 (p=1.10e-05)
#   ➤ RMSE: 1.9090
#
# 🌿 Drug 17 | Samples: 387
#   ➤ Global R²: 0.1681
#   ➤ Pearson r: 0.4268 (p=1.45e-18)
#   ➤ RMSE: 0.8941
#
# 🌿 Drug 29 | Samples: 392
#   ➤ Global R²: 0.2495
#   ➤ Pearson r: 0.5024 (p=1.86e-26)
#   ➤ RMSE: 1.5415
#
# 🌿 Drug 30 | Samples: 388
#   ➤ Global R²: -0.0020
#   ➤ Pearson r: 0.2029 (p=5.70e-05)
#   ➤ RMSE: 1.2069
#
# 🌿 Drug 32 | Samples: 383
#   ➤ Global R²: 0.0728
#   ➤ Pearson r: 0.3089 (p=6.50e-10)
#   ➤ RMSE: 1.8929
#
# 🌿 Drug 34 | Samples: 395
#   ➤ Global R²: -0.0207
#   ➤ Pearson r: 0.2404 (p=1.34e-06)
#   ➤ RMSE: 1.0513
#
# 🌿 Drug 35 | Samples: 394
#   ➤ Global R²: 0.0366
#   ➤ Pearson r: 0.2520 (p=4.02e-07)
#   ➤ RMSE: 1.4848
#
# 🌿 Drug 37 | Samples: 396
#   ➤ Global R²: 0.1562
#   ➤ Pearson r: 0.4111 (p=1.40e-17)
#   ➤ RMSE: 1.0299
#
# 🌿 Drug 38 | Samples: 395
#   ➤ Global R²: -0.0202
#   ➤ Pearson r: 0.2160 (p=1.48e-05)
#   ➤ RMSE: 1.2116
#
# 🌿 Drug 41 | Samples: 387
#   ➤ Global R²: 0.0295
#   ➤ Pearson r: 0.2565 (p=3.13e-07)
#   ➤ RMSE: 1.4854
#
# 🌿 Drug 45 | Samples: 388
#   ➤ Global R²: 0.0299
#   ➤ Pearson r: 0.2893 (p=6.43e-09)
#   ➤ RMSE: 1.2193
#
# 🌿 Drug 51 | Samples: 383
#   ➤ Global R²: 0.2487
#   ➤ Pearson r: 0.5036 (p=5.02e-26)
#   ➤ RMSE: 2.1078
#
# 🌿 Drug 52 | Samples: 386
#   ➤ Global R²: 0.0377
#   ➤ Pearson r: 0.2689 (p=8.10e-08)
#   ➤ RMSE: 0.8213
#
# 🌿 Drug 53 | Samples: 388
#   ➤ Global R²: 0.0298
#   ➤ Pearson r: 0.2563 (p=3.08e-07)
#   ➤ RMSE: 1.2412
#
# 🌿 Drug 54 | Samples: 388
#   ➤ Global R²: 0.1599
#   ➤ Pearson r: 0.4113 (p=2.87e-17)
#   ➤ RMSE: 0.9857
#
# 🌿 Drug 55 | Samples: 388
#   ➤ Global R²: 0.1239
#   ➤ Pearson r: 0.3694 (p=5.43e-14)
#   ➤ RMSE: 1.6720
#
# 🌿 Drug 56 | Samples: 385
#   ➤ Global R²: 0.0989
#   ➤ Pearson r: 0.3475 (p=2.28e-12)
#   ➤ RMSE: 1.9905
#
# 🌿 Drug 59 | Samples: 388
#   ➤ Global R²: 0.0799
#   ➤ Pearson r: 0.3229 (p=7.23e-11)
#   ➤ RMSE: 1.0033
#
# 🌿 Drug 60 | Samples: 386
#   ➤ Global R²: 0.0271
#   ➤ Pearson r: 0.2502 (p=6.41e-07)
#   ➤ RMSE: 1.5845
#
# 🌿 Drug 62 | Samples: 387
#   ➤ Global R²: 0.0207
#   ➤ Pearson r: 0.2322 (p=3.89e-06)
#   ➤ RMSE: 1.6266
#
# 🌿 Drug 63 | Samples: 389
#   ➤ Global R²: 0.0590
#   ➤ Pearson r: 0.2807 (p=1.77e-08)
#   ➤ RMSE: 1.0392
#
# 🌿 Drug 64 | Samples: 388
#   ➤ Global R²: 0.0804
#   ➤ Pearson r: 0.3250 (p=5.35e-11)
#   ➤ RMSE: 1.1555
#
# 🌿 Drug 71 | Samples: 390
#   ➤ Global R²: 0.1424
#   ➤ Pearson r: 0.3877 (p=1.96e-15)
#   ➤ RMSE: 1.3367
#
# 🌿 Drug 83 | Samples: 374
#   ➤ Global R²: 0.0696
#   ➤ Pearson r: 0.3055 (p=1.62e-09)
#   ➤ RMSE: 1.7770
#
# 🌿 Drug 86 | Samples: 388
#   ➤ Global R²: -0.0419
#   ➤ Pearson r: 0.1626 (p=1.31e-03)
#   ➤ RMSE: 1.4236
#
# 🌿 Drug 87 | Samples: 385
#   ➤ Global R²: 0.0909
#   ➤ Pearson r: 0.3286 (p=3.80e-11)
#   ➤ RMSE: 1.7168
#
# 🌿 Drug 88 | Samples: 385
#   ➤ Global R²: 0.0803
#   ➤ Pearson r: 0.3069 (p=7.71e-10)
#   ➤ RMSE: 1.3628
#
# 🌿 Drug 89 | Samples: 392
#   ➤ Global R²: 0.0968
#   ➤ Pearson r: 0.3426 (p=3.09e-12)
#   ➤ RMSE: 1.1184
#
# 🌿 Drug 91 | Samples: 392
#   ➤ Global R²: 0.0849
#   ➤ Pearson r: 0.3332 (p=1.28e-11)
#   ➤ RMSE: 0.5680
#
# 🌿 Drug 94 | Samples: 390
#   ➤ Global R²: 0.1728
#   ➤ Pearson r: 0.4315 (p=4.06e-19)
#   ➤ RMSE: 1.0305
#
# 🌿 Drug 104 | Samples: 384
#   ➤ Global R²: 0.0932
#   ➤ Pearson r: 0.3407 (p=6.89e-12)
#   ➤ RMSE: 1.4798
#
# 🌿 Drug 106 | Samples: 387
#   ➤ Global R²: 0.1567
#   ➤ Pearson r: 0.4092 (p=4.67e-17)
#   ➤ RMSE: 1.0599
#
# 🌿 Drug 110 | Samples: 385
#   ➤ Global R²: 0.0166
#   ➤ Pearson r: 0.2454 (p=1.10e-06)
#   ➤ RMSE: 0.9315
#
# 🌿 Drug 111 | Samples: 388
#   ➤ Global R²: 0.0579
#   ➤ Pearson r: 0.2994 (p=1.78e-09)
#   ➤ RMSE: 1.0420
#
# 🌿 Drug 119 | Samples: 386
#   ➤ Global R²: 0.1481
#   ➤ Pearson r: 0.4005 (p=2.64e-16)
#   ➤ RMSE: 1.0196
#
# 🌿 Drug 127 | Samples: 390
#   ➤ Global R²: 0.1206
#   ➤ Pearson r: 0.3600 (p=2.25e-13)
#   ➤ RMSE: 1.3151
#
# 🌿 Drug 133 | Samples: 854
#   ➤ Global R²: 0.0528
#   ➤ Pearson r: 0.2703 (p=9.26e-16)
#   ➤ RMSE: 1.6139
#
# 🌿 Drug 134 | Samples: 863
#   ➤ Global R²: 0.1357
#   ➤ Pearson r: 0.3757 (p=2.57e-30)
#   ➤ RMSE: 1.8239
#
# 🌿 Drug 135 | Samples: 843
#   ➤ Global R²: 0.1625
#   ➤ Pearson r: 0.4081 (p=3.59e-35)
#   ➤ RMSE: 2.4800
#
# 🌿 Drug 136 | Samples: 854
#   ➤ Global R²: 0.1273
#   ➤ Pearson r: 0.3641 (p=3.67e-28)
#   ➤ RMSE: 1.4819
#
# 🌿 Drug 140 | Samples: 864
#   ➤ Global R²: 0.0592
#   ➤ Pearson r: 0.2748 (p=1.94e-16)
#   ➤ RMSE: 1.5863
#
# 🌿 Drug 147 | Samples: 861
#   ➤ Global R²: 0.0021
#   ➤ Pearson r: 0.1905 (p=1.78e-08)
#   ➤ RMSE: 0.8450
#
# 🌿 Drug 150 | Samples: 855
#   ➤ Global R²: 0.2116
#   ➤ Pearson r: 0.4626 (p=1.50e-46)
#   ➤ RMSE: 0.4754
#
# 🌿 Drug 151 | Samples: 856
#   ➤ Global R²: 0.0992
#   ➤ Pearson r: 0.3388 (p=1.99e-24)
#   ➤ RMSE: 1.3209
#
# 🌿 Drug 152 | Samples: 899
#   ➤ Global R²: 0.2123
#   ➤ Pearson r: 0.4653 (p=1.72e-49)
#   ➤ RMSE: 1.1097
#
# 🌿 Drug 153 | Samples: 865
#   ➤ Global R²: 0.1273
#   ➤ Pearson r: 0.3641 (p=1.63e-28)
#   ➤ RMSE: 1.1732
#
# 🌿 Drug 154 | Samples: 862
#   ➤ Global R²: 0.0071
#   ➤ Pearson r: 0.2115 (p=3.55e-10)
#   ➤ RMSE: 0.9335
#
# 🌿 Drug 155 | Samples: 861
#   ➤ Global R²: 0.1891
#   ➤ Pearson r: 0.4418 (p=1.89e-42)
#   ➤ RMSE: 1.4551
#
# 🌿 Drug 156 | Samples: 860
#   ➤ Global R²: 0.0870
#   ➤ Pearson r: 0.3128 (p=5.67e-21)
#   ➤ RMSE: 1.3009
#
# 🌿 Drug 157 | Samples: 864
#   ➤ Global R²: 0.0451
#   ➤ Pearson r: 0.2525 (p=4.96e-14)
#   ➤ RMSE: 1.0466
#
# 🌿 Drug 158 | Samples: 848
#   ➤ Global R²: 0.0702
#   ➤ Pearson r: 0.2930 (p=3.02e-18)
#   ➤ RMSE: 1.0295
#
# 🌿 Drug 159 | Samples: 859
#   ➤ Global R²: 0.1494
#   ➤ Pearson r: 0.3937 (p=3.19e-33)
#   ➤ RMSE: 1.5222
#
# 🌿 Drug 163 | Samples: 863
#   ➤ Global R²: 0.0586
#   ➤ Pearson r: 0.2697 (p=7.56e-16)
#   ➤ RMSE: 1.4685
#
# 🌿 Drug 164 | Samples: 857
#   ➤ Global R²: 0.0861
#   ➤ Pearson r: 0.3058 (p=5.24e-20)
#   ➤ RMSE: 1.5788
#
# 🌿 Drug 165 | Samples: 860
#   ➤ Global R²: 0.1873
#   ➤ Pearson r: 0.4379 (p=1.36e-41)
#   ➤ RMSE: 1.2858
#
# 🌿 Drug 166 | Samples: 864
#   ➤ Global R²: 0.0480
#   ➤ Pearson r: 0.2622 (p=4.77e-15)
#   ➤ RMSE: 0.7476
#
# 🌿 Drug 167 | Samples: 854
#   ➤ Global R²: 0.1580
#   ➤ Pearson r: 0.4037 (p=8.28e-35)
#   ➤ RMSE: 1.1538
#
# 🌿 Drug 170 | Samples: 857
#   ➤ Global R²: 0.0872
#   ➤ Pearson r: 0.3108 (p=1.21e-20)
#   ➤ RMSE: 1.2654
#
# 🌿 Drug 171 | Samples: 861
#   ➤ Global R²: 0.0523
#   ➤ Pearson r: 0.2576 (p=1.62e-14)
#   ➤ RMSE: 0.9778
#
# 🌿 Drug 172 | Samples: 857
#   ➤ Global R²: 0.1104
#   ➤ Pearson r: 0.3405 (p=1.05e-24)
#   ➤ RMSE: 0.9664
#
# 🌿 Drug 173 | Samples: 852
#   ➤ Global R²: 0.1446
#   ➤ Pearson r: 0.3836 (p=2.92e-31)
#   ➤ RMSE: 1.1281
#
# 🌿 Drug 175 | Samples: 841
#   ➤ Global R²: 0.1968
#   ➤ Pearson r: 0.4484 (p=7.68e-43)
#   ➤ RMSE: 1.0936
#
# 🌿 Drug 176 | Samples: 853
#   ➤ Global R²: 0.1269
#   ➤ Pearson r: 0.3731 (p=1.47e-29)
#   ➤ RMSE: 1.4686
#
# 🌿 Drug 177 | Samples: 848
#   ➤ Global R²: 0.1130
#   ➤ Pearson r: 0.3535 (p=2.31e-26)
#   ➤ RMSE: 1.5113
#
# 🌿 Drug 178 | Samples: 855
#   ➤ Global R²: 0.1474
#   ➤ Pearson r: 0.3948 (p=2.85e-33)
#   ➤ RMSE: 1.3719
#
# 🌿 Drug 179 | Samples: 892
#   ➤ Global R²: 0.2843
#   ➤ Pearson r: 0.5344 (p=5.08e-67)
#   ➤ RMSE: 1.5040
#
# 🌿 Drug 180 | Samples: 836
#   ➤ Global R²: 0.0766
#   ➤ Pearson r: 0.2938 (p=4.13e-18)
#   ➤ RMSE: 1.9206
#
# 🌿 Drug 182 | Samples: 847
#   ➤ Global R²: 0.1533
#   ➤ Pearson r: 0.3970 (p=2.36e-33)
#   ➤ RMSE: 1.5731
#
# 🌿 Drug 184 | Samples: 849
#   ➤ Global R²: 0.0539
#   ➤ Pearson r: 0.2630 (p=6.72e-15)
#   ➤ RMSE: 1.6188
#
# 🌿 Drug 185 | Samples: 852
#   ➤ Global R²: 0.0571
#   ➤ Pearson r: 0.2677 (p=1.88e-15)
#   ➤ RMSE: 1.3815
#
# 🌿 Drug 186 | Samples: 845
#   ➤ Global R²: 0.0428
#   ➤ Pearson r: 0.2521 (p=1.02e-13)
#   ➤ RMSE: 1.0644
#
# 🌿 Drug 190 | Samples: 841
#   ➤ Global R²: 0.1101
#   ➤ Pearson r: 0.3405 (p=2.81e-24)
#   ➤ RMSE: 2.1459
#
# 🌿 Drug 192 | Samples: 855
#   ➤ Global R²: 0.0502
#   ➤ Pearson r: 0.2640 (p=4.28e-15)
#   ➤ RMSE: 0.7012
#
# 🌿 Drug 193 | Samples: 899
#   ➤ Global R²: 0.0497
#   ➤ Pearson r: 0.2873 (p=1.50e-18)
#   ➤ RMSE: 0.6910
#
# 🌿 Drug 194 | Samples: 846
#   ➤ Global R²: 0.0693
#   ➤ Pearson r: 0.2898 (p=7.87e-18)
#   ➤ RMSE: 1.5297
#
# 🌿 Drug 196 | Samples: 886
#   ➤ Global R²: 0.2586
#   ➤ Pearson r: 0.5093 (p=1.24e-59)
#   ➤ RMSE: 1.5927
#
# 🌿 Drug 197 | Samples: 851
#   ➤ Global R²: 0.0363
#   ➤ Pearson r: 0.2326 (p=6.39e-12)
#   ➤ RMSE: 0.8291
#
# 🌿 Drug 199 | Samples: 850
#   ➤ Global R²: 0.0658
#   ➤ Pearson r: 0.2817 (p=5.79e-17)
#   ➤ RMSE: 1.2572
#
# 🌿 Drug 200 | Samples: 855
#   ➤ Global R²: 0.1043
#   ➤ Pearson r: 0.3426 (p=5.82e-25)
#   ➤ RMSE: 1.1491
#
# 🌿 Drug 201 | Samples: 852
#   ➤ Global R²: 0.1208
#   ➤ Pearson r: 0.3594 (p=2.25e-27)
#   ➤ RMSE: 1.7309
#
# 🌿 Drug 202 | Samples: 855
#   ➤ Global R²: 0.0587
#   ➤ Pearson r: 0.2720 (p=5.71e-16)
#   ➤ RMSE: 0.6600
#
# 🌿 Drug 203 | Samples: 900
#   ➤ Global R²: 0.2364
#   ➤ Pearson r: 0.4916 (p=6.14e-56)
#   ➤ RMSE: 0.9470
#
# 🌿 Drug 204 | Samples: 855
#   ➤ Global R²: 0.0553
#   ➤ Pearson r: 0.2669 (p=2.07e-15)
#   ➤ RMSE: 1.6095
#
# 🌿 Drug 205 | Samples: 899
#   ➤ Global R²: 0.2461
#   ➤ Pearson r: 0.5014 (p=2.09e-58)
#   ➤ RMSE: 0.5728
#
# 🌿 Drug 206 | Samples: 900
#   ➤ Global R²: 0.1993
#   ➤ Pearson r: 0.4661 (p=9.92e-50)
#   ➤ RMSE: 0.7969
#
# 🌿 Drug 207 | Samples: 854
#   ➤ Global R²: 0.0200
#   ➤ Pearson r: 0.2129 (p=3.27e-10)
#   ➤ RMSE: 1.1287
#
# 🌿 Drug 208 | Samples: 895
#   ➤ Global R²: 0.2183
#   ➤ Pearson r: 0.4693 (p=3.23e-50)
#   ➤ RMSE: 1.5311
#
# 🌿 Drug 211 | Samples: 899
#   ➤ Global R²: 0.2860
#   ➤ Pearson r: 0.5408 (p=1.99e-69)
#   ➤ RMSE: 1.1098
#
# 🌿 Drug 219 | Samples: 886
#   ➤ Global R²: 0.2364
#   ➤ Pearson r: 0.4898 (p=1.23e-54)
#   ➤ RMSE: 1.6338
#
# 🌿 Drug 221 | Samples: 900
#   ➤ Global R²: 0.3237
#   ➤ Pearson r: 0.5702 (p=1.00e-78)
#   ➤ RMSE: 0.9661
#
# 🌿 Drug 222 | Samples: 898
#   ➤ Global R²: 0.2977
#   ➤ Pearson r: 0.5487 (p=9.79e-72)
#   ➤ RMSE: 1.4818
#
# 🌿 Drug 223 | Samples: 895
#   ➤ Global R²: 0.1850
#   ➤ Pearson r: 0.4363 (p=6.98e-43)
#   ➤ RMSE: 1.5031
#
# 🌿 Drug 224 | Samples: 892
#   ➤ Global R²: 0.1605
#   ➤ Pearson r: 0.4088 (p=3.03e-37)
#   ➤ RMSE: 1.4336
#
# 🌿 Drug 225 | Samples: 896
#   ➤ Global R²: 0.1871
#   ➤ Pearson r: 0.4375 (p=3.38e-43)
#   ➤ RMSE: 1.4899
#
# 🌿 Drug 226 | Samples: 852
#   ➤ Global R²: 0.3571
#   ➤ Pearson r: 0.5978 (p=1.09e-83)
#   ➤ RMSE: 1.7732
#
# 🌿 Drug 228 | Samples: 897
#   ➤ Global R²: 0.3237
#   ➤ Pearson r: 0.5704 (p=1.47e-78)
#   ➤ RMSE: 1.1900
#
# 🌿 Drug 229 | Samples: 897
#   ➤ Global R²: 0.0945
#   ➤ Pearson r: 0.3350 (p=5.86e-25)
#   ➤ RMSE: 1.4916
#
# 🌿 Drug 230 | Samples: 898
#   ➤ Global R²: 0.3128
#   ➤ Pearson r: 0.5609 (p=1.49e-75)
#   ➤ RMSE: 0.9897
#
# 🌿 Drug 231 | Samples: 769
#   ➤ Global R²: 0.2137
#   ➤ Pearson r: 0.4671 (p=6.36e-43)
#   ➤ RMSE: 0.7400
#
# 🌿 Drug 235 | Samples: 890
#   ➤ Global R²: 0.0607
#   ➤ Pearson r: 0.2837 (p=6.13e-18)
#   ➤ RMSE: 1.6422
#
# 🌿 Drug 236 | Samples: 896
#   ➤ Global R²: 0.1873
#   ➤ Pearson r: 0.4428 (p=2.57e-44)
#   ➤ RMSE: 0.7741
#
# 🌿 Drug 238 | Samples: 899
#   ➤ Global R²: 0.2301
#   ➤ Pearson r: 0.4828 (p=1.11e-53)
#   ➤ RMSE: 1.1138
#
# 🌿 Drug 245 | Samples: 892
#   ➤ Global R²: 0.1786
#   ➤ Pearson r: 0.4326 (p=5.61e-42)
#   ➤ RMSE: 1.3256
#
# 🌿 Drug 249 | Samples: 896
#   ➤ Global R²: 0.1093
#   ➤ Pearson r: 0.3499 (p=3.36e-27)
#   ➤ RMSE: 1.2599
#
# 🌿 Drug 252 | Samples: 899
#   ➤ Global R²: 0.2618
#   ➤ Pearson r: 0.5137 (p=1.11e-61)
#   ➤ RMSE: 1.5891
#
# 🌿 Drug 253 | Samples: 899
#   ➤ Global R²: 0.3441
#   ➤ Pearson r: 0.5888 (p=5.59e-85)
#   ➤ RMSE: 0.8040
#
# 🌿 Drug 254 | Samples: 899
#   ➤ Global R²: 0.1581
#   ➤ Pearson r: 0.4414 (p=3.63e-44)
#   ➤ RMSE: 0.9820
#
# 🌿 Drug 255 | Samples: 899
#   ➤ Global R²: 0.0647
#   ➤ Pearson r: 0.2866 (p=1.84e-18)
#   ➤ RMSE: 0.9227
#
# 🌿 Drug 256 | Samples: 899
#   ➤ Global R²: 0.2358
#   ➤ Pearson r: 0.4895 (p=2.41e-55)
#   ➤ RMSE: 1.3259
#
# 🌿 Drug 257 | Samples: 896
#   ➤ Global R²: 0.3836
#   ➤ Pearson r: 0.6204 (p=2.02e-96)
#   ➤ RMSE: 1.3438
#
# 🌿 Drug 258 | Samples: 895
#   ➤ Global R²: 0.2427
#   ➤ Pearson r: 0.5000 (p=8.75e-58)
#   ➤ RMSE: 0.8459
#
# 🌿 Drug 260 | Samples: 897
#   ➤ Global R²: 0.2840
#   ➤ Pearson r: 0.5372 (p=3.35e-68)
#   ➤ RMSE: 1.4405
#
# 🌿 Drug 261 | Samples: 897
#   ➤ Global R²: 0.3345
#   ➤ Pearson r: 0.5826 (p=1.22e-82)
#   ➤ RMSE: 1.3437
#
# 🌿 Drug 262 | Samples: 897
#   ➤ Global R²: 0.2046
#   ➤ Pearson r: 0.4551 (p=4.59e-47)
#   ➤ RMSE: 1.2973
#
# 🌿 Drug 263 | Samples: 897
#   ➤ Global R²: 0.2243
#   ➤ Pearson r: 0.4762 (p=5.70e-52)
#   ➤ RMSE: 0.7577
#
# 🌿 Drug 264 | Samples: 900
#   ➤ Global R²: 0.3319
#   ➤ Pearson r: 0.5771 (p=4.68e-81)
#   ➤ RMSE: 1.0296
#
# 🌿 Drug 265 | Samples: 895
#   ➤ Global R²: 0.3795
#   ➤ Pearson r: 0.6168 (p=6.24e-95)
#   ➤ RMSE: 1.0550
#
# 🌿 Drug 266 | Samples: 897
#   ➤ Global R²: 0.2660
#   ➤ Pearson r: 0.5180 (p=1.01e-62)
#   ➤ RMSE: 0.4765
#
# 🌿 Drug 268 | Samples: 858
#   ➤ Global R²: 0.0366
#   ➤ Pearson r: 0.2511 (p=8.42e-14)
#   ➤ RMSE: 2.3368
#
# 🌿 Drug 269 | Samples: 893
#   ➤ Global R²: 0.1743
#   ➤ Pearson r: 0.4235 (p=3.62e-40)
#   ➤ RMSE: 1.3148
#
# 🌿 Drug 271 | Samples: 893
#   ➤ Global R²: 0.3187
#   ➤ Pearson r: 0.5694 (p=7.06e-78)
#   ➤ RMSE: 0.7927
#
# 🌿 Drug 272 | Samples: 884
#   ➤ Global R²: 0.1687
#   ➤ Pearson r: 0.4228 (p=1.23e-39)
#   ➤ RMSE: 1.5465
#
# 🌿 Drug 273 | Samples: 878
#   ➤ Global R²: 0.1470
#   ➤ Pearson r: 0.3966 (p=1.91e-34)
#   ➤ RMSE: 1.6126
#
# 🌿 Drug 274 | Samples: 871
#   ➤ Global R²: 0.1447
#   ➤ Pearson r: 0.3908 (p=3.62e-33)
#   ➤ RMSE: 1.7331
#
# 🌿 Drug 275 | Samples: 894
#   ➤ Global R²: 0.3755
#   ➤ Pearson r: 0.6139 (p=1.08e-93)
#   ➤ RMSE: 1.3669
#
# 🌿 Drug 276 | Samples: 888
#   ➤ Global R²: 0.2059
#   ➤ Pearson r: 0.4583 (p=2.55e-47)
#   ➤ RMSE: 1.5476
#
# 🌿 Drug 277 | Samples: 899
#   ➤ Global R²: 0.1155
#   ➤ Pearson r: 0.3932 (p=1.33e-34)
#   ➤ RMSE: 0.9077
#
# 🌿 Drug 279 | Samples: 896
#   ➤ Global R²: 0.3239
#   ➤ Pearson r: 0.5714 (p=8.55e-79)
#   ➤ RMSE: 0.9839
#
# 🌿 Drug 281 | Samples: 896
#   ➤ Global R²: 0.2940
#   ➤ Pearson r: 0.5440 (p=3.72e-70)
#   ➤ RMSE: 0.9362
#
# 🌿 Drug 282 | Samples: 898
#   ➤ Global R²: 0.1451
#   ➤ Pearson r: 0.3939 (p=1.06e-34)
#   ➤ RMSE: 1.7421
#
# 🌿 Drug 283 | Samples: 899
#   ➤ Global R²: 0.1428
#   ➤ Pearson r: 0.3859 (p=2.63e-33)
#   ➤ RMSE: 1.7373
#
# 🌿 Drug 284 | Samples: 900
#   ➤ Global R²: -0.0151
#   ➤ Pearson r: 0.1471 (p=9.34e-06)
#   ➤ RMSE: 1.0030
#
# 🌿 Drug 285 | Samples: 901
#   ➤ Global R²: 0.1816
#   ➤ Pearson r: 0.4320 (p=2.85e-42)
#   ➤ RMSE: 1.0953
#
# 🌿 Drug 286 | Samples: 897
#   ➤ Global R²: 0.3204
#   ➤ Pearson r: 0.5691 (p=4.18e-78)
#   ➤ RMSE: 0.8097
#
# 🌿 Drug 287 | Samples: 896
#   ➤ Global R²: 0.2159
#   ➤ Pearson r: 0.4721 (p=6.17e-51)
#   ➤ RMSE: 1.1148
#
# 🌿 Drug 288 | Samples: 897
#   ➤ Global R²: 0.0631
#   ➤ Pearson r: 0.2916 (p=4.91e-19)
#   ➤ RMSE: 0.9930
#
# 🌿 Drug 289 | Samples: 900
#   ➤ Global R²: 0.0799
#   ➤ Pearson r: 0.3096 (p=1.93e-21)
#   ➤ RMSE: 0.6685
#
# 🌿 Drug 290 | Samples: 896
#   ➤ Global R²: 0.3664
#   ➤ Pearson r: 0.6090 (p=4.59e-92)
#   ➤ RMSE: 0.9571
#
# 🌿 Drug 291 | Samples: 896
#   ➤ Global R²: 0.0998
#   ➤ Pearson r: 0.3377 (p=2.47e-25)
#   ➤ RMSE: 1.0593
#
# 🌿 Drug 292 | Samples: 898
#   ➤ Global R²: 0.2144
#   ➤ Pearson r: 0.4677 (p=5.43e-50)
#   ➤ RMSE: 1.1579
#
# 🌿 Drug 293 | Samples: 891
#   ➤ Global R²: 0.0647
#   ➤ Pearson r: 0.3001 (p=5.27e-20)
#   ➤ RMSE: 1.5183
#
# 🌿 Drug 294 | Samples: 895
#   ➤ Global R²: 0.2744
#   ➤ Pearson r: 0.5253 (p=1.26e-64)
#   ➤ RMSE: 1.1680
#
# 🌿 Drug 295 | Samples: 897
#   ➤ Global R²: 0.3122
#   ➤ Pearson r: 0.5613 (p=1.39e-75)
#   ➤ RMSE: 1.3779
#
# 🌿 Drug 298 | Samples: 898
#   ➤ Global R²: 0.3222
#   ➤ Pearson r: 0.5681 (p=7.33e-78)
#   ➤ RMSE: 0.8637
#
# 🌿 Drug 299 | Samples: 885
#   ➤ Global R²: 0.1772
#   ➤ Pearson r: 0.4310 (p=2.47e-41)
#   ➤ RMSE: 2.0744
#
# 🌿 Drug 300 | Samples: 891
#   ➤ Global R²: 0.2607
#   ➤ Pearson r: 0.5138 (p=3.43e-61)
#   ➤ RMSE: 1.7171
#
# 🌿 Drug 301 | Samples: 897
#   ➤ Global R²: 0.3376
#   ➤ Pearson r: 0.5819 (p=2.09e-82)
#   ➤ RMSE: 1.6792
#
# 🌿 Drug 302 | Samples: 887
#   ➤ Global R²: 0.2140
#   ➤ Pearson r: 0.4673 (p=2.56e-49)
#   ➤ RMSE: 2.1104
#
# 🌿 Drug 303 | Samples: 896
#   ➤ Global R²: 0.3310
#   ➤ Pearson r: 0.5771 (p=1.06e-80)
#   ➤ RMSE: 1.3934
#
# 🌿 Drug 304 | Samples: 895
#   ➤ Global R²: 0.1769
#   ➤ Pearson r: 0.4298 (p=1.57e-41)
#   ➤ RMSE: 1.1587
#
# 🌿 Drug 305 | Samples: 897
#   ➤ Global R²: 0.3477
#   ➤ Pearson r: 0.5905 (p=2.06e-85)
#   ➤ RMSE: 1.3371
#
# 🌿 Drug 306 | Samples: 899
#   ➤ Global R²: 0.3150
#   ➤ Pearson r: 0.5627 (p=3.21e-76)
#   ➤ RMSE: 1.2820
#
# 🌿 Drug 308 | Samples: 894
#   ➤ Global R²: 0.1660
#   ➤ Pearson r: 0.4135 (p=3.13e-38)
#   ➤ RMSE: 1.2733
#
# 🌿 Drug 309 | Samples: 896
#   ➤ Global R²: 0.2858
#   ➤ Pearson r: 0.5376 (p=2.97e-68)
#   ➤ RMSE: 1.1577
#
# 🌿 Drug 310 | Samples: 897
#   ➤ Global R²: 0.2352
#   ➤ Pearson r: 0.4893 (p=3.64e-55)
#   ➤ RMSE: 1.0936
#
# 🌿 Drug 312 | Samples: 897
#   ➤ Global R²: 0.2107
#   ➤ Pearson r: 0.4710 (p=1.01e-50)
#   ➤ RMSE: 0.6876
#
# 🌿 Drug 317 | Samples: 889
#   ➤ Global R²: 0.2124
#   ➤ Pearson r: 0.4631 (p=1.88e-48)
#   ➤ RMSE: 1.8198
#
# 🌿 Drug 326 | Samples: 895
#   ➤ Global R²: 0.2566
#   ➤ Pearson r: 0.5121 (p=5.47e-61)
#   ➤ RMSE: 1.5169
#
# 🌿 Drug 328 | Samples: 887
#   ➤ Global R²: 0.2454
#   ➤ Pearson r: 0.5002 (p=2.47e-57)
#   ➤ RMSE: 1.8780
#
# 🌿 Drug 329 | Samples: 899
#   ➤ Global R²: 0.2978
#   ➤ Pearson r: 0.5474 (p=2.08e-71)
#   ➤ RMSE: 1.0869
#
# 🌿 Drug 330 | Samples: 898
#   ➤ Global R²: 0.3350
#   ➤ Pearson r: 0.5795 (p=1.08e-81)
#   ➤ RMSE: 1.0844
#
# 🌿 Drug 331 | Samples: 888
#   ➤ Global R²: 0.1995
#   ➤ Pearson r: 0.4516 (p=7.61e-46)
#   ➤ RMSE: 1.5107
#
# 🌿 Drug 332 | Samples: 899
#   ➤ Global R²: 0.2728
#   ➤ Pearson r: 0.5255 (p=5.68e-65)
#   ➤ RMSE: 0.7429
#
# 🌿 Drug 333 | Samples: 892
#   ➤ Global R²: 0.2872
#   ➤ Pearson r: 0.5459 (p=2.08e-70)
#   ➤ RMSE: 0.8899
#
# 🌿 Drug 341 | Samples: 894
#   ➤ Global R²: 0.2252
#   ➤ Pearson r: 0.4788 (p=2.02e-52)
#   ➤ RMSE: 0.5707
#
# 🌿 Drug 342 | Samples: 902
#   ➤ Global R²: 0.1814
#   ➤ Pearson r: 0.4355 (p=4.95e-43)
#   ➤ RMSE: 0.9660
#
# 🌿 Drug 344 | Samples: 884
#   ➤ Global R²: 0.3200
#   ➤ Pearson r: 0.5657 (p=6.41e-76)
#   ➤ RMSE: 1.8782
#
# 🌿 Drug 345 | Samples: 897
#   ➤ Global R²: 0.3262
#   ➤ Pearson r: 0.5719 (p=4.79e-79)
#   ➤ RMSE: 0.7428
#
# 🌿 Drug 346 | Samples: 875
#   ➤ Global R²: 0.2161
#   ➤ Pearson r: 0.4702 (p=2.46e-49)
#   ➤ RMSE: 2.3183
#
# 🌿 Drug 356 | Samples: 902
#   ➤ Global R²: 0.2670
#   ➤ Pearson r: 0.5169 (p=8.85e-63)
#   ➤ RMSE: 1.2657
#
# 🌿 Drug 362 | Samples: 899
#   ➤ Global R²: 0.1110
#   ➤ Pearson r: 0.3413 (p=5.89e-26)
#   ➤ RMSE: 1.3673
#
# 🌿 Drug 363 | Samples: 892
#   ➤ Global R²: 0.0817
#   ➤ Pearson r: 0.3015 (p=3.30e-20)
#   ➤ RMSE: 1.1550
#
# 🌿 Drug 366 | Samples: 902
#   ➤ Global R²: 0.1084
#   ➤ Pearson r: 0.3407 (p=6.01e-26)
#   ➤ RMSE: 1.2850
#
# 🌿 Drug 371 | Samples: 855
#   ➤ Global R²: 0.1973
#   ➤ Pearson r: 0.4479 (p=2.04e-43)
#   ➤ RMSE: 1.7151
#
# 🌿 Drug 372 | Samples: 902
#   ➤ Global R²: 0.1455
#   ➤ Pearson r: 0.3879 (p=9.26e-34)
#   ➤ RMSE: 0.9609
#
# 🌿 Drug 374 | Samples: 887
#   ➤ Global R²: 0.1832
#   ➤ Pearson r: 0.4324 (p=1.04e-41)
#   ➤ RMSE: 1.3849
#
# 🌿 Drug 375 | Samples: 902
#   ➤ Global R²: 0.0950
#   ➤ Pearson r: 0.3311 (p=1.61e-24)
#   ➤ RMSE: 0.9223
#
# 🌿 Drug 376 | Samples: 901
#   ➤ Global R²: 0.2234
#   ➤ Pearson r: 0.4757 (p=4.54e-52)
#   ➤ RMSE: 0.9580
#
# 🌿 Drug 380 | Samples: 901
#   ➤ Global R²: 0.1475
#   ➤ Pearson r: 0.3906 (p=3.25e-34)
#   ➤ RMSE: 1.4624
#
# 🌿 Drug 381 | Samples: 886
#   ➤ Global R²: 0.0549
#   ➤ Pearson r: 0.2684 (p=4.33e-16)
#   ➤ RMSE: 1.2657
#
# 🌿 Drug 382 | Samples: 892
#   ➤ Global R²: 0.1356
#   ➤ Pearson r: 0.3769 (p=1.75e-31)
#   ➤ RMSE: 1.4054
#
# 🌿 Drug 406 | Samples: 902
#   ➤ Global R²: 0.1617
#   ➤ Pearson r: 0.4029 (p=1.57e-36)
#   ➤ RMSE: 0.8542
#
# 🌿 Drug 407 | Samples: 902
#   ➤ Global R²: 0.2320
#   ➤ Pearson r: 0.4852 (p=1.89e-54)
#   ➤ RMSE: 1.0387
#
# 🌿 Drug 408 | Samples: 902
#   ➤ Global R²: 0.2590
#   ➤ Pearson r: 0.5107 (p=4.65e-61)
#   ➤ RMSE: 0.4781
#
# 🌿 Drug 409 | Samples: 900
#   ➤ Global R²: 0.3020
#   ➤ Pearson r: 0.5506 (p=1.79e-72)
#   ➤ RMSE: 0.4651
#
# 🌿 Drug 410 | Samples: 886
#   ➤ Global R²: 0.1547
#   ➤ Pearson r: 0.3981 (p=4.96e-35)
#   ➤ RMSE: 0.7810
#
# 🌿 Drug 412 | Samples: 889
#   ➤ Global R²: 0.3212
#   ➤ Pearson r: 0.5718 (p=2.49e-78)
#   ➤ RMSE: 1.0609
#
# 🌿 Drug 415 | Samples: 892
#   ➤ Global R²: 0.1078
#   ➤ Pearson r: 0.3433 (p=4.49e-26)
#   ➤ RMSE: 0.8511
#
# 🌿 Drug 416 | Samples: 887
#   ➤ Global R²: 0.2730
#   ➤ Pearson r: 0.5258 (p=3.35e-64)
#   ➤ RMSE: 1.1008
#
# 🌿 Drug 427 | Samples: 889
#   ➤ Global R²: 0.5025
#   ➤ Pearson r: 0.7089 (p=1.18e-136)
#   ➤ RMSE: 0.7269
#
# 🌿 Drug 428 | Samples: 882
#   ➤ Global R²: 0.3022
#   ➤ Pearson r: 0.5517 (p=2.14e-71)
#   ➤ RMSE: 1.5696
#
# 🌿 Drug 431 | Samples: 875
#   ➤ Global R²: 0.2995
#   ➤ Pearson r: 0.5484 (p=7.47e-70)
#   ➤ RMSE: 1.5307
#
# 🌿 Drug 432 | Samples: 887
#   ➤ Global R²: 0.1565
#   ➤ Pearson r: 0.4035 (p=4.72e-36)
#   ➤ RMSE: 1.0084
#
# 🌿 Drug 435 | Samples: 891
#   ➤ Global R²: 0.2696
#   ➤ Pearson r: 0.5201 (p=6.80e-63)
#   ➤ RMSE: 1.0256
#
# 🌿 Drug 436 | Samples: 889
#   ➤ Global R²: 0.1342
#   ➤ Pearson r: 0.3781 (p=1.37e-31)
#   ➤ RMSE: 1.1273
#
# 🌿 Drug 437 | Samples: 888
#   ➤ Global R²: 0.1528
#   ➤ Pearson r: 0.3969 (p=7.12e-35)
#   ➤ RMSE: 1.0936
#
# 🌿 Drug 438 | Samples: 882
#   ➤ Global R²: 0.2225
#   ➤ Pearson r: 0.4741 (p=1.28e-50)
#   ➤ RMSE: 1.1655
#
# 🌿 Drug 439 | Samples: 889
#   ➤ Global R²: 0.0067
#   ➤ Pearson r: 0.1919 (p=8.06e-09)
#   ➤ RMSE: 1.1610
#
# 🌿 Drug 442 | Samples: 895
#   ➤ Global R²: 0.1898
#   ➤ Pearson r: 0.4426 (p=3.17e-44)
#   ➤ RMSE: 1.1367
#
# 🌿 Drug 446 | Samples: 885
#   ➤ Global R²: 0.2077
#   ➤ Pearson r: 0.4593 (p=2.17e-47)
#   ➤ RMSE: 0.9462
#
# 🌿 Drug 447 | Samples: 903
#   ➤ Global R²: 0.1933
#   ➤ Pearson r: 0.4421 (p=1.72e-44)
#   ➤ RMSE: 0.5733
#
# 🌿 Drug 449 | Samples: 903
#   ➤ Global R²: 0.3275
#   ➤ Pearson r: 0.5724 (p=1.01e-79)
#   ➤ RMSE: 0.8153
#
# 🌿 Drug 461 | Samples: 857
#   ➤ Global R²: 0.2092
#   ➤ Pearson r: 0.4631 (p=8.95e-47)
#   ➤ RMSE: 1.9256
#
# 🌿 Drug 474 | Samples: 882
#   ➤ Global R²: 0.1583
#   ➤ Pearson r: 0.4078 (p=1.13e-36)
#   ➤ RMSE: 1.9502
#
# 🌿 Drug 476 | Samples: 888
#   ➤ Global R²: 0.2100
#   ➤ Pearson r: 0.4653 (p=6.51e-49)
#   ➤ RMSE: 1.3576
#
# 🌿 Drug 477 | Samples: 889
#   ➤ Global R²: 0.0858
#   ➤ Pearson r: 0.3116 (p=1.78e-21)
#   ➤ RMSE: 0.7610
#
# 🌿 Drug 478 | Samples: 891
#   ➤ Global R²: 0.1986
#   ➤ Pearson r: 0.4477 (p=3.86e-45)
#   ➤ RMSE: 0.6102
#
# 🌿 Drug 546 | Samples: 892
#   ➤ Global R²: 0.2093
#   ➤ Pearson r: 0.4586 (p=1.36e-47)
#   ➤ RMSE: 0.5913
#
# 🌿 Drug 552 | Samples: 891
#   ➤ Global R²: 0.1226
#   ➤ Pearson r: 0.3595 (p=1.44e-28)
#   ➤ RMSE: 0.8010
#
# 🌿 Drug 562 | Samples: 892
#   ➤ Global R²: 0.1492
#   ➤ Pearson r: 0.3956 (p=8.63e-35)
#   ➤ RMSE: 0.5773
#
# 🌿 Drug 563 | Samples: 890
#   ➤ Global R²: 0.1591
#   ➤ Pearson r: 0.4044 (p=2.40e-36)
#   ➤ RMSE: 0.8066
#
# 🌿 Drug 573 | Samples: 889
#   ➤ Global R²: 0.2069
#   ➤ Pearson r: 0.4565 (p=5.79e-47)
#   ➤ RMSE: 0.6897
#
# 🌿 Drug 574 | Samples: 891
#   ➤ Global R²: 0.1754
#   ➤ Pearson r: 0.4207 (p=1.58e-39)
#   ➤ RMSE: 0.6646
#
# 🌿 Drug 576 | Samples: 891
#   ➤ Global R²: 0.3088
#   ➤ Pearson r: 0.5557 (p=2.34e-73)
#   ➤ RMSE: 0.9098
#
# 🌿 Drug 1001 | Samples: 910
#   ➤ Global R²: 0.2747
#   ➤ Pearson r: 0.5257 (p=8.18e-66)
#   ➤ RMSE: 1.0795
#
# 🌿 Drug 1003 | Samples: 956
#   ➤ Global R²: 0.4004
#   ➤ Pearson r: 0.6329 (p=3.85e-108)
#   ➤ RMSE: 1.4223
#
# 🌿 Drug 1004 | Samples: 915
#   ➤ Global R²: 0.1992
#   ➤ Pearson r: 0.4510 (p=4.88e-47)
#   ➤ RMSE: 1.2657
#
# 🌿 Drug 1005 | Samples: 919
#   ➤ Global R²: 0.1623
#   ➤ Pearson r: 0.4092 (p=2.02e-38)
#   ➤ RMSE: 1.0372
#
# 🌿 Drug 1006 | Samples: 908
#   ➤ Global R²: 0.2012
#   ➤ Pearson r: 0.4521 (p=6.05e-47)
#   ➤ RMSE: 1.4012
#
# 🌿 Drug 1007 | Samples: 918
#   ➤ Global R²: 0.2477
#   ➤ Pearson r: 0.5000 (p=3.08e-59)
#   ➤ RMSE: 1.2544
#
# 🌿 Drug 1008 | Samples: 918
#   ➤ Global R²: 0.4334
#   ➤ Pearson r: 0.6586 (p=3.16e-115)
#   ➤ RMSE: 1.2514
#
# 🌿 Drug 1009 | Samples: 908
#   ➤ Global R²: 0.1804
#   ➤ Pearson r: 0.4344 (p=4.32e-43)
#   ➤ RMSE: 1.1703
#
# 🌿 Drug 1010 | Samples: 912
#   ➤ Global R²: 0.1674
#   ➤ Pearson r: 0.4201 (p=2.67e-40)
#   ➤ RMSE: 0.9861
#
# 🌿 Drug 1011 | Samples: 914
#   ➤ Global R²: 0.3108
#   ➤ Pearson r: 0.5588 (p=3.39e-76)
#   ➤ RMSE: 1.4646
#
# 🌿 Drug 1012 | Samples: 918
#   ➤ Global R²: 0.3016
#   ➤ Pearson r: 0.5505 (p=7.09e-74)
#   ➤ RMSE: 0.9132
#
# 🌿 Drug 1013 | Samples: 918
#   ➤ Global R²: 0.2302
#   ➤ Pearson r: 0.4857 (p=1.62e-55)
#   ➤ RMSE: 1.0887
#
# 🌿 Drug 1014 | Samples: 898
#   ➤ Global R²: 0.4159
#   ➤ Pearson r: 0.6454 (p=5.96e-107)
#   ➤ RMSE: 1.3366
#
# 🌿 Drug 1015 | Samples: 902
#   ➤ Global R²: 0.2678
#   ➤ Pearson r: 0.5183 (p=3.65e-63)
#   ➤ RMSE: 1.1912
#
# 🌿 Drug 1016 | Samples: 899
#   ➤ Global R²: 0.1904
#   ➤ Pearson r: 0.4414 (p=3.66e-44)
#   ➤ RMSE: 1.4159
#
# 🌿 Drug 1017 | Samples: 917
#   ➤ Global R²: 0.2411
#   ➤ Pearson r: 0.4942 (p=1.20e-57)
#   ➤ RMSE: 0.8607
#
# 🌿 Drug 1018 | Samples: 918
#   ➤ Global R²: 0.1827
#   ➤ Pearson r: 0.4316 (p=6.12e-43)
#   ➤ RMSE: 0.6537
#
# 🌿 Drug 1019 | Samples: 918
#   ➤ Global R²: 0.2571
#   ➤ Pearson r: 0.5078 (p=2.44e-61)
#   ➤ RMSE: 1.1346
#
# 🌿 Drug 1020 | Samples: 919
#   ➤ Global R²: 0.2066
#   ➤ Pearson r: 0.4622 (p=7.90e-50)
#   ➤ RMSE: 0.6847
#
# 🌿 Drug 1021 | Samples: 912
#   ➤ Global R²: 0.1724
#   ➤ Pearson r: 0.4246 (p=3.18e-41)
#   ➤ RMSE: 1.1371
#
# 🌿 Drug 1022 | Samples: 916
#   ➤ Global R²: 0.1920
#   ➤ Pearson r: 0.4444 (p=1.26e-45)
#   ➤ RMSE: 1.3142
#
# 🌿 Drug 1023 | Samples: 915
#   ➤ Global R²: -0.0391
#   ➤ Pearson r: 0.1062 (p=1.29e-03)
#   ➤ RMSE: 1.0784
#
# 🌿 Drug 1024 | Samples: 914
#   ➤ Global R²: 0.1946
#   ➤ Pearson r: 0.4494 (p=1.22e-46)
#   ➤ RMSE: 1.3584
#
# 🌿 Drug 1025 | Samples: 825
#   ➤ Global R²: 0.1071
#   ➤ Pearson r: 0.3425 (p=4.02e-24)
#   ➤ RMSE: 0.8092
#
# 🌿 Drug 1026 | Samples: 915
#   ➤ Global R²: 0.2767
#   ➤ Pearson r: 0.5282 (p=7.14e-67)
#   ➤ RMSE: 1.4892
#
# 🌿 Drug 1028 | Samples: 912
#   ➤ Global R²: 0.1816
#   ➤ Pearson r: 0.4391 (p=2.90e-44)
#   ➤ RMSE: 0.7791
#
# 🌿 Drug 1029 | Samples: 912
#   ➤ Global R²: -0.0531
#   ➤ Pearson r: 0.1282 (p=1.03e-04)
#   ➤ RMSE: 0.9211
#
# 🌿 Drug 1030 | Samples: 916
#   ➤ Global R²: 0.1234
#   ➤ Pearson r: 0.3639 (p=4.55e-30)
#   ➤ RMSE: 0.8564
#
# 🌿 Drug 1031 | Samples: 907
#   ➤ Global R²: 0.1876
#   ➤ Pearson r: 0.4377 (p=9.91e-44)
#   ➤ RMSE: 1.5310
#
# 🌿 Drug 1032 | Samples: 914
#   ➤ Global R²: 0.2213
#   ➤ Pearson r: 0.4771 (p=3.97e-53)
#   ➤ RMSE: 1.2948
#
# 🌿 Drug 1033 | Samples: 920
#   ➤ Global R²: 0.2154
#   ➤ Pearson r: 0.4684 (p=2.31e-51)
#   ➤ RMSE: 0.7198
#
# 🌿 Drug 1034 | Samples: 956
#   ➤ Global R²: 0.2524
#   ➤ Pearson r: 0.5029 (p=2.06e-62)
#   ➤ RMSE: 1.1967
#
# 🌿 Drug 1036 | Samples: 915
#   ➤ Global R²: 0.2043
#   ➤ Pearson r: 0.4609 (p=2.54e-49)
#   ➤ RMSE: 1.1248
#
# 🌿 Drug 1037 | Samples: 917
#   ➤ Global R²: 0.2213
#   ➤ Pearson r: 0.4732 (p=2.41e-52)
#   ➤ RMSE: 1.0759
#
# 🌿 Drug 1038 | Samples: 911
#   ➤ Global R²: 0.1213
#   ➤ Pearson r: 0.3635 (p=7.64e-30)
#   ➤ RMSE: 0.8479
#
# 🌿 Drug 1039 | Samples: 901
#   ➤ Global R²: 0.0952
#   ➤ Pearson r: 0.3297 (p=2.77e-24)
#   ➤ RMSE: 0.7813
#
# 🌿 Drug 1042 | Samples: 898
#   ➤ Global R²: 0.0208
#   ➤ Pearson r: 0.2011 (p=1.19e-09)
#   ➤ RMSE: 0.8487
#
# 🌿 Drug 1043 | Samples: 914
#   ➤ Global R²: 0.0242
#   ➤ Pearson r: 0.2299 (p=1.97e-12)
#   ➤ RMSE: 0.7760
#
# 🌿 Drug 1046 | Samples: 829
#   ➤ Global R²: 0.1036
#   ➤ Pearson r: 0.3426 (p=3.03e-24)
#   ➤ RMSE: 1.0511
#
# 🌿 Drug 1047 | Samples: 918
#   ➤ Global R²: 0.1678
#   ➤ Pearson r: 0.4133 (p=3.49e-39)
#   ➤ RMSE: 1.1971
#
# 🌿 Drug 1048 | Samples: 832
#   ➤ Global R²: 0.1905
#   ➤ Pearson r: 0.4410 (p=6.54e-41)
#   ➤ RMSE: 1.1528
#
# 🌿 Drug 1049 | Samples: 917
#   ➤ Global R²: 0.0569
#   ➤ Pearson r: 0.2818 (p=3.37e-18)
#   ➤ RMSE: 1.0968
#
# 🌿 Drug 1050 | Samples: 918
#   ➤ Global R²: 0.1495
#   ➤ Pearson r: 0.3929 (p=2.91e-35)
#   ➤ RMSE: 1.1041
#
# 🌿 Drug 1051 | Samples: 937
#   ➤ Global R²: 0.3639
#   ➤ Pearson r: 0.6043 (p=2.31e-94)
#   ➤ RMSE: 1.8284
#
# 🌿 Drug 1052 | Samples: 917
#   ➤ Global R²: 0.0859
#   ➤ Pearson r: 0.3059 (p=2.56e-21)
#   ➤ RMSE: 0.9468
#
# 🌿 Drug 1053 | Samples: 873
#   ➤ Global R²: 0.0152
#   ➤ Pearson r: 0.2132 (p=1.96e-10)
#   ➤ RMSE: 1.3498
#
# 🌿 Drug 1054 | Samples: 873
#   ➤ Global R²: 0.1969
#   ➤ Pearson r: 0.4479 (p=2.71e-44)
#   ➤ RMSE: 1.3605
#
# 🌿 Drug 1057 | Samples: 903
#   ➤ Global R²: 0.1894
#   ➤ Pearson r: 0.4388 (p=8.79e-44)
#   ➤ RMSE: 1.1180
#
# 🌿 Drug 1058 | Samples: 905
#   ➤ Global R²: 0.0369
#   ➤ Pearson r: 0.2453 (p=7.18e-14)
#   ➤ RMSE: 1.4154
#
# 🌿 Drug 1059 | Samples: 906
#   ➤ Global R²: 0.1165
#   ➤ Pearson r: 0.3611 (p=2.73e-29)
#   ➤ RMSE: 1.0065
#
# 🌿 Drug 1060 | Samples: 903
#   ➤ Global R²: 0.3599
#   ➤ Pearson r: 0.6001 (p=1.95e-89)
#   ➤ RMSE: 1.5323
#
# 🌿 Drug 1061 | Samples: 880
#   ➤ Global R²: 0.2508
#   ➤ Pearson r: 0.5050 (p=3.91e-58)
#   ➤ RMSE: 1.0261
#
# 🌿 Drug 1062 | Samples: 865
#   ➤ Global R²: 0.1587
#   ➤ Pearson r: 0.4011 (p=9.08e-35)
#   ➤ RMSE: 1.3755
#
# 🌿 Drug 1066 | Samples: 887
#   ➤ Global R²: 0.1026
#   ➤ Pearson r: 0.3322 (p=2.66e-24)
#   ➤ RMSE: 1.2441
#
# 🌿 Drug 1067 | Samples: 907
#   ➤ Global R²: 0.0572
#   ➤ Pearson r: 0.2780 (p=1.46e-17)
#   ➤ RMSE: 0.7046
#
# 🌿 Drug 1068 | Samples: 780
#   ➤ Global R²: 0.2993
#   ➤ Pearson r: 0.5484 (p=1.86e-62)
#   ➤ RMSE: 0.9341
#
# 🌿 Drug 1069 | Samples: 912
#   ➤ Global R²: 0.1311
#   ➤ Pearson r: 0.3712 (p=3.57e-31)
#   ➤ RMSE: 0.8172
#
# 🌿 Drug 1070 | Samples: 911
#   ➤ Global R²: 0.2015
#   ➤ Pearson r: 0.4519 (p=4.72e-47)
#   ➤ RMSE: 1.0451
#
# 🌿 Drug 1071 | Samples: 908
#   ➤ Global R²: 0.1526
#   ➤ Pearson r: 0.3931 (p=6.23e-35)
#   ➤ RMSE: 0.8646
#
# 🌿 Drug 1072 | Samples: 912
#   ➤ Global R²: -0.0342
#   ➤ Pearson r: 0.1101 (p=8.70e-04)
#   ➤ RMSE: 0.8872
#
# 🌿 Drug 1073 | Samples: 956
#   ➤ Global R²: 0.4425
#   ➤ Pearson r: 0.6655 (p=2.47e-123)
#   ➤ RMSE: 1.2806
#
# 🌿 Drug 1079 | Samples: 950
#   ➤ Global R²: 0.3479
#   ➤ Pearson r: 0.5901 (p=3.39e-90)
#   ➤ RMSE: 1.8761
#
# 🌿 Drug 1080 | Samples: 946
#   ➤ Global R²: 0.4091
#   ➤ Pearson r: 0.6400 (p=3.95e-110)
#   ➤ RMSE: 1.3497
#
# 🌿 Drug 1083 | Samples: 954
#   ➤ Global R²: 0.4533
#   ➤ Pearson r: 0.6735 (p=4.11e-127)
#   ➤ RMSE: 1.1179
#
# 🌿 Drug 1084 | Samples: 938
#   ➤ Global R²: 0.3389
#   ➤ Pearson r: 0.5823 (p=3.09e-86)
#   ➤ RMSE: 1.2680
#
# 🌿 Drug 1085 | Samples: 946
#   ➤ Global R²: 0.3664
#   ➤ Pearson r: 0.6068 (p=3.27e-96)
#   ➤ RMSE: 0.9691
#
# 🌿 Drug 1086 | Samples: 912
#   ➤ Global R²: 0.5203
#   ➤ Pearson r: 0.7219 (p=1.22e-147)
#   ➤ RMSE: 1.6850
#
# 🌿 Drug 1088 | Samples: 953
#   ➤ Global R²: 0.4161
#   ➤ Pearson r: 0.6453 (p=2.51e-113)
#   ➤ RMSE: 1.4749
#
# 🌿 Drug 1089 | Samples: 955
#   ➤ Global R²: 0.5173
#   ➤ Pearson r: 0.7193 (p=5.97e-153)
#   ➤ RMSE: 1.2066
#
# 🌿 Drug 1091 | Samples: 894
#   ➤ Global R²: 0.0984
#   ➤ Pearson r: 0.3280 (p=7.25e-24)
#   ➤ RMSE: 1.0962
#
# 🌿 Drug 1093 | Samples: 953
#   ➤ Global R²: 0.2313
#   ➤ Pearson r: 0.4857 (p=1.41e-57)
#   ➤ RMSE: 0.9580
#
# 🌿 Drug 1096 | Samples: 260
#   ➤ Global R²: 0.4213
#   ➤ Pearson r: 0.6493 (p=1.62e-32)
#   ➤ RMSE: 1.8211
#
# 🌿 Drug 1114 | Samples: 848
#   ➤ Global R²: 0.0439
#   ➤ Pearson r: 0.2770 (p=2.09e-16)
#   ➤ RMSE: 0.9920
#
# 🌿 Drug 1128 | Samples: 910
#   ➤ Global R²: 0.1047
#   ➤ Pearson r: 0.3411 (p=3.16e-26)
#   ➤ RMSE: 1.2318
#
# 🌿 Drug 1129 | Samples: 901
#   ➤ Global R²: 0.0496
#   ➤ Pearson r: 0.2570 (p=4.61e-15)
#   ➤ RMSE: 0.8875
#
# 🌿 Drug 1131 | Samples: 883
#   ➤ Global R²: 0.3265
#   ➤ Pearson r: 0.5718 (p=8.12e-78)
#   ➤ RMSE: 1.4789
#
# 🌿 Drug 1133 | Samples: 909
#   ➤ Global R²: 0.1227
#   ➤ Pearson r: 0.3611 (p=2.19e-29)
#   ➤ RMSE: 0.9186
#
# 🌿 Drug 1135 | Samples: 909
#   ➤ Global R²: 0.2136
#   ➤ Pearson r: 0.4635 (p=1.30e-49)
#   ➤ RMSE: 1.3001
#
# 🌿 Drug 1136 | Samples: 909
#   ➤ Global R²: 0.0903
#   ➤ Pearson r: 0.3294 (p=1.88e-24)
#   ➤ RMSE: 1.6129
#
# 🌿 Drug 1142 | Samples: 485
#   ➤ Global R²: 0.1630
#   ➤ Pearson r: 0.4125 (p=2.40e-21)
#   ➤ RMSE: 0.8903
#
# 🌿 Drug 1143 | Samples: 484
#   ➤ Global R²: 0.0676
#   ➤ Pearson r: 0.3087 (p=3.84e-12)
#   ➤ RMSE: 1.2005
# ⚠️ Skipped drug 1145 (samples: 98)
#
# 🌿 Drug 1149 | Samples: 910
#   ➤ Global R²: 0.1832
#   ➤ Pearson r: 0.4339 (p=4.55e-43)
#   ➤ RMSE: 1.0491
# ⚠️ Skipped drug 1155 (samples: 97)
# ⚠️ Skipped drug 1157 (samples: 98)
#
# 🌿 Drug 1158 | Samples: 485
#   ➤ Global R²: 0.0865
#   ➤ Pearson r: 0.3313 (p=6.92e-14)
#   ➤ RMSE: 0.8697
#
# 🌿 Drug 1161 | Samples: 485
#   ➤ Global R²: 0.0526
#   ➤ Pearson r: 0.2884 (p=9.56e-11)
#   ➤ RMSE: 1.1435
#
# 🌿 Drug 1164 | Samples: 486
#   ➤ Global R²: 0.0719
#   ➤ Pearson r: 0.2997 (p=1.52e-11)
#   ➤ RMSE: 0.9694
# ⚠️ Skipped drug 1165 (samples: 98)
#
# 🌿 Drug 1166 | Samples: 487
#   ➤ Global R²: 0.1265
#   ➤ Pearson r: 0.3715 (p=2.21e-17)
#   ➤ RMSE: 1.2908
# ⚠️ Skipped drug 1167 (samples: 95)
#
# 🌿 Drug 1168 | Samples: 943
#   ➤ Global R²: 0.2342
#   ➤ Pearson r: 0.4854 (p=6.53e-57)
#   ➤ RMSE: 1.1830
#
# 🌿 Drug 1170 | Samples: 906
#   ➤ Global R²: 0.1669
#   ➤ Pearson r: 0.4145 (p=6.20e-39)
#   ➤ RMSE: 0.9689
#
# 🌿 Drug 1175 | Samples: 911
#   ➤ Global R²: 0.1303
#   ➤ Pearson r: 0.3729 (p=1.95e-31)
#   ➤ RMSE: 0.9043
#
# 🌿 Drug 1177 | Samples: 883
#   ➤ Global R²: 0.4494
#   ➤ Pearson r: 0.6704 (p=2.72e-116)
#   ➤ RMSE: 1.1219
#
# 🌿 Drug 1179 | Samples: 955
#   ➤ Global R²: 0.4760
#   ➤ Pearson r: 0.6903 (p=4.52e-136)
#   ➤ RMSE: 1.0179
#
# 🌿 Drug 1180 | Samples: 880
#   ➤ Global R²: 0.3338
#   ➤ Pearson r: 0.5779 (p=1.54e-79)
#   ➤ RMSE: 1.2013
#
# 🌿 Drug 1183 | Samples: 911
#   ➤ Global R²: 0.0660
#   ➤ Pearson r: 0.2874 (p=8.87e-19)
#   ➤ RMSE: 1.1574
#
# 🌿 Drug 1184 | Samples: 911
#   ➤ Global R²: 0.2338
#   ➤ Pearson r: 0.4856 (p=4.59e-55)
#   ➤ RMSE: 0.9795
#
# 🌿 Drug 1185 | Samples: 910
#   ➤ Global R²: 0.1607
#   ➤ Pearson r: 0.4076 (p=9.54e-38)
#   ➤ RMSE: 0.9068
#
# 🌿 Drug 1186 | Samples: 910
#   ➤ Global R²: 0.2507
#   ➤ Pearson r: 0.5012 (p=4.79e-59)
#   ➤ RMSE: 1.1051
#
# 🌿 Drug 1187 | Samples: 911
#   ➤ Global R²: 0.1639
#   ➤ Pearson r: 0.4137 (p=5.63e-39)
#   ➤ RMSE: 1.0258
#
# 🌿 Drug 1188 | Samples: 910
#   ➤ Global R²: 0.0779
#   ➤ Pearson r: 0.2959 (p=7.65e-20)
#   ➤ RMSE: 1.0161
#
# 🌿 Drug 1190 | Samples: 948
#   ➤ Global R²: 0.4277
#   ➤ Pearson r: 0.6540 (p=9.10e-117)
#   ➤ RMSE: 2.2749
#
# 🌿 Drug 1191 | Samples: 945
#   ➤ Global R²: 0.2206
#   ➤ Pearson r: 0.4724 (p=1.09e-53)
#   ➤ RMSE: 0.9394
#
# 🌿 Drug 1192 | Samples: 894
#   ➤ Global R²: 0.1502
#   ➤ Pearson r: 0.3948 (p=1.02e-34)
#   ➤ RMSE: 1.2768
#
# 🌿 Drug 1194 | Samples: 896
#   ➤ Global R²: 0.1575
#   ➤ Pearson r: 0.4041 (p=1.58e-36)
#   ➤ RMSE: 0.8123
#
# 🌿 Drug 1195 | Samples: 900
#   ➤ Global R²: 0.1211
#   ➤ Pearson r: 0.3586 (p=1.06e-28)
#   ➤ RMSE: 1.0503
#
# 🌿 Drug 1196 | Samples: 895
#   ➤ Global R²: 0.1069
#   ➤ Pearson r: 0.3351 (p=6.40e-25)
#   ➤ RMSE: 1.0377
#
# 🌿 Drug 1197 | Samples: 898
#   ➤ Global R²: 0.1203
#   ➤ Pearson r: 0.3653 (p=9.79e-30)
#   ➤ RMSE: 1.0642
#
# 🌿 Drug 1198 | Samples: 899
#   ➤ Global R²: 0.1453
#   ➤ Pearson r: 0.3868 (p=1.87e-33)
#   ➤ RMSE: 0.9029
#
# 🌿 Drug 1199 | Samples: 896
#   ➤ Global R²: 0.1766
#   ➤ Pearson r: 0.4278 (p=3.59e-41)
#   ➤ RMSE: 0.6820
#
# 🌿 Drug 1200 | Samples: 951
#   ➤ Global R²: 0.3531
#   ➤ Pearson r: 0.5951 (p=3.62e-92)
#   ➤ RMSE: 0.7222
#
# 🌿 Drug 1202 | Samples: 130
#   ➤ Global R²: 0.1883
#   ➤ Pearson r: 0.4431 (p=1.29e-07)
#   ➤ RMSE: 1.3355
#
# 🌿 Drug 1203 | Samples: 463
#   ➤ Global R²: 0.1087
#   ➤ Pearson r: 0.3618 (p=9.19e-16)
#   ➤ RMSE: 1.1633
#
# 🌿 Drug 1204 | Samples: 130
#   ➤ Global R²: 0.2478
#   ➤ Pearson r: 0.5029 (p=1.08e-09)
#   ➤ RMSE: 1.2687
#
# 🌿 Drug 1218 | Samples: 883
#   ➤ Global R²: 0.2438
#   ➤ Pearson r: 0.4958 (p=5.89e-56)
#   ➤ RMSE: 0.9742
#
# 🌿 Drug 1219 | Samples: 899
#   ➤ Global R²: 0.1305
#   ➤ Pearson r: 0.3711 (p=9.99e-31)
#   ➤ RMSE: 0.9981
#
# 🌿 Drug 1230 | Samples: 898
#   ➤ Global R²: 0.0500
#   ➤ Pearson r: 0.2718 (p=1.13e-16)
#   ➤ RMSE: 0.6971
#
# 🌿 Drug 1232 | Samples: 884
#   ➤ Global R²: 0.0930
#   ➤ Pearson r: 0.3264 (p=2.20e-23)
#   ➤ RMSE: 1.2706
#
# 🌿 Drug 1236 | Samples: 899
#   ➤ Global R²: 0.1395
#   ➤ Pearson r: 0.3821 (p=1.25e-32)
#   ➤ RMSE: 1.2644
#
# 🌿 Drug 1237 | Samples: 953
#   ➤ Global R²: 0.3636
#   ➤ Pearson r: 0.6046 (p=4.78e-96)
#   ➤ RMSE: 0.7749
#
# 🌿 Drug 1239 | Samples: 766
#   ➤ Global R²: 0.1814
#   ➤ Pearson r: 0.4296 (p=9.67e-36)
#   ➤ RMSE: 1.1317
#
# 🌿 Drug 1241 | Samples: 883
#   ➤ Global R²: 0.1960
#   ➤ Pearson r: 0.4436 (p=7.18e-44)
#   ➤ RMSE: 0.9923
#
# 🌿 Drug 1242 | Samples: 884
#   ➤ Global R²: 0.3068
#   ➤ Pearson r: 0.5544 (p=2.16e-72)
#   ➤ RMSE: 1.1864
#
# 🌿 Drug 1243 | Samples: 896
#   ➤ Global R²: 0.1130
#   ➤ Pearson r: 0.3512 (p=2.07e-27)
#   ➤ RMSE: 0.9006
#
# 🌿 Drug 1248 | Samples: 862
#   ➤ Global R²: 0.3454
#   ➤ Pearson r: 0.5878 (p=3.11e-81)
#   ➤ RMSE: 2.4860
#
# 🌿 Drug 1249 | Samples: 881
#   ➤ Global R²: 0.3719
#   ➤ Pearson r: 0.6102 (p=5.55e-91)
#   ➤ RMSE: 1.0471
#
# 🌿 Drug 1250 | Samples: 881
#   ➤ Global R²: 0.3445
#   ➤ Pearson r: 0.5874 (p=7.71e-83)
#   ➤ RMSE: 1.3893
#
# 🌿 Drug 1251 | Samples: 898
#   ➤ Global R²: 0.2009
#   ➤ Pearson r: 0.4507 (p=3.89e-46)
#   ➤ RMSE: 0.7441
#
# 🌿 Drug 1252 | Samples: 898
#   ➤ Global R²: 0.0905
#   ➤ Pearson r: 0.3099 (p=1.92e-21)
#   ➤ RMSE: 0.6767
#
# 🌿 Drug 1253 | Samples: 893
#   ➤ Global R²: 0.1922
#   ➤ Pearson r: 0.4462 (p=6.76e-45)
#   ➤ RMSE: 0.5262
#
# 🌿 Drug 1254 | Samples: 893
#   ➤ Global R²: 0.1649
#   ➤ Pearson r: 0.4107 (p=1.19e-37)
#   ➤ RMSE: 1.2040
#
# 🌿 Drug 1259 | Samples: 884
#   ➤ Global R²: 0.2341
#   ➤ Pearson r: 0.4844 (p=3.34e-53)
#   ➤ RMSE: 1.6120
#
# 🌿 Drug 1261 | Samples: 892
#   ➤ Global R²: 0.0583
#   ➤ Pearson r: 0.2719 (p=1.38e-16)
#   ➤ RMSE: 1.3286
#
# 🌿 Drug 1262 | Samples: 883
#   ➤ Global R²: 0.2605
#   ➤ Pearson r: 0.5143 (p=8.91e-61)
#   ➤ RMSE: 0.4699
#
# 🌿 Drug 1263 | Samples: 869
#   ➤ Global R²: 0.1611
#   ➤ Pearson r: 0.4111 (p=9.15e-37)
#   ➤ RMSE: 0.5560
#
# 🌿 Drug 1264 | Samples: 882
#   ➤ Global R²: 0.1197
#   ➤ Pearson r: 0.3637 (p=5.73e-29)
#   ➤ RMSE: 0.5172
#
# 🌿 Drug 1266 | Samples: 886
#   ➤ Global R²: 0.2468
#   ➤ Pearson r: 0.4974 (p=1.47e-56)
#   ➤ RMSE: 1.4836
#
# 🌿 Drug 1268 | Samples: 890
#   ➤ Global R²: 0.1154
#   ➤ Pearson r: 0.3497 (p=5.32e-27)
#   ➤ RMSE: 0.8354
#
# 🌿 Drug 1359 | Samples: 818
#   ➤ Global R²: 0.0593
#   ➤ Pearson r: 0.2869 (p=5.84e-17)
#   ➤ RMSE: 1.0201
#
# 🌿 Drug 1360 | Samples: 820
#   ➤ Global R²: 0.0591
#   ➤ Pearson r: 0.2805 (p=2.75e-16)
#   ➤ RMSE: 0.7738
#
# 🌿 Drug 1362 | Samples: 821
#   ➤ Global R²: 0.1737
#   ➤ Pearson r: 0.4244 (p=3.20e-37)
#   ➤ RMSE: 0.7622
#
# 🌿 Drug 1363 | Samples: 821
#   ➤ Global R²: 0.0538
#   ➤ Pearson r: 0.2794 (p=3.47e-16)
#   ➤ RMSE: 1.4526
#
# 🌿 Drug 1364 | Samples: 822
#   ➤ Global R²: 0.1635
#   ➤ Pearson r: 0.4119 (p=5.18e-35)
#   ➤ RMSE: 1.1831
#
# 🌿 Drug 1365 | Samples: 821
#   ➤ Global R²: 0.1488
#   ➤ Pearson r: 0.3944 (p=5.89e-32)
#   ➤ RMSE: 1.0568
#
# 🌿 Drug 1367 | Samples: 821
#   ➤ Global R²: 0.0900
#   ➤ Pearson r: 0.3220 (p=2.92e-21)
#   ➤ RMSE: 0.9842
#
# 🌿 Drug 1368 | Samples: 822
#   ➤ Global R²: 0.2511
#   ➤ Pearson r: 0.5018 (p=1.22e-53)
#   ➤ RMSE: 1.3726
#
# 🌿 Drug 1369 | Samples: 702
#   ➤ Global R²: 0.2399
#   ➤ Pearson r: 0.4904 (p=9.20e-44)
#   ➤ RMSE: 1.2901
#
# 🌿 Drug 1370 | Samples: 706
#   ➤ Global R²: 0.2393
#   ➤ Pearson r: 0.4909 (p=4.28e-44)
#   ➤ RMSE: 1.2808
#
# 🌿 Drug 1371 | Samples: 898
#   ➤ Global R²: 0.2893
#   ➤ Pearson r: 0.5389 (p=8.91e-69)
#   ➤ RMSE: 1.0240
#
# 🌿 Drug 1372 | Samples: 866
#   ➤ Global R²: 0.4739
#   ➤ Pearson r: 0.6894 (p=3.87e-123)
#   ➤ RMSE: 1.8031
#
# 🌿 Drug 1373 | Samples: 844
#   ➤ Global R²: 0.3599
#   ➤ Pearson r: 0.6001 (p=1.03e-83)
#   ➤ RMSE: 1.5500
#
# 🌿 Drug 1375 | Samples: 882
#   ➤ Global R²: 0.2878
#   ➤ Pearson r: 0.5375 (p=3.44e-67)
#   ➤ RMSE: 0.6646
#
# 🌿 Drug 1377 | Samples: 888
#   ➤ Global R²: 0.2038
#   ➤ Pearson r: 0.4585 (p=2.29e-47)
#   ➤ RMSE: 1.4607
#
# 🌿 Drug 1378 | Samples: 906
#   ➤ Global R²: 0.3587
#   ➤ Pearson r: 0.5989 (p=2.67e-89)
#   ➤ RMSE: 1.6426
#
# 🌿 Drug 1379 | Samples: 900
#   ➤ Global R²: 0.0924
#   ➤ Pearson r: 0.3173 (p=1.68e-22)
#   ➤ RMSE: 0.8688
#
# 🌿 Drug 1382 | Samples: 903
#   ➤ Global R²: 0.1106
#   ➤ Pearson r: 0.3481 (p=4.08e-27)
#   ➤ RMSE: 0.9036
#
# 🌿 Drug 1386 | Samples: 907
#   ➤ Global R²: 0.2281
#   ➤ Pearson r: 0.4801 (p=1.79e-53)
#   ➤ RMSE: 1.2133
#
# 🌿 Drug 1392 | Samples: 903
#   ➤ Global R²: 0.3256
#   ➤ Pearson r: 0.5708 (p=3.45e-79)
#   ➤ RMSE: 1.5024
#
# 🌿 Drug 1393 | Samples: 905
#   ➤ Global R²: 0.2501
#   ➤ Pearson r: 0.5010 (p=1.16e-58)
#   ➤ RMSE: 1.2279
#
# 🌿 Drug 1394 | Samples: 904
#   ➤ Global R²: 0.2427
#   ➤ Pearson r: 0.4931 (p=1.45e-56)
#   ➤ RMSE: 1.0376
#
# 🌿 Drug 1401 | Samples: 901
#   ➤ Global R²: 0.1944
#   ➤ Pearson r: 0.4465 (p=2.30e-45)
#   ➤ RMSE: 0.8050
#
# 🌿 Drug 1402 | Samples: 905
#   ➤ Global R²: 0.2818
#   ➤ Pearson r: 0.5315 (p=4.04e-67)
#   ➤ RMSE: 1.2241
#
# 🌿 Drug 1403 | Samples: 904
#   ➤ Global R²: -0.0107
#   ➤ Pearson r: 0.2033 (p=6.86e-10)
#   ➤ RMSE: 0.9221
#
# 🌿 Drug 1407 | Samples: 903
#   ➤ Global R²: 0.0671
#   ➤ Pearson r: 0.2892 (p=7.48e-19)
#   ➤ RMSE: 1.0851
#
# 🌿 Drug 1409 | Samples: 902
#   ➤ Global R²: 0.1360
#   ➤ Pearson r: 0.3738 (p=2.77e-31)
#   ➤ RMSE: 1.4146
#
# 🌿 Drug 1413 | Samples: 900
#   ➤ Global R²: 0.2470
#   ➤ Pearson r: 0.4990 (p=7.62e-58)
#   ➤ RMSE: 1.3716
#
# 🌿 Drug 1414 | Samples: 900
#   ➤ Global R²: 0.0896
#   ➤ Pearson r: 0.3106 (p=1.38e-21)
#   ➤ RMSE: 0.8062
#
# 🌿 Drug 1416 | Samples: 899
#   ➤ Global R²: 0.2380
#   ➤ Pearson r: 0.4910 (p=9.97e-56)
#   ➤ RMSE: 1.2967
#
# 🌿 Drug 1419 | Samples: 897
#   ➤ Global R²: 0.2326
#   ➤ Pearson r: 0.4842 (p=6.67e-54)
#   ➤ RMSE: 0.8643
#
# 🌿 Drug 1421 | Samples: 904
#   ➤ Global R²: 0.1434
#   ➤ Pearson r: 0.3828 (p=6.29e-33)
#   ➤ RMSE: 0.8840
#
# 🌿 Drug 1422 | Samples: 902
#   ➤ Global R²: 0.1679
#   ➤ Pearson r: 0.4164 (p=3.81e-39)
#   ➤ RMSE: 1.2160
#
# 🌿 Drug 1425 | Samples: 901
#   ➤ Global R²: 0.0877
#   ➤ Pearson r: 0.3161 (p=2.33e-22)
#   ➤ RMSE: 1.1350
#
# 🌿 Drug 1426 | Samples: 899
#   ➤ Global R²: 0.2432
#   ➤ Pearson r: 0.4972 (p=2.63e-57)
#   ➤ RMSE: 1.0679
#
# 🌿 Drug 1427 | Samples: 893
#   ➤ Global R²: 0.1150
#   ➤ Pearson r: 0.3456 (p=1.89e-26)
#   ➤ RMSE: 1.9556
#
# 🌿 Drug 1428 | Samples: 895
#   ➤ Global R²: 0.0501
#   ➤ Pearson r: 0.2535 (p=1.36e-14)
#   ➤ RMSE: 1.6585
#
# 🌿 Drug 1429 | Samples: 894
#   ➤ Global R²: 0.0312
#   ➤ Pearson r: 0.2335 (p=1.56e-12)
#   ➤ RMSE: 1.4892
#
# 🌿 Drug 1430 | Samples: 901
#   ➤ Global R²: 0.1980
#   ➤ Pearson r: 0.4504 (p=3.20e-46)
#   ➤ RMSE: 1.4450
#
# 🌿 Drug 1432 | Samples: 906
#   ➤ Global R²: 0.0953
#   ➤ Pearson r: 0.3176 (p=1.12e-22)
#   ➤ RMSE: 1.0478
#
# 🌿 Drug 1433 | Samples: 905
#   ➤ Global R²: 0.1659
#   ➤ Pearson r: 0.4184 (p=1.16e-39)
#   ➤ RMSE: 0.8157
#
# 🌿 Drug 1434 | Samples: 903
#   ➤ Global R²: 0.0924
#   ➤ Pearson r: 0.3208 (p=4.67e-23)
#   ➤ RMSE: 1.0705
#
# 🌿 Drug 1436 | Samples: 883
#   ➤ Global R²: 0.0940
#   ➤ Pearson r: 0.3373 (p=6.09e-25)
#   ➤ RMSE: 1.1581
#
# 🌿 Drug 1437 | Samples: 903
#   ➤ Global R²: 0.0813
#   ➤ Pearson r: 0.3049 (p=7.08e-21)
#   ➤ RMSE: 0.8259
#
# 🌿 Drug 1441 | Samples: 903
#   ➤ Global R²: 0.1371
#   ➤ Pearson r: 0.3811 (p=1.36e-32)
#   ➤ RMSE: 1.1938
#
# 🌿 Drug 1444 | Samples: 900
#   ➤ Global R²: 0.0944
#   ➤ Pearson r: 0.3228 (p=2.87e-23)
#   ➤ RMSE: 1.1430
#
# 🌿 Drug 1445 | Samples: 895
#   ➤ Global R²: 0.0351
#   ➤ Pearson r: 0.2464 (p=7.57e-14)
#   ➤ RMSE: 1.1918
#
# 🌿 Drug 1446 | Samples: 898
#   ➤ Global R²: 0.0868
#   ➤ Pearson r: 0.3120 (p=9.99e-22)
#   ➤ RMSE: 1.1833
#
# 🌿 Drug 1449 | Samples: 906
#   ➤ Global R²: 0.1055
#   ➤ Pearson r: 0.3416 (p=3.35e-26)
#   ➤ RMSE: 0.9856
#
# 🌿 Drug 1451 | Samples: 888
#   ➤ Global R²: 0.2435
#   ➤ Pearson r: 0.4943 (p=6.62e-56)
#   ➤ RMSE: 1.4907
#
# 🌿 Drug 1453 | Samples: 903
#   ➤ Global R²: 0.2676
#   ➤ Pearson r: 0.5178 (p=4.24e-63)
#   ➤ RMSE: 1.1103
#
# 🌿 Drug 1458 | Samples: 896
#   ➤ Global R²: 0.2027
#   ➤ Pearson r: 0.4509 (p=4.36e-46)
#   ➤ RMSE: 1.1306
#
# 🌿 Drug 1459 | Samples: 903
#   ➤ Global R²: 0.2487
#   ➤ Pearson r: 0.4998 (p=3.13e-58)
#   ➤ RMSE: 1.6440
#
# 🌿 Drug 1460 | Samples: 900
#   ➤ Global R²: 0.2100
#   ➤ Pearson r: 0.4622 (p=7.69e-49)
#   ➤ RMSE: 1.9132
#
# 🌿 Drug 1461 | Samples: 903
#   ➤ Global R²: 0.1057
#   ➤ Pearson r: 0.3424 (p=3.14e-26)
#   ➤ RMSE: 0.8847
#
# 🌿 Drug 1463 | Samples: 904
#   ➤ Global R²: 0.1142
#   ➤ Pearson r: 0.3492 (p=2.51e-27)
#   ➤ RMSE: 1.1020
#
# 🌿 Drug 1464 | Samples: 903
#   ➤ Global R²: 0.1826
#   ➤ Pearson r: 0.4304 (p=5.18e-42)
#   ➤ RMSE: 0.8414
#
# 🌿 Drug 1490 | Samples: 896
#   ➤ Global R²: 0.2024
#   ➤ Pearson r: 0.4508 (p=4.71e-46)
#   ➤ RMSE: 1.9738
#
# 🌿 Drug 1494 | Samples: 923
#   ➤ Global R²: 0.2464
#   ➤ Pearson r: 0.4973 (p=7.95e-59)
#   ➤ RMSE: 1.4162
#
# 🌿 Drug 1495 | Samples: 880
#   ➤ Global R²: 0.1872
#   ➤ Pearson r: 0.4374 (p=2.03e-42)
#   ➤ RMSE: 0.9239
#
# 🌿 Drug 1496 | Samples: 904
#   ➤ Global R²: 0.1118
#   ➤ Pearson r: 0.3489 (p=2.87e-27)
#   ➤ RMSE: 1.1559
#
# 🌿 Drug 1497 | Samples: 859
#   ➤ Global R²: 0.0406
#   ➤ Pearson r: 0.2705 (p=7.23e-16)
#   ➤ RMSE: 1.0765
#
# 🌿 Drug 1498 | Samples: 891
#   ➤ Global R²: 0.4191
#   ➤ Pearson r: 0.6475 (p=4.84e-107)
#   ➤ RMSE: 1.3402
#
# 🌿 Drug 1502 | Samples: 850
#   ➤ Global R²: 0.0768
#   ➤ Pearson r: 0.3034 (p=1.49e-19)
#   ➤ RMSE: 0.6179
#
# 🌿 Drug 1507 | Samples: 887
#   ➤ Global R²: 0.3607
#   ➤ Pearson r: 0.6014 (p=2.32e-88)
#   ➤ RMSE: 0.9119
#
# 🌿 Drug 1510 | Samples: 954
#   ➤ Global R²: 0.3128
#   ➤ Pearson r: 0.5594 (p=1.18e-79)
#   ➤ RMSE: 1.0926
#
# 🌿 Drug 1511 | Samples: 946
#   ➤ Global R²: 0.4192
#   ➤ Pearson r: 0.6476 (p=1.43e-113)
#   ➤ RMSE: 1.2361
#
# 🌿 Drug 1512 | Samples: 945
#   ➤ Global R²: 0.3364
#   ➤ Pearson r: 0.5808 (p=2.43e-86)
#   ➤ RMSE: 0.7212
#
# 🌿 Drug 1526 | Samples: 847
#   ➤ Global R²: 0.4729
#   ➤ Pearson r: 0.6882 (p=6.85e-120)
#   ➤ RMSE: 1.2229
#
# 🌿 Drug 1527 | Samples: 854
#   ➤ Global R²: -0.0349
#   ➤ Pearson r: 0.1459 (p=1.88e-05)
#   ➤ RMSE: 1.2943
#
# 🌿 Drug 1529 | Samples: 678
#   ➤ Global R²: 0.1294
#   ➤ Pearson r: 0.3727 (p=9.09e-24)
#   ➤ RMSE: 1.3957
#
# 🌿 Drug 1530 | Samples: 820
#   ➤ Global R²: 0.2318
#   ➤ Pearson r: 0.4869 (p=5.05e-50)
#   ➤ RMSE: 0.5348
#
# 🌿 Drug 1531 | Samples: 816
#   ➤ Global R²: 0.1734
#   ➤ Pearson r: 0.4262 (p=2.39e-37)
#   ➤ RMSE: 0.6273
#
# 🌿 Drug 1549 | Samples: 954
#   ➤ Global R²: 0.2973
#   ➤ Pearson r: 0.5463 (p=2.46e-75)
#   ➤ RMSE: 1.4859
#
# 🌿 Drug 1553 | Samples: 887
#   ➤ Global R²: 0.1585
#   ➤ Pearson r: 0.4089 (p=4.58e-37)
#   ➤ RMSE: 1.4789
#
# 🌿 Drug 1557 | Samples: 882
#   ➤ Global R²: 0.0995
#   ➤ Pearson r: 0.3320 (p=3.82e-24)
#   ➤ RMSE: 1.1747
#
# 🌿 Drug 1558 | Samples: 954
#   ➤ Global R²: 0.2520
#   ➤ Pearson r: 0.5026 (p=3.39e-62)
#   ➤ RMSE: 1.3667
#
# 🌿 Drug 1559 | Samples: 952
#   ➤ Global R²: 0.3571
#   ➤ Pearson r: 0.5976 (p=3.08e-93)
#   ➤ RMSE: 1.4510
#
# 🌿 Drug 1560 | Samples: 953
#   ➤ Global R²: 0.1817
#   ➤ Pearson r: 0.4285 (p=7.86e-44)
#   ➤ RMSE: 1.2341
#
# 🌿 Drug 1561 | Samples: 954
#   ➤ Global R²: 0.1331
#   ➤ Pearson r: 0.3746 (p=3.78e-33)
#   ➤ RMSE: 1.5807
#
# 🌿 Drug 1563 | Samples: 950
#   ➤ Global R²: 0.3931
#   ➤ Pearson r: 0.6272 (p=5.13e-105)
#   ➤ RMSE: 0.7959
#
# 🌿 Drug 1564 | Samples: 952
#   ➤ Global R²: 0.3845
#   ➤ Pearson r: 0.6204 (p=2.40e-102)
#   ➤ RMSE: 1.4046
#
# 🌿 Drug 1576 | Samples: 882
#   ➤ Global R²: 0.3460
#   ➤ Pearson r: 0.5894 (p=1.32e-83)
#   ➤ RMSE: 0.7231
#
# 🌿 Drug 1578 | Samples: 883
#   ➤ Global R²: 0.3626
#   ➤ Pearson r: 0.6043 (p=5.16e-89)
#   ➤ RMSE: 0.7277
#
# 🌿 Drug 1580 | Samples: 713
#   ➤ Global R²: 0.2962
#   ➤ Pearson r: 0.5462 (p=1.11e-56)
#   ➤ RMSE: 0.7422
#
# 🌿 Drug 1581 | Samples: 712
#   ➤ Global R²: 0.2835
#   ➤ Pearson r: 0.5371 (p=1.86e-54)
#   ➤ RMSE: 1.0569
#
# 🌿 Drug 1582 | Samples: 712
#   ➤ Global R²: 0.2752
#   ➤ Pearson r: 0.5277 (p=2.66e-52)
#   ➤ RMSE: 0.7473
#
# 🌿 Drug 1583 | Samples: 712
#   ➤ Global R²: 0.2470
#   ➤ Pearson r: 0.4992 (p=3.90e-46)
#   ➤ RMSE: 0.7601
#
# 🌿 Drug 1584 | Samples: 713
#   ➤ Global R²: 0.1039
#   ➤ Pearson r: 0.3445 (p=2.70e-21)
#   ➤ RMSE: 0.9167
#
# 🌿 Drug 1585 | Samples: 713
#   ➤ Global R²: 0.2049
#   ➤ Pearson r: 0.4540 (p=1.51e-37)
#   ➤ RMSE: 0.7105
#
# 🌿 Drug 1586 | Samples: 713
#   ➤ Global R²: 0.2462
#   ➤ Pearson r: 0.5007 (p=1.62e-46)
#   ➤ RMSE: 0.7356
#
# 🌿 Drug 1593 | Samples: 887
#   ➤ Global R²: 0.3757
#   ➤ Pearson r: 0.6135 (p=7.47e-93)
#   ➤ RMSE: 1.2925
#
# 🌿 Drug 1594 | Samples: 948
#   ➤ Global R²: 0.0769
#   ➤ Pearson r: 0.2944 (p=2.06e-20)
#   ➤ RMSE: 1.4170
#
# 🌿 Drug 1598 | Samples: 952
#   ➤ Global R²: 0.3105
#   ➤ Pearson r: 0.5592 (p=2.01e-79)
#   ➤ RMSE: 0.9157
#
# 🌿 Drug 1613 | Samples: 883
#   ➤ Global R²: 0.3825
#   ➤ Pearson r: 0.6190 (p=1.62e-94)
#   ➤ RMSE: 1.4038
#
# 🌿 Drug 1614 | Samples: 883
#   ➤ Global R²: 0.1790
#   ➤ Pearson r: 0.4283 (p=1.07e-40)
#   ➤ RMSE: 1.2410
#
# 🌿 Drug 1615 | Samples: 883
#   ➤ Global R²: 0.2895
#   ➤ Pearson r: 0.5430 (p=7.16e-69)
#   ➤ RMSE: 0.7964
#
# 🌿 Drug 1617 | Samples: 870
#   ➤ Global R²: 0.2010
#   ➤ Pearson r: 0.4489 (p=2.28e-44)
#   ➤ RMSE: 2.0929
#
# 🌿 Drug 1618 | Samples: 875
#   ➤ Global R²: 0.2719
#   ➤ Pearson r: 0.5229 (p=1.46e-62)
#   ➤ RMSE: 1.0366
#
# 🌿 Drug 1620 | Samples: 883
#   ➤ Global R²: 0.3517
#   ➤ Pearson r: 0.5942 (p=2.17e-85)
#   ➤ RMSE: 0.6738
#
# 🌿 Drug 1621 | Samples: 883
#   ➤ Global R²: 0.4137
#   ➤ Pearson r: 0.6434 (p=2.35e-104)
#   ➤ RMSE: 0.9795
#
# 🌿 Drug 1622 | Samples: 883
#   ➤ Global R²: 0.2861
#   ➤ Pearson r: 0.5376 (p=2.76e-67)
#   ➤ RMSE: 0.9234
#
# 🌿 Drug 1624 | Samples: 882
#   ➤ Global R²: 0.3267
#   ➤ Pearson r: 0.5733 (p=3.39e-78)
#   ➤ RMSE: 1.2975
#
# 🌿 Drug 1625 | Samples: 882
#   ➤ Global R²: 0.3027
#   ➤ Pearson r: 0.5544 (p=3.27e-72)
#   ➤ RMSE: 0.8964
#
# 🌿 Drug 1626 | Samples: 882
#   ➤ Global R²: 0.2641
#   ➤ Pearson r: 0.5177 (p=1.24e-61)
#   ➤ RMSE: 1.6008
#
# 🌿 Drug 1627 | Samples: 882
#   ➤ Global R²: 0.3268
#   ➤ Pearson r: 0.5729 (p=4.65e-78)
#   ➤ RMSE: 0.7129
#
# 🌿 Drug 1629 | Samples: 880
#   ➤ Global R²: 0.3350
#   ➤ Pearson r: 0.5791 (p=6.16e-80)
#   ➤ RMSE: 0.8511
#
# 🌿 Drug 1630 | Samples: 883
#   ➤ Global R²: 0.2078
#   ➤ Pearson r: 0.4593 (p=2.75e-47)
#   ➤ RMSE: 1.0848
#
# 🌿 Drug 1631 | Samples: 883
#   ➤ Global R²: 0.3113
#   ➤ Pearson r: 0.5583 (p=1.72e-73)
#   ➤ RMSE: 1.1597
#
# 🌿 Drug 1632 | Samples: 947
#   ➤ Global R²: 0.4427
#   ➤ Pearson r: 0.6658 (p=2.50e-122)
#   ➤ RMSE: 0.8655
#
# 🌿 Drug 1634 | Samples: 882
#   ➤ Global R²: 0.3101
#   ➤ Pearson r: 0.5589 (p=1.28e-73)
#   ➤ RMSE: 0.9001
#
# 🌿 Drug 1635 | Samples: 882
#   ➤ Global R²: 0.3414
#   ➤ Pearson r: 0.5862 (p=1.62e-82)
#   ➤ RMSE: 0.6508
#
# 🌿 Drug 1706 | Samples: 713
#   ➤ Global R²: 0.3222
#   ➤ Pearson r: 0.5717 (p=4.11e-63)
#   ➤ RMSE: 1.6189
#
# 🌿 Drug 1708 | Samples: 712
#   ➤ Global R²: 0.2997
#   ➤ Pearson r: 0.5492 (p=2.42e-57)
#   ➤ RMSE: 1.2491
#
# 🌿 Drug 1709 | Samples: 712
#   ➤ Global R²: 0.3140
#   ➤ Pearson r: 0.5622 (p=1.44e-60)
#   ➤ RMSE: 1.5850
#
# 🌿 Drug 1712 | Samples: 709
#   ➤ Global R²: 0.3334
#   ➤ Pearson r: 0.5783 (p=1.66e-64)
#   ➤ RMSE: 1.4390
#
# 🌿 Drug 1713 | Samples: 713
#   ➤ Global R²: 0.2222
#   ➤ Pearson r: 0.4747 (p=2.40e-41)
#   ➤ RMSE: 1.3866
#
# ...
#   ➤ Pearson r: 0.4208 (p=2.31e-42)
#   ➤ RMSE: 0.6574
#
# 🌿 Drug 1866 | Samples: 739
#   ➤ Global R²: 0.2273
#   ➤ Pearson r: 0.4809 (p=4.94e-44)
#   ➤ RMSE: 1.0613
#
# 🌿 Drug 1873 | Samples: 946
#   ➤ Global R²: 0.3131
#   ➤ Pearson r: 0.5599 (p=3.65e-79)
#   ➤ RMSE: 0.7733
#
# 🌿 Drug 1908 | Samples: 946
#   ➤ Global R²: 0.3523
#   ➤ Pearson r: 0.5936 (p=3.82e-91)
#   ➤ RMSE: 1.1415
#
# 🌿 Drug 1909 | Samples: 946
#   ➤ Global R²: 0.4719
#   ➤ Pearson r: 0.6872 (p=3.57e-133)
#   ➤ RMSE: 1.3892
#
# 🌿 Drug 1910 | Samples: 945
#   ➤ Global R²: 0.4009
#   ➤ Pearson r: 0.6339 (p=2.39e-107)
#   ➤ RMSE: 1.5905
#
# 🌿 Drug 1911 | Samples: 930
#   ➤ Global R²: 0.4193
#   ➤ Pearson r: 0.6476 (p=1.14e-111)
#   ➤ RMSE: 1.2062
#
# 🌿 Drug 1912 | Samples: 945
#   ➤ Global R²: 0.2067
#   ➤ Pearson r: 0.4582 (p=3.20e-50)
#   ➤ RMSE: 1.3116
#
# 🌿 Drug 1913 | Samples: 946
#   ➤ Global R²: 0.2054
#   ➤ Pearson r: 0.4617 (p=3.93e-51)
#   ➤ RMSE: 0.8072
#
# 🌿 Drug 1915 | Samples: 954
#   ➤ Global R²: 0.2064
#   ➤ Pearson r: 0.4583 (p=1.02e-50)
#   ➤ RMSE: 0.9547
#
# 🌿 Drug 1916 | Samples: 946
#   ➤ Global R²: 0.1768
#   ➤ Pearson r: 0.4269 (p=3.54e-43)
#   ➤ RMSE: 1.3092
#
# 🌿 Drug 1917 | Samples: 946
#   ➤ Global R²: 0.3573
#   ➤ Pearson r: 0.5980 (p=8.69e-93)
#   ➤ RMSE: 1.1701
#
# 🌿 Drug 1918 | Samples: 946
#   ➤ Global R²: 0.0930
#   ➤ Pearson r: 0.3214 (p=3.58e-24)
#   ➤ RMSE: 1.3268
#
# 🌿 Drug 1919 | Samples: 945
#   ➤ Global R²: 0.1895
#   ➤ Pearson r: 0.4389 (p=9.04e-46)
#   ➤ RMSE: 1.1450
#
# 🌿 Drug 1922 | Samples: 946
#   ➤ Global R²: 0.1726
#   ➤ Pearson r: 0.4169 (p=4.50e-41)
#   ➤ RMSE: 1.0861
#
# 🌿 Drug 1924 | Samples: 946
#   ➤ Global R²: 0.1715
#   ➤ Pearson r: 0.4210 (p=6.25e-42)
#   ➤ RMSE: 1.3227
#
# 🌿 Drug 1925 | Samples: 946
#   ➤ Global R²: 0.2836
#   ➤ Pearson r: 0.5337 (p=8.98e-71)
#   ➤ RMSE: 0.7964
#
# 🌿 Drug 1926 | Samples: 932
#   ➤ Global R²: 0.1669
#   ➤ Pearson r: 0.4145 (p=5.25e-40)
#   ➤ RMSE: 1.1871
#
# 🌿 Drug 1927 | Samples: 946
#   ➤ Global R²: 0.2270
#   ➤ Pearson r: 0.4805 (p=8.33e-56)
#   ➤ RMSE: 0.8446
#
# 🌿 Drug 1928 | Samples: 946
#   ➤ Global R²: 0.4258
#   ➤ Pearson r: 0.6529 (p=5.07e-116)
#   ➤ RMSE: 0.9633
#
# 🌿 Drug 1930 | Samples: 946
#   ➤ Global R²: 0.3633
#   ➤ Pearson r: 0.6028 (p=1.20e-94)
#   ➤ RMSE: 0.9796
#
# 🌿 Drug 1931 | Samples: 954
#   ➤ Global R²: 0.4962
#   ➤ Pearson r: 0.7045 (p=6.49e-144)
#   ➤ RMSE: 0.8733
#
# 🌿 Drug 1932 | Samples: 946
#   ➤ Global R²: 0.2645
#   ➤ Pearson r: 0.5146 (p=4.28e-65)
#   ➤ RMSE: 1.2601
#
# 🌿 Drug 1933 | Samples: 946
#   ➤ Global R²: 0.3047
#   ➤ Pearson r: 0.5528 (p=8.06e-77)
#   ➤ RMSE: 1.2586
#
# 🌿 Drug 1936 | Samples: 945
#   ➤ Global R²: 0.1365
#   ➤ Pearson r: 0.3837 (p=1.64e-34)
#   ➤ RMSE: 1.1037
#
# 🌿 Drug 1939 | Samples: 739
#   ➤ Global R²: 0.1662
#   ➤ Pearson r: 0.4140 (p=5.79e-32)
#   ➤ RMSE: 1.2189
#
# 🌿 Drug 1940 | Samples: 945
#   ➤ Global R²: 0.0333
#   ➤ Pearson r: 0.2374 (p=1.43e-13)
#   ➤ RMSE: 0.9453
#
# 🌿 Drug 1941 | Samples: 946
#   ➤ Global R²: 0.2178
#   ➤ Pearson r: 0.4676 (p=1.44e-52)
#   ➤ RMSE: 1.4404
#
# 🌿 Drug 1996 | Samples: 739
#   ➤ Global R²: 0.2557
#   ➤ Pearson r: 0.5100 (p=3.61e-50)
#   ➤ RMSE: 1.0339
#
# 🌿 Drug 1997 | Samples: 950
#   ➤ Global R²: 0.2268
#   ➤ Pearson r: 0.4788 (p=1.35e-55)
#   ➤ RMSE: 1.5118
#
# 🌿 Drug 1998 | Samples: 739
#   ➤ Global R²: 0.2197
#   ➤ Pearson r: 0.4749 (p=7.65e-43)
#   ➤ RMSE: 1.0112
#
# 🌿 Drug 1999 | Samples: 738
#   ➤ Global R²: 0.4223
#   ➤ Pearson r: 0.6501 (p=7.65e-90)
#   ➤ RMSE: 1.1710
#
# 🌿 Drug 2000 | Samples: 739
#   ➤ Global R²: 0.3475
#   ➤ Pearson r: 0.5929 (p=2.45e-71)
#   ➤ RMSE: 0.7811
#
# 🌿 Drug 2002 | Samples: 739
#   ➤ Global R²: 0.4173
#   ➤ Pearson r: 0.6464 (p=1.22e-88)
#   ➤ RMSE: 0.8507
#
# 🌿 Drug 2003 | Samples: 739
#   ➤ Global R²: 0.3853
#   ➤ Pearson r: 0.6220 (p=2.41e-80)
#   ➤ RMSE: 0.7539
#
# 🌿 Drug 2010 | Samples: 736
#   ➤ Global R²: 0.3992
#   ➤ Pearson r: 0.6321 (p=2.41e-83)
#   ➤ RMSE: 1.2310
#
# 🌿 Drug 2011 | Samples: 735
#   ➤ Global R²: 0.3919
#   ➤ Pearson r: 0.6261 (p=2.86e-81)
#   ➤ RMSE: 1.0773
#
# 🌿 Drug 2037 | Samples: 736
#   ➤ Global R²: 0.3466
#   ➤ Pearson r: 0.5891 (p=5.90e-70)
#   ➤ RMSE: 1.0962
#
# 🌿 Drug 2038 | Samples: 728
#   ➤ Global R²: 0.4838
#   ➤ Pearson r: 0.6963 (p=1.19e-106)
#   ➤ RMSE: 1.0202
#
# 🌿 Drug 2039 | Samples: 922
#   ➤ Global R²: 0.1974
#   ➤ Pearson r: 0.4503 (p=3.06e-47)
#   ➤ RMSE: 0.8269
#
# 🌿 Drug 2040 | Samples: 941
#   ➤ Global R²: 0.2337
#   ➤ Pearson r: 0.4859 (p=6.45e-57)
#   ➤ RMSE: 1.1961
#
# 🌿 Drug 2043 | Samples: 940
#   ➤ Global R²: 0.2069
#   ➤ Pearson r: 0.4667 (p=5.09e-52)
#   ➤ RMSE: 0.8962
#
# 🌿 Drug 2044 | Samples: 939
#   ➤ Global R²: 0.3658
#   ➤ Pearson r: 0.6049 (p=8.52e-95)
#   ➤ RMSE: 1.0341
#
# 🌿 Drug 2045 | Samples: 938
#   ➤ Global R²: 0.3709
#   ➤ Pearson r: 0.6100 (p=1.14e-96)
#   ➤ RMSE: 0.9327
#
# 🌿 Drug 2046 | Samples: 940
#   ➤ Global R²: 0.3709
#   ➤ Pearson r: 0.6095 (p=1.12e-96)
#   ➤ RMSE: 1.3120
#
# 🌿 Drug 2047 | Samples: 735
#   ➤ Global R²: 0.1441
#   ➤ Pearson r: 0.3922 (p=1.91e-28)
#   ➤ RMSE: 1.4165
#
# 🌿 Drug 2048 | Samples: 944
#   ➤ Global R²: 0.4551
#   ➤ Pearson r: 0.6748 (p=2.05e-126)
#   ➤ RMSE: 1.5574
#
# 🌿 Drug 2055 | Samples: 733
#   ➤ Global R²: 0.4025
#   ➤ Pearson r: 0.6345 (p=7.87e-84)
#   ➤ RMSE: 1.1876
#
# 🌿 Drug 2057 | Samples: 367
#   ➤ Global R²: 0.1917
#   ➤ Pearson r: 0.4477 (p=1.71e-19)
#   ➤ RMSE: 1.0377
#
# 🌿 Drug 2096 | Samples: 942
#   ➤ Global R²: 0.3134
#   ➤ Pearson r: 0.5598 (p=8.11e-79)
#   ➤ RMSE: 1.1647
#
# 🌿 Drug 2106 | Samples: 732
#   ➤ Global R²: 0.2538
#   ➤ Pearson r: 0.5039 (p=2.21e-48)
#   ➤ RMSE: 1.5668
#
# 🌿 Drug 2107 | Samples: 942
#   ➤ Global R²: 0.3136
#   ➤ Pearson r: 0.5606 (p=4.40e-79)
#   ➤ RMSE: 0.8887
#
# 🌿 Drug 2109 | Samples: 943
#   ➤ Global R²: 0.1447
#   ➤ Pearson r: 0.3918 (p=5.73e-36)
#   ➤ RMSE: 1.0412
#
# 🌿 Drug 2110 | Samples: 942
#   ➤ Global R²: 0.2586
#   ➤ Pearson r: 0.5106 (p=1.09e-63)
#   ➤ RMSE: 1.0386
#
# 🌿 Drug 2111 | Samples: 939
#   ➤ Global R²: 0.4039
#   ➤ Pearson r: 0.6360 (p=1.44e-107)
#   ➤ RMSE: 1.2158
#
# 🌿 Drug 2112 | Samples: 733
#   ➤ Global R²: 0.2121
#   ➤ Pearson r: 0.4705 (p=1.22e-41)
#   ➤ RMSE: 0.7714
#
# 🌿 Drug 2113 | Samples: 733
#   ➤ Global R²: 0.2717
#   ➤ Pearson r: 0.5235 (p=8.30e-53)
#   ➤ RMSE: 0.6933
#
# 🌿 Drug 2145 | Samples: 737
#   ➤ Global R²: 0.4938
#   ➤ Pearson r: 0.7034 (p=4.32e-111)
#   ➤ RMSE: 1.1268
#
# 🌿 Drug 2148 | Samples: 737
#   ➤ Global R²: 0.3309
#   ➤ Pearson r: 0.5768 (p=1.42e-66)
#   ➤ RMSE: 1.0466
#
# 🌿 Drug 2149 | Samples: 737
#   ➤ Global R²: 0.4712
#   ➤ Pearson r: 0.6867 (p=6.79e-104)
#   ➤ RMSE: 0.9040
#
# 🌿 Drug 2154 | Samples: 735
#   ➤ Global R²: 0.2907
#   ➤ Pearson r: 0.5442 (p=6.94e-58)
#   ➤ RMSE: 0.7997
#
# 🌿 Drug 2156 | Samples: 736
#   ➤ Global R²: 0.3877
#   ➤ Pearson r: 0.6229 (p=2.64e-80)
#   ➤ RMSE: 1.0886
#
# 🌿 Drug 2157 | Samples: 737
#   ➤ Global R²: 0.3030
#   ➤ Pearson r: 0.5522 (p=4.65e-60)
#   ➤ RMSE: 0.8557
#
# 🌿 Drug 2158 | Samples: 737
#   ➤ Global R²: 0.3729
#   ➤ Pearson r: 0.6117 (p=7.32e-77)
#   ➤ RMSE: 1.1387
#
# 🌿 Drug 2159 | Samples: 737
#   ➤ Global R²: 0.4152
#   ➤ Pearson r: 0.6451 (p=5.93e-88)
#   ➤ RMSE: 1.1053
#
# 🌿 Drug 2169 | Samples: 259
#   ➤ Global R²: 0.0155
#   ➤ Pearson r: 0.2593 (p=2.38e-05)
#   ➤ RMSE: 1.3450
#
# 🌿 Drug 2170 | Samples: 942
#   ➤ Global R²: 0.1911
#   ➤ Pearson r: 0.4421 (p=2.34e-46)
#   ➤ RMSE: 1.4436
#
# 🌿 Drug 2171 | Samples: 938
#   ➤ Global R²: 0.3046
#   ➤ Pearson r: 0.5519 (p=6.84e-76)
#   ➤ RMSE: 1.6607
#
# 🌿 Drug 2172 | Samples: 938
#   ➤ Global R²: 0.3583
#   ➤ Pearson r: 0.5990 (p=1.98e-92)
#   ➤ RMSE: 1.5631
#
# 🌿 Drug 2173 | Samples: 935
#   ➤ Global R²: 0.3285
#   ➤ Pearson r: 0.5747 (p=2.74e-83)
#   ➤ RMSE: 0.9168
#
# 🌿 Drug 2174 | Samples: 217
#   ➤ Global R²: 0.2154
#   ➤ Pearson r: 0.4743 (p=1.44e-13)
#   ➤ RMSE: 0.7664
#
# 🌿 Drug 2175 | Samples: 217
#   ➤ Global R²: 0.2525
#   ➤ Pearson r: 0.5142 (p=4.81e-16)
#   ➤ RMSE: 1.2853
#
# 🌿 Drug 2177 | Samples: 935
#   ➤ Global R²: 0.1593
#   ➤ Pearson r: 0.4098 (p=3.61e-39)
#   ➤ RMSE: 0.7283
#
# 🌿 Drug 2359 | Samples: 728
#   ➤ Global R²: 0.4783
#   ➤ Pearson r: 0.6918 (p=9.00e-105)
#   ➤ RMSE: 0.8434
#
# 🌿 Drug 2360 | Samples: 728
#   ➤ Global R²: 0.3096
#   ➤ Pearson r: 0.5596 (p=3.13e-61)
#   ➤ RMSE: 0.8464
#
# 🌿 Drug 2361 | Samples: 728
#   ➤ Global R²: 0.2905
#   ➤ Pearson r: 0.5417 (p=9.39e-57)
#   ➤ RMSE: 0.8152
#
# 🌿 Drug 2362 | Samples: 728
#   ➤ Global R²: 0.3550
#   ➤ Pearson r: 0.5961 (p=2.96e-71)
#   ➤ RMSE: 0.9298
#
# 🌿 Drug 2438 | Samples: 729
#   ➤ Global R²: 0.2492
#   ➤ Pearson r: 0.5028 (p=5.68e-48)
#   ➤ RMSE: 1.1091
#
# 🌿 Drug 2439 | Samples: 729
#   ➤ Global R²: 0.1604
#   ➤ Pearson r: 0.4105 (p=5.31e-31)
#   ➤ RMSE: 0.8152
#
# 🌿 Drug 2498 | Samples: 732
#   ➤ Global R²: 0.2743
#   ➤ Pearson r: 0.5259 (p=2.66e-53)
#   ➤ RMSE: 0.8231
#
# 🌿 Drug 2499 | Samples: 732
#   ➤ Global R²: 0.0569
#   ➤ Pearson r: 0.2874 (p=2.19e-15)
#   ➤ RMSE: 0.8427
#
# 🌿 Drug 2500 | Samples: 737
#   ➤ Global R²: 0.4578
#   ➤ Pearson r: 0.6766 (p=8.95e-100)
#   ➤ RMSE: 1.6031
#
# 🌿 Drug 2501 | Samples: 755
#   ➤ Global R²: 0.4119
#   ➤ Pearson r: 0.6418 (p=6.93e-89)
#   ➤ RMSE: 1.4141
#
# 🌿 Drug 2502 | Samples: 739
#   ➤ Global R²: 0.4953
#   ➤ Pearson r: 0.7038 (p=1.51e-111)
#   ➤ RMSE: 1.6137
#
# 🌿 Drug 2503 | Samples: 955
#   ➤ Global R²: 0.4210
#   ➤ Pearson r: 0.6491 (p=2.59e-115)
#   ➤ RMSE: 1.1882
#
# 🌿 Drug 2504 | Samples: 870
#   ➤ Global R²: 0.1876
#   ➤ Pearson r: 0.4390 (p=2.73e-42)
#   ➤ RMSE: 2.2397
#
# 🌿 Drug 2505 | Samples: 217
#   ➤ Global R²: 0.1863
#   ➤ Pearson r: 0.4504 (p=3.09e-12)
#   ➤ RMSE: 0.9262
#
# 🌿 Drug 2506 | Samples: 946
#   ➤ Global R²: 0.2007
#   ➤ Pearson r: 0.4557 (p=1.09e-49)
#   ➤ RMSE: 1.0714
#
# 🌿 Drug 2507 | Samples: 955
#   ➤ Global R²: 0.3940
#   ➤ Pearson r: 0.6278 (p=8.67e-106)
#   ➤ RMSE: 1.5600
#
# 🌿 Drug 2508 | Samples: 947
#   ➤ Global R²: 0.5187
#   ➤ Pearson r: 0.7202 (p=3.12e-152)
#   ➤ RMSE: 0.7570
#
# 🌿 Drug 2509 | Samples: 943
#   ➤ Global R²: 0.3571
#   ➤ Pearson r: 0.5995 (p=4.43e-93)
#   ➤ RMSE: 1.2446
#
# 🌿 Drug 2510 | Samples: 936
#   ➤ Global R²: 0.3883
#   ➤ Pearson r: 0.6232 (p=7.78e-102)
#   ➤ RMSE: 1.4925
#
# 🌿 Drug 2511 | Samples: 911
#   ➤ Global R²: 0.3061
#   ➤ Pearson r: 0.5535 (p=3.06e-74)
#   ➤ RMSE: 1.4113
#
# 🌿 Drug 2512 | Samples: 955
#   ➤ Global R²: 0.4474
#   ➤ Pearson r: 0.6689 (p=6.99e-125)
#   ➤ RMSE: 0.9648
#
# 🌿 Drug 2513 | Samples: 938
#   ➤ Global R²: 0.3616
#   ➤ Pearson r: 0.6034 (p=4.35e-94)
#   ➤ RMSE: 0.7270
#
# 🌿 Drug 2514 | Samples: 938
#   ➤ Global R²: 0.4163
#   ➤ Pearson r: 0.6461 (p=6.32e-112)
#   ➤ RMSE: 1.1681
#
# 🌿 Drug 2515 | Samples: 938
#   ➤ Global R²: 0.4686
#   ➤ Pearson r: 0.6851 (p=5.77e-131)
#   ➤ RMSE: 0.7787
#
# 🌿 Drug 2516 | Samples: 949
#   ➤ Global R²: 0.4242
#   ➤ Pearson r: 0.6514 (p=1.14e-115)
#   ➤ RMSE: 1.2698
#
# 🌿 Drug 2517 | Samples: 949
#   ➤ Global R²: 0.3877
#   ➤ Pearson r: 0.6229 (p=4.42e-103)
#   ➤ RMSE: 1.1944
#
# 🌿 Drug 2518 | Samples: 942
#   ➤ Global R²: 0.2158
#   ➤ Pearson r: 0.4718 (p=2.18e-53)
#   ➤ RMSE: 0.8182
#
# 🌿 Drug 2519 | Samples: 936
#   ➤ Global R²: 0.4379
#   ➤ Pearson r: 0.6621 (p=3.95e-119)
#   ➤ RMSE: 1.2113
#
# 🌿 Drug 2520 | Samples: 945
#   ➤ Global R²: 0.2487
#   ➤ Pearson r: 0.5020 (p=1.79e-61)
#   ➤ RMSE: 0.8972
#
# 🌿 Drug 2521 | Samples: 938
#   ➤ Global R²: 0.2203
#   ➤ Pearson r: 0.4714 (p=4.54e-53)
#   ➤ RMSE: 1.3995
#
# 🌿 Drug 2522 | Samples: 938
#   ➤ Global R²: 0.3379
#   ➤ Pearson r: 0.5878 (p=3.19e-88)
#   ➤ RMSE: 0.9187
#
# 🌿 Drug 2523 | Samples: 944
#   ➤ Global R²: 0.3163
#   ➤ Pearson r: 0.5633 (p=3.94e-80)
#   ➤ RMSE: 0.9263
#
# 🌿 Drug 2524 | Samples: 217
#   ➤ Global R²: 0.2275
#   ➤ Pearson r: 0.4793 (p=7.30e-14)
#   ➤ RMSE: 1.7685
#
# 🌿 Drug 2525 | Samples: 954
#   ➤ Global R²: 0.2313
#   ➤ Pearson r: 0.4815 (p=1.62e-56)
#   ➤ RMSE: 1.2833
#
# 🌿 Drug 2526 | Samples: 938
#   ➤ Global R²: 0.3329
#   ➤ Pearson r: 0.5790 (p=4.53e-85)
#   ➤ RMSE: 0.7979
#
# 🌿 Drug 2527 | Samples: 949
#   ➤ Global R²: 0.2964
#   ➤ Pearson r: 0.5445 (p=2.30e-74)
#   ➤ RMSE: 1.2250
#
# 🌿 Drug 2528 | Samples: 217
#   ➤ Global R²: 0.3433
#   ➤ Pearson r: 0.5867 (p=1.84e-21)
#   ➤ RMSE: 1.0115
#
# 🌿 Drug 2529 | Samples: 934
#   ➤ Global R²: 0.2430
#   ➤ Pearson r: 0.4951 (p=6.60e-59)
#   ➤ RMSE: 1.1618
#
# 🌿 Drug 2530 | Samples: 217
#   ➤ Global R²: 0.1923
#   ➤ Pearson r: 0.4533 (p=2.16e-12)
#   ➤ RMSE: 0.7421
#
# 🌿 Drug 2531 | Samples: 944
#   ➤ Global R²: 0.1835
#   ➤ Pearson r: 0.4368 (p=2.89e-45)
#   ➤ RMSE: 1.0649
#
# 🌿 Drug 2532 | Samples: 939
#   ➤ Global R²: 0.2421
#   ➤ Pearson r: 0.4957 (p=2.27e-59)
#   ➤ RMSE: 0.8306
#
# 🌿 Drug 2533 | Samples: 945
#   ➤ Global R²: 0.4160
#   ➤ Pearson r: 0.6453 (p=2.08e-112)
#   ➤ RMSE: 1.1735
#
# 🌿 Drug 2534 | Samples: 956
#   ➤ Global R²: 0.3848
#   ➤ Pearson r: 0.6203 (p=9.32e-103)
#   ➤ RMSE: 1.4065
#
# 🌿 Drug 2535 | Samples: 883
#   ➤ Global R²: 0.3162
#   ➤ Pearson r: 0.5635 (p=3.83e-75)
#   ➤ RMSE: 0.9760
#
# 🌿 Drug 2536 | Samples: 955
#   ➤ Global R²: 0.2057
#   ➤ Pearson r: 0.4579 (p=1.12e-50)
#   ➤ RMSE: 1.2481
#
# 🌿 Drug 2537 | Samples: 933
#   ➤ Global R²: 0.3711
#   ➤ Pearson r: 0.6092 (p=7.45e-96)
#   ➤ RMSE: 1.3537
#
# 🌿 Drug 2538 | Samples: 944
#   ➤ Global R²: 0.4349
#   ➤ Pearson r: 0.6595 (p=6.95e-119)
#   ➤ RMSE: 1.2139
#
# 🌿 Drug 2539 | Samples: 956
#   ➤ Global R²: 0.2953
#   ➤ Pearson r: 0.5439 (p=1.06e-74)
#   ➤ RMSE: 1.2464
#
# 🌿 Drug 2540 | Samples: 956
#   ➤ Global R²: 0.5480
#   ➤ Pearson r: 0.7403 (p=9.92e-167)
#   ➤ RMSE: 1.0577
#
# 🌿 Drug 2541 | Samples: 946
#   ➤ Global R²: 0.3782
#   ➤ Pearson r: 0.6150 (p=1.72e-99)
#   ➤ RMSE: 1.1220
#
# 🌿 Drug 2542 | Samples: 955
#   ➤ Global R²: 0.1511
#   ➤ Pearson r: 0.3961 (p=3.17e-37)
#   ➤ RMSE: 1.1543
#
# 🌿 Drug 2543 | Samples: 741
#   ➤ Global R²: 0.2587
#   ➤ Pearson r: 0.5103 (p=2.23e-50)
#   ➤ RMSE: 1.1813
#
# 🌿 Drug 2544 | Samples: 956
#   ➤ Global R²: 0.4412
#   ➤ Pearson r: 0.6654 (p=2.89e-123)
#   ➤ RMSE: 1.5940
#
# 🌿 Drug 2545 | Samples: 933
#   ➤ Global R²: 0.3674
#   ➤ Pearson r: 0.6082 (p=1.86e-95)
#   ➤ RMSE: 1.0737
#
# 🌿 Drug 2546 | Samples: 938
#   ➤ Global R²: 0.3690
#   ➤ Pearson r: 0.6078 (p=8.50e-96)
#   ➤ RMSE: 1.3908
#
# 🌿 Drug 2547 | Samples: 927
#   ➤ Global R²: 0.2546
#   ➤ Pearson r: 0.5061 (p=1.92e-61)
#   ➤ RMSE: 0.7371
#
# 🌿 Drug 2548 | Samples: 932
#   ➤ Global R²: 0.1994
#   ➤ Pearson r: 0.4528 (p=2.71e-48)
#   ➤ RMSE: 0.8769
#
# 🌿 Drug 2549 | Samples: 943
#   ➤ Global R²: 0.2880
#   ➤ Pearson r: 0.5373 (p=1.18e-71)
#   ➤ RMSE: 0.9023
#
# 🌿 Drug 2550 | Samples: 946
#   ➤ Global R²: 0.1617
#   ➤ Pearson r: 0.4063 (p=6.54e-39)
#   ➤ RMSE: 1.2558
#
# 🌿 Drug 2551 | Samples: 260
#   ➤ Global R²: 0.1607
#   ➤ Pearson r: 0.4254 (p=7.52e-13)
#   ➤ RMSE: 0.8478
#
# 🌿 Drug 2552 | Samples: 937
#   ➤ Global R²: 0.3941
#   ➤ Pearson r: 0.6282 (p=5.33e-104)
#   ➤ RMSE: 0.9942
#
# 🌿 Drug 2553 | Samples: 375
#   ➤ Global R²: 0.1118
#   ➤ Pearson r: 0.3687 (p=1.62e-13)
#   ➤ RMSE: 1.3338
#
# 🌿 Drug 2554 | Samples: 217
#   ➤ Global R²: 0.1992
#   ➤ Pearson r: 0.4583 (p=1.15e-12)
#   ➤ RMSE: 1.2065
#
# 🌿 Drug 2555 | Samples: 937
#   ➤ Global R²: 0.3254
#   ➤ Pearson r: 0.5719 (p=1.78e-82)
#   ➤ RMSE: 0.8688
#
# 🌿 Drug 2556 | Samples: 260
#   ➤ Global R²: 0.2507
#   ➤ Pearson r: 0.5017 (p=5.57e-18)
#   ➤ RMSE: 1.2360
#
# 🌿 Drug 2557 | Samples: 257
#   ➤ Global R²: 0.1762
#   ➤ Pearson r: 0.4338 (p=3.25e-13)
#   ➤ RMSE: 1.3866
#
# 🌿 Drug 2558 | Samples: 945
#   ➤ Global R²: 0.2411
#   ➤ Pearson r: 0.4941 (p=2.57e-59)
#   ➤ RMSE: 1.0604
#
# 🌿 Drug 2559 | Samples: 946
#   ➤ Global R²: 0.4212
#   ➤ Pearson r: 0.6490 (p=3.14e-114)
#   ➤ RMSE: 1.2552
#
# 🌿 Drug 2560 | Samples: 217
#   ➤ Global R²: 0.2697
#   ➤ Pearson r: 0.5215 (p=1.57e-16)
#   ➤ RMSE: 1.0339
#
# 🌿 Drug 2561 | Samples: 586
#   ➤ Global R²: 0.2065
#   ➤ Pearson r: 0.4644 (p=1.09e-32)
#   ➤ RMSE: 2.4592
#
# 🌿 Drug 2562 | Samples: 944
#   ➤ Global R²: 0.3596
#   ➤ Pearson r: 0.5997 (p=2.87e-93)
#   ➤ RMSE: 1.7727
#
# 🌿 Drug 2563 | Samples: 882
#   ➤ Global R²: 0.1209
#   ➤ Pearson r: 0.3620 (p=1.08e-28)
#   ➤ RMSE: 0.9326
#
# 🌿 Drug 2564 | Samples: 954
#   ➤ Global R²: 0.4461
#   ➤ Pearson r: 0.6687 (p=1.10e-124)
#   ➤ RMSE: 1.6684
#
# 🌿 Drug 2565 | Samples: 942
#   ➤ Global R²: 0.3588
#   ➤ Pearson r: 0.6018 (p=7.09e-94)
#   ➤ RMSE: 1.4623
#
# 🌿 Drug 2566 | Samples: 953
#   ➤ Global R²: 0.4705
#   ➤ Pearson r: 0.6860 (p=1.76e-133)
#   ➤ RMSE: 0.9474
#
# 🌿 Drug 2567 | Samples: 728
#   ➤ Global R²: 0.2748
#   ➤ Pearson r: 0.5244 (p=1.12e-52)
#   ➤ RMSE: 1.7714
#
# 🌿 Drug 2568 | Samples: 713
#   ➤ Global R²: 0.3263
#   ➤ Pearson r: 0.5725 (p=2.60e-63)
#   ➤ RMSE: 1.2388
#
# 🌿 Drug 2569 | Samples: 710
#   ➤ Global R²: 0.0815
#   ➤ Pearson r: 0.3159 (p=6.36e-18)
#   ➤ RMSE: 1.5327
#
# 🌿 Drug 2570 | Samples: 713
#   ➤ Global R²: 0.1212
#   ➤ Pearson r: 0.3662 (p=4.71e-24)
#   ➤ RMSE: 1.3547
#
# 🌿 Drug 2571 | Samples: 712
#   ➤ Global R²: 0.3456
#   ➤ Pearson r: 0.5900 (p=5.46e-68)
#   ➤ RMSE: 0.8173
#
# 🌿 Drug 2572 | Samples: 713
#   ➤ Global R²: 0.0972
#   ➤ Pearson r: 0.3274 (p=2.83e-19)
#   ➤ RMSE: 1.4509
#
# 🌿 Drug 2573 | Samples: 946
#   ➤ Global R²: 0.3229
#   ➤ Pearson r: 0.5684 (p=4.87e-82)
#   ➤ RMSE: 1.6667
#
# 🌿 Drug 2574 | Samples: 217
#   ➤ Global R²: 0.2333
#   ➤ Pearson r: 0.4911 (p=1.42e-14)
#   ➤ RMSE: 0.7768
#
# 🌿 Drug 2575 | Samples: 944
#   ➤ Global R²: 0.3722
#   ➤ Pearson r: 0.6108 (p=1.36e-97)
#   ➤ RMSE: 1.7001

# %%
# Results dataframe
results_df = pd.DataFrame(results)
results_df.to_csv("results/xgboost/10_fold_voom_30_pcs_tissue_growth.csv", index=False)
print("\n📁 Saved results to results/xgboost/xgboost_cv_concatenated_metrics.csv")
# Out:
# 📁 Saved results to results/xgboost/xgboost_cv_concatenated_metrics.csv

# %% [markdown]
# ### 📊 Distribution of XGBoost Model Performance
#
# These plots visualize the RMSE and R² across all drug-specific models trained using XGBoost.

# %%
# RMSE Distribution
plt.figure(figsize=(8, 5))
sns.histplot(results_df["rmse"], kde=True, bins=30, color="darkorange")
plt.title("RMSE Distribution Across Drugs (XGBoost, 10-fold CV, concatenated)")
plt.xlabel("RMSE")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()

# %%
# 📊 Global R² Distribution Across Drugs (XGBoost)
plt.figure(figsize=(8, 5))
sns.histplot(results_df["r2_global"], kde=True, bins=30, color="teal")
plt.title("Global R² Distribution Across Drugs (XGBoost, 10-fold CV, concatenated)")
plt.xlabel("Global R² Score")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()
plt.close()

# %%
# Pearson r Distribution
plt.figure(figsize=(8, 5))
sns.histplot(results_df["pearson_r"], kde=True, bins=30, color="mediumpurple")
plt.title("Pearson r Distribution Across Drugs (XGBoost, 10-fold CV, concatenated)")
plt.xlabel("Pearson r")
plt.ylabel("Number of Drugs")
plt.grid(True)
plt.show()

# %%
# 📊 Global R² vs. Pearson r consistency plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="r2_global", y="pearson_r")
plt.title("Global R² vs. Pearson r per Drug (XGBoost)")
plt.xlabel("Global R² Score")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()

# %%
# Scatter: R² vs. Sample Size
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="n_samples", y="r2_global")
plt.title("Global R² vs. Sample Size per Drug (XGBoost)")
plt.xlabel("Number of Samples")
plt.ylabel("Global R² Score")
plt.grid(True)
plt.show()

# %%
# Scatter: Pearson r vs. Sample Size
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="n_samples", y="pearson_r")
plt.title("Pearson r vs. Sample Size per Drug (XGBoost)")
plt.xlabel("Number of Samples")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()

# %%
# Correlations
from scipy.stats import spearmanr

pearson_corr_r2, pval_pearson_r2 = pearsonr(results_df["n_samples"], results_df["r2_global"])
spearman_corr_r2, pval_spearman_r2 = spearmanr(results_df["n_samples"], results_df["r2_global"])
print(f"\n📊 Pearson r (samples vs R²) = {pearson_corr_r2:.3f} (p = {pval_pearson_r2:.3g})")
print(f"📊 Spearman ρ (samples vs R²) = {spearman_corr_r2:.3f} (p = {pval_spearman_r2:.3g})")

pearson_corr_r, pval_pearson_r = pearsonr(results_df["n_samples"], results_df["pearson_r"])
spearman_corr_r, pval_spearman_r = spearmanr(results_df["n_samples"], results_df["pearson_r"])
print(f"📊 Pearson r (samples vs Pearson r) = {pearson_corr_r:.3f} (p = {pval_pearson_r:.3g})")
print(f"📊 Spearman ρ (samples vs Pearson r) = {spearman_corr_r:.3f} (p = {pval_spearman_r:.3g})")
# Out:
# 📊 Pearson r (samples vs R²) = 0.203 (p = 7.69e-08)
# 📊 Spearman ρ (samples vs R²) = 0.212 (p = 1.89e-08)
# 📊 Pearson r (samples vs Pearson r) = 0.189 (p = 5.74e-07)
# 📊 Spearman ρ (samples vs Pearson r) = 0.203 (p = 7.66e-08)

# %%
# IC50 variance correlations
variances = data.groupby("DRUG_ID")["LN_IC50"].var()
results_df = results_df.merge(variances.rename("ic50_variance"), on="DRUG_ID")

plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="ic50_variance", y="r2_global")
plt.title("Global R² vs. IC50 Variance (XGBoost)")
plt.xlabel("IC50 Variance (LN_IC50)")
plt.ylabel("Global R² Score")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=results_df, x="ic50_variance", y="pearson_r")
plt.title("Pearson r vs. IC50 Variance (XGBoost)")
plt.xlabel("IC50 Variance (LN_IC50)")
plt.ylabel("Pearson r")
plt.grid(True)
plt.show()

# %%
pearson_corr_var, pval_pearson_var = pearsonr(results_df["ic50_variance"], results_df["pearson_r"])
spearman_corr_var, pval_spearman_var = spearmanr(results_df["ic50_variance"], results_df["pearson_r"])
print(f"📊 Pearson r (IC50 variance vs Pearson r) = {pearson_corr_var:.3f} (p = {pval_pearson_var:.3g})")
print(f"📊 Spearman ρ (IC50 variance vs Pearson r) = {spearman_corr_var:.3f} (p = {pval_spearman_var:.3g})")
# Out:
# 📊 Pearson r (IC50 variance vs Pearson r) = 0.270 (p = 4.62e-13)
# 📊 Spearman ρ (IC50 variance vs Pearson r) = 0.273 (p = 2.83e-13)
